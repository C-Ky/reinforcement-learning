# %% [markdown]
# # RL7 - Goal Based Policy
#
# In this notebook, we are going to see what is goal based reinforcement learning, how Hindsight experience replay can solve the sparce reward problem in this context, and finaly we will try to use it to gather good rewards in swing up environment.
#
#
#  1. [Goal Based Reinforcement Learning](#gbrl)
#      1. [Problem statement](#gbrl_problem)
#      2. [Goal based grid-world environment](#gbrl_grid_world)
#      3. [Goal Conditioned DQN](#gbrl_dqn)
#  2. [Sparce reward problem](#sparse)
#      1. [Problem statement](#sparse_problem)
#      2. [Hindsight Experience Replay (HER)](#her)
#  3. [Swing Up]()

# %% [markdown]
# ## Goal Based Reinforcement Learning
# <div id="gbrl"></div>
#
# ### Problem statement
# <div id="gbrl_problem"></div>
#
# In reinforcement learning, an agent learn to maximise it's expected reward sum in an environment, by trials and errors. To learn, he will interact with it's environment, doing actions and reciving states and rewards in return. A serie of interactions is called an episode.
#
# In goal based reinforcement learning, the agent will interact with it's environment the same way, except that the reward function will depend on a goal, given by the environment.
#
# In general, the reward is constant while the agent don't find the goal, and is more important when he find it. If we want our agent to learn the shortest path to a goal, we can give him a reward of -1 at each step, and then a reward of 0 when he find it. Otherwise, we can simply give him a reward of 0, and a reward of 1 if he reach the goal. For this notebook, we will take the latest example in consideration.
#
# #### Out of this course
# Sometime, but we will not go deeper into it in this notebook, goal based reinforcement learning can be used while no  goals are given by the environment. The agent can choose (by [goal generation](https://arxiv.org/pdf/1807.04742.pdf) or by [goal selection among states inside the buffer](https://arxiv.org/pdf/1906.05253.pdf)) goals, that are suposed to help him explore or [that are promising to find rewards](https://arxiv.org/pdf/2106.03853.pdf), and try to reach them.
#
#
# ### Goal based grid-world environment
# <div id="gbrl_grid_world"></div>
#
# In order to go to the code step by step, we will consider the simplest goal reaching problem: the goal conditioned grid world environment.
#
# Here, the agent is inside a grid of states, and try to reach another tile of the grid given by the environment.
# States represent agent coordinates inside the grid, and availables actions are four simple mouvements TOP, RIGHT, DOWN and LEFT. In the grid, there is walls that make the environment more complex.

# %%
import gym
import environments.grid_world


environment = gym.make("goal_conditioned_discrete_grid_world-v0")
environment.reset()
environment.render()
# Out:
# /home/ubuntu/anaconda3/envs/pie-rl/lib/python3.8/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# array([[[50, 54, 51],
#         [50, 54, 51],
#         [50, 54, 51],
#         ...,
#         [50, 54, 51],
#         [50, 54, 51],
#         [50, 54, 51]],
#
#        [[50, 54, 51],
#         [50, 54, 51],
#         [50, 54, 51],
#         ...,
#         [50, 54, 51],
#         [50, 54, 51],
#         [50, 54, 51]],
#
#        [[50, 54, 51],
#         [50, 54, 51],
#         [50, 54, 51],
#         ...,
#         [50, 54, 51],
#         [50, 54, 51],
#         [50, 54, 51]],
#
#        ...,
#
#        [[50, 54, 51],
#         [50, 54, 51],
#         [50, 54, 51],
#         ...,
#         [50, 54, 51],
#         [50, 54, 51],
#         [50, 54, 51]],
#
#        [[50, 54, 51],
#         [50, 54, 51],
#         [50, 54, 51],
#         ...,
#         [50, 54, 51],
#         [50, 54, 51],
#         [50, 54, 51]],
#
#        [[50, 54, 51],
#         [50, 54, 51],
#         [50, 54, 51],
#         ...,
#         [50, 54, 51],
#         [50, 54, 51],
#         [50, 54, 51]]], dtype=uint8)

# %% [markdown]
# ### Goal Conditioned DQN
# <div id="gbrl_dqn"></div>
#
# Because the action space is discrete, we will use a DQN (the state space is also discrete but neural network will archive better performances than tabular Q-learning).
#
# Here is a "simple" implementation of goal conditioned default agent (this new agent looks like our last global agent class from RL6 notebook, so I put a # NEW tag when there is something new.).

# %%
import torch


DEFAULT_DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")


class GoalConditionedAgent:
    """
    An global agent class for goal conditioned agents. The # NEW tag indicate differences between Agent class and this
    one.
    """

    def __init__(self, state_space, action_space, goal_size=None, device=DEFAULT_DEVICE, name="Random agent"):
        self.name = name  # The name is used inside plot legend, outputs directory path, and outputs file names

        self.state_space = state_space
        self.state_shape = state_space.shape
        self.state_size = state_space.shape[0]  # Assume state space is continuous
        self.goal_size = self.state_size if goal_size is None else goal_size
        self.continuous = isinstance(action_space, gym.spaces.Box)
        self.action_space = action_space
        self.nb_actions = self.action_space.shape[0] if self.continuous else self.action_space.n
        self.last_state = None
        self.device = device
        self.episode_id = 0
        self.episode_time_step_id = 0
        self.time_step_id = 0

        # New
        # The goal we are trying to reach will be set when a new episode is started.
        # We need to keep it in memory during the entire episode
        self.current_goal = None

    def on_simulation_start(self):
        """
        Called when an episode is started. will be used by child class.
        """
        pass

    def on_episode_start(self, state, goal): # <-
        # because the signature of this function changed, 
        # this class cannot heritate from Agent base class :(.
        self.last_state = state
        self.episode_time_step_id = 0
        self.episode_id = 0
        self.current_goal = goal  # NEW

    def action(self, state):
        res = self.action_space.sample()
        return res

    def on_action_stop(self, action, new_state, reward, done):
        self.episode_time_step_id += 1
        self.time_step_id += 1
        self.last_state = new_state

    def on_episode_stop(self):
        self.episode_id += 1

    def on_simulation_stop(self):
        pass

# %% [markdown]
# Now we want to convert the DQN adgent we had in RL6 notebook into a goal-conditionned agent.
# Bellow, you will find this exact same class, with # TODO tags where you should modify something to handle the given goal, and make our DQN agent be conditioned by a goal.

# %% [markdown]
# <div class="alert alert-warning">
# At each episode, we will receive a new goal. How can we make a DQN agent (that use a Q-network and choose actions using argmax(Q(s, a))) choose actions depending on the goal ?
# <div/>

# %% [markdown]
# <details class="alert alert-danger">
#     <summary markdown="span"><b>Ready to see the answer? (click to expand)</b></summary>
#     In RL6 notebook we modified our Q-Network ton convert him into a critic, so he can return a value from a state and an action. Here, we are going to do something similar, and append the goal to the state before giving it the the Q-network.
#
# For your curiosity, we can do that kind of "intrinsic state" for many usage, like for example make our agent learn different behaviours as skills. We can have for example five skills, and concatenate a skill id to the state to make our agent have different behaviours, depending on the skill we give to him (like in [DIAYN](https://sites.google.com/view/diayn/) algorithm). But it's not the subject of this notebook, maybe of another one :).
#
# For the critic, we will do the exact same thing. Because the Q-value of a state action pair will depends on the goal, the input of the critic will look like this: (state, goal, action)
#
# <details/>

# %% [markdown]
# Now you can modify the DQN class below.
#
# HINT: For now, we will assume that the goal is another state in the environment. So it's size is 'self.state_size'.
#
# To help you find them faster:
#  - TODO: Change __init__ function to handle goal inside agent parameters initialisation,
#  - TODO: Change the action function so the action can be conditioned by BOTH state and goal,
#  - TODO: Change the on_action_stop function so the goal can be also stored by the agent,
#  - TODO: Change the learn function so the q-values can be conditioned by BOTH state and goal.

# %%
# First, let's modify our last replay buffer to make it able to store goals
import random


class ReplayBuffer:
    def __init__(self, capacity, device=DEFAULT_DEVICE):
        self.capacity = capacity # capacity of the buffer
        self.device = device
        self.data = []
        self.index = 0 # index of the next cell to be filled

    def append(self, s, a, r, s_, d, g):  # NEW added goal
        if len(self.data) < self.capacity:
            self.data.append(None)
        self.data[self.index] = (s, a, r, s_, d, g)  # NEW added goal
        self.index = (self.index + 1) % self.capacity

    def sample(self, batch_size):
        batch = random.sample(self.data, batch_size)
        return list(map(lambda x:torch.Tensor(x).to(self.device), list(zip(*batch))))

    def __len__(self):
        return len(self.data)

# I also give the converge_to function if you want to use it, but it's not necessarily needed.
def converge_to(self, model, other_model, tau=0.01):
    for self_param, other_param in zip(model.parameters(), other_model.parameters()):
        self_param.data.copy_(
            self_param.data * (1.0 - tau) + other_param.data * tau
        )

# %%
import copy

import gym
import numpy as np
import torch
from torch import nn
from agents.nn.multilayers_perceptron import MLP
from agents.agent import Agent


class GCDQNAgent(GoalConditionedAgent):  # NEW, our DQN agent heritate from GoalConditionedAgent.
    """
    GCDQN for Goal Conditioned Deep Q-Network
    An agent that learn to reach goals using DQN.
    This Q-Function is used to find the best action to execute in a given state.
    """

    def __init__(self, state_space, action_space, goal_size=None, name="DQN",
                 gamma=0.95, epsilon_min=0.01, epsilon_max=1., epsilon_decay_period=1000, epsilon_decay_delay=20,
                 buffer_size=1000000, learning_rate=0.001, update_target_freq=100, batch_size=20,
                 layer_1_size=50, layer_2_size=50, nb_gradient_steps=1):

        assert isinstance(action_space, gym.spaces.Discrete)  # Make sure our action space is discrete
        super().__init__(state_space, action_space, goal_size=goal_size, name=name)

        self.gamma = gamma
        self.epsilon_min = epsilon_min
        self.epsilon_max = epsilon_max
        self.epsilon_decay_delay = epsilon_decay_delay
        self.epsilon = None
        self.batch_size = batch_size
        self.learning_rate = learning_rate
        self.update_target_freq = update_target_freq
        self.nb_gradient_steps = nb_gradient_steps

        self.epsilon_step = (epsilon_max - self.epsilon_min) / epsilon_decay_period

        # TODO: Change __init__ function to handle goal inside agent parameters initialisation
        # (Spoiler: There is nothing to change above)
        self.replay_buffer = ReplayBuffer(buffer_size)
        self.total_steps = 0
        self.model = MLP(self.state_size*2, layer_1_size, layer_2_size, self.nb_actions, 
                         learning_rate=self.learning_rate, device=self.device)

        self.criterion = torch.nn.SmoothL1Loss()
        self.target_model = copy.deepcopy(self.model).to(self.device)
        self.update_target_freq = update_target_freq
    
    def on_episode_start(self, state, goal):
        # New, call to super class, it will store the goal so we can use it later.
        super().on_episode_start(state, goal)

    def on_simulation_start(self):
        self.epsilon = self.epsilon_max

    def action(self, state, goal):
        if self.time_step_id > self.epsilon_decay_delay:
            self.epsilon = max(self.epsilon_min, self.epsilon - self.epsilon_step)

        if np.random.rand() < self.epsilon:  # Epsilon greedy
            action = np.random.randint(self.nb_actions)
        else:
            # greedy_action(self.model, state) function in RL5 notebook
            with torch.no_grad():
                Q = self.model(torch.Tensor(state, goal).unsqueeze(0).to(self.device))
                action = torch.argmax(Q).item()
        return action

    def on_action_stop(self, action, new_state, reward, done):
        self.replay_buffer.append(self.last_state, action, reward, new_state, done, goal)
        self.learn()
        super().on_action_stop(action, new_state, reward, done, goal)  # Replace self.last_state by the new_state

    def learn(self):
        for _ in range(self.nb_gradient_steps):
            # gradient_step() function in RL5 notebook
            if len(self.replay_buffer) > self.batch_size:
                states, actions, rewards, new_states, dones, goals = self.replay_buffer.sample(self.batch_size)
                q_prime = self.target_model(new_states, goals).max(1)[0].detach()
                update = torch.addcmul(rewards, self.gamma, 1 - dones, q_prime)
                q_s_a = self.model(states, goals).gather(1, actions.to(torch.long).unsqueeze(1))
                loss = self.criterion(q_s_a, update.unsqueeze(1))
                self.model.learn(loss)

        # update target network if needed
        if self.time_step_id % self.update_target_freq == 0:
            self.target_model.load_state_dict(self.model.state_dict())

# %%
# %load solutions/RL7/goal_conditioned_dqn.py
import copy

import gym
import numpy as np
import torch
from torch import nn, optim
from torch.nn import ReLU

from agents.nn.multilayers_perceptron import MLP


class GCDQNAgent(GoalConditionedAgent):
    """
    An agent that learn an approximated Q-Function using a neural network.
    This Q-Function is used to find the best action to execute in a given state.
    """

    def __init__(self, state_space, action_space, goal_size=None, name="DQN",
                 gamma=0.95, epsilon_min=0.01, epsilon_max=1., epsilon_decay_period=1000, epsilon_decay_delay=20,
                 buffer_size=1000000, learning_rate=0.001, update_target_freq=100, batch_size=125,
                 layer_1_size=250, layer_2_size=200, nb_gradient_steps=1):

        assert isinstance(action_space, gym.spaces.Discrete)  # Make sure our action space is discrete
        super().__init__(state_space, action_space, goal_size=goal_size, name=name)

        self.gamma = gamma
        self.epsilon_min = epsilon_min
        self.epsilon_max = epsilon_max
        self.epsilon_decay_delay = epsilon_decay_delay
        self.epsilon = None

        #  NEW, goals will be stored inside the replay buffer. We need a specific one with enough place to do so
        self.replay_buffer = ReplayBuffer(buffer_size)
        self.batch_size = batch_size
        self.learning_rate = learning_rate
        self.update_target_freq = update_target_freq
        self.nb_gradient_steps = nb_gradient_steps

        self.epsilon_step = (epsilon_max - self.epsilon_min) / epsilon_decay_period
        self.total_steps = 0

        # NEW, The input state size is multiplied by two because we need to also take the goal as input
        self.model = MLP(self.state_size + self.goal_size, layer_1_size, ReLU(), layer_2_size, ReLU(), 
                         self.nb_actions, learning_rate=learning_rate, optimizer_class=optim.Adam, 
                         device=self.device).float()

        self.criterion = torch.nn.SmoothL1Loss()
        self.target_model = copy.deepcopy(self.model).to(self.device)
        self.update_target_freq = update_target_freq

    def on_simulation_start(self):
        self.epsilon = self.epsilon_max

    def action(self, state):
        if self.time_step_id > self.epsilon_decay_delay:
            self.epsilon = max(self.epsilon_min, self.epsilon - self.epsilon_step)

        if np.random.rand() < self.epsilon:  # Epsilon greedy
            action = np.random.randint(self.nb_actions)
        else:
            # greedy_action(self.model, state) function in RL5 notebook
            with torch.no_grad():
                goal_conditioned_state = np.concatenate((state, self.current_goal), axis=-1)
                Q = self.model(goal_conditioned_state)
                action = torch.argmax(Q).item()
        return action

    def on_action_stop(self, action, new_state, reward, done):
        # NEW store the current goal, so it can be associated with samples
        self.replay_buffer.append(self.last_state, action, reward, new_state, done, self.current_goal)
        self.learn()
        super().on_action_stop(action, new_state, reward, done)  # Replace self.last_state by the new_state

    def learn(self):
        for _ in range(self.nb_gradient_steps):
            # gradient_step() function in RL5 notebook
            if len(self.replay_buffer) > self.batch_size:
                #  NEW, samples from buffer contains goals
                states, actions, rewards, new_states, dones, goals = self.replay_buffer.sample(self.batch_size)

                # NEW concatenate states and goals, because we need to put them inside our model
                goal_conditioned_states = torch.concat((states, goals), dim=-1)
                goal_conditioned_new_states = torch.concat((new_states, goals), dim=-1)

                q_prime = self.target_model(goal_conditioned_new_states).max(1)[0].detach()
                update = rewards + self.gamma * (1 - dones) * q_prime
                q_s_a = self.model(goal_conditioned_states).gather(1, actions.to(torch.long).unsqueeze(1))
                loss = self.criterion(q_s_a, update.unsqueeze(1))
                self.model.learn(loss)

        # update target network if needed
        if self.time_step_id % self.update_target_freq == 0:
            self.target_model.load_state_dict(self.model.state_dict())

# %% [markdown]
# Now, we can test our agent performences in the first map of the grid world environment.
# First, let's reload the simulation function we had at RL6 notebook.

# %%
from statistics import mean


def simulation(environment, agent, nb_episodes=1000, verbose=True):
    episodes_rewards_sum = []
    test_results = []
    agent.on_simulation_start()
    for episode_id in range(nb_episodes):
        state, goal = environment.reset()
        agent.on_episode_start(state, goal)

        episode_rewards = []
        done = False
        while not done:
            action = agent.action(state)
            state, reward, done, _ = environment.step(action)

            # Ending time step process ...
            agent.on_action_stop(action, state, reward, done)

            # Store reward
            episode_rewards.append(reward)
        agent.on_episode_stop()
        rewards_sum = sum(episode_rewards)
        episodes_rewards_sum.append(rewards_sum)
        environment.close()
        if len(episodes_rewards_sum) > 20:
            last_20_average = mean(episodes_rewards_sum[-20:])
        else:
            last_20_average = mean(episodes_rewards_sum)

        if verbose:
            print("Episode " + str(episode_id) + ", episode return " + str(rewards_sum) + ", last 20 avg "
                  + str(last_20_average))
        
        if episode_id != 0 and episode_id % 10 == 0:
            render = False
            test_results.append(test(environment, agent, verbose=False, render=render))

    return episodes_rewards_sum, test_results  # We will plot tests results, not the sum of rewards

# %% [markdown]
# Now, we want a function to evaluate our agent performances. In a test function, we want to exploit what our agent learned, but we don't want him to learn. Sometime, testing process can give extrinsic information that are too hard for him to gather.
#
# For example, in general, in goal gonditioned learning, we want our agent to generate his own goals (by taking
# states from his buffer [https://arxiv.org/abs/1906.05253], or generate them using VAE
# [https://arxiv.org/pdf/1807.04742.pdf]. But, by testing our agent, we will generate goals that are far from his
# starting position to verify if he can reach them. Doing so, we will give his the information that these states
# exist, and help him to explore.
#
# To make sure the agent don't learn, we don't call the agent function that make him train (agent.on_action_stop).
# Then, we want this function to return an average grade over every tests. This distance can be the average distance between the final state of the trajectory, and the goal.

# %%
from statistics import mean


def test(environment, agent, nb_tests=20, verbose=True, render=False):
    episodes_grades = []
    agent.on_simulation_start()
    average_grade = None
    for test_id in range(nb_tests):
        if isinstance(environment, GoalCartPoleSwingUp):
            state, goal = environment.reset(test=True)
        else:
            state, goal = environment.reset()
        agent.on_episode_start(state, goal)
        if render:
            plt.cla()
            image = environment.render()
            plt.imshow(image)
            plt.show()

        episode_rewards = []
        done = False
        while not done:
            action = agent.action(state)
            state, reward, done, _ = environment.step(action)
            if render:
                plt.imshow(environment.render())
                plt.show()

        # Compute distance to goal
        distance_to_goal = np.linalg.norm(state[-2:] - goal, 2)
        episodes_grades.append(- distance_to_goal)
        agent.on_episode_stop()
        environment.close()
        average_grade = mean(episodes_grades)
        if verbose:
            print("Test " + str(test_id) + ", - distance = " + str(- distance_to_goal) + ", avg "
                  + str(average_grade))
    return average_grade

# %% [markdown]
# Finally, with a simulation function and a test one, we can observe how our DQNAgent learn on a simple tiny single room map.

# %%
import matplotlib.pyplot as plt
from environments.swingup import GoalCartPoleSwingUp


environment = gym.make("goal_conditioned_discrete_grid_world-v0")
environment.__init__(map_id=1)
environment.render()

nb_seeds = 4
nb_episodes_per_simulations = 600

dqn_seeds_rewards_result = []
dqn_seeds_tests_result = []
colors = ["#ff0000", "#ff9500"]

for seed_id in range(nb_seeds):
    print()
    print("###################")
    print()
    print("      SEED " + str(seed_id))
    print()
    print("###################")

    print()
    print(" > Training DQN")
    print()
    dqn_agent = GCDQNAgent(environment.observation_space, environment.action_space)
    rewards_sum_per_episode, tests_results = simulation(environment, dqn_agent,
                                                        nb_episodes=nb_episodes_per_simulations)
    dqn_seeds_rewards_result.append(rewards_sum_per_episode)
    dqn_seeds_tests_result.append(tests_results)

    plt.cla()
    plt.title("Rewards sum per episode")
    dqn_means = np.mean(np.array(dqn_seeds_rewards_result), axis=0)
    dqn_stds = np.std(np.array(dqn_seeds_rewards_result), axis=0)
    plt.plot(dqn_means, color=colors[0], label="DQN")
    plt.fill_between([x for x in range(len(dqn_means))], dqn_means + dqn_stds, dqn_means - dqn_stds, color=colors[0],
                     alpha=0.2)
    plt.legend()
    plt.show()

    plt.cla()
    plt.title("Tests grades evolution during agent learning")
    dqn_means = np.mean(np.array(dqn_seeds_tests_result), axis=0)
    dqn_stds = np.std(np.array(dqn_seeds_tests_result), axis=0)
    plt.plot(dqn_means, color=colors[0], label="DQN")
    plt.fill_between([x for x in range(len(dqn_means))], dqn_means + dqn_stds, dqn_means - dqn_stds, color=colors[0],
                     alpha=0.2)
    plt.legend()
    plt.show()
# Out:
# /home/ubuntu/anaconda3/envs/pie-rl/lib/python3.8/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# ###################
#
#       SEED 0
#
# ###################
#
#  > Training DQN
#
# Episode 0, episode return 1.0, last 20 avg 1.0
# Episode 1, episode return 0.0, last 20 avg 0.5
# Episode 2, episode return 1.0, last 20 avg 0.6666666666666666
# Episode 3, episode return 0.0, last 20 avg 0.5
# Episode 4, episode return 0.0, last 20 avg 0.4
# Episode 5, episode return 0.0, last 20 avg 0.3333333333333333
# Episode 6, episode return 0.0, last 20 avg 0.2857142857142857
# Episode 7, episode return 0.0, last 20 avg 0.25
# Episode 8, episode return 0.0, last 20 avg 0.2222222222222222
# Episode 9, episode return 1.0, last 20 avg 0.3
# Episode 10, episode return 0.0, last 20 avg 0.2727272727272727
# Episode 11, episode return 0.0, last 20 avg 0.25
# Episode 12, episode return 0.0, last 20 avg 0.23076923076923078
# Episode 13, episode return 0.0, last 20 avg 0.21428571428571427
# Episode 14, episode return 1.0, last 20 avg 0.26666666666666666
# Episode 15, episode return 0.0, last 20 avg 0.25
# Episode 16, episode return 0.0, last 20 avg 0.23529411764705882
# Episode 17, episode return 1.0, last 20 avg 0.2777777777777778
# Episode 18, episode return 1.0, last 20 avg 0.3157894736842105
# Episode 19, episode return 0.0, last 20 avg 0.3
# Episode 20, episode return 0.0, last 20 avg 0.25
# Episode 21, episode return 1.0, last 20 avg 0.3
# Episode 22, episode return 0.0, last 20 avg 0.25
# Episode 23, episode return 1.0, last 20 avg 0.3
# Episode 24, episode return 0.0, last 20 avg 0.3
# Episode 25, episode return 0.0, last 20 avg 0.3
# Episode 26, episode return 0.0, last 20 avg 0.3
# Episode 27, episode return 0.0, last 20 avg 0.3
# Episode 28, episode return 1.0, last 20 avg 0.35
# Episode 29, episode return 0.0, last 20 avg 0.3
# Episode 30, episode return 0.0, last 20 avg 0.3
# Episode 31, episode return 0.0, last 20 avg 0.3
# Episode 32, episode return 0.0, last 20 avg 0.3
# Episode 33, episode return 0.0, last 20 avg 0.3
# Episode 34, episode return 0.0, last 20 avg 0.25
# Episode 35, episode return 1.0, last 20 avg 0.3
# Episode 36, episode return 0.0, last 20 avg 0.3
# Episode 37, episode return 0.0, last 20 avg 0.25
# Episode 38, episode return 1.0, last 20 avg 0.25
# Episode 39, episode return 1.0, last 20 avg 0.3
# Episode 40, episode return 1.0, last 20 avg 0.35
# Episode 41, episode return 1.0, last 20 avg 0.35
# Episode 42, episode return 0.0, last 20 avg 0.35
# Episode 43, episode return 0.0, last 20 avg 0.3
# Episode 44, episode return 1.0, last 20 avg 0.35
# Episode 45, episode return 1.0, last 20 avg 0.4
# Episode 46, episode return 0.0, last 20 avg 0.4
# Episode 47, episode return 0.0, last 20 avg 0.4
# Episode 48, episode return 0.0, last 20 avg 0.35
# Episode 49, episode return 0.0, last 20 avg 0.35
# Episode 50, episode return 0.0, last 20 avg 0.35
# Episode 51, episode return 0.0, last 20 avg 0.35
# Episode 52, episode return 0.0, last 20 avg 0.35
# Episode 53, episode return 0.0, last 20 avg 0.35
# Episode 54, episode return 1.0, last 20 avg 0.4
# Episode 55, episode return 0.0, last 20 avg 0.35
# Episode 56, episode return 1.0, last 20 avg 0.4
# Episode 57, episode return 0.0, last 20 avg 0.4
# Episode 58, episode return 1.0, last 20 avg 0.4
# Episode 59, episode return 1.0, last 20 avg 0.4
# Episode 60, episode return 1.0, last 20 avg 0.4
# Episode 61, episode return 1.0, last 20 avg 0.4
# Episode 62, episode return 0.0, last 20 avg 0.4
# Episode 63, episode return 1.0, last 20 avg 0.45
# Episode 64, episode return 1.0, last 20 avg 0.45
# Episode 65, episode return 0.0, last 20 avg 0.4
# Episode 66, episode return 0.0, last 20 avg 0.4
# Episode 67, episode return 0.0, last 20 avg 0.4
# Episode 68, episode return 1.0, last 20 avg 0.45
# Episode 69, episode return 0.0, last 20 avg 0.45
# Episode 70, episode return 0.0, last 20 avg 0.45
# Episode 71, episode return 1.0, last 20 avg 0.5
# Episode 72, episode return 0.0, last 20 avg 0.5
# Episode 73, episode return 1.0, last 20 avg 0.55
# Episode 74, episode return 1.0, last 20 avg 0.55
# Episode 75, episode return 1.0, last 20 avg 0.6
# Episode 76, episode return 0.0, last 20 avg 0.55
# Episode 77, episode return 0.0, last 20 avg 0.55
# Episode 78, episode return 1.0, last 20 avg 0.55
# Episode 79, episode return 1.0, last 20 avg 0.55
# Episode 80, episode return 0.0, last 20 avg 0.5
# Episode 81, episode return 1.0, last 20 avg 0.5
# Episode 82, episode return 1.0, last 20 avg 0.55
# Episode 83, episode return 0.0, last 20 avg 0.5
# Episode 84, episode return 1.0, last 20 avg 0.5
# Episode 85, episode return 0.0, last 20 avg 0.5
# Episode 86, episode return 0.0, last 20 avg 0.5
# Episode 87, episode return 0.0, last 20 avg 0.5
# Episode 88, episode return 1.0, last 20 avg 0.5
# Episode 89, episode return 0.0, last 20 avg 0.5
# Episode 90, episode return 0.0, last 20 avg 0.5
# Episode 91, episode return 1.0, last 20 avg 0.5
# Episode 92, episode return 1.0, last 20 avg 0.55
# Episode 93, episode return 1.0, last 20 avg 0.55
# Episode 94, episode return 1.0, last 20 avg 0.55
# Episode 95, episode return 0.0, last 20 avg 0.5
# Episode 96, episode return 0.0, last 20 avg 0.5
# Episode 97, episode return 0.0, last 20 avg 0.5
# Episode 98, episode return 1.0, last 20 avg 0.5
# Episode 99, episode return 1.0, last 20 avg 0.5
# Episode 100, episode return 0.0, last 20 avg 0.5
# Episode 101, episode return 1.0, last 20 avg 0.5
# Episode 102, episode return 0.0, last 20 avg 0.45
# Episode 103, episode return 0.0, last 20 avg 0.45
# Episode 104, episode return 0.0, last 20 avg 0.4
# Episode 105, episode return 1.0, last 20 avg 0.45
# Episode 106, episode return 0.0, last 20 avg 0.45
# Episode 107, episode return 1.0, last 20 avg 0.5
# Episode 108, episode return 1.0, last 20 avg 0.5
# Episode 109, episode return 1.0, last 20 avg 0.55
# Episode 110, episode return 1.0, last 20 avg 0.6
# Episode 111, episode return 1.0, last 20 avg 0.6
# Episode 112, episode return 0.0, last 20 avg 0.55
# Episode 113, episode return 0.0, last 20 avg 0.5
# Episode 114, episode return 0.0, last 20 avg 0.45
# Episode 115, episode return 1.0, last 20 avg 0.5
# Episode 116, episode return 0.0, last 20 avg 0.5
# Episode 117, episode return 0.0, last 20 avg 0.5
# Episode 118, episode return 0.0, last 20 avg 0.45
# Episode 119, episode return 1.0, last 20 avg 0.45
# Episode 120, episode return 1.0, last 20 avg 0.5
# Episode 121, episode return 1.0, last 20 avg 0.5
# Episode 122, episode return 1.0, last 20 avg 0.55
# Episode 123, episode return 0.0, last 20 avg 0.55
# Episode 124, episode return 1.0, last 20 avg 0.6
# Episode 125, episode return 1.0, last 20 avg 0.6
# Episode 126, episode return 0.0, last 20 avg 0.6
# Episode 127, episode return 0.0, last 20 avg 0.55
# Episode 128, episode return 1.0, last 20 avg 0.55
# Episode 129, episode return 1.0, last 20 avg 0.55
# Episode 130, episode return 1.0, last 20 avg 0.55
# Episode 131, episode return 0.0, last 20 avg 0.5
# Episode 132, episode return 1.0, last 20 avg 0.55
# Episode 133, episode return 0.0, last 20 avg 0.55
# Episode 134, episode return 1.0, last 20 avg 0.6
# Episode 135, episode return 1.0, last 20 avg 0.6
# Episode 136, episode return 1.0, last 20 avg 0.65
# Episode 137, episode return 1.0, last 20 avg 0.7
# Episode 138, episode return 0.0, last 20 avg 0.7
# Episode 139, episode return 1.0, last 20 avg 0.7
# Episode 140, episode return 1.0, last 20 avg 0.7
# Episode 141, episode return 1.0, last 20 avg 0.7
# Episode 142, episode return 0.0, last 20 avg 0.65
# Episode 143, episode return 1.0, last 20 avg 0.7
# Episode 144, episode return 1.0, last 20 avg 0.7
# Episode 145, episode return 1.0, last 20 avg 0.7
# Episode 146, episode return 1.0, last 20 avg 0.75
# Episode 147, episode return 1.0, last 20 avg 0.8
# Episode 148, episode return 1.0, last 20 avg 0.8
# Episode 149, episode return 1.0, last 20 avg 0.8
# Episode 150, episode return 0.0, last 20 avg 0.75
# Episode 151, episode return 0.0, last 20 avg 0.75
# Episode 152, episode return 0.0, last 20 avg 0.7
# Episode 153, episode return 1.0, last 20 avg 0.75
# Episode 154, episode return 1.0, last 20 avg 0.75
# Episode 155, episode return 1.0, last 20 avg 0.75
# Episode 156, episode return 1.0, last 20 avg 0.75
# Episode 157, episode return 0.0, last 20 avg 0.7
# Episode 158, episode return 0.0, last 20 avg 0.7
# Episode 159, episode return 1.0, last 20 avg 0.7
# Episode 160, episode return 1.0, last 20 avg 0.7
# Episode 161, episode return 1.0, last 20 avg 0.7
# Episode 162, episode return 1.0, last 20 avg 0.75
# Episode 163, episode return 1.0, last 20 avg 0.75
# Episode 164, episode return 0.0, last 20 avg 0.7
# Episode 165, episode return 1.0, last 20 avg 0.7
# Episode 166, episode return 1.0, last 20 avg 0.7
# Episode 167, episode return 1.0, last 20 avg 0.7
# Episode 168, episode return 1.0, last 20 avg 0.7
# Episode 169, episode return 0.0, last 20 avg 0.65
# Episode 170, episode return 1.0, last 20 avg 0.7
# Episode 171, episode return 1.0, last 20 avg 0.75
# Episode 172, episode return 0.0, last 20 avg 0.75
# Episode 173, episode return 0.0, last 20 avg 0.7
# Episode 174, episode return 1.0, last 20 avg 0.7
# Episode 175, episode return 1.0, last 20 avg 0.7
# Episode 176, episode return 1.0, last 20 avg 0.7
# Episode 177, episode return 1.0, last 20 avg 0.75
# Episode 178, episode return 0.0, last 20 avg 0.75
# Episode 179, episode return 0.0, last 20 avg 0.7
# Episode 180, episode return 1.0, last 20 avg 0.7
# Episode 181, episode return 1.0, last 20 avg 0.7
# Episode 182, episode return 1.0, last 20 avg 0.7
# Episode 183, episode return 1.0, last 20 avg 0.7
# Episode 184, episode return 1.0, last 20 avg 0.75
# Episode 185, episode return 0.0, last 20 avg 0.7
# Episode 186, episode return 1.0, last 20 avg 0.7
# Episode 187, episode return 1.0, last 20 avg 0.7
# Episode 188, episode return 0.0, last 20 avg 0.65
# Episode 189, episode return 0.0, last 20 avg 0.65
# Episode 190, episode return 1.0, last 20 avg 0.65
# Episode 191, episode return 0.0, last 20 avg 0.6
# Episode 192, episode return 1.0, last 20 avg 0.65
# Episode 193, episode return 0.0, last 20 avg 0.65
# Episode 194, episode return 1.0, last 20 avg 0.65
# Episode 195, episode return 1.0, last 20 avg 0.65
# Episode 196, episode return 0.0, last 20 avg 0.6
# Episode 197, episode return 1.0, last 20 avg 0.6
# Episode 198, episode return 1.0, last 20 avg 0.65
# Episode 199, episode return 0.0, last 20 avg 0.65
# Episode 200, episode return 1.0, last 20 avg 0.65
# Episode 201, episode return 1.0, last 20 avg 0.65
# Episode 202, episode return 1.0, last 20 avg 0.65
# Episode 203, episode return 1.0, last 20 avg 0.65
# Episode 204, episode return 1.0, last 20 avg 0.65
# Episode 205, episode return 1.0, last 20 avg 0.7
# Episode 206, episode return 1.0, last 20 avg 0.7
# Episode 207, episode return 1.0, last 20 avg 0.7
# Episode 208, episode return 1.0, last 20 avg 0.75
# Episode 209, episode return 0.0, last 20 avg 0.75
# Episode 210, episode return 1.0, last 20 avg 0.75
# Episode 211, episode return 0.0, last 20 avg 0.75
# Episode 212, episode return 1.0, last 20 avg 0.75
# Episode 213, episode return 1.0, last 20 avg 0.8
# Episode 214, episode return 1.0, last 20 avg 0.8
# Episode 215, episode return 1.0, last 20 avg 0.8
# Episode 216, episode return 1.0, last 20 avg 0.85
# Episode 217, episode return 1.0, last 20 avg 0.85
# Episode 218, episode return 1.0, last 20 avg 0.85
# Episode 219, episode return 1.0, last 20 avg 0.9
# Episode 220, episode return 0.0, last 20 avg 0.85
# Episode 221, episode return 0.0, last 20 avg 0.8
# Episode 222, episode return 1.0, last 20 avg 0.8
# Episode 223, episode return 0.0, last 20 avg 0.75
# Episode 224, episode return 1.0, last 20 avg 0.75
# Episode 225, episode return 1.0, last 20 avg 0.75
# Episode 226, episode return 1.0, last 20 avg 0.75
# Episode 227, episode return 1.0, last 20 avg 0.75
# Episode 228, episode return 1.0, last 20 avg 0.75
# Episode 229, episode return 1.0, last 20 avg 0.8
# Episode 230, episode return 1.0, last 20 avg 0.8
# Episode 231, episode return 1.0, last 20 avg 0.85
# Episode 232, episode return 1.0, last 20 avg 0.85
# Episode 233, episode return 1.0, last 20 avg 0.85
# Episode 234, episode return 1.0, last 20 avg 0.85
# Episode 235, episode return 1.0, last 20 avg 0.85
# Episode 236, episode return 1.0, last 20 avg 0.85
# Episode 237, episode return 1.0, last 20 avg 0.85
# Episode 238, episode return 1.0, last 20 avg 0.85
# Episode 239, episode return 1.0, last 20 avg 0.85
# Episode 240, episode return 1.0, last 20 avg 0.9
# Episode 241, episode return 0.0, last 20 avg 0.9
# Episode 242, episode return 1.0, last 20 avg 0.9
# Episode 243, episode return 1.0, last 20 avg 0.95
# Episode 244, episode return 0.0, last 20 avg 0.9
# Episode 245, episode return 0.0, last 20 avg 0.85
# Episode 246, episode return 1.0, last 20 avg 0.85
# Episode 247, episode return 1.0, last 20 avg 0.85
# Episode 248, episode return 1.0, last 20 avg 0.85
# Episode 249, episode return 1.0, last 20 avg 0.85
# Episode 250, episode return 1.0, last 20 avg 0.85
# Episode 251, episode return 1.0, last 20 avg 0.85
# Episode 252, episode return 1.0, last 20 avg 0.85
# Episode 253, episode return 1.0, last 20 avg 0.85
# Episode 254, episode return 0.0, last 20 avg 0.8
# Episode 255, episode return 1.0, last 20 avg 0.8
# Episode 256, episode return 1.0, last 20 avg 0.8
# Episode 257, episode return 1.0, last 20 avg 0.8
# Episode 258, episode return 1.0, last 20 avg 0.8
# Episode 259, episode return 0.0, last 20 avg 0.75
# Episode 260, episode return 1.0, last 20 avg 0.75
# Episode 261, episode return 1.0, last 20 avg 0.8
# Episode 262, episode return 1.0, last 20 avg 0.8
# Episode 263, episode return 1.0, last 20 avg 0.8
# Episode 264, episode return 1.0, last 20 avg 0.85
# Episode 265, episode return 1.0, last 20 avg 0.9
# Episode 266, episode return 0.0, last 20 avg 0.85
# Episode 267, episode return 1.0, last 20 avg 0.85
# Episode 268, episode return 1.0, last 20 avg 0.85
# Episode 269, episode return 0.0, last 20 avg 0.8
# Episode 270, episode return 0.0, last 20 avg 0.75
# Episode 271, episode return 1.0, last 20 avg 0.75
# Episode 272, episode return 1.0, last 20 avg 0.75
# Episode 273, episode return 1.0, last 20 avg 0.75
# Episode 274, episode return 1.0, last 20 avg 0.8
# Episode 275, episode return 1.0, last 20 avg 0.8
# Episode 276, episode return 1.0, last 20 avg 0.8
# Episode 277, episode return 1.0, last 20 avg 0.8
# Episode 278, episode return 1.0, last 20 avg 0.8
# Episode 279, episode return 1.0, last 20 avg 0.85
# Episode 280, episode return 1.0, last 20 avg 0.85
# Episode 281, episode return 0.0, last 20 avg 0.8
# Episode 282, episode return 0.0, last 20 avg 0.75
# Episode 283, episode return 1.0, last 20 avg 0.75
# Episode 284, episode return 1.0, last 20 avg 0.75
# Episode 285, episode return 1.0, last 20 avg 0.75
# Episode 286, episode return 1.0, last 20 avg 0.8
# Episode 287, episode return 1.0, last 20 avg 0.8
# Episode 288, episode return 1.0, last 20 avg 0.8
# Episode 289, episode return 1.0, last 20 avg 0.85
# Episode 290, episode return 1.0, last 20 avg 0.9
# Episode 291, episode return 1.0, last 20 avg 0.9
# Episode 292, episode return 0.0, last 20 avg 0.85
# Episode 293, episode return 0.0, last 20 avg 0.8
# Episode 294, episode return 0.0, last 20 avg 0.75
# Episode 295, episode return 1.0, last 20 avg 0.75
# Episode 296, episode return 1.0, last 20 avg 0.75
# Episode 297, episode return 1.0, last 20 avg 0.75
# Episode 298, episode return 1.0, last 20 avg 0.75
# Episode 299, episode return 1.0, last 20 avg 0.75
# Episode 300, episode return 0.0, last 20 avg 0.7
# Episode 301, episode return 1.0, last 20 avg 0.75
# Episode 302, episode return 1.0, last 20 avg 0.8
# Episode 303, episode return 0.0, last 20 avg 0.75
# Episode 304, episode return 1.0, last 20 avg 0.75
# Episode 305, episode return 1.0, last 20 avg 0.75
# Episode 306, episode return 0.0, last 20 avg 0.7
# Episode 307, episode return 0.0, last 20 avg 0.65
# Episode 308, episode return 1.0, last 20 avg 0.65
# Episode 309, episode return 0.0, last 20 avg 0.6
# Episode 310, episode return 1.0, last 20 avg 0.6
# Episode 311, episode return 1.0, last 20 avg 0.6
# Episode 312, episode return 1.0, last 20 avg 0.65
# Episode 313, episode return 1.0, last 20 avg 0.7
# Episode 314, episode return 1.0, last 20 avg 0.75
# Episode 315, episode return 1.0, last 20 avg 0.75
# Episode 316, episode return 1.0, last 20 avg 0.75
# Episode 317, episode return 0.0, last 20 avg 0.7
# Episode 318, episode return 1.0, last 20 avg 0.7
# Episode 319, episode return 1.0, last 20 avg 0.7
# Episode 320, episode return 0.0, last 20 avg 0.7
# Episode 321, episode return 0.0, last 20 avg 0.65
# Episode 322, episode return 1.0, last 20 avg 0.65
# Episode 323, episode return 1.0, last 20 avg 0.7
# Episode 324, episode return 1.0, last 20 avg 0.7
# Episode 325, episode return 0.0, last 20 avg 0.65
# Episode 326, episode return 1.0, last 20 avg 0.7
# Episode 327, episode return 1.0, last 20 avg 0.75
# Episode 328, episode return 1.0, last 20 avg 0.75
# Episode 329, episode return 0.0, last 20 avg 0.75
# Episode 330, episode return 1.0, last 20 avg 0.75
# Episode 331, episode return 1.0, last 20 avg 0.75
# Episode 332, episode return 1.0, last 20 avg 0.75
# Episode 333, episode return 1.0, last 20 avg 0.75
# Episode 334, episode return 1.0, last 20 avg 0.75
# Episode 335, episode return 1.0, last 20 avg 0.75
# Episode 336, episode return 1.0, last 20 avg 0.75
# Episode 337, episode return 0.0, last 20 avg 0.75
# Episode 338, episode return 1.0, last 20 avg 0.75
# Episode 339, episode return 1.0, last 20 avg 0.75
# Episode 340, episode return 0.0, last 20 avg 0.75
# Episode 341, episode return 1.0, last 20 avg 0.8
# Episode 342, episode return 1.0, last 20 avg 0.8
# Episode 343, episode return 1.0, last 20 avg 0.8
# Episode 344, episode return 1.0, last 20 avg 0.8
# Episode 345, episode return 1.0, last 20 avg 0.85
# Episode 346, episode return 1.0, last 20 avg 0.85
# Episode 347, episode return 1.0, last 20 avg 0.85
# Episode 348, episode return 1.0, last 20 avg 0.85
# Episode 349, episode return 0.0, last 20 avg 0.85
# Episode 350, episode return 1.0, last 20 avg 0.85
# Episode 351, episode return 1.0, last 20 avg 0.85
# Episode 352, episode return 1.0, last 20 avg 0.85
# Episode 353, episode return 1.0, last 20 avg 0.85
# Episode 354, episode return 1.0, last 20 avg 0.85
# Episode 355, episode return 1.0, last 20 avg 0.85
# Episode 356, episode return 1.0, last 20 avg 0.85
# Episode 357, episode return 1.0, last 20 avg 0.9
# Episode 358, episode return 1.0, last 20 avg 0.9
# Episode 359, episode return 1.0, last 20 avg 0.9
# Episode 360, episode return 1.0, last 20 avg 0.95
# Episode 361, episode return 1.0, last 20 avg 0.95
# Episode 362, episode return 0.0, last 20 avg 0.9
# Episode 363, episode return 0.0, last 20 avg 0.85
# Episode 364, episode return 1.0, last 20 avg 0.85
# Episode 365, episode return 1.0, last 20 avg 0.85
# Episode 366, episode return 1.0, last 20 avg 0.85
# Episode 367, episode return 1.0, last 20 avg 0.85
# Episode 368, episode return 1.0, last 20 avg 0.85
# Episode 369, episode return 1.0, last 20 avg 0.9
# Episode 370, episode return 1.0, last 20 avg 0.9
# Episode 371, episode return 1.0, last 20 avg 0.9
# Episode 372, episode return 1.0, last 20 avg 0.9
# Episode 373, episode return 1.0, last 20 avg 0.9
# Episode 374, episode return 1.0, last 20 avg 0.9
# Episode 375, episode return 1.0, last 20 avg 0.9
# Episode 376, episode return 1.0, last 20 avg 0.9
# Episode 377, episode return 1.0, last 20 avg 0.9
# Episode 378, episode return 1.0, last 20 avg 0.9
# Episode 379, episode return 0.0, last 20 avg 0.85
# Episode 380, episode return 0.0, last 20 avg 0.8
# Episode 381, episode return 1.0, last 20 avg 0.8
# Episode 382, episode return 1.0, last 20 avg 0.85
# Episode 383, episode return 1.0, last 20 avg 0.9
# Episode 384, episode return 0.0, last 20 avg 0.85
# Episode 385, episode return 1.0, last 20 avg 0.85
# Episode 386, episode return 1.0, last 20 avg 0.85
# Episode 387, episode return 1.0, last 20 avg 0.85
# Episode 388, episode return 0.0, last 20 avg 0.8
# Episode 389, episode return 1.0, last 20 avg 0.8
# Episode 390, episode return 1.0, last 20 avg 0.8
# Episode 391, episode return 1.0, last 20 avg 0.8
# Episode 392, episode return 1.0, last 20 avg 0.8
# Episode 393, episode return 1.0, last 20 avg 0.8
# Episode 394, episode return 1.0, last 20 avg 0.8
# Episode 395, episode return 1.0, last 20 avg 0.8
# Episode 396, episode return 1.0, last 20 avg 0.8
# Episode 397, episode return 1.0, last 20 avg 0.8
# Episode 398, episode return 1.0, last 20 avg 0.8
# Episode 399, episode return 1.0, last 20 avg 0.85
# Episode 400, episode return 1.0, last 20 avg 0.9
# Episode 401, episode return 1.0, last 20 avg 0.9
# Episode 402, episode return 1.0, last 20 avg 0.9
# Episode 403, episode return 0.0, last 20 avg 0.85
# Episode 404, episode return 0.0, last 20 avg 0.85
# Episode 405, episode return 1.0, last 20 avg 0.85
# Episode 406, episode return 1.0, last 20 avg 0.85
# Episode 407, episode return 1.0, last 20 avg 0.85
# Episode 408, episode return 1.0, last 20 avg 0.9
# Episode 409, episode return 0.0, last 20 avg 0.85
# Episode 410, episode return 1.0, last 20 avg 0.85
# Episode 411, episode return 1.0, last 20 avg 0.85
# Episode 412, episode return 1.0, last 20 avg 0.85
# Episode 413, episode return 1.0, last 20 avg 0.85
# Episode 414, episode return 1.0, last 20 avg 0.85
# Episode 415, episode return 0.0, last 20 avg 0.8
# Episode 416, episode return 1.0, last 20 avg 0.8
# Episode 417, episode return 1.0, last 20 avg 0.8
# Episode 418, episode return 1.0, last 20 avg 0.8
# Episode 419, episode return 1.0, last 20 avg 0.8
# Episode 420, episode return 1.0, last 20 avg 0.8
# Episode 421, episode return 1.0, last 20 avg 0.8
# Episode 422, episode return 1.0, last 20 avg 0.8
# Episode 423, episode return 1.0, last 20 avg 0.85
# Episode 424, episode return 1.0, last 20 avg 0.9
# Episode 425, episode return 1.0, last 20 avg 0.9
# Episode 426, episode return 1.0, last 20 avg 0.9
# Episode 427, episode return 1.0, last 20 avg 0.9
# Episode 428, episode return 1.0, last 20 avg 0.9
# Episode 429, episode return 1.0, last 20 avg 0.95
# Episode 430, episode return 1.0, last 20 avg 0.95
# Episode 431, episode return 1.0, last 20 avg 0.95
# Episode 432, episode return 1.0, last 20 avg 0.95
# Episode 433, episode return 1.0, last 20 avg 0.95
# Episode 434, episode return 1.0, last 20 avg 0.95
# Episode 435, episode return 1.0, last 20 avg 1.0
# Episode 436, episode return 1.0, last 20 avg 1.0
# Episode 437, episode return 1.0, last 20 avg 1.0
# Episode 438, episode return 1.0, last 20 avg 1.0
# Episode 439, episode return 1.0, last 20 avg 1.0
# Episode 440, episode return 1.0, last 20 avg 1.0
# Episode 441, episode return 1.0, last 20 avg 1.0
# Episode 442, episode return 1.0, last 20 avg 1.0
# Episode 443, episode return 1.0, last 20 avg 1.0
# Episode 444, episode return 1.0, last 20 avg 1.0
# Episode 445, episode return 1.0, last 20 avg 1.0
# Episode 446, episode return 1.0, last 20 avg 1.0
# Episode 447, episode return 1.0, last 20 avg 1.0
# Episode 448, episode return 1.0, last 20 avg 1.0
# Episode 449, episode return 1.0, last 20 avg 1.0
# Episode 450, episode return 1.0, last 20 avg 1.0
# Episode 451, episode return 1.0, last 20 avg 1.0
# Episode 452, episode return 1.0, last 20 avg 1.0
# Episode 453, episode return 1.0, last 20 avg 1.0
# Episode 454, episode return 1.0, last 20 avg 1.0
# Episode 455, episode return 1.0, last 20 avg 1.0
# Episode 456, episode return 0.0, last 20 avg 0.95
# Episode 457, episode return 1.0, last 20 avg 0.95
# Episode 458, episode return 1.0, last 20 avg 0.95
# Episode 459, episode return 1.0, last 20 avg 0.95
# Episode 460, episode return 1.0, last 20 avg 0.95
# Episode 461, episode return 1.0, last 20 avg 0.95
# Episode 462, episode return 1.0, last 20 avg 0.95
# Episode 463, episode return 1.0, last 20 avg 0.95
# Episode 464, episode return 0.0, last 20 avg 0.9
# Episode 465, episode return 1.0, last 20 avg 0.9
# Episode 466, episode return 1.0, last 20 avg 0.9
# Episode 467, episode return 1.0, last 20 avg 0.9
# Episode 468, episode return 1.0, last 20 avg 0.9
# Episode 469, episode return 0.0, last 20 avg 0.85
# Episode 470, episode return 1.0, last 20 avg 0.85
# Episode 471, episode return 1.0, last 20 avg 0.85
# Episode 472, episode return 1.0, last 20 avg 0.85
# Episode 473, episode return 1.0, last 20 avg 0.85
# Episode 474, episode return 1.0, last 20 avg 0.85
# Episode 475, episode return 1.0, last 20 avg 0.85
# Episode 476, episode return 1.0, last 20 avg 0.9
# Episode 477, episode return 1.0, last 20 avg 0.9
# Episode 478, episode return 1.0, last 20 avg 0.9
# Episode 479, episode return 1.0, last 20 avg 0.9
# Episode 480, episode return 1.0, last 20 avg 0.9
# Episode 481, episode return 1.0, last 20 avg 0.9
# Episode 482, episode return 1.0, last 20 avg 0.9
# Episode 483, episode return 1.0, last 20 avg 0.9
# Episode 484, episode return 1.0, last 20 avg 0.95
# Episode 485, episode return 1.0, last 20 avg 0.95
# Episode 486, episode return 1.0, last 20 avg 0.95
# Episode 487, episode return 1.0, last 20 avg 0.95
# Episode 488, episode return 1.0, last 20 avg 0.95
# Episode 489, episode return 1.0, last 20 avg 1.0
# Episode 490, episode return 1.0, last 20 avg 1.0
# Episode 491, episode return 1.0, last 20 avg 1.0
# Episode 492, episode return 1.0, last 20 avg 1.0
# Episode 493, episode return 1.0, last 20 avg 1.0
# Episode 494, episode return 1.0, last 20 avg 1.0
# Episode 495, episode return 1.0, last 20 avg 1.0
# Episode 496, episode return 1.0, last 20 avg 1.0
# Episode 497, episode return 0.0, last 20 avg 0.95
# Episode 498, episode return 1.0, last 20 avg 0.95
# Episode 499, episode return 1.0, last 20 avg 0.95
# Episode 500, episode return 1.0, last 20 avg 0.95
# Episode 501, episode return 1.0, last 20 avg 0.95
# Episode 502, episode return 1.0, last 20 avg 0.95
# Episode 503, episode return 1.0, last 20 avg 0.95
# Episode 504, episode return 1.0, last 20 avg 0.95
# Episode 505, episode return 1.0, last 20 avg 0.95
# Episode 506, episode return 1.0, last 20 avg 0.95
# Episode 507, episode return 1.0, last 20 avg 0.95
# Episode 508, episode return 1.0, last 20 avg 0.95
# Episode 509, episode return 1.0, last 20 avg 0.95
# Episode 510, episode return 1.0, last 20 avg 0.95
# Episode 511, episode return 1.0, last 20 avg 0.95
# Episode 512, episode return 1.0, last 20 avg 0.95
# Episode 513, episode return 1.0, last 20 avg 0.95
# Episode 514, episode return 1.0, last 20 avg 0.95
# Episode 515, episode return 1.0, last 20 avg 0.95
# Episode 516, episode return 1.0, last 20 avg 0.95
# Episode 517, episode return 1.0, last 20 avg 1.0
# Episode 518, episode return 1.0, last 20 avg 1.0
# Episode 519, episode return 1.0, last 20 avg 1.0
# Episode 520, episode return 1.0, last 20 avg 1.0
# Episode 521, episode return 1.0, last 20 avg 1.0
# Episode 522, episode return 1.0, last 20 avg 1.0
# Episode 523, episode return 1.0, last 20 avg 1.0
# Episode 524, episode return 1.0, last 20 avg 1.0
# Episode 525, episode return 1.0, last 20 avg 1.0
# Episode 526, episode return 1.0, last 20 avg 1.0
# Episode 527, episode return 1.0, last 20 avg 1.0
# Episode 528, episode return 1.0, last 20 avg 1.0
# Episode 529, episode return 1.0, last 20 avg 1.0
# Episode 530, episode return 1.0, last 20 avg 1.0
# Episode 531, episode return 1.0, last 20 avg 1.0
# Episode 532, episode return 1.0, last 20 avg 1.0
# Episode 533, episode return 1.0, last 20 avg 1.0
# Episode 534, episode return 1.0, last 20 avg 1.0
# Episode 535, episode return 1.0, last 20 avg 1.0
# Episode 536, episode return 1.0, last 20 avg 1.0
# Episode 537, episode return 1.0, last 20 avg 1.0
# Episode 538, episode return 1.0, last 20 avg 1.0
# Episode 539, episode return 1.0, last 20 avg 1.0
# Episode 540, episode return 1.0, last 20 avg 1.0
# Episode 541, episode return 1.0, last 20 avg 1.0
# Episode 542, episode return 1.0, last 20 avg 1.0
# Episode 543, episode return 1.0, last 20 avg 1.0
# Episode 544, episode return 1.0, last 20 avg 1.0
# Episode 545, episode return 1.0, last 20 avg 1.0
# Episode 546, episode return 1.0, last 20 avg 1.0
# Episode 547, episode return 1.0, last 20 avg 1.0
# Episode 548, episode return 1.0, last 20 avg 1.0
# Episode 549, episode return 1.0, last 20 avg 1.0
# Episode 550, episode return 1.0, last 20 avg 1.0
# Episode 551, episode return 1.0, last 20 avg 1.0
# Episode 552, episode return 1.0, last 20 avg 1.0
# Episode 553, episode return 1.0, last 20 avg 1.0
# Episode 554, episode return 1.0, last 20 avg 1.0
# Episode 555, episode return 1.0, last 20 avg 1.0
# Episode 556, episode return 1.0, last 20 avg 1.0
# Episode 557, episode return 1.0, last 20 avg 1.0
# Episode 558, episode return 1.0, last 20 avg 1.0
# Episode 559, episode return 1.0, last 20 avg 1.0
# Episode 560, episode return 1.0, last 20 avg 1.0
# Episode 561, episode return 1.0, last 20 avg 1.0
# Episode 562, episode return 1.0, last 20 avg 1.0
# Episode 563, episode return 1.0, last 20 avg 1.0
# Episode 564, episode return 1.0, last 20 avg 1.0
# Episode 565, episode return 1.0, last 20 avg 1.0
# Episode 566, episode return 1.0, last 20 avg 1.0
# Episode 567, episode return 1.0, last 20 avg 1.0
# Episode 568, episode return 1.0, last 20 avg 1.0
# Episode 569, episode return 1.0, last 20 avg 1.0
# Episode 570, episode return 1.0, last 20 avg 1.0
# Episode 571, episode return 1.0, last 20 avg 1.0
# Episode 572, episode return 1.0, last 20 avg 1.0
# Episode 573, episode return 1.0, last 20 avg 1.0
# Episode 574, episode return 1.0, last 20 avg 1.0
# Episode 575, episode return 1.0, last 20 avg 1.0
# Episode 576, episode return 1.0, last 20 avg 1.0
# Episode 577, episode return 1.0, last 20 avg 1.0
# Episode 578, episode return 1.0, last 20 avg 1.0
# Episode 579, episode return 1.0, last 20 avg 1.0
# Episode 580, episode return 1.0, last 20 avg 1.0
# Episode 581, episode return 1.0, last 20 avg 1.0
# Episode 582, episode return 1.0, last 20 avg 1.0
# Episode 583, episode return 1.0, last 20 avg 1.0
# Episode 584, episode return 1.0, last 20 avg 1.0
# Episode 585, episode return 1.0, last 20 avg 1.0
# Episode 586, episode return 1.0, last 20 avg 1.0
# Episode 587, episode return 1.0, last 20 avg 1.0
# Episode 588, episode return 1.0, last 20 avg 1.0
# Episode 589, episode return 1.0, last 20 avg 1.0
# Episode 590, episode return 1.0, last 20 avg 1.0
# Episode 591, episode return 1.0, last 20 avg 1.0
# Episode 592, episode return 1.0, last 20 avg 1.0
# Episode 593, episode return 1.0, last 20 avg 1.0
# Episode 594, episode return 1.0, last 20 avg 1.0
# Episode 595, episode return 1.0, last 20 avg 1.0
# Episode 596, episode return 1.0, last 20 avg 1.0
# Episode 597, episode return 1.0, last 20 avg 1.0
# Episode 598, episode return 1.0, last 20 avg 1.0
# Episode 599, episode return 1.0, last 20 avg 1.0
# ###################
#
#       SEED 1
#
# ###################
#
#  > Training DQN
#
# Episode 0, episode return 0.0, last 20 avg 0.0
# Episode 1, episode return 0.0, last 20 avg 0.0
# Episode 2, episode return 0.0, last 20 avg 0.0
# Episode 3, episode return 0.0, last 20 avg 0.0
# Episode 4, episode return 0.0, last 20 avg 0.0
# Episode 5, episode return 0.0, last 20 avg 0.0
# Episode 6, episode return 0.0, last 20 avg 0.0
# Episode 7, episode return 0.0, last 20 avg 0.0
# Episode 8, episode return 0.0, last 20 avg 0.0
# Episode 9, episode return 0.0, last 20 avg 0.0
# Episode 10, episode return 0.0, last 20 avg 0.0
# Episode 11, episode return 0.0, last 20 avg 0.0
# Episode 12, episode return 0.0, last 20 avg 0.0
# Episode 13, episode return 0.0, last 20 avg 0.0
# Episode 14, episode return 0.0, last 20 avg 0.0
# Episode 15, episode return 0.0, last 20 avg 0.0
# Episode 16, episode return 0.0, last 20 avg 0.0
# Episode 17, episode return 0.0, last 20 avg 0.0
# Episode 18, episode return 0.0, last 20 avg 0.0
# Episode 19, episode return 0.0, last 20 avg 0.0
# Episode 20, episode return 0.0, last 20 avg 0.0
# Episode 21, episode return 0.0, last 20 avg 0.0
# Episode 22, episode return 0.0, last 20 avg 0.0
# Episode 23, episode return 1.0, last 20 avg 0.05
# Episode 24, episode return 0.0, last 20 avg 0.05
# Episode 25, episode return 0.0, last 20 avg 0.05
# Episode 26, episode return 0.0, last 20 avg 0.05
# Episode 27, episode return 0.0, last 20 avg 0.05
# Episode 28, episode return 0.0, last 20 avg 0.05
# Episode 29, episode return 0.0, last 20 avg 0.05
# Episode 30, episode return 0.0, last 20 avg 0.05
# Episode 31, episode return 0.0, last 20 avg 0.05
# Episode 32, episode return 0.0, last 20 avg 0.05
# Episode 33, episode return 0.0, last 20 avg 0.05
# Episode 34, episode return 1.0, last 20 avg 0.1
# Episode 35, episode return 0.0, last 20 avg 0.1
# Episode 36, episode return 1.0, last 20 avg 0.15
# Episode 37, episode return 0.0, last 20 avg 0.15
# Episode 38, episode return 0.0, last 20 avg 0.15
# Episode 39, episode return 0.0, last 20 avg 0.15
# Episode 40, episode return 0.0, last 20 avg 0.15
# Episode 41, episode return 0.0, last 20 avg 0.15
# Episode 42, episode return 0.0, last 20 avg 0.15
# Episode 43, episode return 0.0, last 20 avg 0.1
# Episode 44, episode return 0.0, last 20 avg 0.1
# Episode 45, episode return 0.0, last 20 avg 0.1
# Episode 46, episode return 0.0, last 20 avg 0.1
# Episode 47, episode return 0.0, last 20 avg 0.1
# Episode 48, episode return 0.0, last 20 avg 0.1
# Episode 49, episode return 0.0, last 20 avg 0.1
# Episode 50, episode return 0.0, last 20 avg 0.1
# Episode 51, episode return 0.0, last 20 avg 0.1
# Episode 52, episode return 0.0, last 20 avg 0.1
# Episode 53, episode return 0.0, last 20 avg 0.1
# Episode 54, episode return 0.0, last 20 avg 0.05
# Episode 55, episode return 0.0, last 20 avg 0.05
# Episode 56, episode return 0.0, last 20 avg 0.0
# Episode 57, episode return 1.0, last 20 avg 0.05
# Episode 58, episode return 0.0, last 20 avg 0.05
# Episode 59, episode return 0.0, last 20 avg 0.05
# Episode 60, episode return 0.0, last 20 avg 0.05
# Episode 61, episode return 0.0, last 20 avg 0.05
# Episode 62, episode return 0.0, last 20 avg 0.05
# Episode 63, episode return 0.0, last 20 avg 0.05
# Episode 64, episode return 0.0, last 20 avg 0.05
# Episode 65, episode return 0.0, last 20 avg 0.05
# Episode 66, episode return 1.0, last 20 avg 0.1
# Episode 67, episode return 0.0, last 20 avg 0.1
# Episode 68, episode return 1.0, last 20 avg 0.15
# Episode 69, episode return 0.0, last 20 avg 0.15
# Episode 70, episode return 0.0, last 20 avg 0.15
# Episode 71, episode return 0.0, last 20 avg 0.15
# Episode 72, episode return 0.0, last 20 avg 0.15
# Episode 73, episode return 0.0, last 20 avg 0.15
# Episode 74, episode return 0.0, last 20 avg 0.15
# Episode 75, episode return 0.0, last 20 avg 0.15
# Episode 76, episode return 0.0, last 20 avg 0.15
# Episode 77, episode return 0.0, last 20 avg 0.1
# Episode 78, episode return 0.0, last 20 avg 0.1
# Episode 79, episode return 0.0, last 20 avg 0.1
# Episode 80, episode return 0.0, last 20 avg 0.1
# Episode 81, episode return 0.0, last 20 avg 0.1
# Episode 82, episode return 0.0, last 20 avg 0.1
# Episode 83, episode return 0.0, last 20 avg 0.1
# Episode 84, episode return 0.0, last 20 avg 0.1
# Episode 85, episode return 0.0, last 20 avg 0.1
# Episode 86, episode return 0.0, last 20 avg 0.05
# Episode 87, episode return 0.0, last 20 avg 0.05
# Episode 88, episode return 1.0, last 20 avg 0.05
# Episode 89, episode return 0.0, last 20 avg 0.05
# Episode 90, episode return 0.0, last 20 avg 0.05
# Episode 91, episode return 0.0, last 20 avg 0.05
# Episode 92, episode return 1.0, last 20 avg 0.1
# Episode 93, episode return 0.0, last 20 avg 0.1
# Episode 94, episode return 0.0, last 20 avg 0.1
# Episode 95, episode return 0.0, last 20 avg 0.1
# Episode 96, episode return 0.0, last 20 avg 0.1
# Episode 97, episode return 0.0, last 20 avg 0.1
# Episode 98, episode return 0.0, last 20 avg 0.1
# Episode 99, episode return 0.0, last 20 avg 0.1
# Episode 100, episode return 1.0, last 20 avg 0.15
# Episode 101, episode return 0.0, last 20 avg 0.15
# Episode 102, episode return 0.0, last 20 avg 0.15
# Episode 103, episode return 0.0, last 20 avg 0.15
# Episode 104, episode return 0.0, last 20 avg 0.15
# Episode 105, episode return 0.0, last 20 avg 0.15
# Episode 106, episode return 0.0, last 20 avg 0.15
# Episode 107, episode return 0.0, last 20 avg 0.15
# Episode 108, episode return 0.0, last 20 avg 0.1
# Episode 109, episode return 0.0, last 20 avg 0.1
# Episode 110, episode return 0.0, last 20 avg 0.1
# Episode 111, episode return 0.0, last 20 avg 0.1
# Episode 112, episode return 0.0, last 20 avg 0.05
# Episode 113, episode return 0.0, last 20 avg 0.05
# Episode 114, episode return 0.0, last 20 avg 0.05
# Episode 115, episode return 1.0, last 20 avg 0.1
# Episode 116, episode return 0.0, last 20 avg 0.1
# Episode 117, episode return 1.0, last 20 avg 0.15
# Episode 118, episode return 0.0, last 20 avg 0.15
# Episode 119, episode return 0.0, last 20 avg 0.15
# Episode 120, episode return 0.0, last 20 avg 0.1
# Episode 121, episode return 0.0, last 20 avg 0.1
# Episode 122, episode return 1.0, last 20 avg 0.15
# Episode 123, episode return 1.0, last 20 avg 0.2
# Episode 124, episode return 0.0, last 20 avg 0.2
# Episode 125, episode return 1.0, last 20 avg 0.25
# Episode 126, episode return 0.0, last 20 avg 0.25
# Episode 127, episode return 0.0, last 20 avg 0.25
# Episode 128, episode return 0.0, last 20 avg 0.25
# Episode 129, episode return 0.0, last 20 avg 0.25
# Episode 130, episode return 0.0, last 20 avg 0.25
# Episode 131, episode return 0.0, last 20 avg 0.25
# Episode 132, episode return 1.0, last 20 avg 0.3
# Episode 133, episode return 1.0, last 20 avg 0.35
# Episode 134, episode return 0.0, last 20 avg 0.35
# Episode 135, episode return 0.0, last 20 avg 0.3
# Episode 136, episode return 1.0, last 20 avg 0.35
# Episode 137, episode return 0.0, last 20 avg 0.3
# Episode 138, episode return 0.0, last 20 avg 0.3
# Episode 139, episode return 0.0, last 20 avg 0.3
# Episode 140, episode return 1.0, last 20 avg 0.35
# Episode 141, episode return 1.0, last 20 avg 0.4
# Episode 142, episode return 0.0, last 20 avg 0.35
# Episode 143, episode return 1.0, last 20 avg 0.35
# Episode 144, episode return 0.0, last 20 avg 0.35
# Episode 145, episode return 1.0, last 20 avg 0.35
# Episode 146, episode return 1.0, last 20 avg 0.4
# Episode 147, episode return 1.0, last 20 avg 0.45
# Episode 148, episode return 1.0, last 20 avg 0.5
# Episode 149, episode return 1.0, last 20 avg 0.55
# Episode 150, episode return 0.0, last 20 avg 0.55
# Episode 151, episode return 1.0, last 20 avg 0.6
# Episode 152, episode return 1.0, last 20 avg 0.6
# Episode 153, episode return 1.0, last 20 avg 0.6
# Episode 154, episode return 0.0, last 20 avg 0.6
# Episode 155, episode return 1.0, last 20 avg 0.65
# Episode 156, episode return 0.0, last 20 avg 0.6
# Episode 157, episode return 0.0, last 20 avg 0.6
# Episode 158, episode return 0.0, last 20 avg 0.6
# Episode 159, episode return 1.0, last 20 avg 0.65
# Episode 160, episode return 0.0, last 20 avg 0.6
# Episode 161, episode return 0.0, last 20 avg 0.55
# Episode 162, episode return 1.0, last 20 avg 0.6
# Episode 163, episode return 0.0, last 20 avg 0.55
# Episode 164, episode return 1.0, last 20 avg 0.6
# Episode 165, episode return 0.0, last 20 avg 0.55
# Episode 166, episode return 1.0, last 20 avg 0.55
# Episode 167, episode return 0.0, last 20 avg 0.5
# Episode 168, episode return 1.0, last 20 avg 0.5
# Episode 169, episode return 1.0, last 20 avg 0.5
# Episode 170, episode return 1.0, last 20 avg 0.55
# Episode 171, episode return 0.0, last 20 avg 0.5
# Episode 172, episode return 1.0, last 20 avg 0.5
# Episode 173, episode return 0.0, last 20 avg 0.45
# Episode 174, episode return 1.0, last 20 avg 0.5
# Episode 175, episode return 1.0, last 20 avg 0.5
# Episode 176, episode return 1.0, last 20 avg 0.55
# Episode 177, episode return 1.0, last 20 avg 0.6
# Episode 178, episode return 0.0, last 20 avg 0.6
# Episode 179, episode return 0.0, last 20 avg 0.55
# Episode 180, episode return 1.0, last 20 avg 0.6
# Episode 181, episode return 0.0, last 20 avg 0.6
# Episode 182, episode return 1.0, last 20 avg 0.6
# Episode 183, episode return 1.0, last 20 avg 0.65
# Episode 184, episode return 0.0, last 20 avg 0.6
# Episode 185, episode return 0.0, last 20 avg 0.6
# Episode 186, episode return 0.0, last 20 avg 0.55
# Episode 187, episode return 0.0, last 20 avg 0.55
# Episode 188, episode return 1.0, last 20 avg 0.55
# Episode 189, episode return 0.0, last 20 avg 0.5
# Episode 190, episode return 1.0, last 20 avg 0.5
# Episode 191, episode return 0.0, last 20 avg 0.5
# Episode 192, episode return 0.0, last 20 avg 0.45
# Episode 193, episode return 1.0, last 20 avg 0.5
# Episode 194, episode return 0.0, last 20 avg 0.45
# Episode 195, episode return 0.0, last 20 avg 0.4
# Episode 196, episode return 1.0, last 20 avg 0.4
# Episode 197, episode return 0.0, last 20 avg 0.35
# Episode 198, episode return 1.0, last 20 avg 0.4
# Episode 199, episode return 1.0, last 20 avg 0.45
# Episode 200, episode return 0.0, last 20 avg 0.4
# Episode 201, episode return 0.0, last 20 avg 0.4
# Episode 202, episode return 0.0, last 20 avg 0.35
# Episode 203, episode return 0.0, last 20 avg 0.3
# Episode 204, episode return 0.0, last 20 avg 0.3
# Episode 205, episode return 0.0, last 20 avg 0.3
# Episode 206, episode return 0.0, last 20 avg 0.3
# Episode 207, episode return 1.0, last 20 avg 0.35
# Episode 208, episode return 0.0, last 20 avg 0.3
# Episode 209, episode return 0.0, last 20 avg 0.3
# Episode 210, episode return 0.0, last 20 avg 0.25
# Episode 211, episode return 0.0, last 20 avg 0.25
# Episode 212, episode return 0.0, last 20 avg 0.25
# Episode 213, episode return 0.0, last 20 avg 0.2
# Episode 214, episode return 1.0, last 20 avg 0.25
# Episode 215, episode return 1.0, last 20 avg 0.3
# Episode 216, episode return 1.0, last 20 avg 0.3
# Episode 217, episode return 1.0, last 20 avg 0.35
# Episode 218, episode return 0.0, last 20 avg 0.3
# Episode 219, episode return 0.0, last 20 avg 0.25
# Episode 220, episode return 0.0, last 20 avg 0.25
# Episode 221, episode return 0.0, last 20 avg 0.25
# Episode 222, episode return 0.0, last 20 avg 0.25
# Episode 223, episode return 1.0, last 20 avg 0.3
# Episode 224, episode return 1.0, last 20 avg 0.35
# Episode 225, episode return 1.0, last 20 avg 0.4
# Episode 226, episode return 1.0, last 20 avg 0.45
# Episode 227, episode return 0.0, last 20 avg 0.4
# Episode 228, episode return 1.0, last 20 avg 0.45
# Episode 229, episode return 1.0, last 20 avg 0.5
# Episode 230, episode return 1.0, last 20 avg 0.55
# Episode 231, episode return 1.0, last 20 avg 0.6
# Episode 232, episode return 1.0, last 20 avg 0.65
# Episode 233, episode return 1.0, last 20 avg 0.7
# Episode 234, episode return 0.0, last 20 avg 0.65
# Episode 235, episode return 0.0, last 20 avg 0.6
# Episode 236, episode return 0.0, last 20 avg 0.55
# Episode 237, episode return 0.0, last 20 avg 0.5
# Episode 238, episode return 0.0, last 20 avg 0.5
# Episode 239, episode return 0.0, last 20 avg 0.5
# Episode 240, episode return 1.0, last 20 avg 0.55
# Episode 241, episode return 1.0, last 20 avg 0.6
# Episode 242, episode return 1.0, last 20 avg 0.65
# Episode 243, episode return 1.0, last 20 avg 0.65
# Episode 244, episode return 1.0, last 20 avg 0.65
# Episode 245, episode return 0.0, last 20 avg 0.6
# Episode 246, episode return 0.0, last 20 avg 0.55
# Episode 247, episode return 1.0, last 20 avg 0.6
# Episode 248, episode return 1.0, last 20 avg 0.6
# Episode 249, episode return 1.0, last 20 avg 0.6
# Episode 250, episode return 1.0, last 20 avg 0.6
# Episode 251, episode return 1.0, last 20 avg 0.6
# Episode 252, episode return 0.0, last 20 avg 0.55
# Episode 253, episode return 1.0, last 20 avg 0.55
# Episode 254, episode return 0.0, last 20 avg 0.55
# Episode 255, episode return 1.0, last 20 avg 0.6
# Episode 256, episode return 0.0, last 20 avg 0.6
# Episode 257, episode return 0.0, last 20 avg 0.6
# Episode 258, episode return 0.0, last 20 avg 0.6
# Episode 259, episode return 1.0, last 20 avg 0.65
# Episode 260, episode return 0.0, last 20 avg 0.6
# Episode 261, episode return 0.0, last 20 avg 0.55
# Episode 262, episode return 1.0, last 20 avg 0.55
# Episode 263, episode return 1.0, last 20 avg 0.55
# Episode 264, episode return 0.0, last 20 avg 0.5
# Episode 265, episode return 0.0, last 20 avg 0.5
# Episode 266, episode return 1.0, last 20 avg 0.55
# Episode 267, episode return 1.0, last 20 avg 0.55
# Episode 268, episode return 1.0, last 20 avg 0.55
# Episode 269, episode return 0.0, last 20 avg 0.5
# Episode 270, episode return 1.0, last 20 avg 0.5
# Episode 271, episode return 0.0, last 20 avg 0.45
# Episode 272, episode return 1.0, last 20 avg 0.5
# Episode 273, episode return 0.0, last 20 avg 0.45
# Episode 274, episode return 0.0, last 20 avg 0.45
# Episode 275, episode return 0.0, last 20 avg 0.4
# Episode 276, episode return 0.0, last 20 avg 0.4
# Episode 277, episode return 0.0, last 20 avg 0.4
# Episode 278, episode return 1.0, last 20 avg 0.45
# Episode 279, episode return 0.0, last 20 avg 0.4
# Episode 280, episode return 1.0, last 20 avg 0.45
# Episode 281, episode return 1.0, last 20 avg 0.5
# Episode 282, episode return 0.0, last 20 avg 0.45
# Episode 283, episode return 1.0, last 20 avg 0.45
# Episode 284, episode return 0.0, last 20 avg 0.45
# Episode 285, episode return 1.0, last 20 avg 0.5
# Episode 286, episode return 1.0, last 20 avg 0.5
# Episode 287, episode return 0.0, last 20 avg 0.45
# Episode 288, episode return 0.0, last 20 avg 0.4
# Episode 289, episode return 1.0, last 20 avg 0.45
# Episode 290, episode return 1.0, last 20 avg 0.45
# Episode 291, episode return 0.0, last 20 avg 0.45
# Episode 292, episode return 0.0, last 20 avg 0.4
# Episode 293, episode return 1.0, last 20 avg 0.45
# Episode 294, episode return 1.0, last 20 avg 0.5
# Episode 295, episode return 1.0, last 20 avg 0.55
# Episode 296, episode return 0.0, last 20 avg 0.55
# Episode 297, episode return 1.0, last 20 avg 0.6
# Episode 298, episode return 1.0, last 20 avg 0.6
# Episode 299, episode return 0.0, last 20 avg 0.6
# Episode 300, episode return 0.0, last 20 avg 0.55
# Episode 301, episode return 0.0, last 20 avg 0.5
# Episode 302, episode return 1.0, last 20 avg 0.55
# Episode 303, episode return 1.0, last 20 avg 0.55
# Episode 304, episode return 1.0, last 20 avg 0.6
# Episode 305, episode return 1.0, last 20 avg 0.6
# Episode 306, episode return 0.0, last 20 avg 0.55
# Episode 307, episode return 1.0, last 20 avg 0.6
# Episode 308, episode return 1.0, last 20 avg 0.65
# Episode 309, episode return 0.0, last 20 avg 0.6
# Episode 310, episode return 1.0, last 20 avg 0.6
# Episode 311, episode return 0.0, last 20 avg 0.6
# Episode 312, episode return 1.0, last 20 avg 0.65
# Episode 313, episode return 0.0, last 20 avg 0.6
# Episode 314, episode return 0.0, last 20 avg 0.55
# Episode 315, episode return 1.0, last 20 avg 0.55
# Episode 316, episode return 0.0, last 20 avg 0.55
# Episode 317, episode return 1.0, last 20 avg 0.55
# Episode 318, episode return 0.0, last 20 avg 0.5
# Episode 319, episode return 1.0, last 20 avg 0.55
# Episode 320, episode return 1.0, last 20 avg 0.6
# Episode 321, episode return 0.0, last 20 avg 0.6
# Episode 322, episode return 0.0, last 20 avg 0.55
# Episode 323, episode return 0.0, last 20 avg 0.5
# Episode 324, episode return 0.0, last 20 avg 0.45
# Episode 325, episode return 1.0, last 20 avg 0.45
# Episode 326, episode return 0.0, last 20 avg 0.45
# Episode 327, episode return 0.0, last 20 avg 0.4
# Episode 328, episode return 0.0, last 20 avg 0.35
# Episode 329, episode return 0.0, last 20 avg 0.35
# Episode 330, episode return 1.0, last 20 avg 0.35
# Episode 331, episode return 1.0, last 20 avg 0.4
# Episode 332, episode return 1.0, last 20 avg 0.4
# Episode 333, episode return 1.0, last 20 avg 0.45
# Episode 334, episode return 1.0, last 20 avg 0.5
# Episode 335, episode return 0.0, last 20 avg 0.45
# Episode 336, episode return 1.0, last 20 avg 0.5
# Episode 337, episode return 1.0, last 20 avg 0.5
# Episode 338, episode return 1.0, last 20 avg 0.55
# Episode 339, episode return 1.0, last 20 avg 0.55
# Episode 340, episode return 1.0, last 20 avg 0.55
# Episode 341, episode return 1.0, last 20 avg 0.6
# Episode 342, episode return 0.0, last 20 avg 0.6
# Episode 343, episode return 1.0, last 20 avg 0.65
# Episode 344, episode return 0.0, last 20 avg 0.65
# Episode 345, episode return 1.0, last 20 avg 0.65
# Episode 346, episode return 0.0, last 20 avg 0.65
# Episode 347, episode return 1.0, last 20 avg 0.7
# Episode 348, episode return 0.0, last 20 avg 0.7
# Episode 349, episode return 1.0, last 20 avg 0.75
# Episode 350, episode return 1.0, last 20 avg 0.75
# Episode 351, episode return 1.0, last 20 avg 0.75
# Episode 352, episode return 1.0, last 20 avg 0.75
# Episode 353, episode return 0.0, last 20 avg 0.7
# Episode 354, episode return 1.0, last 20 avg 0.7
# Episode 355, episode return 1.0, last 20 avg 0.75
# Episode 356, episode return 1.0, last 20 avg 0.75
# Episode 357, episode return 1.0, last 20 avg 0.75
# Episode 358, episode return 1.0, last 20 avg 0.75
# Episode 359, episode return 0.0, last 20 avg 0.7
# Episode 360, episode return 1.0, last 20 avg 0.7
# Episode 361, episode return 0.0, last 20 avg 0.65
# Episode 362, episode return 1.0, last 20 avg 0.7
# Episode 363, episode return 1.0, last 20 avg 0.7
# ...
# Episode 277, episode return 1.0, last 20 avg 0.55
# Episode 278, episode return 1.0, last 20 avg 0.6
# Episode 279, episode return 1.0, last 20 avg 0.6
# Episode 280, episode return 1.0, last 20 avg 0.6
# Episode 281, episode return 0.0, last 20 avg 0.55
# Episode 282, episode return 1.0, last 20 avg 0.55
# Episode 283, episode return 1.0, last 20 avg 0.55
# Episode 284, episode return 1.0, last 20 avg 0.55
# Episode 285, episode return 1.0, last 20 avg 0.6
# Episode 286, episode return 0.0, last 20 avg 0.55
# Episode 287, episode return 0.0, last 20 avg 0.5
# Episode 288, episode return 0.0, last 20 avg 0.5
# Episode 289, episode return 1.0, last 20 avg 0.55
# Episode 290, episode return 1.0, last 20 avg 0.6
# Episode 291, episode return 0.0, last 20 avg 0.6
# Episode 292, episode return 1.0, last 20 avg 0.65
# Episode 293, episode return 1.0, last 20 avg 0.7
# Episode 294, episode return 1.0, last 20 avg 0.7
# Episode 295, episode return 0.0, last 20 avg 0.7
# Episode 296, episode return 0.0, last 20 avg 0.65
# Episode 297, episode return 1.0, last 20 avg 0.65
# Episode 298, episode return 0.0, last 20 avg 0.6
# Episode 299, episode return 0.0, last 20 avg 0.55
# Episode 300, episode return 0.0, last 20 avg 0.5
# Episode 301, episode return 1.0, last 20 avg 0.55
# Episode 302, episode return 1.0, last 20 avg 0.55
# Episode 303, episode return 1.0, last 20 avg 0.55
# Episode 304, episode return 1.0, last 20 avg 0.55
# Episode 305, episode return 0.0, last 20 avg 0.5
# Episode 306, episode return 1.0, last 20 avg 0.55
# Episode 307, episode return 0.0, last 20 avg 0.55
# Episode 308, episode return 1.0, last 20 avg 0.6
# Episode 309, episode return 1.0, last 20 avg 0.6
# Episode 310, episode return 0.0, last 20 avg 0.55
# Episode 311, episode return 0.0, last 20 avg 0.55
# Episode 312, episode return 1.0, last 20 avg 0.55
# Episode 313, episode return 0.0, last 20 avg 0.5
# Episode 314, episode return 0.0, last 20 avg 0.45
# Episode 315, episode return 1.0, last 20 avg 0.5
# Episode 316, episode return 0.0, last 20 avg 0.5
# Episode 317, episode return 1.0, last 20 avg 0.5
# Episode 318, episode return 1.0, last 20 avg 0.55
# Episode 319, episode return 1.0, last 20 avg 0.6
# Episode 320, episode return 0.0, last 20 avg 0.6
# Episode 321, episode return 1.0, last 20 avg 0.6
# Episode 322, episode return 0.0, last 20 avg 0.55
# Episode 323, episode return 0.0, last 20 avg 0.5
# Episode 324, episode return 0.0, last 20 avg 0.45
# Episode 325, episode return 0.0, last 20 avg 0.45
# Episode 326, episode return 1.0, last 20 avg 0.45
# Episode 327, episode return 1.0, last 20 avg 0.5
# Episode 328, episode return 1.0, last 20 avg 0.5
# Episode 329, episode return 0.0, last 20 avg 0.45
# Episode 330, episode return 1.0, last 20 avg 0.5
# Episode 331, episode return 1.0, last 20 avg 0.55
# Episode 332, episode return 1.0, last 20 avg 0.55
# Episode 333, episode return 1.0, last 20 avg 0.6
# Episode 334, episode return 0.0, last 20 avg 0.6
# Episode 335, episode return 0.0, last 20 avg 0.55
# Episode 336, episode return 1.0, last 20 avg 0.6
# Episode 337, episode return 1.0, last 20 avg 0.6
# Episode 338, episode return 1.0, last 20 avg 0.6
# Episode 339, episode return 1.0, last 20 avg 0.6
# Episode 340, episode return 1.0, last 20 avg 0.65
# Episode 341, episode return 0.0, last 20 avg 0.6
# Episode 342, episode return 1.0, last 20 avg 0.65
# Episode 343, episode return 1.0, last 20 avg 0.7
# Episode 344, episode return 1.0, last 20 avg 0.75
# Episode 345, episode return 0.0, last 20 avg 0.75
# Episode 346, episode return 0.0, last 20 avg 0.7
# Episode 347, episode return 1.0, last 20 avg 0.7
# Episode 348, episode return 0.0, last 20 avg 0.65
# Episode 349, episode return 1.0, last 20 avg 0.7
# Episode 350, episode return 0.0, last 20 avg 0.65
# Episode 351, episode return 1.0, last 20 avg 0.65
# Episode 352, episode return 1.0, last 20 avg 0.65
# Episode 353, episode return 1.0, last 20 avg 0.65
# Episode 354, episode return 1.0, last 20 avg 0.7
# Episode 355, episode return 1.0, last 20 avg 0.75
# Episode 356, episode return 0.0, last 20 avg 0.7
# Episode 357, episode return 1.0, last 20 avg 0.7
# Episode 358, episode return 1.0, last 20 avg 0.7
# Episode 359, episode return 1.0, last 20 avg 0.7
# Episode 360, episode return 1.0, last 20 avg 0.7
# Episode 361, episode return 0.0, last 20 avg 0.7
# Episode 362, episode return 0.0, last 20 avg 0.65
# Episode 363, episode return 1.0, last 20 avg 0.65
# Episode 364, episode return 1.0, last 20 avg 0.65
# Episode 365, episode return 0.0, last 20 avg 0.65
# Episode 366, episode return 1.0, last 20 avg 0.7
# Episode 367, episode return 1.0, last 20 avg 0.7
# Episode 368, episode return 1.0, last 20 avg 0.75
# Episode 369, episode return 1.0, last 20 avg 0.75
# Episode 370, episode return 0.0, last 20 avg 0.75
# Episode 371, episode return 1.0, last 20 avg 0.75
# Episode 372, episode return 1.0, last 20 avg 0.75
# Episode 373, episode return 1.0, last 20 avg 0.75
# Episode 374, episode return 0.0, last 20 avg 0.7
# Episode 375, episode return 1.0, last 20 avg 0.7
# Episode 376, episode return 0.0, last 20 avg 0.7
# Episode 377, episode return 1.0, last 20 avg 0.7
# Episode 378, episode return 1.0, last 20 avg 0.7
# Episode 379, episode return 0.0, last 20 avg 0.65
# Episode 380, episode return 1.0, last 20 avg 0.65
# Episode 381, episode return 0.0, last 20 avg 0.65
# Episode 382, episode return 1.0, last 20 avg 0.7
# Episode 383, episode return 1.0, last 20 avg 0.7
# Episode 384, episode return 1.0, last 20 avg 0.7
# Episode 385, episode return 0.0, last 20 avg 0.7
# Episode 386, episode return 0.0, last 20 avg 0.65
# Episode 387, episode return 0.0, last 20 avg 0.6
# Episode 388, episode return 0.0, last 20 avg 0.55
# Episode 389, episode return 0.0, last 20 avg 0.5
# Episode 390, episode return 1.0, last 20 avg 0.55
# Episode 391, episode return 0.0, last 20 avg 0.5
# Episode 392, episode return 1.0, last 20 avg 0.5
# Episode 393, episode return 0.0, last 20 avg 0.45
# Episode 394, episode return 1.0, last 20 avg 0.5
# Episode 395, episode return 1.0, last 20 avg 0.5
# Episode 396, episode return 0.0, last 20 avg 0.5
# Episode 397, episode return 0.0, last 20 avg 0.45
# Episode 398, episode return 0.0, last 20 avg 0.4
# Episode 399, episode return 0.0, last 20 avg 0.4
# Episode 400, episode return 0.0, last 20 avg 0.35
# Episode 401, episode return 1.0, last 20 avg 0.4
# Episode 402, episode return 0.0, last 20 avg 0.35
# Episode 403, episode return 1.0, last 20 avg 0.35
# Episode 404, episode return 1.0, last 20 avg 0.35
# Episode 405, episode return 0.0, last 20 avg 0.35
# Episode 406, episode return 1.0, last 20 avg 0.4
# Episode 407, episode return 1.0, last 20 avg 0.45
# Episode 408, episode return 1.0, last 20 avg 0.5
# Episode 409, episode return 1.0, last 20 avg 0.55
# Episode 410, episode return 1.0, last 20 avg 0.55
# Episode 411, episode return 1.0, last 20 avg 0.6
# Episode 412, episode return 1.0, last 20 avg 0.6
# Episode 413, episode return 0.0, last 20 avg 0.6
# Episode 414, episode return 1.0, last 20 avg 0.6
# Episode 415, episode return 0.0, last 20 avg 0.55
# Episode 416, episode return 0.0, last 20 avg 0.55
# Episode 417, episode return 1.0, last 20 avg 0.6
# Episode 418, episode return 1.0, last 20 avg 0.65
# Episode 419, episode return 0.0, last 20 avg 0.65
# Episode 420, episode return 0.0, last 20 avg 0.65
# Episode 421, episode return 0.0, last 20 avg 0.6
# Episode 422, episode return 0.0, last 20 avg 0.6
# Episode 423, episode return 1.0, last 20 avg 0.6
# Episode 424, episode return 0.0, last 20 avg 0.55
# Episode 425, episode return 1.0, last 20 avg 0.6
# Episode 426, episode return 1.0, last 20 avg 0.6
# Episode 427, episode return 1.0, last 20 avg 0.6
# Episode 428, episode return 1.0, last 20 avg 0.6
# Episode 429, episode return 1.0, last 20 avg 0.6
# Episode 430, episode return 0.0, last 20 avg 0.55
# Episode 431, episode return 0.0, last 20 avg 0.5
# Episode 432, episode return 0.0, last 20 avg 0.45
# Episode 433, episode return 0.0, last 20 avg 0.45
# Episode 434, episode return 1.0, last 20 avg 0.45
# Episode 435, episode return 1.0, last 20 avg 0.5
# Episode 436, episode return 0.0, last 20 avg 0.5
# Episode 437, episode return 1.0, last 20 avg 0.5
# Episode 438, episode return 0.0, last 20 avg 0.45
# Episode 439, episode return 1.0, last 20 avg 0.5
# Episode 440, episode return 1.0, last 20 avg 0.55
# Episode 441, episode return 1.0, last 20 avg 0.6
# Episode 442, episode return 1.0, last 20 avg 0.65
# Episode 443, episode return 0.0, last 20 avg 0.6
# Episode 444, episode return 1.0, last 20 avg 0.65
# Episode 445, episode return 0.0, last 20 avg 0.6
# Episode 446, episode return 1.0, last 20 avg 0.6
# Episode 447, episode return 0.0, last 20 avg 0.55
# Episode 448, episode return 0.0, last 20 avg 0.5
# Episode 449, episode return 0.0, last 20 avg 0.45
# Episode 450, episode return 1.0, last 20 avg 0.5
# Episode 451, episode return 0.0, last 20 avg 0.5
# Episode 452, episode return 1.0, last 20 avg 0.55
# Episode 453, episode return 1.0, last 20 avg 0.6
# Episode 454, episode return 1.0, last 20 avg 0.6
# Episode 455, episode return 1.0, last 20 avg 0.6
# Episode 456, episode return 0.0, last 20 avg 0.6
# Episode 457, episode return 0.0, last 20 avg 0.55
# Episode 458, episode return 1.0, last 20 avg 0.6
# Episode 459, episode return 1.0, last 20 avg 0.6
# Episode 460, episode return 1.0, last 20 avg 0.6
# Episode 461, episode return 1.0, last 20 avg 0.6
# Episode 462, episode return 1.0, last 20 avg 0.6
# Episode 463, episode return 0.0, last 20 avg 0.6
# Episode 464, episode return 1.0, last 20 avg 0.6
# Episode 465, episode return 0.0, last 20 avg 0.6
# Episode 466, episode return 1.0, last 20 avg 0.6
# Episode 467, episode return 0.0, last 20 avg 0.6
# Episode 468, episode return 1.0, last 20 avg 0.65
# Episode 469, episode return 1.0, last 20 avg 0.7
# Episode 470, episode return 1.0, last 20 avg 0.7
# Episode 471, episode return 1.0, last 20 avg 0.75
# Episode 472, episode return 0.0, last 20 avg 0.7
# Episode 473, episode return 1.0, last 20 avg 0.7
# Episode 474, episode return 1.0, last 20 avg 0.7
# Episode 475, episode return 0.0, last 20 avg 0.65
# Episode 476, episode return 1.0, last 20 avg 0.7
# Episode 477, episode return 0.0, last 20 avg 0.7
# Episode 478, episode return 1.0, last 20 avg 0.7
# Episode 479, episode return 1.0, last 20 avg 0.7
# Episode 480, episode return 1.0, last 20 avg 0.7
# Episode 481, episode return 0.0, last 20 avg 0.65
# Episode 482, episode return 1.0, last 20 avg 0.65
# Episode 483, episode return 1.0, last 20 avg 0.7
# Episode 484, episode return 1.0, last 20 avg 0.7
# Episode 485, episode return 0.0, last 20 avg 0.7
# Episode 486, episode return 0.0, last 20 avg 0.65
# Episode 487, episode return 0.0, last 20 avg 0.65
# Episode 488, episode return 1.0, last 20 avg 0.65
# Episode 489, episode return 1.0, last 20 avg 0.65
# Episode 490, episode return 0.0, last 20 avg 0.6
# Episode 491, episode return 1.0, last 20 avg 0.6
# Episode 492, episode return 1.0, last 20 avg 0.65
# Episode 493, episode return 1.0, last 20 avg 0.65
# Episode 494, episode return 0.0, last 20 avg 0.6
# Episode 495, episode return 1.0, last 20 avg 0.65
# Episode 496, episode return 1.0, last 20 avg 0.65
# Episode 497, episode return 0.0, last 20 avg 0.65
# Episode 498, episode return 0.0, last 20 avg 0.6
# Episode 499, episode return 0.0, last 20 avg 0.55
# Episode 500, episode return 1.0, last 20 avg 0.55
# Episode 501, episode return 1.0, last 20 avg 0.6
# Episode 502, episode return 0.0, last 20 avg 0.55
# Episode 503, episode return 1.0, last 20 avg 0.55
# Episode 504, episode return 0.0, last 20 avg 0.5
# Episode 505, episode return 1.0, last 20 avg 0.55
# Episode 506, episode return 0.0, last 20 avg 0.55
# Episode 507, episode return 1.0, last 20 avg 0.6
# Episode 508, episode return 1.0, last 20 avg 0.6
# Episode 509, episode return 0.0, last 20 avg 0.55
# Episode 510, episode return 0.0, last 20 avg 0.55
# Episode 511, episode return 0.0, last 20 avg 0.5
# Episode 512, episode return 0.0, last 20 avg 0.45
# Episode 513, episode return 0.0, last 20 avg 0.4
# Episode 514, episode return 0.0, last 20 avg 0.4
# Episode 515, episode return 1.0, last 20 avg 0.4
# Episode 516, episode return 1.0, last 20 avg 0.4
# Episode 517, episode return 1.0, last 20 avg 0.45
# Episode 518, episode return 1.0, last 20 avg 0.5
# Episode 519, episode return 1.0, last 20 avg 0.55
# Episode 520, episode return 0.0, last 20 avg 0.5
# Episode 521, episode return 0.0, last 20 avg 0.45
# Episode 522, episode return 1.0, last 20 avg 0.5
# Episode 523, episode return 1.0, last 20 avg 0.5
# Episode 524, episode return 1.0, last 20 avg 0.55
# Episode 525, episode return 1.0, last 20 avg 0.55
# Episode 526, episode return 0.0, last 20 avg 0.55
# Episode 527, episode return 1.0, last 20 avg 0.55
# Episode 528, episode return 1.0, last 20 avg 0.55
# Episode 529, episode return 1.0, last 20 avg 0.6
# Episode 530, episode return 1.0, last 20 avg 0.65
# Episode 531, episode return 0.0, last 20 avg 0.65
# Episode 532, episode return 1.0, last 20 avg 0.7
# Episode 533, episode return 1.0, last 20 avg 0.75
# Episode 534, episode return 0.0, last 20 avg 0.75
# Episode 535, episode return 0.0, last 20 avg 0.7
# Episode 536, episode return 1.0, last 20 avg 0.7
# Episode 537, episode return 1.0, last 20 avg 0.7
# Episode 538, episode return 0.0, last 20 avg 0.65
# Episode 539, episode return 1.0, last 20 avg 0.65
# Episode 540, episode return 1.0, last 20 avg 0.7
# Episode 541, episode return 0.0, last 20 avg 0.7
# Episode 542, episode return 1.0, last 20 avg 0.7
# Episode 543, episode return 0.0, last 20 avg 0.65
# Episode 544, episode return 1.0, last 20 avg 0.65
# Episode 545, episode return 1.0, last 20 avg 0.65
# Episode 546, episode return 1.0, last 20 avg 0.7
# Episode 547, episode return 0.0, last 20 avg 0.65
# Episode 548, episode return 1.0, last 20 avg 0.65
# Episode 549, episode return 1.0, last 20 avg 0.65
# Episode 550, episode return 1.0, last 20 avg 0.65
# Episode 551, episode return 0.0, last 20 avg 0.65
# Episode 552, episode return 0.0, last 20 avg 0.6
# Episode 553, episode return 1.0, last 20 avg 0.6
# Episode 554, episode return 1.0, last 20 avg 0.65
# Episode 555, episode return 0.0, last 20 avg 0.65
# Episode 556, episode return 1.0, last 20 avg 0.65
# Episode 557, episode return 1.0, last 20 avg 0.65
# Episode 558, episode return 0.0, last 20 avg 0.65
# Episode 559, episode return 0.0, last 20 avg 0.6
# Episode 560, episode return 0.0, last 20 avg 0.55
# Episode 561, episode return 1.0, last 20 avg 0.6
# Episode 562, episode return 1.0, last 20 avg 0.6
# Episode 563, episode return 1.0, last 20 avg 0.65
# Episode 564, episode return 1.0, last 20 avg 0.65
# Episode 565, episode return 1.0, last 20 avg 0.65
# Episode 566, episode return 1.0, last 20 avg 0.65
# Episode 567, episode return 0.0, last 20 avg 0.65
# Episode 568, episode return 0.0, last 20 avg 0.6
# Episode 569, episode return 1.0, last 20 avg 0.6
# Episode 570, episode return 0.0, last 20 avg 0.55
# Episode 571, episode return 1.0, last 20 avg 0.6
# Episode 572, episode return 0.0, last 20 avg 0.6
# Episode 573, episode return 1.0, last 20 avg 0.6
# Episode 574, episode return 0.0, last 20 avg 0.55
# Episode 575, episode return 1.0, last 20 avg 0.6
# Episode 576, episode return 1.0, last 20 avg 0.6
# Episode 577, episode return 1.0, last 20 avg 0.6
# Episode 578, episode return 1.0, last 20 avg 0.65
# Episode 579, episode return 1.0, last 20 avg 0.7
# Episode 580, episode return 1.0, last 20 avg 0.75
# Episode 581, episode return 1.0, last 20 avg 0.75
# Episode 582, episode return 0.0, last 20 avg 0.7
# Episode 583, episode return 1.0, last 20 avg 0.7
# Episode 584, episode return 0.0, last 20 avg 0.65
# Episode 585, episode return 1.0, last 20 avg 0.65
# Episode 586, episode return 0.0, last 20 avg 0.6
# Episode 587, episode return 1.0, last 20 avg 0.65
# Episode 588, episode return 1.0, last 20 avg 0.7
# Episode 589, episode return 0.0, last 20 avg 0.65
# Episode 590, episode return 1.0, last 20 avg 0.7
# Episode 591, episode return 1.0, last 20 avg 0.7
# Episode 592, episode return 1.0, last 20 avg 0.75
# Episode 593, episode return 1.0, last 20 avg 0.75
# Episode 594, episode return 0.0, last 20 avg 0.75
# Episode 595, episode return 1.0, last 20 avg 0.75
# Episode 596, episode return 1.0, last 20 avg 0.75
# Episode 597, episode return 0.0, last 20 avg 0.7
# Episode 598, episode return 1.0, last 20 avg 0.7
# Episode 599, episode return 1.0, last 20 avg 0.7

# %% [markdown]
# At this step, you should have a goal conditioned DQN that learn well on a simple and tiny map. Let's try him on a more large and more complicated 4 rooms environment.

# %%
import matplotlib.pyplot as plt


environment = gym.make("goal_conditioned_discrete_grid_world-v0")
# We modified the map id to select the second map, the rest of the code is the same than above
environment.__init__(map_id=2)
environment.render()

nb_seeds = 4
nb_episodes_per_simulations = 600

dqn_seeds_rewards_result = []
dqn_seeds_tests_result = []
colors = ["#ff0000", "#ff9500"]

for seed_id in range(nb_seeds):
    print()
    print("###################")
    print()
    print("      SEED " + str(seed_id))
    print()
    print("###################")

    print()
    print(" > Training DQN")
    print()
    dqn_agent = GCDQNAgent(environment.observation_space, environment.action_space)
    rewards_sum_per_episode, tests_results = simulation(environment, dqn_agent,
                                                        nb_episodes=nb_episodes_per_simulations)
    dqn_seeds_rewards_result.append(rewards_sum_per_episode)
    dqn_seeds_tests_result.append(tests_results)

    plt.cla()
    plt.title("Rewards sum per episode")
    dqn_means = np.mean(np.array(dqn_seeds_rewards_result), axis=0)
    dqn_stds = np.std(np.array(dqn_seeds_rewards_result), axis=0)
    plt.plot(dqn_means, color=colors[0], label="DQN")
    plt.fill_between([x for x in range(len(dqn_means))], dqn_means + dqn_stds, dqn_means - dqn_stds, color=colors[0],
                     alpha=0.2)
    plt.legend()
    plt.show()

    plt.cla()
    plt.title("Tests grades evolution during agent learning")
    dqn_means = np.mean(np.array(dqn_seeds_tests_result), axis=0)
    dqn_stds = np.std(np.array(dqn_seeds_tests_result), axis=0)
    plt.plot(dqn_means, color=colors[0], label="DQN")
    plt.fill_between([x for x in range(len(dqn_means))], dqn_means + dqn_stds, dqn_means - dqn_stds, color=colors[0],
                     alpha=0.2)
    plt.legend()
    plt.show()
# Out:
# ###################
#
#       SEED 0
#
# ###################
#
#  > Training DQN
#
# Episode 0, episode return 0.0, last 20 avg 0.0
# Episode 1, episode return 0.0, last 20 avg 0.0
# Episode 2, episode return 0.0, last 20 avg 0.0
# Episode 3, episode return 0.0, last 20 avg 0.0
# Episode 4, episode return 0.0, last 20 avg 0.0
# Episode 5, episode return 0.0, last 20 avg 0.0
# Episode 6, episode return 0.0, last 20 avg 0.0
# Episode 7, episode return 0.0, last 20 avg 0.0
# Episode 8, episode return 0.0, last 20 avg 0.0
# Episode 9, episode return 0.0, last 20 avg 0.0
# Episode 10, episode return 0.0, last 20 avg 0.0
# Episode 11, episode return 0.0, last 20 avg 0.0
# Episode 12, episode return 0.0, last 20 avg 0.0
# Episode 13, episode return 0.0, last 20 avg 0.0
# Episode 14, episode return 0.0, last 20 avg 0.0
# Episode 15, episode return 0.0, last 20 avg 0.0
# Episode 16, episode return 0.0, last 20 avg 0.0
# Episode 17, episode return 0.0, last 20 avg 0.0
# Episode 18, episode return 0.0, last 20 avg 0.0
# Episode 19, episode return 0.0, last 20 avg 0.0
# Episode 20, episode return 0.0, last 20 avg 0.0
# Episode 21, episode return 0.0, last 20 avg 0.0
# Episode 22, episode return 0.0, last 20 avg 0.0
# Episode 23, episode return 0.0, last 20 avg 0.0
# Episode 24, episode return 0.0, last 20 avg 0.0
# Episode 25, episode return 0.0, last 20 avg 0.0
# Episode 26, episode return 0.0, last 20 avg 0.0
# Episode 27, episode return 0.0, last 20 avg 0.0
# Episode 28, episode return 0.0, last 20 avg 0.0
# Episode 29, episode return 0.0, last 20 avg 0.0
# Episode 30, episode return 0.0, last 20 avg 0.0
# Episode 31, episode return 0.0, last 20 avg 0.0
# Episode 32, episode return 0.0, last 20 avg 0.0
# Episode 33, episode return 0.0, last 20 avg 0.0
# Episode 34, episode return 0.0, last 20 avg 0.0
# Episode 35, episode return 0.0, last 20 avg 0.0
# Episode 36, episode return 0.0, last 20 avg 0.0
# Episode 37, episode return 0.0, last 20 avg 0.0
# Episode 38, episode return 0.0, last 20 avg 0.0
# Episode 39, episode return 0.0, last 20 avg 0.0
# Episode 40, episode return 0.0, last 20 avg 0.0
# Episode 41, episode return 0.0, last 20 avg 0.0
# Episode 42, episode return 0.0, last 20 avg 0.0
# Episode 43, episode return 0.0, last 20 avg 0.0
# Episode 44, episode return 0.0, last 20 avg 0.0
# Episode 45, episode return 0.0, last 20 avg 0.0
# Episode 46, episode return 1.0, last 20 avg 0.05
# Episode 47, episode return 0.0, last 20 avg 0.05
# Episode 48, episode return 0.0, last 20 avg 0.05
# Episode 49, episode return 0.0, last 20 avg 0.05
# Episode 50, episode return 0.0, last 20 avg 0.05
# Episode 51, episode return 0.0, last 20 avg 0.05
# Episode 52, episode return 0.0, last 20 avg 0.05
# Episode 53, episode return 0.0, last 20 avg 0.05
# Episode 54, episode return 0.0, last 20 avg 0.05
# Episode 55, episode return 0.0, last 20 avg 0.05
# Episode 56, episode return 0.0, last 20 avg 0.05
# Episode 57, episode return 0.0, last 20 avg 0.05
# Episode 58, episode return 0.0, last 20 avg 0.05
# Episode 59, episode return 0.0, last 20 avg 0.05
# Episode 60, episode return 0.0, last 20 avg 0.05
# Episode 61, episode return 0.0, last 20 avg 0.05
# Episode 62, episode return 0.0, last 20 avg 0.05
# Episode 63, episode return 0.0, last 20 avg 0.05
# Episode 64, episode return 0.0, last 20 avg 0.05
# Episode 65, episode return 0.0, last 20 avg 0.05
# Episode 66, episode return 0.0, last 20 avg 0.0
# Episode 67, episode return 0.0, last 20 avg 0.0
# Episode 68, episode return 0.0, last 20 avg 0.0
# Episode 69, episode return 0.0, last 20 avg 0.0
# Episode 70, episode return 0.0, last 20 avg 0.0
# Episode 71, episode return 0.0, last 20 avg 0.0
# Episode 72, episode return 0.0, last 20 avg 0.0
# Episode 73, episode return 0.0, last 20 avg 0.0
# Episode 74, episode return 0.0, last 20 avg 0.0
# Episode 75, episode return 0.0, last 20 avg 0.0
# Episode 76, episode return 0.0, last 20 avg 0.0
# Episode 77, episode return 0.0, last 20 avg 0.0
# Episode 78, episode return 0.0, last 20 avg 0.0
# Episode 79, episode return 0.0, last 20 avg 0.0
# Episode 80, episode return 0.0, last 20 avg 0.0
# Episode 81, episode return 0.0, last 20 avg 0.0
# Episode 82, episode return 0.0, last 20 avg 0.0
# Episode 83, episode return 0.0, last 20 avg 0.0
# Episode 84, episode return 0.0, last 20 avg 0.0
# Episode 85, episode return 0.0, last 20 avg 0.0
# Episode 86, episode return 0.0, last 20 avg 0.0
# Episode 87, episode return 0.0, last 20 avg 0.0
# Episode 88, episode return 0.0, last 20 avg 0.0
# Episode 89, episode return 0.0, last 20 avg 0.0
# Episode 90, episode return 0.0, last 20 avg 0.0
# Episode 91, episode return 0.0, last 20 avg 0.0
# Episode 92, episode return 0.0, last 20 avg 0.0
# Episode 93, episode return 0.0, last 20 avg 0.0
# Episode 94, episode return 0.0, last 20 avg 0.0
# Episode 95, episode return 0.0, last 20 avg 0.0
# Episode 96, episode return 0.0, last 20 avg 0.0
# Episode 97, episode return 0.0, last 20 avg 0.0
# Episode 98, episode return 0.0, last 20 avg 0.0
# Episode 99, episode return 0.0, last 20 avg 0.0
# Episode 100, episode return 0.0, last 20 avg 0.0
# Episode 101, episode return 0.0, last 20 avg 0.0
# Episode 102, episode return 0.0, last 20 avg 0.0
# Episode 103, episode return 0.0, last 20 avg 0.0
# Episode 104, episode return 0.0, last 20 avg 0.0
# Episode 105, episode return 0.0, last 20 avg 0.0
# Episode 106, episode return 0.0, last 20 avg 0.0
# Episode 107, episode return 0.0, last 20 avg 0.0
# Episode 108, episode return 0.0, last 20 avg 0.0
# Episode 109, episode return 0.0, last 20 avg 0.0
# Episode 110, episode return 0.0, last 20 avg 0.0
# Episode 111, episode return 0.0, last 20 avg 0.0
# Episode 112, episode return 0.0, last 20 avg 0.0
# Episode 113, episode return 0.0, last 20 avg 0.0
# Episode 114, episode return 0.0, last 20 avg 0.0
# Episode 115, episode return 0.0, last 20 avg 0.0
# Episode 116, episode return 0.0, last 20 avg 0.0
# Episode 117, episode return 0.0, last 20 avg 0.0
# Episode 118, episode return 0.0, last 20 avg 0.0
# Episode 119, episode return 0.0, last 20 avg 0.0
# Episode 120, episode return 0.0, last 20 avg 0.0
# Episode 121, episode return 0.0, last 20 avg 0.0
# Episode 122, episode return 0.0, last 20 avg 0.0
# Episode 123, episode return 0.0, last 20 avg 0.0
# Episode 124, episode return 0.0, last 20 avg 0.0
# Episode 125, episode return 1.0, last 20 avg 0.05
# Episode 126, episode return 0.0, last 20 avg 0.05
# Episode 127, episode return 0.0, last 20 avg 0.05
# Episode 128, episode return 0.0, last 20 avg 0.05
# Episode 129, episode return 0.0, last 20 avg 0.05
# Episode 130, episode return 0.0, last 20 avg 0.05
# Episode 131, episode return 0.0, last 20 avg 0.05
# Episode 132, episode return 0.0, last 20 avg 0.05
# Episode 133, episode return 0.0, last 20 avg 0.05
# Episode 134, episode return 0.0, last 20 avg 0.05
# Episode 135, episode return 0.0, last 20 avg 0.05
# Episode 136, episode return 0.0, last 20 avg 0.05
# Episode 137, episode return 0.0, last 20 avg 0.05
# Episode 138, episode return 0.0, last 20 avg 0.05
# Episode 139, episode return 0.0, last 20 avg 0.05
# Episode 140, episode return 1.0, last 20 avg 0.1
# Episode 141, episode return 0.0, last 20 avg 0.1
# Episode 142, episode return 0.0, last 20 avg 0.1
# Episode 143, episode return 0.0, last 20 avg 0.1
# Episode 144, episode return 0.0, last 20 avg 0.1
# Episode 145, episode return 0.0, last 20 avg 0.05
# Episode 146, episode return 0.0, last 20 avg 0.05
# Episode 147, episode return 0.0, last 20 avg 0.05
# Episode 148, episode return 0.0, last 20 avg 0.05
# Episode 149, episode return 0.0, last 20 avg 0.05
# Episode 150, episode return 0.0, last 20 avg 0.05
# Episode 151, episode return 1.0, last 20 avg 0.1
# Episode 152, episode return 0.0, last 20 avg 0.1
# Episode 153, episode return 0.0, last 20 avg 0.1
# Episode 154, episode return 0.0, last 20 avg 0.1
# Episode 155, episode return 0.0, last 20 avg 0.1
# Episode 156, episode return 0.0, last 20 avg 0.1
# Episode 157, episode return 0.0, last 20 avg 0.1
# Episode 158, episode return 0.0, last 20 avg 0.1
# Episode 159, episode return 0.0, last 20 avg 0.1
# Episode 160, episode return 0.0, last 20 avg 0.05
# Episode 161, episode return 0.0, last 20 avg 0.05
# Episode 162, episode return 0.0, last 20 avg 0.05
# Episode 163, episode return 0.0, last 20 avg 0.05
# Episode 164, episode return 0.0, last 20 avg 0.05
# Episode 165, episode return 0.0, last 20 avg 0.05
# Episode 166, episode return 0.0, last 20 avg 0.05
# Episode 167, episode return 0.0, last 20 avg 0.05
# Episode 168, episode return 1.0, last 20 avg 0.1
# Episode 169, episode return 0.0, last 20 avg 0.1
# Episode 170, episode return 0.0, last 20 avg 0.1
# Episode 171, episode return 0.0, last 20 avg 0.05
# Episode 172, episode return 0.0, last 20 avg 0.05
# Episode 173, episode return 0.0, last 20 avg 0.05
# Episode 174, episode return 0.0, last 20 avg 0.05
# Episode 175, episode return 0.0, last 20 avg 0.05
# Episode 176, episode return 0.0, last 20 avg 0.05
# Episode 177, episode return 0.0, last 20 avg 0.05
# Episode 178, episode return 0.0, last 20 avg 0.05
# Episode 179, episode return 0.0, last 20 avg 0.05
# Episode 180, episode return 0.0, last 20 avg 0.05
# Episode 181, episode return 0.0, last 20 avg 0.05
# Episode 182, episode return 0.0, last 20 avg 0.05
# Episode 183, episode return 0.0, last 20 avg 0.05
# Episode 184, episode return 0.0, last 20 avg 0.05
# Episode 185, episode return 0.0, last 20 avg 0.05
# Episode 186, episode return 0.0, last 20 avg 0.05
# Episode 187, episode return 0.0, last 20 avg 0.05
# Episode 188, episode return 1.0, last 20 avg 0.05
# Episode 189, episode return 0.0, last 20 avg 0.05
# Episode 190, episode return 0.0, last 20 avg 0.05
# Episode 191, episode return 0.0, last 20 avg 0.05
# Episode 192, episode return 0.0, last 20 avg 0.05
# Episode 193, episode return 0.0, last 20 avg 0.05
# Episode 194, episode return 0.0, last 20 avg 0.05
# Episode 195, episode return 0.0, last 20 avg 0.05
# Episode 196, episode return 0.0, last 20 avg 0.05
# Episode 197, episode return 0.0, last 20 avg 0.05
# Episode 198, episode return 0.0, last 20 avg 0.05
# Episode 199, episode return 0.0, last 20 avg 0.05
# Episode 200, episode return 0.0, last 20 avg 0.05
# Episode 201, episode return 0.0, last 20 avg 0.05
# Episode 202, episode return 0.0, last 20 avg 0.05
# Episode 203, episode return 0.0, last 20 avg 0.05
# Episode 204, episode return 0.0, last 20 avg 0.05
# Episode 205, episode return 0.0, last 20 avg 0.05
# Episode 206, episode return 0.0, last 20 avg 0.05
# Episode 207, episode return 0.0, last 20 avg 0.05
# Episode 208, episode return 0.0, last 20 avg 0.0
# Episode 209, episode return 0.0, last 20 avg 0.0
# Episode 210, episode return 0.0, last 20 avg 0.0
# Episode 211, episode return 0.0, last 20 avg 0.0
# Episode 212, episode return 0.0, last 20 avg 0.0
# Episode 213, episode return 0.0, last 20 avg 0.0
# Episode 214, episode return 0.0, last 20 avg 0.0
# Episode 215, episode return 0.0, last 20 avg 0.0
# Episode 216, episode return 0.0, last 20 avg 0.0
# Episode 217, episode return 0.0, last 20 avg 0.0
# Episode 218, episode return 0.0, last 20 avg 0.0
# Episode 219, episode return 0.0, last 20 avg 0.0
# Episode 220, episode return 1.0, last 20 avg 0.05
# Episode 221, episode return 0.0, last 20 avg 0.05
# Episode 222, episode return 0.0, last 20 avg 0.05
# Episode 223, episode return 0.0, last 20 avg 0.05
# Episode 224, episode return 0.0, last 20 avg 0.05
# Episode 225, episode return 0.0, last 20 avg 0.05
# Episode 226, episode return 0.0, last 20 avg 0.05
# Episode 227, episode return 0.0, last 20 avg 0.05
# Episode 228, episode return 0.0, last 20 avg 0.05
# Episode 229, episode return 0.0, last 20 avg 0.05
# Episode 230, episode return 0.0, last 20 avg 0.05
# Episode 231, episode return 0.0, last 20 avg 0.05
# Episode 232, episode return 0.0, last 20 avg 0.05
# Episode 233, episode return 0.0, last 20 avg 0.05
# Episode 234, episode return 0.0, last 20 avg 0.05
# Episode 235, episode return 0.0, last 20 avg 0.05
# Episode 236, episode return 0.0, last 20 avg 0.05
# Episode 237, episode return 0.0, last 20 avg 0.05
# Episode 238, episode return 0.0, last 20 avg 0.05
# Episode 239, episode return 0.0, last 20 avg 0.05
# Episode 240, episode return 0.0, last 20 avg 0.0
# Episode 241, episode return 0.0, last 20 avg 0.0
# Episode 242, episode return 0.0, last 20 avg 0.0
# Episode 243, episode return 0.0, last 20 avg 0.0
# Episode 244, episode return 0.0, last 20 avg 0.0
# Episode 245, episode return 0.0, last 20 avg 0.0
# Episode 246, episode return 0.0, last 20 avg 0.0
# Episode 247, episode return 0.0, last 20 avg 0.0
# Episode 248, episode return 0.0, last 20 avg 0.0
# Episode 249, episode return 0.0, last 20 avg 0.0
# Episode 250, episode return 0.0, last 20 avg 0.0
# Episode 251, episode return 0.0, last 20 avg 0.0
# Episode 252, episode return 0.0, last 20 avg 0.0
# Episode 253, episode return 0.0, last 20 avg 0.0
# Episode 254, episode return 1.0, last 20 avg 0.05
# Episode 255, episode return 0.0, last 20 avg 0.05
# Episode 256, episode return 0.0, last 20 avg 0.05
# Episode 257, episode return 0.0, last 20 avg 0.05
# Episode 258, episode return 0.0, last 20 avg 0.05
# Episode 259, episode return 0.0, last 20 avg 0.05
# Episode 260, episode return 0.0, last 20 avg 0.05
# Episode 261, episode return 0.0, last 20 avg 0.05
# Episode 262, episode return 1.0, last 20 avg 0.1
# Episode 263, episode return 0.0, last 20 avg 0.1
# Episode 264, episode return 0.0, last 20 avg 0.1
# Episode 265, episode return 0.0, last 20 avg 0.1
# Episode 266, episode return 0.0, last 20 avg 0.1
# Episode 267, episode return 0.0, last 20 avg 0.1
# Episode 268, episode return 0.0, last 20 avg 0.1
# Episode 269, episode return 0.0, last 20 avg 0.1
# Episode 270, episode return 0.0, last 20 avg 0.1
# Episode 271, episode return 0.0, last 20 avg 0.1
# Episode 272, episode return 0.0, last 20 avg 0.1
# Episode 273, episode return 0.0, last 20 avg 0.1
# Episode 274, episode return 0.0, last 20 avg 0.05
# Episode 275, episode return 0.0, last 20 avg 0.05
# Episode 276, episode return 0.0, last 20 avg 0.05
# Episode 277, episode return 0.0, last 20 avg 0.05
# Episode 278, episode return 0.0, last 20 avg 0.05
# Episode 279, episode return 0.0, last 20 avg 0.05
# Episode 280, episode return 0.0, last 20 avg 0.05
# Episode 281, episode return 0.0, last 20 avg 0.05
# Episode 282, episode return 0.0, last 20 avg 0.0
# Episode 283, episode return 0.0, last 20 avg 0.0
# Episode 284, episode return 0.0, last 20 avg 0.0
# Episode 285, episode return 0.0, last 20 avg 0.0
# Episode 286, episode return 0.0, last 20 avg 0.0
# Episode 287, episode return 0.0, last 20 avg 0.0
# Episode 288, episode return 1.0, last 20 avg 0.05
# Episode 289, episode return 0.0, last 20 avg 0.05
# Episode 290, episode return 0.0, last 20 avg 0.05
# Episode 291, episode return 0.0, last 20 avg 0.05
# Episode 292, episode return 0.0, last 20 avg 0.05
# Episode 293, episode return 0.0, last 20 avg 0.05
# Episode 294, episode return 0.0, last 20 avg 0.05
# Episode 295, episode return 0.0, last 20 avg 0.05
# Episode 296, episode return 0.0, last 20 avg 0.05
# Episode 297, episode return 0.0, last 20 avg 0.05
# Episode 298, episode return 1.0, last 20 avg 0.1
# Episode 299, episode return 0.0, last 20 avg 0.1
# Episode 300, episode return 0.0, last 20 avg 0.1
# Episode 301, episode return 0.0, last 20 avg 0.1
# Episode 302, episode return 0.0, last 20 avg 0.1
# Episode 303, episode return 0.0, last 20 avg 0.1
# Episode 304, episode return 0.0, last 20 avg 0.1
# Episode 305, episode return 0.0, last 20 avg 0.1
# Episode 306, episode return 0.0, last 20 avg 0.1
# Episode 307, episode return 0.0, last 20 avg 0.1
# Episode 308, episode return 0.0, last 20 avg 0.05
# Episode 309, episode return 1.0, last 20 avg 0.1
# Episode 310, episode return 0.0, last 20 avg 0.1
# Episode 311, episode return 0.0, last 20 avg 0.1
# Episode 312, episode return 0.0, last 20 avg 0.1
# Episode 313, episode return 0.0, last 20 avg 0.1
# Episode 314, episode return 0.0, last 20 avg 0.1
# Episode 315, episode return 0.0, last 20 avg 0.1
# Episode 316, episode return 0.0, last 20 avg 0.1
# Episode 317, episode return 0.0, last 20 avg 0.1
# Episode 318, episode return 0.0, last 20 avg 0.05
# Episode 319, episode return 0.0, last 20 avg 0.05
# Episode 320, episode return 0.0, last 20 avg 0.05
# Episode 321, episode return 0.0, last 20 avg 0.05
# Episode 322, episode return 1.0, last 20 avg 0.1
# Episode 323, episode return 0.0, last 20 avg 0.1
# Episode 324, episode return 0.0, last 20 avg 0.1
# Episode 325, episode return 0.0, last 20 avg 0.1
# Episode 326, episode return 0.0, last 20 avg 0.1
# Episode 327, episode return 1.0, last 20 avg 0.15
# Episode 328, episode return 0.0, last 20 avg 0.15
# Episode 329, episode return 0.0, last 20 avg 0.1
# Episode 330, episode return 0.0, last 20 avg 0.1
# Episode 331, episode return 1.0, last 20 avg 0.15
# Episode 332, episode return 0.0, last 20 avg 0.15
# Episode 333, episode return 0.0, last 20 avg 0.15
# Episode 334, episode return 0.0, last 20 avg 0.15
# Episode 335, episode return 0.0, last 20 avg 0.15
# Episode 336, episode return 0.0, last 20 avg 0.15
# Episode 337, episode return 0.0, last 20 avg 0.15
# Episode 338, episode return 0.0, last 20 avg 0.15
# Episode 339, episode return 0.0, last 20 avg 0.15
# Episode 340, episode return 0.0, last 20 avg 0.15
# Episode 341, episode return 0.0, last 20 avg 0.15
# Episode 342, episode return 0.0, last 20 avg 0.1
# Episode 343, episode return 0.0, last 20 avg 0.1
# Episode 344, episode return 0.0, last 20 avg 0.1
# Episode 345, episode return 0.0, last 20 avg 0.1
# Episode 346, episode return 0.0, last 20 avg 0.1
# Episode 347, episode return 0.0, last 20 avg 0.05
# Episode 348, episode return 0.0, last 20 avg 0.05
# Episode 349, episode return 0.0, last 20 avg 0.05
# Episode 350, episode return 1.0, last 20 avg 0.1
# Episode 351, episode return 0.0, last 20 avg 0.05
# Episode 352, episode return 0.0, last 20 avg 0.05
# Episode 353, episode return 0.0, last 20 avg 0.05
# Episode 354, episode return 0.0, last 20 avg 0.05
# Episode 355, episode return 0.0, last 20 avg 0.05
# Episode 356, episode return 0.0, last 20 avg 0.05
# Episode 357, episode return 0.0, last 20 avg 0.05
# Episode 358, episode return 0.0, last 20 avg 0.05
# Episode 359, episode return 0.0, last 20 avg 0.05
# Episode 360, episode return 0.0, last 20 avg 0.05
# Episode 361, episode return 0.0, last 20 avg 0.05
# Episode 362, episode return 0.0, last 20 avg 0.05
# Episode 363, episode return 0.0, last 20 avg 0.05
# Episode 364, episode return 0.0, last 20 avg 0.05
# Episode 365, episode return 0.0, last 20 avg 0.05
# Episode 366, episode return 0.0, last 20 avg 0.05
# Episode 367, episode return 0.0, last 20 avg 0.05
# Episode 368, episode return 0.0, last 20 avg 0.05
# Episode 369, episode return 0.0, last 20 avg 0.05
# Episode 370, episode return 0.0, last 20 avg 0.0
# Episode 371, episode return 0.0, last 20 avg 0.0
# Episode 372, episode return 0.0, last 20 avg 0.0
# Episode 373, episode return 0.0, last 20 avg 0.0
# Episode 374, episode return 0.0, last 20 avg 0.0
# Episode 375, episode return 0.0, last 20 avg 0.0
# Episode 376, episode return 0.0, last 20 avg 0.0
# Episode 377, episode return 0.0, last 20 avg 0.0
# Episode 378, episode return 0.0, last 20 avg 0.0
# Episode 379, episode return 0.0, last 20 avg 0.0
# Episode 380, episode return 0.0, last 20 avg 0.0
# Episode 381, episode return 0.0, last 20 avg 0.0
# Episode 382, episode return 0.0, last 20 avg 0.0
# Episode 383, episode return 0.0, last 20 avg 0.0
# Episode 384, episode return 0.0, last 20 avg 0.0
# Episode 385, episode return 0.0, last 20 avg 0.0
# Episode 386, episode return 0.0, last 20 avg 0.0
# Episode 387, episode return 0.0, last 20 avg 0.0
# Episode 388, episode return 0.0, last 20 avg 0.0
# Episode 389, episode return 0.0, last 20 avg 0.0
# Episode 390, episode return 0.0, last 20 avg 0.0
# Episode 391, episode return 0.0, last 20 avg 0.0
# Episode 392, episode return 0.0, last 20 avg 0.0
# Episode 393, episode return 0.0, last 20 avg 0.0
# Episode 394, episode return 0.0, last 20 avg 0.0
# Episode 395, episode return 0.0, last 20 avg 0.0
# Episode 396, episode return 0.0, last 20 avg 0.0
# Episode 397, episode return 0.0, last 20 avg 0.0
# Episode 398, episode return 0.0, last 20 avg 0.0
# Episode 399, episode return 0.0, last 20 avg 0.0
# Episode 400, episode return 0.0, last 20 avg 0.0
# Episode 401, episode return 0.0, last 20 avg 0.0
# Episode 402, episode return 0.0, last 20 avg 0.0
# Episode 403, episode return 0.0, last 20 avg 0.0
# Episode 404, episode return 0.0, last 20 avg 0.0
# Episode 405, episode return 0.0, last 20 avg 0.0
# Episode 406, episode return 0.0, last 20 avg 0.0
# Episode 407, episode return 0.0, last 20 avg 0.0
# Episode 408, episode return 0.0, last 20 avg 0.0
# Episode 409, episode return 1.0, last 20 avg 0.05
# Episode 410, episode return 0.0, last 20 avg 0.05
# Episode 411, episode return 0.0, last 20 avg 0.05
# Episode 412, episode return 0.0, last 20 avg 0.05
# Episode 413, episode return 0.0, last 20 avg 0.05
# Episode 414, episode return 0.0, last 20 avg 0.05
# Episode 415, episode return 0.0, last 20 avg 0.05
# Episode 416, episode return 0.0, last 20 avg 0.05
# Episode 417, episode return 0.0, last 20 avg 0.05
# Episode 418, episode return 0.0, last 20 avg 0.05
# Episode 419, episode return 0.0, last 20 avg 0.05
# Episode 420, episode return 0.0, last 20 avg 0.05
# Episode 421, episode return 0.0, last 20 avg 0.05
# Episode 422, episode return 0.0, last 20 avg 0.05
# Episode 423, episode return 0.0, last 20 avg 0.05
# Episode 424, episode return 0.0, last 20 avg 0.05
# Episode 425, episode return 0.0, last 20 avg 0.05
# Episode 426, episode return 0.0, last 20 avg 0.05
# Episode 427, episode return 0.0, last 20 avg 0.05
# Episode 428, episode return 0.0, last 20 avg 0.05
# Episode 429, episode return 0.0, last 20 avg 0.0
# Episode 430, episode return 0.0, last 20 avg 0.0
# Episode 431, episode return 0.0, last 20 avg 0.0
# Episode 432, episode return 0.0, last 20 avg 0.0
# Episode 433, episode return 0.0, last 20 avg 0.0
# Episode 434, episode return 0.0, last 20 avg 0.0
# Episode 435, episode return 0.0, last 20 avg 0.0
# Episode 436, episode return 0.0, last 20 avg 0.0
# Episode 437, episode return 0.0, last 20 avg 0.0
# Episode 438, episode return 0.0, last 20 avg 0.0
# Episode 439, episode return 0.0, last 20 avg 0.0
# Episode 440, episode return 0.0, last 20 avg 0.0
# Episode 441, episode return 0.0, last 20 avg 0.0
# Episode 442, episode return 0.0, last 20 avg 0.0
# Episode 443, episode return 0.0, last 20 avg 0.0
# Episode 444, episode return 0.0, last 20 avg 0.0
# Episode 445, episode return 0.0, last 20 avg 0.0
# Episode 446, episode return 0.0, last 20 avg 0.0
# Episode 447, episode return 0.0, last 20 avg 0.0
# Episode 448, episode return 0.0, last 20 avg 0.0
# Episode 449, episode return 0.0, last 20 avg 0.0
# Episode 450, episode return 0.0, last 20 avg 0.0
# Episode 451, episode return 0.0, last 20 avg 0.0
# Episode 452, episode return 0.0, last 20 avg 0.0
# Episode 453, episode return 0.0, last 20 avg 0.0
# Episode 454, episode return 0.0, last 20 avg 0.0
# Episode 455, episode return 0.0, last 20 avg 0.0
# Episode 456, episode return 0.0, last 20 avg 0.0
# Episode 457, episode return 0.0, last 20 avg 0.0
# Episode 458, episode return 0.0, last 20 avg 0.0
# Episode 459, episode return 0.0, last 20 avg 0.0
# Episode 460, episode return 0.0, last 20 avg 0.0
# Episode 461, episode return 0.0, last 20 avg 0.0
# Episode 462, episode return 0.0, last 20 avg 0.0
# Episode 463, episode return 0.0, last 20 avg 0.0
# Episode 464, episode return 0.0, last 20 avg 0.0
# Episode 465, episode return 0.0, last 20 avg 0.0
# Episode 466, episode return 0.0, last 20 avg 0.0
# Episode 467, episode return 0.0, last 20 avg 0.0
# Episode 468, episode return 0.0, last 20 avg 0.0
# Episode 469, episode return 0.0, last 20 avg 0.0
# Episode 470, episode return 0.0, last 20 avg 0.0
# Episode 471, episode return 0.0, last 20 avg 0.0
# Episode 472, episode return 0.0, last 20 avg 0.0
# Episode 473, episode return 0.0, last 20 avg 0.0
# Episode 474, episode return 0.0, last 20 avg 0.0
# Episode 475, episode return 0.0, last 20 avg 0.0
# Episode 476, episode return 0.0, last 20 avg 0.0
# Episode 477, episode return 0.0, last 20 avg 0.0
# Episode 478, episode return 0.0, last 20 avg 0.0
# Episode 479, episode return 0.0, last 20 avg 0.0
# Episode 480, episode return 0.0, last 20 avg 0.0
# Episode 481, episode return 0.0, last 20 avg 0.0
# Episode 482, episode return 0.0, last 20 avg 0.0
# Episode 483, episode return 0.0, last 20 avg 0.0
# Episode 484, episode return 0.0, last 20 avg 0.0
# Episode 485, episode return 0.0, last 20 avg 0.0
# Episode 486, episode return 0.0, last 20 avg 0.0
# Episode 487, episode return 0.0, last 20 avg 0.0
# Episode 488, episode return 0.0, last 20 avg 0.0
# Episode 489, episode return 0.0, last 20 avg 0.0
# Episode 490, episode return 0.0, last 20 avg 0.0
# Episode 491, episode return 0.0, last 20 avg 0.0
# Episode 492, episode return 0.0, last 20 avg 0.0
# Episode 493, episode return 0.0, last 20 avg 0.0
# Episode 494, episode return 0.0, last 20 avg 0.0
# Episode 495, episode return 0.0, last 20 avg 0.0
# Episode 496, episode return 0.0, last 20 avg 0.0
# Episode 497, episode return 0.0, last 20 avg 0.0
# Episode 498, episode return 1.0, last 20 avg 0.05
# Episode 499, episode return 0.0, last 20 avg 0.05
# Episode 500, episode return 0.0, last 20 avg 0.05
# Episode 501, episode return 0.0, last 20 avg 0.05
# Episode 502, episode return 0.0, last 20 avg 0.05
# Episode 503, episode return 0.0, last 20 avg 0.05
# Episode 504, episode return 0.0, last 20 avg 0.05
# Episode 505, episode return 0.0, last 20 avg 0.05
# Episode 506, episode return 0.0, last 20 avg 0.05
# Episode 507, episode return 0.0, last 20 avg 0.05
# Episode 508, episode return 0.0, last 20 avg 0.05
# Episode 509, episode return 0.0, last 20 avg 0.05
# Episode 510, episode return 0.0, last 20 avg 0.05
# Episode 511, episode return 0.0, last 20 avg 0.05
# Episode 512, episode return 0.0, last 20 avg 0.05
# Episode 513, episode return 0.0, last 20 avg 0.05
# Episode 514, episode return 0.0, last 20 avg 0.05
# Episode 515, episode return 0.0, last 20 avg 0.05
# Episode 516, episode return 0.0, last 20 avg 0.05
# Episode 517, episode return 0.0, last 20 avg 0.05
# Episode 518, episode return 0.0, last 20 avg 0.0
# Episode 519, episode return 0.0, last 20 avg 0.0
# Episode 520, episode return 0.0, last 20 avg 0.0
# Episode 521, episode return 0.0, last 20 avg 0.0
# Episode 522, episode return 0.0, last 20 avg 0.0
# Episode 523, episode return 0.0, last 20 avg 0.0
# Episode 524, episode return 0.0, last 20 avg 0.0
# Episode 525, episode return 0.0, last 20 avg 0.0
# Episode 526, episode return 0.0, last 20 avg 0.0
# Episode 527, episode return 0.0, last 20 avg 0.0
# Episode 528, episode return 0.0, last 20 avg 0.0
# Episode 529, episode return 0.0, last 20 avg 0.0
# Episode 530, episode return 0.0, last 20 avg 0.0
# Episode 531, episode return 0.0, last 20 avg 0.0
# Episode 532, episode return 0.0, last 20 avg 0.0
# Episode 533, episode return 0.0, last 20 avg 0.0
# Episode 534, episode return 0.0, last 20 avg 0.0
# Episode 535, episode return 0.0, last 20 avg 0.0
# Episode 536, episode return 0.0, last 20 avg 0.0
# Episode 537, episode return 0.0, last 20 avg 0.0
# Episode 538, episode return 0.0, last 20 avg 0.0
# Episode 539, episode return 0.0, last 20 avg 0.0
# Episode 540, episode return 0.0, last 20 avg 0.0
# Episode 541, episode return 0.0, last 20 avg 0.0
# Episode 542, episode return 0.0, last 20 avg 0.0
# Episode 543, episode return 0.0, last 20 avg 0.0
# Episode 544, episode return 0.0, last 20 avg 0.0
# Episode 545, episode return 0.0, last 20 avg 0.0
# Episode 546, episode return 0.0, last 20 avg 0.0
# Episode 547, episode return 0.0, last 20 avg 0.0
# Episode 548, episode return 0.0, last 20 avg 0.0
# Episode 549, episode return 0.0, last 20 avg 0.0
# Episode 550, episode return 0.0, last 20 avg 0.0
# Episode 551, episode return 0.0, last 20 avg 0.0
# Episode 552, episode return 0.0, last 20 avg 0.0
# Episode 553, episode return 0.0, last 20 avg 0.0
# Episode 554, episode return 0.0, last 20 avg 0.0
# Episode 555, episode return 0.0, last 20 avg 0.0
# Episode 556, episode return 0.0, last 20 avg 0.0
# Episode 557, episode return 0.0, last 20 avg 0.0
# Episode 558, episode return 0.0, last 20 avg 0.0
# Episode 559, episode return 1.0, last 20 avg 0.05
# Episode 560, episode return 0.0, last 20 avg 0.05
# Episode 561, episode return 0.0, last 20 avg 0.05
# Episode 562, episode return 0.0, last 20 avg 0.05
# Episode 563, episode return 0.0, last 20 avg 0.05
# Episode 564, episode return 0.0, last 20 avg 0.05
# Episode 565, episode return 0.0, last 20 avg 0.05
# Episode 566, episode return 0.0, last 20 avg 0.05
# Episode 567, episode return 0.0, last 20 avg 0.05
# Episode 568, episode return 0.0, last 20 avg 0.05
# Episode 569, episode return 1.0, last 20 avg 0.1
# Episode 570, episode return 0.0, last 20 avg 0.1
# Episode 571, episode return 0.0, last 20 avg 0.1
# Episode 572, episode return 0.0, last 20 avg 0.1
# Episode 573, episode return 0.0, last 20 avg 0.1
# Episode 574, episode return 1.0, last 20 avg 0.15
# Episode 575, episode return 0.0, last 20 avg 0.15
# Episode 576, episode return 0.0, last 20 avg 0.15
# Episode 577, episode return 0.0, last 20 avg 0.15
# Episode 578, episode return 0.0, last 20 avg 0.15
# Episode 579, episode return 0.0, last 20 avg 0.1
# Episode 580, episode return 0.0, last 20 avg 0.1
# Episode 581, episode return 0.0, last 20 avg 0.1
# Episode 582, episode return 1.0, last 20 avg 0.15
# Episode 583, episode return 0.0, last 20 avg 0.15
# Episode 584, episode return 0.0, last 20 avg 0.15
# Episode 585, episode return 0.0, last 20 avg 0.15
# Episode 586, episode return 0.0, last 20 avg 0.15
# Episode 587, episode return 0.0, last 20 avg 0.15
# Episode 588, episode return 0.0, last 20 avg 0.15
# Episode 589, episode return 0.0, last 20 avg 0.1
# Episode 590, episode return 0.0, last 20 avg 0.1
# Episode 591, episode return 0.0, last 20 avg 0.1
# Episode 592, episode return 0.0, last 20 avg 0.1
# Episode 593, episode return 0.0, last 20 avg 0.1
# Episode 594, episode return 0.0, last 20 avg 0.05
# Episode 595, episode return 0.0, last 20 avg 0.05
# Episode 596, episode return 0.0, last 20 avg 0.05
# Episode 597, episode return 0.0, last 20 avg 0.05
# Episode 598, episode return 0.0, last 20 avg 0.05
# Episode 599, episode return 0.0, last 20 avg 0.05
# ###################
#
#       SEED 1
#
# ###################
#
#  > Training DQN
#
# Episode 0, episode return 0.0, last 20 avg 0.0
# Episode 1, episode return 0.0, last 20 avg 0.0
# Episode 2, episode return 0.0, last 20 avg 0.0
# Episode 3, episode return 0.0, last 20 avg 0.0
# Episode 4, episode return 0.0, last 20 avg 0.0
# Episode 5, episode return 0.0, last 20 avg 0.0
# Episode 6, episode return 0.0, last 20 avg 0.0
# Episode 7, episode return 0.0, last 20 avg 0.0
# Episode 8, episode return 0.0, last 20 avg 0.0
# Episode 9, episode return 0.0, last 20 avg 0.0
# Episode 10, episode return 0.0, last 20 avg 0.0
# Episode 11, episode return 0.0, last 20 avg 0.0
# Episode 12, episode return 0.0, last 20 avg 0.0
# Episode 13, episode return 0.0, last 20 avg 0.0
# Episode 14, episode return 0.0, last 20 avg 0.0
# Episode 15, episode return 0.0, last 20 avg 0.0
# Episode 16, episode return 0.0, last 20 avg 0.0
# Episode 17, episode return 0.0, last 20 avg 0.0
# Episode 18, episode return 0.0, last 20 avg 0.0
# Episode 19, episode return 0.0, last 20 avg 0.0
# Episode 20, episode return 0.0, last 20 avg 0.0
# Episode 21, episode return 0.0, last 20 avg 0.0
# Episode 22, episode return 0.0, last 20 avg 0.0
# Episode 23, episode return 0.0, last 20 avg 0.0
# Episode 24, episode return 1.0, last 20 avg 0.05
# Episode 25, episode return 0.0, last 20 avg 0.05
# Episode 26, episode return 0.0, last 20 avg 0.05
# Episode 27, episode return 0.0, last 20 avg 0.05
# Episode 28, episode return 0.0, last 20 avg 0.05
# Episode 29, episode return 0.0, last 20 avg 0.05
# Episode 30, episode return 0.0, last 20 avg 0.05
# Episode 31, episode return 0.0, last 20 avg 0.05
# Episode 32, episode return 0.0, last 20 avg 0.05
# Episode 33, episode return 0.0, last 20 avg 0.05
# Episode 34, episode return 0.0, last 20 avg 0.05
# Episode 35, episode return 0.0, last 20 avg 0.05
# Episode 36, episode return 0.0, last 20 avg 0.05
# Episode 37, episode return 0.0, last 20 avg 0.05
# Episode 38, episode return 0.0, last 20 avg 0.05
# Episode 39, episode return 0.0, last 20 avg 0.05
# Episode 40, episode return 0.0, last 20 avg 0.05
# Episode 41, episode return 0.0, last 20 avg 0.05
# Episode 42, episode return 0.0, last 20 avg 0.05
# Episode 43, episode return 0.0, last 20 avg 0.05
# Episode 44, episode return 0.0, last 20 avg 0.0
# Episode 45, episode return 0.0, last 20 avg 0.0
# Episode 46, episode return 0.0, last 20 avg 0.0
# Episode 47, episode return 0.0, last 20 avg 0.0
# Episode 48, episode return 0.0, last 20 avg 0.0
# Episode 49, episode return 0.0, last 20 avg 0.0
# Episode 50, episode return 0.0, last 20 avg 0.0
# Episode 51, episode return 0.0, last 20 avg 0.0
# Episode 52, episode return 0.0, last 20 avg 0.0
# Episode 53, episode return 0.0, last 20 avg 0.0
# Episode 54, episode return 0.0, last 20 avg 0.0
# Episode 55, episode return 0.0, last 20 avg 0.0
# Episode 56, episode return 0.0, last 20 avg 0.0
# Episode 57, episode return 0.0, last 20 avg 0.0
# Episode 58, episode return 0.0, last 20 avg 0.0
# Episode 59, episode return 0.0, last 20 avg 0.0
# Episode 60, episode return 0.0, last 20 avg 0.0
# Episode 61, episode return 0.0, last 20 avg 0.0
# Episode 62, episode return 0.0, last 20 avg 0.0
# Episode 63, episode return 0.0, last 20 avg 0.0
# Episode 64, episode return 0.0, last 20 avg 0.0
# Episode 65, episode return 0.0, last 20 avg 0.0
# Episode 66, episode return 0.0, last 20 avg 0.0
# Episode 67, episode return 0.0, last 20 avg 0.0
# Episode 68, episode return 0.0, last 20 avg 0.0
# Episode 69, episode return 0.0, last 20 avg 0.0
# Episode 70, episode return 0.0, last 20 avg 0.0
# Episode 71, episode return 0.0, last 20 avg 0.0
# Episode 72, episode return 0.0, last 20 avg 0.0
# Episode 73, episode return 0.0, last 20 avg 0.0
# Episode 74, episode return 0.0, last 20 avg 0.0
# Episode 75, episode return 0.0, last 20 avg 0.0
# Episode 76, episode return 0.0, last 20 avg 0.0
# Episode 77, episode return 0.0, last 20 avg 0.0
# Episode 78, episode return 0.0, last 20 avg 0.0
# Episode 79, episode return 0.0, last 20 avg 0.0
# Episode 80, episode return 0.0, last 20 avg 0.0
# Episode 81, episode return 0.0, last 20 avg 0.0
# Episode 82, episode return 0.0, last 20 avg 0.0
# Episode 83, episode return 0.0, last 20 avg 0.0
# Episode 84, episode return 0.0, last 20 avg 0.0
# Episode 85, episode return 0.0, last 20 avg 0.0
# Episode 86, episode return 0.0, last 20 avg 0.0
# Episode 87, episode return 0.0, last 20 avg 0.0
# Episode 88, episode return 0.0, last 20 avg 0.0
# Episode 89, episode return 0.0, last 20 avg 0.0
# Episode 90, episode return 0.0, last 20 avg 0.0
# Episode 91, episode return 0.0, last 20 avg 0.0
# Episode 92, episode return 0.0, last 20 avg 0.0
# Episode 93, episode return 0.0, last 20 avg 0.0
# Episode 94, episode return 0.0, last 20 avg 0.0
# Episode 95, episode return 0.0, last 20 avg 0.0
# Episode 96, episode return 0.0, last 20 avg 0.0
# Episode 97, episode return 0.0, last 20 avg 0.0
# Episode 98, episode return 0.0, last 20 avg 0.0
# Episode 99, episode return 0.0, last 20 avg 0.0
# Episode 100, episode return 0.0, last 20 avg 0.0
# Episode 101, episode return 0.0, last 20 avg 0.0
# Episode 102, episode return 0.0, last 20 avg 0.0
# Episode 103, episode return 0.0, last 20 avg 0.0
# Episode 104, episode return 0.0, last 20 avg 0.0
# Episode 105, episode return 0.0, last 20 avg 0.0
# Episode 106, episode return 0.0, last 20 avg 0.0
# Episode 107, episode return 0.0, last 20 avg 0.0
# Episode 108, episode return 0.0, last 20 avg 0.0
# Episode 109, episode return 0.0, last 20 avg 0.0
# Episode 110, episode return 0.0, last 20 avg 0.0
# Episode 111, episode return 0.0, last 20 avg 0.0
# Episode 112, episode return 0.0, last 20 avg 0.0
# Episode 113, episode return 0.0, last 20 avg 0.0
# Episode 114, episode return 0.0, last 20 avg 0.0
# Episode 115, episode return 0.0, last 20 avg 0.0
# Episode 116, episode return 0.0, last 20 avg 0.0
# Episode 117, episode return 0.0, last 20 avg 0.0
# Episode 118, episode return 0.0, last 20 avg 0.0
# Episode 119, episode return 0.0, last 20 avg 0.0
# Episode 120, episode return 0.0, last 20 avg 0.0
# Episode 121, episode return 0.0, last 20 avg 0.0
# Episode 122, episode return 0.0, last 20 avg 0.0
# Episode 123, episode return 0.0, last 20 avg 0.0
# Episode 124, episode return 0.0, last 20 avg 0.0
# Episode 125, episode return 0.0, last 20 avg 0.0
# Episode 126, episode return 0.0, last 20 avg 0.0
# Episode 127, episode return 0.0, last 20 avg 0.0
# Episode 128, episode return 0.0, last 20 avg 0.0
# Episode 129, episode return 0.0, last 20 avg 0.0
# Episode 130, episode return 0.0, last 20 avg 0.0
# Episode 131, episode return 0.0, last 20 avg 0.0
# Episode 132, episode return 0.0, last 20 avg 0.0
# Episode 133, episode return 0.0, last 20 avg 0.0
# Episode 134, episode return 0.0, last 20 avg 0.0
# Episode 135, episode return 0.0, last 20 avg 0.0
# Episode 136, episode return 0.0, last 20 avg 0.0
# Episode 137, episode return 0.0, last 20 avg 0.0
# Episode 138, episode return 0.0, last 20 avg 0.0
# Episode 139, episode return 0.0, last 20 avg 0.0
# Episode 140, episode return 0.0, last 20 avg 0.0
# Episode 141, episode return 0.0, last 20 avg 0.0
# Episode 142, episode return 0.0, last 20 avg 0.0
# Episode 143, episode return 0.0, last 20 avg 0.0
# Episode 144, episode return 0.0, last 20 avg 0.0
# Episode 145, episode return 0.0, last 20 avg 0.0
# Episode 146, episode return 0.0, last 20 avg 0.0
# Episode 147, episode return 0.0, last 20 avg 0.0
# Episode 148, episode return 0.0, last 20 avg 0.0
# Episode 149, episode return 1.0, last 20 avg 0.05
# Episode 150, episode return 0.0, last 20 avg 0.05
# Episode 151, episode return 0.0, last 20 avg 0.05
# Episode 152, episode return 0.0, last 20 avg 0.05
# Episode 153, episode return 0.0, last 20 avg 0.05
# Episode 154, episode return 0.0, last 20 avg 0.05
# Episode 155, episode return 0.0, last 20 avg 0.05
# Episode 156, episode return 0.0, last 20 avg 0.05
# Episode 157, episode return 0.0, last 20 avg 0.05
# Episode 158, episode return 0.0, last 20 avg 0.05
# Episode 159, episode return 0.0, last 20 avg 0.05
# Episode 160, episode return 0.0, last 20 avg 0.05
# Episode 161, episode return 0.0, last 20 avg 0.05
# Episode 162, episode return 0.0, last 20 avg 0.05
# Episode 163, episode return 0.0, last 20 avg 0.05
# Episode 164, episode return 0.0, last 20 avg 0.05
# Episode 165, episode return 0.0, last 20 avg 0.05
# Episode 166, episode return 0.0, last 20 avg 0.05
# Episode 167, episode return 0.0, last 20 avg 0.05
# Episode 168, episode return 0.0, last 20 avg 0.05
# Episode 169, episode return 0.0, last 20 avg 0.0
# Episode 170, episode return 0.0, last 20 avg 0.0
# Episode 171, episode return 0.0, last 20 avg 0.0
# Episode 172, episode return 0.0, last 20 avg 0.0
# Episode 173, episode return 0.0, last 20 avg 0.0
# Episode 174, episode return 0.0, last 20 avg 0.0
# Episode 175, episode return 0.0, last 20 avg 0.0
# Episode 176, episode return 0.0, last 20 avg 0.0
# Episode 177, episode return 0.0, last 20 avg 0.0
# Episode 178, episode return 0.0, last 20 avg 0.0
# Episode 179, episode return 0.0, last 20 avg 0.0
# Episode 180, episode return 0.0, last 20 avg 0.0
# Episode 181, episode return 0.0, last 20 avg 0.0
# Episode 182, episode return 0.0, last 20 avg 0.0
# Episode 183, episode return 0.0, last 20 avg 0.0
# Episode 184, episode return 0.0, last 20 avg 0.0
# Episode 185, episode return 0.0, last 20 avg 0.0
# Episode 186, episode return 0.0, last 20 avg 0.0
# Episode 187, episode return 0.0, last 20 avg 0.0
# Episode 188, episode return 0.0, last 20 avg 0.0
# Episode 189, episode return 0.0, last 20 avg 0.0
# Episode 190, episode return 0.0, last 20 avg 0.0
# Episode 191, episode return 0.0, last 20 avg 0.0
# Episode 192, episode return 0.0, last 20 avg 0.0
# Episode 193, episode return 0.0, last 20 avg 0.0
# Episode 194, episode return 0.0, last 20 avg 0.0
# Episode 195, episode return 0.0, last 20 avg 0.0
# Episode 196, episode return 0.0, last 20 avg 0.0
# Episode 197, episode return 0.0, last 20 avg 0.0
# Episode 198, episode return 0.0, last 20 avg 0.0
# Episode 199, episode return 0.0, last 20 avg 0.0
# Episode 200, episode return 0.0, last 20 avg 0.0
# Episode 201, episode return 0.0, last 20 avg 0.0
# Episode 202, episode return 0.0, last 20 avg 0.0
# Episode 203, episode return 0.0, last 20 avg 0.0
# Episode 204, episode return 0.0, last 20 avg 0.0
# Episode 205, episode return 0.0, last 20 avg 0.0
# Episode 206, episode return 0.0, last 20 avg 0.0
# Episode 207, episode return 0.0, last 20 avg 0.0
# Episode 208, episode return 0.0, last 20 avg 0.0
# Episode 209, episode return 0.0, last 20 avg 0.0
# Episode 210, episode return 0.0, last 20 avg 0.0
# Episode 211, episode return 0.0, last 20 avg 0.0
# Episode 212, episode return 0.0, last 20 avg 0.0
# Episode 213, episode return 0.0, last 20 avg 0.0
# Episode 214, episode return 0.0, last 20 avg 0.0
# Episode 215, episode return 0.0, last 20 avg 0.0
# Episode 216, episode return 0.0, last 20 avg 0.0
# Episode 217, episode return 0.0, last 20 avg 0.0
# Episode 218, episode return 0.0, last 20 avg 0.0
# Episode 219, episode return 0.0, last 20 avg 0.0
# Episode 220, episode return 0.0, last 20 avg 0.0
# Episode 221, episode return 0.0, last 20 avg 0.0
# Episode 222, episode return 0.0, last 20 avg 0.0
# Episode 223, episode return 0.0, last 20 avg 0.0
# Episode 224, episode return 0.0, last 20 avg 0.0
# Episode 225, episode return 0.0, last 20 avg 0.0
# Episode 226, episode return 0.0, last 20 avg 0.0
# Episode 227, episode return 0.0, last 20 avg 0.0
# Episode 228, episode return 0.0, last 20 avg 0.0
# Episode 229, episode return 0.0, last 20 avg 0.0
# Episode 230, episode return 0.0, last 20 avg 0.0
# Episode 231, episode return 0.0, last 20 avg 0.0
# Episode 232, episode return 0.0, last 20 avg 0.0
# Episode 233, episode return 0.0, last 20 avg 0.0
# Episode 234, episode return 0.0, last 20 avg 0.0
# Episode 235, episode return 0.0, last 20 avg 0.0
# Episode 236, episode return 0.0, last 20 avg 0.0
# Episode 237, episode return 0.0, last 20 avg 0.0
# Episode 238, episode return 0.0, last 20 avg 0.0
# Episode 239, episode return 0.0, last 20 avg 0.0
# Episode 240, episode return 0.0, last 20 avg 0.0
# Episode 241, episode return 0.0, last 20 avg 0.0
# Episode 242, episode return 0.0, last 20 avg 0.0
# Episode 243, episode return 0.0, last 20 avg 0.0
# Episode 244, episode return 0.0, last 20 avg 0.0
# Episode 245, episode return 0.0, last 20 avg 0.0
# Episode 246, episode return 0.0, last 20 avg 0.0
# Episode 247, episode return 0.0, last 20 avg 0.0
# Episode 248, episode return 0.0, last 20 avg 0.0
# Episode 249, episode return 0.0, last 20 avg 0.0
# Episode 250, episode return 0.0, last 20 avg 0.0
# Episode 251, episode return 0.0, last 20 avg 0.0
# Episode 252, episode return 0.0, last 20 avg 0.0
# Episode 253, episode return 0.0, last 20 avg 0.0
# Episode 254, episode return 0.0, last 20 avg 0.0
# Episode 255, episode return 0.0, last 20 avg 0.0
# Episode 256, episode return 0.0, last 20 avg 0.0
# Episode 257, episode return 0.0, last 20 avg 0.0
# Episode 258, episode return 0.0, last 20 avg 0.0
# Episode 259, episode return 0.0, last 20 avg 0.0
# Episode 260, episode return 0.0, last 20 avg 0.0
# Episode 261, episode return 0.0, last 20 avg 0.0
# Episode 262, episode return 0.0, last 20 avg 0.0
# Episode 263, episode return 0.0, last 20 avg 0.0
# Episode 264, episode return 0.0, last 20 avg 0.0
# Episode 265, episode return 0.0, last 20 avg 0.0
# Episode 266, episode return 0.0, last 20 avg 0.0
# Episode 267, episode return 0.0, last 20 avg 0.0
# Episode 268, episode return 0.0, last 20 avg 0.0
# Episode 269, episode return 0.0, last 20 avg 0.0
# Episode 270, episode return 0.0, last 20 avg 0.0
# Episode 271, episode return 0.0, last 20 avg 0.0
# Episode 272, episode return 0.0, last 20 avg 0.0
# Episode 273, episode return 0.0, last 20 avg 0.0
# Episode 274, episode return 0.0, last 20 avg 0.0
# Episode 275, episode return 0.0, last 20 avg 0.0
# Episode 276, episode return 0.0, last 20 avg 0.0
# Episode 277, episode return 0.0, last 20 avg 0.0
# Episode 278, episode return 0.0, last 20 avg 0.0
# Episode 279, episode return 0.0, last 20 avg 0.0
# Episode 280, episode return 0.0, last 20 avg 0.0
# Episode 281, episode return 0.0, last 20 avg 0.0
# Episode 282, episode return 0.0, last 20 avg 0.0
# Episode 283, episode return 0.0, last 20 avg 0.0
# Episode 284, episode return 0.0, last 20 avg 0.0
# Episode 285, episode return 0.0, last 20 avg 0.0
# Episode 286, episode return 0.0, last 20 avg 0.0
# Episode 287, episode return 0.0, last 20 avg 0.0
# Episode 288, episode return 0.0, last 20 avg 0.0
# Episode 289, episode return 0.0, last 20 avg 0.0
# Episode 290, episode return 0.0, last 20 avg 0.0
# Episode 291, episode return 0.0, last 20 avg 0.0
# Episode 292, episode return 0.0, last 20 avg 0.0
# Episode 293, episode return 0.0, last 20 avg 0.0
# Episode 294, episode return 0.0, last 20 avg 0.0
# Episode 295, episode return 0.0, last 20 avg 0.0
# Episode 296, episode return 0.0, last 20 avg 0.0
# Episode 297, episode return 0.0, last 20 avg 0.0
# Episode 298, episode return 0.0, last 20 avg 0.0
# Episode 299, episode return 0.0, last 20 avg 0.0
# Episode 300, episode return 0.0, last 20 avg 0.0
# Episode 301, episode return 0.0, last 20 avg 0.0
# Episode 302, episode return 0.0, last 20 avg 0.0
# Episode 303, episode return 0.0, last 20 avg 0.0
# Episode 304, episode return 0.0, last 20 avg 0.0
# Episode 305, episode return 1.0, last 20 avg 0.05
# Episode 306, episode return 0.0, last 20 avg 0.05
# Episode 307, episode return 0.0, last 20 avg 0.05
# Episode 308, episode return 0.0, last 20 avg 0.05
# Episode 309, episode return 0.0, last 20 avg 0.05
# Episode 310, episode return 0.0, last 20 avg 0.05
# Episode 311, episode return 0.0, last 20 avg 0.05
# Episode 312, episode return 0.0, last 20 avg 0.05
# Episode 313, episode return 0.0, last 20 avg 0.05
# Episode 314, episode return 0.0, last 20 avg 0.05
# Episode 315, episode return 0.0, last 20 avg 0.05
# Episode 316, episode return 0.0, last 20 avg 0.05
# Episode 317, episode return 0.0, last 20 avg 0.05
# Episode 318, episode return 0.0, last 20 avg 0.05
# Episode 319, episode return 0.0, last 20 avg 0.05
# Episode 320, episode return 0.0, last 20 avg 0.05
# Episode 321, episode return 0.0, last 20 avg 0.05
# Episode 322, episode return 0.0, last 20 avg 0.05
# Episode 323, episode return 0.0, last 20 avg 0.05
# Episode 324, episode return 0.0, last 20 avg 0.05
# Episode 325, episode return 0.0, last 20 avg 0.0
# Episode 326, episode return 0.0, last 20 avg 0.0
# Episode 327, episode return 0.0, last 20 avg 0.0
# Episode 328, episode return 0.0, last 20 avg 0.0
# Episode 329, episode return 0.0, last 20 avg 0.0
# Episode 330, episode return 0.0, last 20 avg 0.0
# Episode 331, episode return 0.0, last 20 avg 0.0
# Episode 332, episode return 0.0, last 20 avg 0.0
# Episode 333, episode return 0.0, last 20 avg 0.0
# Episode 334, episode return 0.0, last 20 avg 0.0
# Episode 335, episode return 0.0, last 20 avg 0.0
# Episode 336, episode return 0.0, last 20 avg 0.0
# Episode 337, episode return 0.0, last 20 avg 0.0
# Episode 338, episode return 0.0, last 20 avg 0.0
# Episode 339, episode return 0.0, last 20 avg 0.0
# Episode 340, episode return 0.0, last 20 avg 0.0
# Episode 341, episode return 0.0, last 20 avg 0.0
# Episode 342, episode return 0.0, last 20 avg 0.0
# Episode 343, episode return 0.0, last 20 avg 0.0
# Episode 344, episode return 0.0, last 20 avg 0.0
# Episode 345, episode return 0.0, last 20 avg 0.0
# Episode 346, episode return 0.0, last 20 avg 0.0
# Episode 347, episode return 1.0, last 20 avg 0.05
# Episode 348, episode return 0.0, last 20 avg 0.05
# Episode 349, episode return 0.0, last 20 avg 0.05
# Episode 350, episode return 0.0, last 20 avg 0.05
# Episode 351, episode return 0.0, last 20 avg 0.05
# Episode 352, episode return 0.0, last 20 avg 0.05
# Episode 353, episode return 0.0, last 20 avg 0.05
# Episode 354, episode return 0.0, last 20 avg 0.05
# Episode 355, episode return 0.0, last 20 avg 0.05
# Episode 356, episode return 0.0, last 20 avg 0.05
# Episode 357, episode return 0.0, last 20 avg 0.05
# Episode 358, episode return 0.0, last 20 avg 0.05
# Episode 359, episode return 0.0, last 20 avg 0.05
# Episode 360, episode return 0.0, last 20 avg 0.05
# Episode 361, episode return 0.0, last 20 avg 0.05
# Episode 362, episode return 0.0, last 20 avg 0.05
# Episode 363, episode return 0.0, last 20 avg 0.05
# Episode 364, episode return 0.0, last 20 avg 0.05
# Episode 365, episode return 0.0, last 20 avg 0.05
# Episode 366, episode return 0.0, last 20 avg 0.05
# Episode 367, episode return 0.0, last 20 avg 0.0
# Episode 368, episode return 0.0, last 20 avg 0.0
# Episode 369, episode return 0.0, last 20 avg 0.0
# Episode 370, episode return 0.0, last 20 avg 0.0
# Episode 371, episode return 0.0, last 20 avg 0.0
# Episode 372, episode return 0.0, last 20 avg 0.0
# Episode 373, episode return 0.0, last 20 avg 0.0
# ...
# Episode 276, episode return 0.0, last 20 avg 0.0
# Episode 277, episode return 0.0, last 20 avg 0.0
# Episode 278, episode return 0.0, last 20 avg 0.0
# Episode 279, episode return 0.0, last 20 avg 0.0
# Episode 280, episode return 0.0, last 20 avg 0.0
# Episode 281, episode return 0.0, last 20 avg 0.0
# Episode 282, episode return 0.0, last 20 avg 0.0
# Episode 283, episode return 0.0, last 20 avg 0.0
# Episode 284, episode return 0.0, last 20 avg 0.0
# Episode 285, episode return 0.0, last 20 avg 0.0
# Episode 286, episode return 0.0, last 20 avg 0.0
# Episode 287, episode return 0.0, last 20 avg 0.0
# Episode 288, episode return 0.0, last 20 avg 0.0
# Episode 289, episode return 0.0, last 20 avg 0.0
# Episode 290, episode return 0.0, last 20 avg 0.0
# Episode 291, episode return 0.0, last 20 avg 0.0
# Episode 292, episode return 0.0, last 20 avg 0.0
# Episode 293, episode return 0.0, last 20 avg 0.0
# Episode 294, episode return 0.0, last 20 avg 0.0
# Episode 295, episode return 0.0, last 20 avg 0.0
# Episode 296, episode return 0.0, last 20 avg 0.0
# Episode 297, episode return 0.0, last 20 avg 0.0
# Episode 298, episode return 0.0, last 20 avg 0.0
# Episode 299, episode return 0.0, last 20 avg 0.0
# Episode 300, episode return 0.0, last 20 avg 0.0
# Episode 301, episode return 0.0, last 20 avg 0.0
# Episode 302, episode return 0.0, last 20 avg 0.0
# Episode 303, episode return 0.0, last 20 avg 0.0
# Episode 304, episode return 0.0, last 20 avg 0.0
# Episode 305, episode return 0.0, last 20 avg 0.0
# Episode 306, episode return 0.0, last 20 avg 0.0
# Episode 307, episode return 0.0, last 20 avg 0.0
# Episode 308, episode return 0.0, last 20 avg 0.0
# Episode 309, episode return 0.0, last 20 avg 0.0
# Episode 310, episode return 0.0, last 20 avg 0.0
# Episode 311, episode return 0.0, last 20 avg 0.0
# Episode 312, episode return 0.0, last 20 avg 0.0
# Episode 313, episode return 0.0, last 20 avg 0.0
# Episode 314, episode return 0.0, last 20 avg 0.0
# Episode 315, episode return 0.0, last 20 avg 0.0
# Episode 316, episode return 0.0, last 20 avg 0.0
# Episode 317, episode return 0.0, last 20 avg 0.0
# Episode 318, episode return 0.0, last 20 avg 0.0
# Episode 319, episode return 0.0, last 20 avg 0.0
# Episode 320, episode return 0.0, last 20 avg 0.0
# Episode 321, episode return 0.0, last 20 avg 0.0
# Episode 322, episode return 1.0, last 20 avg 0.05
# Episode 323, episode return 0.0, last 20 avg 0.05
# Episode 324, episode return 0.0, last 20 avg 0.05
# Episode 325, episode return 0.0, last 20 avg 0.05
# Episode 326, episode return 0.0, last 20 avg 0.05
# Episode 327, episode return 0.0, last 20 avg 0.05
# Episode 328, episode return 0.0, last 20 avg 0.05
# Episode 329, episode return 0.0, last 20 avg 0.05
# Episode 330, episode return 0.0, last 20 avg 0.05
# Episode 331, episode return 0.0, last 20 avg 0.05
# Episode 332, episode return 0.0, last 20 avg 0.05
# Episode 333, episode return 0.0, last 20 avg 0.05
# Episode 334, episode return 0.0, last 20 avg 0.05
# Episode 335, episode return 0.0, last 20 avg 0.05
# Episode 336, episode return 0.0, last 20 avg 0.05
# Episode 337, episode return 0.0, last 20 avg 0.05
# Episode 338, episode return 0.0, last 20 avg 0.05
# Episode 339, episode return 0.0, last 20 avg 0.05
# Episode 340, episode return 0.0, last 20 avg 0.05
# Episode 341, episode return 0.0, last 20 avg 0.05
# Episode 342, episode return 0.0, last 20 avg 0.0
# Episode 343, episode return 0.0, last 20 avg 0.0
# Episode 344, episode return 0.0, last 20 avg 0.0
# Episode 345, episode return 0.0, last 20 avg 0.0
# Episode 346, episode return 0.0, last 20 avg 0.0
# Episode 347, episode return 0.0, last 20 avg 0.0
# Episode 348, episode return 0.0, last 20 avg 0.0
# Episode 349, episode return 0.0, last 20 avg 0.0
# Episode 350, episode return 0.0, last 20 avg 0.0
# Episode 351, episode return 0.0, last 20 avg 0.0
# Episode 352, episode return 0.0, last 20 avg 0.0
# Episode 353, episode return 0.0, last 20 avg 0.0
# Episode 354, episode return 0.0, last 20 avg 0.0
# Episode 355, episode return 0.0, last 20 avg 0.0
# Episode 356, episode return 0.0, last 20 avg 0.0
# Episode 357, episode return 0.0, last 20 avg 0.0
# Episode 358, episode return 0.0, last 20 avg 0.0
# Episode 359, episode return 0.0, last 20 avg 0.0
# Episode 360, episode return 0.0, last 20 avg 0.0
# Episode 361, episode return 0.0, last 20 avg 0.0
# Episode 362, episode return 0.0, last 20 avg 0.0
# Episode 363, episode return 0.0, last 20 avg 0.0
# Episode 364, episode return 0.0, last 20 avg 0.0
# Episode 365, episode return 0.0, last 20 avg 0.0
# Episode 366, episode return 0.0, last 20 avg 0.0
# Episode 367, episode return 0.0, last 20 avg 0.0
# Episode 368, episode return 0.0, last 20 avg 0.0
# Episode 369, episode return 0.0, last 20 avg 0.0
# Episode 370, episode return 0.0, last 20 avg 0.0
# Episode 371, episode return 0.0, last 20 avg 0.0
# Episode 372, episode return 0.0, last 20 avg 0.0
# Episode 373, episode return 0.0, last 20 avg 0.0
# Episode 374, episode return 0.0, last 20 avg 0.0
# Episode 375, episode return 1.0, last 20 avg 0.05
# Episode 376, episode return 0.0, last 20 avg 0.05
# Episode 377, episode return 0.0, last 20 avg 0.05
# Episode 378, episode return 0.0, last 20 avg 0.05
# Episode 379, episode return 0.0, last 20 avg 0.05
# Episode 380, episode return 0.0, last 20 avg 0.05
# Episode 381, episode return 0.0, last 20 avg 0.05
# Episode 382, episode return 0.0, last 20 avg 0.05
# Episode 383, episode return 0.0, last 20 avg 0.05
# Episode 384, episode return 0.0, last 20 avg 0.05
# Episode 385, episode return 0.0, last 20 avg 0.05
# Episode 386, episode return 0.0, last 20 avg 0.05
# Episode 387, episode return 0.0, last 20 avg 0.05
# Episode 388, episode return 1.0, last 20 avg 0.1
# Episode 389, episode return 0.0, last 20 avg 0.1
# Episode 390, episode return 0.0, last 20 avg 0.1
# Episode 391, episode return 0.0, last 20 avg 0.1
# Episode 392, episode return 0.0, last 20 avg 0.1
# Episode 393, episode return 0.0, last 20 avg 0.1
# Episode 394, episode return 0.0, last 20 avg 0.1
# Episode 395, episode return 0.0, last 20 avg 0.05
# Episode 396, episode return 0.0, last 20 avg 0.05
# Episode 397, episode return 0.0, last 20 avg 0.05
# Episode 398, episode return 0.0, last 20 avg 0.05
# Episode 399, episode return 0.0, last 20 avg 0.05
# Episode 400, episode return 0.0, last 20 avg 0.05
# Episode 401, episode return 1.0, last 20 avg 0.1
# Episode 402, episode return 0.0, last 20 avg 0.1
# Episode 403, episode return 0.0, last 20 avg 0.1
# Episode 404, episode return 0.0, last 20 avg 0.1
# Episode 405, episode return 0.0, last 20 avg 0.1
# Episode 406, episode return 0.0, last 20 avg 0.1
# Episode 407, episode return 0.0, last 20 avg 0.1
# Episode 408, episode return 0.0, last 20 avg 0.05
# Episode 409, episode return 0.0, last 20 avg 0.05
# Episode 410, episode return 0.0, last 20 avg 0.05
# Episode 411, episode return 0.0, last 20 avg 0.05
# Episode 412, episode return 0.0, last 20 avg 0.05
# Episode 413, episode return 0.0, last 20 avg 0.05
# Episode 414, episode return 0.0, last 20 avg 0.05
# Episode 415, episode return 0.0, last 20 avg 0.05
# Episode 416, episode return 0.0, last 20 avg 0.05
# Episode 417, episode return 0.0, last 20 avg 0.05
# Episode 418, episode return 0.0, last 20 avg 0.05
# Episode 419, episode return 0.0, last 20 avg 0.05
# Episode 420, episode return 0.0, last 20 avg 0.05
# Episode 421, episode return 0.0, last 20 avg 0.0
# Episode 422, episode return 0.0, last 20 avg 0.0
# Episode 423, episode return 0.0, last 20 avg 0.0
# Episode 424, episode return 0.0, last 20 avg 0.0
# Episode 425, episode return 0.0, last 20 avg 0.0
# Episode 426, episode return 0.0, last 20 avg 0.0
# Episode 427, episode return 0.0, last 20 avg 0.0
# Episode 428, episode return 0.0, last 20 avg 0.0
# Episode 429, episode return 0.0, last 20 avg 0.0
# Episode 430, episode return 0.0, last 20 avg 0.0
# Episode 431, episode return 0.0, last 20 avg 0.0
# Episode 432, episode return 0.0, last 20 avg 0.0
# Episode 433, episode return 0.0, last 20 avg 0.0
# Episode 434, episode return 0.0, last 20 avg 0.0
# Episode 435, episode return 0.0, last 20 avg 0.0
# Episode 436, episode return 0.0, last 20 avg 0.0
# Episode 437, episode return 0.0, last 20 avg 0.0
# Episode 438, episode return 0.0, last 20 avg 0.0
# Episode 439, episode return 0.0, last 20 avg 0.0
# Episode 440, episode return 0.0, last 20 avg 0.0
# Episode 441, episode return 0.0, last 20 avg 0.0
# Episode 442, episode return 0.0, last 20 avg 0.0
# Episode 443, episode return 0.0, last 20 avg 0.0
# Episode 444, episode return 0.0, last 20 avg 0.0
# Episode 445, episode return 0.0, last 20 avg 0.0
# Episode 446, episode return 0.0, last 20 avg 0.0
# Episode 447, episode return 0.0, last 20 avg 0.0
# Episode 448, episode return 0.0, last 20 avg 0.0
# Episode 449, episode return 0.0, last 20 avg 0.0
# Episode 450, episode return 0.0, last 20 avg 0.0
# Episode 451, episode return 0.0, last 20 avg 0.0
# Episode 452, episode return 0.0, last 20 avg 0.0
# Episode 453, episode return 0.0, last 20 avg 0.0
# Episode 454, episode return 0.0, last 20 avg 0.0
# Episode 455, episode return 0.0, last 20 avg 0.0
# Episode 456, episode return 0.0, last 20 avg 0.0
# Episode 457, episode return 0.0, last 20 avg 0.0
# Episode 458, episode return 0.0, last 20 avg 0.0
# Episode 459, episode return 0.0, last 20 avg 0.0
# Episode 460, episode return 0.0, last 20 avg 0.0
# Episode 461, episode return 0.0, last 20 avg 0.0
# Episode 462, episode return 1.0, last 20 avg 0.05
# Episode 463, episode return 0.0, last 20 avg 0.05
# Episode 464, episode return 0.0, last 20 avg 0.05
# Episode 465, episode return 0.0, last 20 avg 0.05
# Episode 466, episode return 0.0, last 20 avg 0.05
# Episode 467, episode return 0.0, last 20 avg 0.05
# Episode 468, episode return 0.0, last 20 avg 0.05
# Episode 469, episode return 0.0, last 20 avg 0.05
# Episode 470, episode return 0.0, last 20 avg 0.05
# Episode 471, episode return 0.0, last 20 avg 0.05
# Episode 472, episode return 0.0, last 20 avg 0.05
# Episode 473, episode return 0.0, last 20 avg 0.05
# Episode 474, episode return 1.0, last 20 avg 0.1
# Episode 475, episode return 0.0, last 20 avg 0.1
# Episode 476, episode return 0.0, last 20 avg 0.1
# Episode 477, episode return 0.0, last 20 avg 0.1
# Episode 478, episode return 0.0, last 20 avg 0.1
# Episode 479, episode return 0.0, last 20 avg 0.1
# Episode 480, episode return 0.0, last 20 avg 0.1
# Episode 481, episode return 0.0, last 20 avg 0.1
# Episode 482, episode return 0.0, last 20 avg 0.05
# Episode 483, episode return 0.0, last 20 avg 0.05
# Episode 484, episode return 0.0, last 20 avg 0.05
# Episode 485, episode return 0.0, last 20 avg 0.05
# Episode 486, episode return 0.0, last 20 avg 0.05
# Episode 487, episode return 0.0, last 20 avg 0.05
# Episode 488, episode return 0.0, last 20 avg 0.05
# Episode 489, episode return 0.0, last 20 avg 0.05
# Episode 490, episode return 0.0, last 20 avg 0.05
# Episode 491, episode return 0.0, last 20 avg 0.05
# Episode 492, episode return 0.0, last 20 avg 0.05
# Episode 493, episode return 0.0, last 20 avg 0.05
# Episode 494, episode return 0.0, last 20 avg 0.0
# Episode 495, episode return 0.0, last 20 avg 0.0
# Episode 496, episode return 0.0, last 20 avg 0.0
# Episode 497, episode return 0.0, last 20 avg 0.0
# Episode 498, episode return 0.0, last 20 avg 0.0
# Episode 499, episode return 0.0, last 20 avg 0.0
# Episode 500, episode return 0.0, last 20 avg 0.0
# Episode 501, episode return 0.0, last 20 avg 0.0
# Episode 502, episode return 0.0, last 20 avg 0.0
# Episode 503, episode return 0.0, last 20 avg 0.0
# Episode 504, episode return 0.0, last 20 avg 0.0
# Episode 505, episode return 1.0, last 20 avg 0.05
# Episode 506, episode return 0.0, last 20 avg 0.05
# Episode 507, episode return 0.0, last 20 avg 0.05
# Episode 508, episode return 0.0, last 20 avg 0.05
# Episode 509, episode return 1.0, last 20 avg 0.1
# Episode 510, episode return 0.0, last 20 avg 0.1
# Episode 511, episode return 0.0, last 20 avg 0.1
# Episode 512, episode return 0.0, last 20 avg 0.1
# Episode 513, episode return 0.0, last 20 avg 0.1
# Episode 514, episode return 0.0, last 20 avg 0.1
# Episode 515, episode return 0.0, last 20 avg 0.1
# Episode 516, episode return 0.0, last 20 avg 0.1
# Episode 517, episode return 0.0, last 20 avg 0.1
# Episode 518, episode return 0.0, last 20 avg 0.1
# Episode 519, episode return 0.0, last 20 avg 0.1
# Episode 520, episode return 0.0, last 20 avg 0.1
# Episode 521, episode return 0.0, last 20 avg 0.1
# Episode 522, episode return 0.0, last 20 avg 0.1
# Episode 523, episode return 0.0, last 20 avg 0.1
# Episode 524, episode return 0.0, last 20 avg 0.1
# Episode 525, episode return 0.0, last 20 avg 0.05
# Episode 526, episode return 0.0, last 20 avg 0.05
# Episode 527, episode return 0.0, last 20 avg 0.05
# Episode 528, episode return 0.0, last 20 avg 0.05
# Episode 529, episode return 0.0, last 20 avg 0.0
# Episode 530, episode return 0.0, last 20 avg 0.0
# Episode 531, episode return 0.0, last 20 avg 0.0
# Episode 532, episode return 0.0, last 20 avg 0.0
# Episode 533, episode return 0.0, last 20 avg 0.0
# Episode 534, episode return 0.0, last 20 avg 0.0
# Episode 535, episode return 0.0, last 20 avg 0.0
# Episode 536, episode return 0.0, last 20 avg 0.0
# Episode 537, episode return 0.0, last 20 avg 0.0
# Episode 538, episode return 0.0, last 20 avg 0.0
# Episode 539, episode return 0.0, last 20 avg 0.0
# Episode 540, episode return 0.0, last 20 avg 0.0
# Episode 541, episode return 0.0, last 20 avg 0.0
# Episode 542, episode return 0.0, last 20 avg 0.0
# Episode 543, episode return 0.0, last 20 avg 0.0
# Episode 544, episode return 0.0, last 20 avg 0.0
# Episode 545, episode return 0.0, last 20 avg 0.0
# Episode 546, episode return 0.0, last 20 avg 0.0
# Episode 547, episode return 0.0, last 20 avg 0.0
# Episode 548, episode return 0.0, last 20 avg 0.0
# Episode 549, episode return 0.0, last 20 avg 0.0
# Episode 550, episode return 0.0, last 20 avg 0.0
# Episode 551, episode return 0.0, last 20 avg 0.0
# Episode 552, episode return 0.0, last 20 avg 0.0
# Episode 553, episode return 0.0, last 20 avg 0.0
# Episode 554, episode return 0.0, last 20 avg 0.0
# Episode 555, episode return 0.0, last 20 avg 0.0
# Episode 556, episode return 0.0, last 20 avg 0.0
# Episode 557, episode return 0.0, last 20 avg 0.0
# Episode 558, episode return 0.0, last 20 avg 0.0
# Episode 559, episode return 0.0, last 20 avg 0.0
# Episode 560, episode return 0.0, last 20 avg 0.0
# Episode 561, episode return 0.0, last 20 avg 0.0
# Episode 562, episode return 0.0, last 20 avg 0.0
# Episode 563, episode return 0.0, last 20 avg 0.0
# Episode 564, episode return 0.0, last 20 avg 0.0
# Episode 565, episode return 0.0, last 20 avg 0.0
# Episode 566, episode return 0.0, last 20 avg 0.0
# Episode 567, episode return 0.0, last 20 avg 0.0
# Episode 568, episode return 0.0, last 20 avg 0.0
# Episode 569, episode return 0.0, last 20 avg 0.0
# Episode 570, episode return 0.0, last 20 avg 0.0
# Episode 571, episode return 0.0, last 20 avg 0.0
# Episode 572, episode return 0.0, last 20 avg 0.0
# Episode 573, episode return 0.0, last 20 avg 0.0
# Episode 574, episode return 0.0, last 20 avg 0.0
# Episode 575, episode return 0.0, last 20 avg 0.0
# Episode 576, episode return 0.0, last 20 avg 0.0
# Episode 577, episode return 0.0, last 20 avg 0.0
# Episode 578, episode return 1.0, last 20 avg 0.05
# Episode 579, episode return 1.0, last 20 avg 0.1
# Episode 580, episode return 0.0, last 20 avg 0.1
# Episode 581, episode return 0.0, last 20 avg 0.1
# Episode 582, episode return 0.0, last 20 avg 0.1
# Episode 583, episode return 0.0, last 20 avg 0.1
# Episode 584, episode return 0.0, last 20 avg 0.1
# Episode 585, episode return 0.0, last 20 avg 0.1
# Episode 586, episode return 0.0, last 20 avg 0.1
# Episode 587, episode return 0.0, last 20 avg 0.1
# Episode 588, episode return 0.0, last 20 avg 0.1
# Episode 589, episode return 0.0, last 20 avg 0.1
# Episode 590, episode return 0.0, last 20 avg 0.1
# Episode 591, episode return 1.0, last 20 avg 0.15
# Episode 592, episode return 0.0, last 20 avg 0.15
# Episode 593, episode return 1.0, last 20 avg 0.2
# Episode 594, episode return 0.0, last 20 avg 0.2
# Episode 595, episode return 0.0, last 20 avg 0.2
# Episode 596, episode return 0.0, last 20 avg 0.2
# Episode 597, episode return 0.0, last 20 avg 0.2
# Episode 598, episode return 1.0, last 20 avg 0.2
# Episode 599, episode return 0.0, last 20 avg 0.15

# %% [markdown]
# <div class="alert alert-warning">
# Why our agent is not able to learn this time? (The expected answer is a bit more complex than just "the environment is harder" ;)
# <div/>

# %% [markdown]
# <details class="alert alert-danger">
#     <summary markdown="span"><b>Ready to see the answer? (click to expand)</b></summary>
#     The agent cannot learn because finding a reaward is too complex in this environment.
#
# With DQN, the model need to have rewards to converge and estimate the Q value of a state-action pair. While our agent don't find any rewards, the executed policy is equivalent to a pseudo-random one.
#
# In the first map, the rewards was rich (goals close to the agent) but in the second one, they weren't. First, the size of the environment make goals far in average from the starting point of the agent. More, walls make the agent needs to go through threshold (which is still a state of the art challenge in reinforcement learning, but not a major one) to explore others rooms and find some rewards.
#
# We can also see that some rewards are not enough to learn how to find new_ones. These rewarded samples are drowned into a larger amount of non-interesting samples inside the buffer.
#
# <details/>

# %% [markdown]
# ## Sparse reward problem
# <div id="sparse"></div>
#
# ### Problem statement
# <div id="sparse"></div>
# Doing the last exercise, you just highlight the sparse reward problem. It occurs when the agent do not manage to find rewards. A way to prevent this, is to find a way to reuse the non-rewarded samples. We just saw that the few rewards found are drowned into a way larger amount of non-rewarded interactions. With Hindsight Experience replay, we will find a way to reuse them.
#
# ### Hindsight Experience Replay (HER)
#
# *(Exemple from the main paper of [HER](https://arxiv.org/pdf/1707.01495.pdf)*
#
# Imagine a robot that tried to score a goal in soccer. After he shoot the ball, he will receive a rewardof 1 when a goal is scored, and a reward of 0 otherwise. If a reinforcement learning agent train on this task, and shoot 1000 times outside of the goal, he will not learn at all, and will still follow a pseudo-random policy. But if a human do the same, they will still learn from failed trials, and reuse what they learned to reach goal (or score goal in this example).
#
# The idea of HER is to associate a reward for every non-rewarded samples, by a relabelling using a new goal in the same trajectory. Taken a failed trajectory, and an interaction (s, a, r=0, s', d=False, g) in this trajectory, this sambles can be associated with a reward using the last state of the trajectory
#
#     (s, a, r=R(s', st), s', d=(s' == st), g=st)
#
# Where st is the last state in the trajectory, and R(s', st) a custom and intrinsic reward function (no more details in the paper about R, but I will give you a way to implement it).
#
# Here is the HER algorithm:
# ![image.png](attachment:image.png)
#
# The part we're interested in is the second for loop of an episode (everything else is reinforcement learning as we saw in previous notebook). There, we can see that for each steps, they sample a set of goals. They propose many way to select them, but according to their experiments, the way that have the best performances is to select 5 subgoals for each sample, with each new goals being between s and st in the trajectory.

# %% [markdown]
# <div class="alert alert-warning">
# To make sure you understood well, if we have a trajectory of length 10 (10 samples (s, a, r, s', d, g)). How many samples in total will be stored in the buffer using HER with the goal selection strategy described above ?
# <div/>

# %% [markdown]
# <details class="alert alert-danger">
#     <summary markdown="span"><b>Ready to see the answer? (click to expand)</b></summary>
#
# First, each of these sample will be stored in the buffer (step "standard experience replay" of the algorithm above). Then, we will store 5 relabelled samples for each samples. In total, we will store 60 samples from a trajectory of size 10.
# <details/>

# %% [markdown]
# <div class="alert alert-warning">
# In an goal reaching task where the agent recieve a reward of 1 when he reach the goal, and a reward of 0 when he don't. What can be a good function for R(s, g) ?
#
# NB: you can use any informations in your possetion at the moment you relabel samples
# <div/>

# %% [markdown]
# <details class="alert alert-danger">
#     <summary markdown="span"><b>Ready to see the answer? (click to expand)</b></summary>
# We can use samples index in the trajectory. After sampling a goal with index $g_i$, for a state with index $s_i$ in the trajectory, we know that the state s it the step $s_i$ in a trajectory that reach $g$ in $g_i$ steps.
#
# Because we did $s_i / s_g * 100$ percent of the travel at this step, and because the reward goes from 0 to 1, we can compute this reward as $R(s, s_i, g, g_i) = s_i / s_g$
# <details/>

# %% [markdown]
# Now you understood HER, implement it below (note that the code heritate from GCDQNAgent).

# %%
import copy
import random
from random import randrange

import gym
import numpy as np
import torch
from torch import nn, optim
from torch.nn import ReLU


class HERAgent(GCDQNAgent):
    """
    An agent that learn an approximated Q-Function using a neural network.
    This Q-Function is used to find the best action to execute in a given state.
    """

    def __init__(self, state_space, action_space, goal_size=None, name="DQN + HER",
                 gamma=0.95, epsilon_min=0.01, epsilon_max=1., epsilon_decay_period=1000, epsilon_decay_delay=20,
                 buffer_size=1000000, learning_rate=0.001, update_target_freq=100, batch_size=125,
                 layer_1_size=250, layer_2_size=200, nb_gradient_steps=1):

        super().__init__(state_space, action_space, goal_size=goal_size, name=name, gamma=gamma, 
                         epsilon_min=epsilon_min, epsilon_max=epsilon_max, 
                         epsilon_decay_period=epsilon_decay_period, epsilon_decay_delay=epsilon_decay_delay, 
                         buffer_size=buffer_size, learning_rate=learning_rate,
                         update_target_freq=update_target_freq, batch_size=batch_size, layer_1_size=layer_1_size,
                         layer_2_size=layer_2_size, nb_gradient_steps=nb_gradient_steps)

    def action(self, state):
        return super().action(state)

    def on_episode_start(self, episode_info, episode_id):
        res = super().on_episode_start(episode_info, episode_id)
        return res

    def on_action_stop(self, action, new_state, reward, done):
        self.last_trajectory.append((self.last_state, action))

        return super().on_action_stop(action, new_state, reward, done)

    def on_episode_stop(self):
        # Relabel last trajectory
        # TODO (For this todo, you will need to add some stuff in the functions above)
# Out:
#   File "/tmp/ipykernel_8522/1528024556.py", line 44
#     # TODO (For this todo, you will need to add some stuff in the functions above)
#                                                                                   ^
# SyntaxError: unexpected EOF while parsing

# %%
# %load solutions/RL7/her.py
import copy
import random
from random import randrange

import gym
import numpy as np
import torch
from torch import nn, optim
from torch.nn import ReLU


class HERAgent(GCDQNAgent):
    """
    An agent that learn an approximated Q-Function using a neural network.
    This Q-Function is used to find the best action to execute in a given state.
    """

    def __init__(self, state_space, action_space, goal_size=None, name="DQN + HER",
                 gamma=0.95, epsilon_min=0.01, epsilon_max=1., epsilon_decay_period=1000, epsilon_decay_delay=20,
                 buffer_size=1000000, learning_rate=0.001, update_target_freq=100, batch_size=125,
                 layer_1_size=250, layer_2_size=200, nb_gradient_steps=1):

        super().__init__(state_space, action_space, goal_size=goal_size, name=name, gamma=gamma, 
                         epsilon_min=epsilon_min, epsilon_max=epsilon_max, 
                         epsilon_decay_period=epsilon_decay_period, epsilon_decay_delay=epsilon_decay_delay, 
                         buffer_size=buffer_size, learning_rate=learning_rate,
                         update_target_freq=update_target_freq, batch_size=batch_size, layer_1_size=layer_1_size,
                         layer_2_size=layer_2_size, nb_gradient_steps=nb_gradient_steps)

        # HER will relabel samples in the last trajectory. To do it, we need to keep this last trajectory in a memory
        self.last_trajectory = []
        # ... and store relabelling parameters
        self.nb_resample_per_states = 5

    def action(self, state):
        return super().action(state)

    def on_episode_start(self, episode_info, episode_id):
        res = super().on_episode_start(episode_info, episode_id)
        self.last_trajectory = []
        return res

    def on_action_stop(self, action, new_state, reward, done):
        self.last_trajectory.append((self.last_state, action))

        return super().on_action_stop(action, new_state, reward, done)

    def on_episode_stop(self):
        # Relabel last trajectory
        if len(self.last_trajectory) <= self.nb_resample_per_states:
            return
        # For each state seen (so each sample):
        for state_index, (state, action) in enumerate(self.last_trajectory[:-4]):
            new_state_index = state_index + 1
            new_state, _ = self.last_trajectory[new_state_index]

            # sample four goals in future states
            for relabelling_id in range(self.nb_resample_per_states):
                goal_index = randrange(new_state_index, len(self.last_trajectory))
                goal, _ = self.last_trajectory[goal_index]
                reward = new_state_index / goal_index
                self.replay_buffer.append(state, action, reward, new_state, goal_index == new_state_index, goal[-2:])

# %% [markdown]
# Now you implemented it, you can compate it to DQN in the simple map using the code below:

# %%
# Compare HER to DQN in simple env
environment = gym.make("goal_conditioned_discrete_grid_world-v0")
environment.__init__(map_id=1)
environment.render()
nb_seeds = 4
nb_episodes_per_simulations = 300
dqn_seeds_rewards_result = []
dqn_seeds_tests_result = []
her_seeds_rewards_result = []
her_seeds_tests_result = []
colors = ["#ff0000", "#ff9500"]
for seed_id in range(nb_seeds):
    print()
    print("###################")
    print()
    print("      SEED " + str(seed_id))
    print()
    print("###################")

    print()
    print(" > Training DQN + HER")
    print()
    her_agent = HERAgent(environment.observation_space, environment.action_space)
    rewards_sum_per_episode, tests_results = simulation(environment, her_agent,
                                                        nb_episodes=nb_episodes_per_simulations)
    her_seeds_rewards_result.append(rewards_sum_per_episode)
    her_seeds_tests_result.append(tests_results)

    print()
    print(" > Training DQN")
    print()
    dqn_agent = GCDQNAgent(environment.observation_space, environment.action_space)
    rewards_sum_per_episode, tests_results = simulation(environment, dqn_agent,
                                                        nb_episodes=nb_episodes_per_simulations)
    dqn_seeds_rewards_result.append(rewards_sum_per_episode)
    dqn_seeds_tests_result.append(tests_results)

    plt.cla()
    plt.title("Rewards sum per episode")
    dqn_means = np.mean(np.array(dqn_seeds_rewards_result), axis=0)
    dqn_stds = np.std(np.array(dqn_seeds_rewards_result), axis=0)
    plt.plot(dqn_means, color=colors[0], label="DQN")
    plt.fill_between([x for x in range(len(dqn_means))], dqn_means + dqn_stds, dqn_means - dqn_stds, color=colors[0],
                     alpha=0.2)
    her_means = np.mean(np.array(her_seeds_rewards_result), axis=0)
    her_stds = np.std(np.array(her_seeds_rewards_result), axis=0)
    plt.plot(her_means, color=colors[1], label="DQN + HER")
    plt.fill_between([x for x in range(len(her_means))], her_means + her_stds, her_means - her_stds, color=colors[1],
                     alpha=0.2)
    plt.legend()
    plt.show()

    plt.cla()
    plt.title("Tests grades evolution during agent learning")
    dqn_means = np.mean(np.array(dqn_seeds_tests_result), axis=0)
    dqn_stds = np.std(np.array(dqn_seeds_tests_result), axis=0)
    plt.plot(dqn_means, color=colors[0], label="DQN")
    plt.fill_between([x for x in range(len(dqn_means))], dqn_means + dqn_stds, dqn_means - dqn_stds, color=colors[0],
                     alpha=0.2)
    her_means = np.mean(np.array(her_seeds_tests_result), axis=0)
    her_stds = np.std(np.array(her_seeds_tests_result), axis=0)
    plt.plot(her_means, color=colors[1], label="DQN + HER")
    plt.fill_between([x for x in range(len(her_means))], her_means + her_stds, her_means - her_stds, color=colors[1],
                     alpha=0.2)
    plt.legend()
    plt.show()
# Out:
# /home/ubuntu/anaconda3/envs/pie-rl/lib/python3.8/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# ###################
#
#       SEED 0
#
# ###################
#
#  > Training DQN + HER
#
# Episode 0, episode return 0.0, last 20 avg 0.0
# Episode 1, episode return 1.0, last 20 avg 0.5
# Episode 2, episode return 0.0, last 20 avg 0.3333333333333333
# Episode 3, episode return 0.0, last 20 avg 0.25
# Episode 4, episode return 0.0, last 20 avg 0.2
# Episode 5, episode return 0.0, last 20 avg 0.16666666666666666
# Episode 6, episode return 0.0, last 20 avg 0.14285714285714285
# Episode 7, episode return 0.0, last 20 avg 0.125
# Episode 8, episode return 1.0, last 20 avg 0.2222222222222222
# Episode 9, episode return 1.0, last 20 avg 0.3
# Episode 10, episode return 1.0, last 20 avg 0.36363636363636365
# Episode 11, episode return 0.0, last 20 avg 0.3333333333333333
# Episode 12, episode return 0.0, last 20 avg 0.3076923076923077
# Episode 13, episode return 0.0, last 20 avg 0.2857142857142857
# Episode 14, episode return 0.0, last 20 avg 0.26666666666666666
# Episode 15, episode return 1.0, last 20 avg 0.3125
# Episode 16, episode return 1.0, last 20 avg 0.35294117647058826
# Episode 17, episode return 0.0, last 20 avg 0.3333333333333333
# Episode 18, episode return 1.0, last 20 avg 0.3684210526315789
# Episode 19, episode return 1.0, last 20 avg 0.4
# Episode 20, episode return 1.0, last 20 avg 0.45
# Episode 21, episode return 0.0, last 20 avg 0.4
# Episode 22, episode return 1.0, last 20 avg 0.45
# Episode 23, episode return 1.0, last 20 avg 0.5
# Episode 24, episode return 1.0, last 20 avg 0.55
# Episode 25, episode return 1.0, last 20 avg 0.6
# Episode 26, episode return 1.0, last 20 avg 0.65
# Episode 27, episode return 1.0, last 20 avg 0.7
# Episode 28, episode return 1.0, last 20 avg 0.7
# Episode 29, episode return 1.0, last 20 avg 0.7
# Episode 30, episode return 1.0, last 20 avg 0.7
# Episode 31, episode return 1.0, last 20 avg 0.75
# Episode 32, episode return 1.0, last 20 avg 0.8
# Episode 33, episode return 1.0, last 20 avg 0.85
# Episode 34, episode return 1.0, last 20 avg 0.9
# Episode 35, episode return 0.0, last 20 avg 0.85
# Episode 36, episode return 1.0, last 20 avg 0.85
# Episode 37, episode return 1.0, last 20 avg 0.9
# Episode 38, episode return 1.0, last 20 avg 0.9
# Episode 39, episode return 1.0, last 20 avg 0.9
# Episode 40, episode return 1.0, last 20 avg 0.9
# Episode 41, episode return 1.0, last 20 avg 0.95
# Episode 42, episode return 1.0, last 20 avg 0.95
# Episode 43, episode return 1.0, last 20 avg 0.95
# Episode 44, episode return 1.0, last 20 avg 0.95
# Episode 45, episode return 1.0, last 20 avg 0.95
# Episode 46, episode return 1.0, last 20 avg 0.95
# Episode 47, episode return 1.0, last 20 avg 0.95
# Episode 48, episode return 1.0, last 20 avg 0.95
# Episode 49, episode return 1.0, last 20 avg 0.95
# Episode 50, episode return 1.0, last 20 avg 0.95
# Episode 51, episode return 0.0, last 20 avg 0.9
# Episode 52, episode return 1.0, last 20 avg 0.9
# Episode 53, episode return 1.0, last 20 avg 0.9
# Episode 54, episode return 1.0, last 20 avg 0.9
# Episode 55, episode return 1.0, last 20 avg 0.95
# Episode 56, episode return 1.0, last 20 avg 0.95
# Episode 57, episode return 1.0, last 20 avg 0.95
# Episode 58, episode return 1.0, last 20 avg 0.95
# Episode 59, episode return 1.0, last 20 avg 0.95
# Episode 60, episode return 1.0, last 20 avg 0.95
# Episode 61, episode return 0.0, last 20 avg 0.9
# Episode 62, episode return 1.0, last 20 avg 0.9
# Episode 63, episode return 1.0, last 20 avg 0.9
# Episode 64, episode return 1.0, last 20 avg 0.9
# Episode 65, episode return 1.0, last 20 avg 0.9
# Episode 66, episode return 1.0, last 20 avg 0.9
# Episode 67, episode return 1.0, last 20 avg 0.9
# Episode 68, episode return 1.0, last 20 avg 0.9
# Episode 69, episode return 0.0, last 20 avg 0.85
# Episode 70, episode return 1.0, last 20 avg 0.85
# Episode 71, episode return 0.0, last 20 avg 0.85
# Episode 72, episode return 1.0, last 20 avg 0.85
# Episode 73, episode return 1.0, last 20 avg 0.85
# Episode 74, episode return 1.0, last 20 avg 0.85
# Episode 75, episode return 1.0, last 20 avg 0.85
# Episode 76, episode return 1.0, last 20 avg 0.85
# Episode 77, episode return 0.0, last 20 avg 0.8
# Episode 78, episode return 0.0, last 20 avg 0.75
# Episode 79, episode return 1.0, last 20 avg 0.75
# Episode 80, episode return 1.0, last 20 avg 0.75
# Episode 81, episode return 1.0, last 20 avg 0.8
# Episode 82, episode return 1.0, last 20 avg 0.8
# Episode 83, episode return 1.0, last 20 avg 0.8
# Episode 84, episode return 1.0, last 20 avg 0.8
# Episode 85, episode return 1.0, last 20 avg 0.8
# Episode 86, episode return 1.0, last 20 avg 0.8
# Episode 87, episode return 1.0, last 20 avg 0.8
# Episode 88, episode return 1.0, last 20 avg 0.8
# Episode 89, episode return 1.0, last 20 avg 0.85
# Episode 90, episode return 0.0, last 20 avg 0.8
# Episode 91, episode return 1.0, last 20 avg 0.85
# Episode 92, episode return 1.0, last 20 avg 0.85
# Episode 93, episode return 0.0, last 20 avg 0.8
# Episode 94, episode return 1.0, last 20 avg 0.8
# Episode 95, episode return 1.0, last 20 avg 0.8
# Episode 96, episode return 1.0, last 20 avg 0.8
# Episode 97, episode return 1.0, last 20 avg 0.85
# Episode 98, episode return 1.0, last 20 avg 0.9
# Episode 99, episode return 0.0, last 20 avg 0.85
# Episode 100, episode return 1.0, last 20 avg 0.85
# Episode 101, episode return 1.0, last 20 avg 0.85
# Episode 102, episode return 1.0, last 20 avg 0.85
# Episode 103, episode return 1.0, last 20 avg 0.85
# Episode 104, episode return 1.0, last 20 avg 0.85
# Episode 105, episode return 1.0, last 20 avg 0.85
# Episode 106, episode return 1.0, last 20 avg 0.85
# Episode 107, episode return 1.0, last 20 avg 0.85
# Episode 108, episode return 1.0, last 20 avg 0.85
# Episode 109, episode return 1.0, last 20 avg 0.85
# Episode 110, episode return 1.0, last 20 avg 0.9
# Episode 111, episode return 1.0, last 20 avg 0.9
# Episode 112, episode return 1.0, last 20 avg 0.9
# Episode 113, episode return 1.0, last 20 avg 0.95
# Episode 114, episode return 0.0, last 20 avg 0.9
# Episode 115, episode return 1.0, last 20 avg 0.9
# Episode 116, episode return 1.0, last 20 avg 0.9
# Episode 117, episode return 0.0, last 20 avg 0.85
# Episode 118, episode return 1.0, last 20 avg 0.85
# Episode 119, episode return 1.0, last 20 avg 0.9
# Episode 120, episode return 1.0, last 20 avg 0.9
# Episode 121, episode return 1.0, last 20 avg 0.9
# Episode 122, episode return 1.0, last 20 avg 0.9
# Episode 123, episode return 1.0, last 20 avg 0.9
# Episode 124, episode return 1.0, last 20 avg 0.9
# Episode 125, episode return 1.0, last 20 avg 0.9
# Episode 126, episode return 1.0, last 20 avg 0.9
# Episode 127, episode return 1.0, last 20 avg 0.9
# Episode 128, episode return 1.0, last 20 avg 0.9
# Episode 129, episode return 1.0, last 20 avg 0.9
# Episode 130, episode return 1.0, last 20 avg 0.9
# Episode 131, episode return 1.0, last 20 avg 0.9
# Episode 132, episode return 1.0, last 20 avg 0.9
# Episode 133, episode return 1.0, last 20 avg 0.9
# Episode 134, episode return 1.0, last 20 avg 0.95
# Episode 135, episode return 1.0, last 20 avg 0.95
# Episode 136, episode return 1.0, last 20 avg 0.95
# Episode 137, episode return 1.0, last 20 avg 1.0
# Episode 138, episode return 1.0, last 20 avg 1.0
# Episode 139, episode return 1.0, last 20 avg 1.0
# Episode 140, episode return 1.0, last 20 avg 1.0
# Episode 141, episode return 1.0, last 20 avg 1.0
# Episode 142, episode return 1.0, last 20 avg 1.0
# Episode 143, episode return 1.0, last 20 avg 1.0
# Episode 144, episode return 1.0, last 20 avg 1.0
# Episode 145, episode return 1.0, last 20 avg 1.0
# Episode 146, episode return 1.0, last 20 avg 1.0
# Episode 147, episode return 1.0, last 20 avg 1.0
# Episode 148, episode return 1.0, last 20 avg 1.0
# Episode 149, episode return 1.0, last 20 avg 1.0
# Episode 150, episode return 0.0, last 20 avg 0.95
# Episode 151, episode return 1.0, last 20 avg 0.95
# Episode 152, episode return 1.0, last 20 avg 0.95
# Episode 153, episode return 1.0, last 20 avg 0.95
# Episode 154, episode return 1.0, last 20 avg 0.95
# Episode 155, episode return 1.0, last 20 avg 0.95
# Episode 156, episode return 1.0, last 20 avg 0.95
# Episode 157, episode return 1.0, last 20 avg 0.95
# Episode 158, episode return 1.0, last 20 avg 0.95
# Episode 159, episode return 1.0, last 20 avg 0.95
# Episode 160, episode return 1.0, last 20 avg 0.95
# Episode 161, episode return 1.0, last 20 avg 0.95
# Episode 162, episode return 1.0, last 20 avg 0.95
# Episode 163, episode return 1.0, last 20 avg 0.95
# Episode 164, episode return 0.0, last 20 avg 0.9
# Episode 165, episode return 1.0, last 20 avg 0.9
# Episode 166, episode return 1.0, last 20 avg 0.9
# Episode 167, episode return 1.0, last 20 avg 0.9
# Episode 168, episode return 1.0, last 20 avg 0.9
# Episode 169, episode return 1.0, last 20 avg 0.9
# Episode 170, episode return 1.0, last 20 avg 0.95
# Episode 171, episode return 1.0, last 20 avg 0.95
# Episode 172, episode return 1.0, last 20 avg 0.95
# Episode 173, episode return 1.0, last 20 avg 0.95
# Episode 174, episode return 1.0, last 20 avg 0.95
# Episode 175, episode return 1.0, last 20 avg 0.95
# Episode 176, episode return 1.0, last 20 avg 0.95
# Episode 177, episode return 1.0, last 20 avg 0.95
# Episode 178, episode return 1.0, last 20 avg 0.95
# Episode 179, episode return 0.0, last 20 avg 0.9
# Episode 180, episode return 1.0, last 20 avg 0.9
# Episode 181, episode return 1.0, last 20 avg 0.9
# Episode 182, episode return 1.0, last 20 avg 0.9
# Episode 183, episode return 0.0, last 20 avg 0.85
# Episode 184, episode return 1.0, last 20 avg 0.9
# Episode 185, episode return 0.0, last 20 avg 0.85
# Episode 186, episode return 1.0, last 20 avg 0.85
# Episode 187, episode return 1.0, last 20 avg 0.85
# Episode 188, episode return 1.0, last 20 avg 0.85
# Episode 189, episode return 1.0, last 20 avg 0.85
# Episode 190, episode return 0.0, last 20 avg 0.8
# Episode 191, episode return 1.0, last 20 avg 0.8
# Episode 192, episode return 1.0, last 20 avg 0.8
# Episode 193, episode return 1.0, last 20 avg 0.8
# Episode 194, episode return 1.0, last 20 avg 0.8
# Episode 195, episode return 1.0, last 20 avg 0.8
# Episode 196, episode return 1.0, last 20 avg 0.8
# Episode 197, episode return 1.0, last 20 avg 0.8
# Episode 198, episode return 0.0, last 20 avg 0.75
# Episode 199, episode return 1.0, last 20 avg 0.8
# Episode 200, episode return 1.0, last 20 avg 0.8
# Episode 201, episode return 1.0, last 20 avg 0.8
# Episode 202, episode return 1.0, last 20 avg 0.8
# Episode 203, episode return 1.0, last 20 avg 0.85
# Episode 204, episode return 1.0, last 20 avg 0.85
# Episode 205, episode return 1.0, last 20 avg 0.9
# Episode 206, episode return 1.0, last 20 avg 0.9
# Episode 207, episode return 0.0, last 20 avg 0.85
# Episode 208, episode return 1.0, last 20 avg 0.85
# Episode 209, episode return 1.0, last 20 avg 0.85
# Episode 210, episode return 1.0, last 20 avg 0.9
# Episode 211, episode return 1.0, last 20 avg 0.9
# Episode 212, episode return 1.0, last 20 avg 0.9
# Episode 213, episode return 1.0, last 20 avg 0.9
# Episode 214, episode return 1.0, last 20 avg 0.9
# Episode 215, episode return 1.0, last 20 avg 0.9
# Episode 216, episode return 1.0, last 20 avg 0.9
# Episode 217, episode return 1.0, last 20 avg 0.9
# Episode 218, episode return 1.0, last 20 avg 0.95
# Episode 219, episode return 1.0, last 20 avg 0.95
# Episode 220, episode return 1.0, last 20 avg 0.95
# Episode 221, episode return 1.0, last 20 avg 0.95
# Episode 222, episode return 1.0, last 20 avg 0.95
# Episode 223, episode return 1.0, last 20 avg 0.95
# Episode 224, episode return 1.0, last 20 avg 0.95
# Episode 225, episode return 1.0, last 20 avg 0.95
# Episode 226, episode return 1.0, last 20 avg 0.95
# Episode 227, episode return 1.0, last 20 avg 1.0
# Episode 228, episode return 1.0, last 20 avg 1.0
# Episode 229, episode return 1.0, last 20 avg 1.0
# Episode 230, episode return 1.0, last 20 avg 1.0
# Episode 231, episode return 1.0, last 20 avg 1.0
# Episode 232, episode return 1.0, last 20 avg 1.0
# Episode 233, episode return 1.0, last 20 avg 1.0
# Episode 234, episode return 1.0, last 20 avg 1.0
# Episode 235, episode return 1.0, last 20 avg 1.0
# Episode 236, episode return 1.0, last 20 avg 1.0
# Episode 237, episode return 1.0, last 20 avg 1.0
# Episode 238, episode return 1.0, last 20 avg 1.0
# Episode 239, episode return 1.0, last 20 avg 1.0
# Episode 240, episode return 1.0, last 20 avg 1.0
# Episode 241, episode return 1.0, last 20 avg 1.0
# Episode 242, episode return 1.0, last 20 avg 1.0
# Episode 243, episode return 1.0, last 20 avg 1.0
# Episode 244, episode return 1.0, last 20 avg 1.0
# Episode 245, episode return 1.0, last 20 avg 1.0
# Episode 246, episode return 1.0, last 20 avg 1.0
# Episode 247, episode return 1.0, last 20 avg 1.0
# Episode 248, episode return 1.0, last 20 avg 1.0
# Episode 249, episode return 1.0, last 20 avg 1.0
# Episode 250, episode return 1.0, last 20 avg 1.0
# Episode 251, episode return 1.0, last 20 avg 1.0
# Episode 252, episode return 1.0, last 20 avg 1.0
# Episode 253, episode return 1.0, last 20 avg 1.0
# Episode 254, episode return 1.0, last 20 avg 1.0
# Episode 255, episode return 1.0, last 20 avg 1.0
# Episode 256, episode return 1.0, last 20 avg 1.0
# Episode 257, episode return 1.0, last 20 avg 1.0
# Episode 258, episode return 0.0, last 20 avg 0.95
# Episode 259, episode return 1.0, last 20 avg 0.95
# Episode 260, episode return 1.0, last 20 avg 0.95
# Episode 261, episode return 1.0, last 20 avg 0.95
# Episode 262, episode return 1.0, last 20 avg 0.95
# Episode 263, episode return 1.0, last 20 avg 0.95
# Episode 264, episode return 1.0, last 20 avg 0.95
# Episode 265, episode return 1.0, last 20 avg 0.95
# Episode 266, episode return 1.0, last 20 avg 0.95
# Episode 267, episode return 1.0, last 20 avg 0.95
# Episode 268, episode return 1.0, last 20 avg 0.95
# Episode 269, episode return 1.0, last 20 avg 0.95
# Episode 270, episode return 1.0, last 20 avg 0.95
# Episode 271, episode return 1.0, last 20 avg 0.95
# Episode 272, episode return 1.0, last 20 avg 0.95
# Episode 273, episode return 1.0, last 20 avg 0.95
# Episode 274, episode return 1.0, last 20 avg 0.95
# Episode 275, episode return 1.0, last 20 avg 0.95
# Episode 276, episode return 1.0, last 20 avg 0.95
# Episode 277, episode return 1.0, last 20 avg 0.95
# Episode 278, episode return 1.0, last 20 avg 1.0
# Episode 279, episode return 0.0, last 20 avg 0.95
# Episode 280, episode return 1.0, last 20 avg 0.95
# Episode 281, episode return 1.0, last 20 avg 0.95
# Episode 282, episode return 1.0, last 20 avg 0.95
# Episode 283, episode return 1.0, last 20 avg 0.95
# Episode 284, episode return 1.0, last 20 avg 0.95
# Episode 285, episode return 1.0, last 20 avg 0.95
# Episode 286, episode return 1.0, last 20 avg 0.95
# Episode 287, episode return 1.0, last 20 avg 0.95
# Episode 288, episode return 1.0, last 20 avg 0.95
# Episode 289, episode return 1.0, last 20 avg 0.95
# Episode 290, episode return 1.0, last 20 avg 0.95
# Episode 291, episode return 1.0, last 20 avg 0.95
# Episode 292, episode return 1.0, last 20 avg 0.95
# Episode 293, episode return 1.0, last 20 avg 0.95
# Episode 294, episode return 1.0, last 20 avg 0.95
# Episode 295, episode return 1.0, last 20 avg 0.95
# Episode 296, episode return 0.0, last 20 avg 0.9
# Episode 297, episode return 1.0, last 20 avg 0.9
# Episode 298, episode return 1.0, last 20 avg 0.9
# Episode 299, episode return 1.0, last 20 avg 0.95
#
#  > Training DQN
#
# Episode 0, episode return 0.0, last 20 avg 0.0
# Episode 1, episode return 0.0, last 20 avg 0.0
# Episode 2, episode return 1.0, last 20 avg 0.3333333333333333
# Episode 3, episode return 0.0, last 20 avg 0.25
# Episode 4, episode return 0.0, last 20 avg 0.2
# Episode 5, episode return 1.0, last 20 avg 0.3333333333333333
# Episode 6, episode return 0.0, last 20 avg 0.2857142857142857
# Episode 7, episode return 0.0, last 20 avg 0.25
# Episode 8, episode return 0.0, last 20 avg 0.2222222222222222
# Episode 9, episode return 0.0, last 20 avg 0.2
# Episode 10, episode return 0.0, last 20 avg 0.18181818181818182
# Episode 11, episode return 0.0, last 20 avg 0.16666666666666666
# Episode 12, episode return 0.0, last 20 avg 0.15384615384615385
# Episode 13, episode return 0.0, last 20 avg 0.14285714285714285
# Episode 14, episode return 0.0, last 20 avg 0.13333333333333333
# Episode 15, episode return 0.0, last 20 avg 0.125
# Episode 16, episode return 0.0, last 20 avg 0.11764705882352941
# Episode 17, episode return 0.0, last 20 avg 0.1111111111111111
# Episode 18, episode return 0.0, last 20 avg 0.10526315789473684
# Episode 19, episode return 1.0, last 20 avg 0.15
# Episode 20, episode return 0.0, last 20 avg 0.15
# Episode 21, episode return 0.0, last 20 avg 0.15
# Episode 22, episode return 0.0, last 20 avg 0.1
# Episode 23, episode return 0.0, last 20 avg 0.1
# Episode 24, episode return 0.0, last 20 avg 0.1
# Episode 25, episode return 0.0, last 20 avg 0.05
# Episode 26, episode return 0.0, last 20 avg 0.05
# Episode 27, episode return 0.0, last 20 avg 0.05
# Episode 28, episode return 0.0, last 20 avg 0.05
# Episode 29, episode return 1.0, last 20 avg 0.1
# Episode 30, episode return 1.0, last 20 avg 0.15
# Episode 31, episode return 0.0, last 20 avg 0.15
# Episode 32, episode return 1.0, last 20 avg 0.2
# Episode 33, episode return 0.0, last 20 avg 0.2
# Episode 34, episode return 0.0, last 20 avg 0.2
# Episode 35, episode return 0.0, last 20 avg 0.2
# Episode 36, episode return 0.0, last 20 avg 0.2
# Episode 37, episode return 0.0, last 20 avg 0.2
# Episode 38, episode return 0.0, last 20 avg 0.2
# Episode 39, episode return 1.0, last 20 avg 0.2
# Episode 40, episode return 0.0, last 20 avg 0.2
# Episode 41, episode return 0.0, last 20 avg 0.2
# Episode 42, episode return 0.0, last 20 avg 0.2
# Episode 43, episode return 0.0, last 20 avg 0.2
# Episode 44, episode return 0.0, last 20 avg 0.2
# Episode 45, episode return 0.0, last 20 avg 0.2
# Episode 46, episode return 1.0, last 20 avg 0.25
# Episode 47, episode return 0.0, last 20 avg 0.25
# Episode 48, episode return 0.0, last 20 avg 0.25
# Episode 49, episode return 0.0, last 20 avg 0.2
# Episode 50, episode return 1.0, last 20 avg 0.2
# Episode 51, episode return 0.0, last 20 avg 0.2
# Episode 52, episode return 1.0, last 20 avg 0.2
# Episode 53, episode return 0.0, last 20 avg 0.2
# Episode 54, episode return 0.0, last 20 avg 0.2
# Episode 55, episode return 0.0, last 20 avg 0.2
# Episode 56, episode return 0.0, last 20 avg 0.2
# Episode 57, episode return 0.0, last 20 avg 0.2
# Episode 58, episode return 1.0, last 20 avg 0.25
# Episode 59, episode return 0.0, last 20 avg 0.2
# Episode 60, episode return 0.0, last 20 avg 0.2
# Episode 61, episode return 0.0, last 20 avg 0.2
# Episode 62, episode return 0.0, last 20 avg 0.2
# Episode 63, episode return 0.0, last 20 avg 0.2
# Episode 64, episode return 0.0, last 20 avg 0.2
# Episode 65, episode return 1.0, last 20 avg 0.25
# Episode 66, episode return 0.0, last 20 avg 0.2
# Episode 67, episode return 0.0, last 20 avg 0.2
# Episode 68, episode return 0.0, last 20 avg 0.2
# Episode 69, episode return 0.0, last 20 avg 0.2
# Episode 70, episode return 0.0, last 20 avg 0.15
# Episode 71, episode return 0.0, last 20 avg 0.15
# Episode 72, episode return 0.0, last 20 avg 0.1
# Episode 73, episode return 0.0, last 20 avg 0.1
# Episode 74, episode return 0.0, last 20 avg 0.1
# Episode 75, episode return 0.0, last 20 avg 0.1
# Episode 76, episode return 0.0, last 20 avg 0.1
# Episode 77, episode return 0.0, last 20 avg 0.1
# Episode 78, episode return 0.0, last 20 avg 0.05
# Episode 79, episode return 0.0, last 20 avg 0.05
# Episode 80, episode return 0.0, last 20 avg 0.05
# Episode 81, episode return 0.0, last 20 avg 0.05
# Episode 82, episode return 1.0, last 20 avg 0.1
# Episode 83, episode return 0.0, last 20 avg 0.1
# Episode 84, episode return 0.0, last 20 avg 0.1
# Episode 85, episode return 1.0, last 20 avg 0.1
# Episode 86, episode return 1.0, last 20 avg 0.15
# Episode 87, episode return 0.0, last 20 avg 0.15
# Episode 88, episode return 0.0, last 20 avg 0.15
# Episode 89, episode return 0.0, last 20 avg 0.15
# Episode 90, episode return 0.0, last 20 avg 0.15
# Episode 91, episode return 0.0, last 20 avg 0.15
# Episode 92, episode return 1.0, last 20 avg 0.2
# Episode 93, episode return 1.0, last 20 avg 0.25
# Episode 94, episode return 0.0, last 20 avg 0.25
# Episode 95, episode return 0.0, last 20 avg 0.25
# Episode 96, episode return 0.0, last 20 avg 0.25
# Episode 97, episode return 0.0, last 20 avg 0.25
# Episode 98, episode return 1.0, last 20 avg 0.3
# Episode 99, episode return 0.0, last 20 avg 0.3
# Episode 100, episode return 1.0, last 20 avg 0.35
# Episode 101, episode return 0.0, last 20 avg 0.35
# Episode 102, episode return 0.0, last 20 avg 0.3
# Episode 103, episode return 0.0, last 20 avg 0.3
# Episode 104, episode return 0.0, last 20 avg 0.3
# Episode 105, episode return 0.0, last 20 avg 0.25
# Episode 106, episode return 0.0, last 20 avg 0.2
# Episode 107, episode return 0.0, last 20 avg 0.2
# Episode 108, episode return 1.0, last 20 avg 0.25
# Episode 109, episode return 1.0, last 20 avg 0.3
# Episode 110, episode return 0.0, last 20 avg 0.3
# Episode 111, episode return 1.0, last 20 avg 0.35
# Episode 112, episode return 1.0, last 20 avg 0.35
# Episode 113, episode return 1.0, last 20 avg 0.35
# Episode 114, episode return 0.0, last 20 avg 0.35
# Episode 115, episode return 0.0, last 20 avg 0.35
# Episode 116, episode return 1.0, last 20 avg 0.4
# Episode 117, episode return 0.0, last 20 avg 0.4
# Episode 118, episode return 1.0, last 20 avg 0.4
# Episode 119, episode return 1.0, last 20 avg 0.45
# Episode 120, episode return 0.0, last 20 avg 0.4
# Episode 121, episode return 1.0, last 20 avg 0.45
# Episode 122, episode return 0.0, last 20 avg 0.45
# Episode 123, episode return 0.0, last 20 avg 0.45
# Episode 124, episode return 0.0, last 20 avg 0.45
# Episode 125, episode return 0.0, last 20 avg 0.45
# Episode 126, episode return 1.0, last 20 avg 0.5
# Episode 127, episode return 1.0, last 20 avg 0.55
# Episode 128, episode return 0.0, last 20 avg 0.5
# Episode 129, episode return 1.0, last 20 avg 0.5
# Episode 130, episode return 1.0, last 20 avg 0.55
# Episode 131, episode return 0.0, last 20 avg 0.5
# Episode 132, episode return 0.0, last 20 avg 0.45
# Episode 133, episode return 0.0, last 20 avg 0.4
# Episode 134, episode return 1.0, last 20 avg 0.45
# Episode 135, episode return 0.0, last 20 avg 0.45
# Episode 136, episode return 0.0, last 20 avg 0.4
# Episode 137, episode return 1.0, last 20 avg 0.45
# Episode 138, episode return 0.0, last 20 avg 0.4
# Episode 139, episode return 0.0, last 20 avg 0.35
# Episode 140, episode return 0.0, last 20 avg 0.35
# Episode 141, episode return 1.0, last 20 avg 0.35
# Episode 142, episode return 1.0, last 20 avg 0.4
# Episode 143, episode return 0.0, last 20 avg 0.4
# Episode 144, episode return 1.0, last 20 avg 0.45
# Episode 145, episode return 1.0, last 20 avg 0.5
# Episode 146, episode return 1.0, last 20 avg 0.5
# Episode 147, episode return 0.0, last 20 avg 0.45
# Episode 148, episode return 1.0, last 20 avg 0.5
# Episode 149, episode return 0.0, last 20 avg 0.45
# Episode 150, episode return 1.0, last 20 avg 0.45
# Episode 151, episode return 1.0, last 20 avg 0.5
# Episode 152, episode return 0.0, last 20 avg 0.5
# Episode 153, episode return 0.0, last 20 avg 0.5
# Episode 154, episode return 0.0, last 20 avg 0.45
# Episode 155, episode return 0.0, last 20 avg 0.45
# Episode 156, episode return 1.0, last 20 avg 0.5
# Episode 157, episode return 1.0, last 20 avg 0.5
# Episode 158, episode return 0.0, last 20 avg 0.5
# Episode 159, episode return 1.0, last 20 avg 0.55
# Episode 160, episode return 1.0, last 20 avg 0.6
# Episode 161, episode return 0.0, last 20 avg 0.55
# Episode 162, episode return 0.0, last 20 avg 0.5
# Episode 163, episode return 1.0, last 20 avg 0.55
# Episode 164, episode return 0.0, last 20 avg 0.5
# Episode 165, episode return 0.0, last 20 avg 0.45
# Episode 166, episode return 1.0, last 20 avg 0.45
# Episode 167, episode return 1.0, last 20 avg 0.5
# Episode 168, episode return 0.0, last 20 avg 0.45
# Episode 169, episode return 0.0, last 20 avg 0.45
# Episode 170, episode return 0.0, last 20 avg 0.4
# Episode 171, episode return 1.0, last 20 avg 0.4
# Episode 172, episode return 1.0, last 20 avg 0.45
# Episode 173, episode return 0.0, last 20 avg 0.45
# Episode 174, episode return 1.0, last 20 avg 0.5
# Episode 175, episode return 0.0, last 20 avg 0.5
# Episode 176, episode return 1.0, last 20 avg 0.5
# Episode 177, episode return 1.0, last 20 avg 0.5
# Episode 178, episode return 0.0, last 20 avg 0.5
# Episode 179, episode return 1.0, last 20 avg 0.5
# Episode 180, episode return 1.0, last 20 avg 0.5
# Episode 181, episode return 0.0, last 20 avg 0.5
# Episode 182, episode return 0.0, last 20 avg 0.5
# Episode 183, episode return 0.0, last 20 avg 0.45
# Episode 184, episode return 1.0, last 20 avg 0.5
# Episode 185, episode return 1.0, last 20 avg 0.55
# Episode 186, episode return 1.0, last 20 avg 0.55
# Episode 187, episode return 0.0, last 20 avg 0.5
# Episode 188, episode return 0.0, last 20 avg 0.5
# Episode 189, episode return 1.0, last 20 avg 0.55
# Episode 190, episode return 1.0, last 20 avg 0.6
# Episode 191, episode return 0.0, last 20 avg 0.55
# Episode 192, episode return 1.0, last 20 avg 0.55
# Episode 193, episode return 1.0, last 20 avg 0.6
# Episode 194, episode return 0.0, last 20 avg 0.55
# Episode 195, episode return 1.0, last 20 avg 0.6
# Episode 196, episode return 1.0, last 20 avg 0.6
# Episode 197, episode return 1.0, last 20 avg 0.6
# Episode 198, episode return 1.0, last 20 avg 0.65
# Episode 199, episode return 0.0, last 20 avg 0.6
# Episode 200, episode return 0.0, last 20 avg 0.55
# Episode 201, episode return 0.0, last 20 avg 0.55
# Episode 202, episode return 1.0, last 20 avg 0.6
# Episode 203, episode return 1.0, last 20 avg 0.65
# Episode 204, episode return 1.0, last 20 avg 0.65
# Episode 205, episode return 1.0, last 20 avg 0.65
# Episode 206, episode return 0.0, last 20 avg 0.6
# Episode 207, episode return 1.0, last 20 avg 0.65
# Episode 208, episode return 1.0, last 20 avg 0.7
# Episode 209, episode return 0.0, last 20 avg 0.65
# Episode 210, episode return 1.0, last 20 avg 0.65
# Episode 211, episode return 1.0, last 20 avg 0.7
# Episode 212, episode return 1.0, last 20 avg 0.7
# Episode 213, episode return 1.0, last 20 avg 0.7
# Episode 214, episode return 1.0, last 20 avg 0.75
# Episode 215, episode return 0.0, last 20 avg 0.7
# Episode 216, episode return 1.0, last 20 avg 0.7
# Episode 217, episode return 1.0, last 20 avg 0.7
# Episode 218, episode return 1.0, last 20 avg 0.7
# Episode 219, episode return 0.0, last 20 avg 0.7
# Episode 220, episode return 1.0, last 20 avg 0.75
# Episode 221, episode return 1.0, last 20 avg 0.8
# Episode 222, episode return 1.0, last 20 avg 0.8
# Episode 223, episode return 1.0, last 20 avg 0.8
# Episode 224, episode return 1.0, last 20 avg 0.8
# Episode 225, episode return 1.0, last 20 avg 0.8
# Episode 226, episode return 1.0, last 20 avg 0.85
# Episode 227, episode return 1.0, last 20 avg 0.85
# Episode 228, episode return 1.0, last 20 avg 0.85
# Episode 229, episode return 1.0, last 20 avg 0.9
# Episode 230, episode return 0.0, last 20 avg 0.85
# Episode 231, episode return 0.0, last 20 avg 0.8
# Episode 232, episode return 1.0, last 20 avg 0.8
# Episode 233, episode return 1.0, last 20 avg 0.8
# Episode 234, episode return 0.0, last 20 avg 0.75
# Episode 235, episode return 0.0, last 20 avg 0.75
# Episode 236, episode return 0.0, last 20 avg 0.7
# Episode 237, episode return 1.0, last 20 avg 0.7
# Episode 238, episode return 0.0, last 20 avg 0.65
# Episode 239, episode return 1.0, last 20 avg 0.7
# Episode 240, episode return 1.0, last 20 avg 0.7
# Episode 241, episode return 1.0, last 20 avg 0.7
# Episode 242, episode return 0.0, last 20 avg 0.65
# Episode 243, episode return 1.0, last 20 avg 0.65
# Episode 244, episode return 1.0, last 20 avg 0.65
# Episode 245, episode return 1.0, last 20 avg 0.65
# Episode 246, episode return 1.0, last 20 avg 0.65
# Episode 247, episode return 1.0, last 20 avg 0.65
# Episode 248, episode return 1.0, last 20 avg 0.65
# Episode 249, episode return 1.0, last 20 avg 0.65
# Episode 250, episode return 0.0, last 20 avg 0.65
# Episode 251, episode return 1.0, last 20 avg 0.7
# Episode 252, episode return 1.0, last 20 avg 0.7
# Episode 253, episode return 0.0, last 20 avg 0.65
# Episode 254, episode return 1.0, last 20 avg 0.7
# Episode 255, episode return 1.0, last 20 avg 0.75
# Episode 256, episode return 1.0, last 20 avg 0.8
# Episode 257, episode return 1.0, last 20 avg 0.8
# Episode 258, episode return 1.0, last 20 avg 0.85
# Episode 259, episode return 1.0, last 20 avg 0.85
# Episode 260, episode return 1.0, last 20 avg 0.85
# Episode 261, episode return 1.0, last 20 avg 0.85
# Episode 262, episode return 1.0, last 20 avg 0.9
# Episode 263, episode return 1.0, last 20 avg 0.9
# Episode 264, episode return 1.0, last 20 avg 0.9
# Episode 265, episode return 1.0, last 20 avg 0.9
# Episode 266, episode return 1.0, last 20 avg 0.9
# Episode 267, episode return 1.0, last 20 avg 0.9
# Episode 268, episode return 1.0, last 20 avg 0.9
# Episode 269, episode return 1.0, last 20 avg 0.9
# Episode 270, episode return 0.0, last 20 avg 0.9
# Episode 271, episode return 0.0, last 20 avg 0.85
# Episode 272, episode return 1.0, last 20 avg 0.85
# Episode 273, episode return 0.0, last 20 avg 0.85
# Episode 274, episode return 0.0, last 20 avg 0.8
# Episode 275, episode return 1.0, last 20 avg 0.8
# Episode 276, episode return 0.0, last 20 avg 0.75
# Episode 277, episode return 0.0, last 20 avg 0.7
# Episode 278, episode return 1.0, last 20 avg 0.7
# Episode 279, episode return 1.0, last 20 avg 0.7
# Episode 280, episode return 0.0, last 20 avg 0.65
# Episode 281, episode return 0.0, last 20 avg 0.6
# Episode 282, episode return 1.0, last 20 avg 0.6
# Episode 283, episode return 1.0, last 20 avg 0.6
# Episode 284, episode return 1.0, last 20 avg 0.6
# Episode 285, episode return 1.0, last 20 avg 0.6
# Episode 286, episode return 1.0, last 20 avg 0.6
# Episode 287, episode return 1.0, last 20 avg 0.6
# Episode 288, episode return 1.0, last 20 avg 0.6
# Episode 289, episode return 1.0, last 20 avg 0.6
# Episode 290, episode return 0.0, last 20 avg 0.6
# Episode 291, episode return 1.0, last 20 avg 0.65
# Episode 292, episode return 0.0, last 20 avg 0.6
# Episode 293, episode return 1.0, last 20 avg 0.65
# Episode 294, episode return 1.0, last 20 avg 0.7
# Episode 295, episode return 1.0, last 20 avg 0.7
# Episode 296, episode return 1.0, last 20 avg 0.75
# Episode 297, episode return 1.0, last 20 avg 0.8
# Episode 298, episode return 1.0, last 20 avg 0.8
# Episode 299, episode return 1.0, last 20 avg 0.8
# ###################
#
#       SEED 1
#
# ###################
#
#  > Training DQN + HER
#
# Episode 0, episode return 0.0, last 20 avg 0.0
# Episode 1, episode return 0.0, last 20 avg 0.0
# Episode 2, episode return 0.0, last 20 avg 0.0
# Episode 3, episode return 0.0, last 20 avg 0.0
# Episode 4, episode return 0.0, last 20 avg 0.0
# Episode 5, episode return 0.0, last 20 avg 0.0
# Episode 6, episode return 0.0, last 20 avg 0.0
# Episode 7, episode return 0.0, last 20 avg 0.0
# Episode 8, episode return 1.0, last 20 avg 0.1111111111111111
# Episode 9, episode return 0.0, last 20 avg 0.1
# Episode 10, episode return 0.0, last 20 avg 0.09090909090909091
# Episode 11, episode return 1.0, last 20 avg 0.16666666666666666
# Episode 12, episode return 1.0, last 20 avg 0.23076923076923078
# Episode 13, episode return 1.0, last 20 avg 0.2857142857142857
# Episode 14, episode return 1.0, last 20 avg 0.3333333333333333
# Episode 15, episode return 1.0, last 20 avg 0.375
# Episode 16, episode return 1.0, last 20 avg 0.4117647058823529
# Episode 17, episode return 1.0, last 20 avg 0.4444444444444444
# Episode 18, episode return 0.0, last 20 avg 0.42105263157894735
# Episode 19, episode return 0.0, last 20 avg 0.4
# Episode 20, episode return 1.0, last 20 avg 0.45
# Episode 21, episode return 0.0, last 20 avg 0.45
# Episode 22, episode return 1.0, last 20 avg 0.5
# Episode 23, episode return 1.0, last 20 avg 0.55
# Episode 24, episode return 1.0, last 20 avg 0.6
# Episode 25, episode return 1.0, last 20 avg 0.65
# Episode 26, episode return 1.0, last 20 avg 0.7
# Episode 27, episode return 0.0, last 20 avg 0.7
# Episode 28, episode return 0.0, last 20 avg 0.65
# Episode 29, episode return 1.0, last 20 avg 0.7
# Episode 30, episode return 1.0, last 20 avg 0.75
# Episode 31, episode return 1.0, last 20 avg 0.75
# Episode 32, episode return 1.0, last 20 avg 0.75
# Episode 33, episode return 1.0, last 20 avg 0.75
# Episode 34, episode return 1.0, last 20 avg 0.75
# Episode 35, episode return 1.0, last 20 avg 0.75
# Episode 36, episode return 1.0, last 20 avg 0.75
# Episode 37, episode return 1.0, last 20 avg 0.75
# Episode 38, episode return 1.0, last 20 avg 0.8
# Episode 39, episode return 1.0, last 20 avg 0.85
# Episode 40, episode return 1.0, last 20 avg 0.85
# Episode 41, episode return 1.0, last 20 avg 0.9
# Episode 42, episode return 0.0, last 20 avg 0.85
# Episode 43, episode return 1.0, last 20 avg 0.85
# Episode 44, episode return 1.0, last 20 avg 0.85
# Episode 45, episode return 0.0, last 20 avg 0.8
# Episode 46, episode return 0.0, last 20 avg 0.75
# Episode 47, episode return 1.0, last 20 avg 0.8
# Episode 48, episode return 1.0, last 20 avg 0.85
# Episode 49, episode return 1.0, last 20 avg 0.85
# Episode 50, episode return 1.0, last 20 avg 0.85
# Episode 51, episode return 1.0, last 20 avg 0.85
# Episode 52, episode return 1.0, last 20 avg 0.85
# Episode 53, episode return 1.0, last 20 avg 0.85
# Episode 54, episode return 0.0, last 20 avg 0.8
# Episode 55, episode return 1.0, last 20 avg 0.8
# Episode 56, episode return 1.0, last 20 avg 0.8
# Episode 57, episode return 1.0, last 20 avg 0.8
# Episode 58, episode return 0.0, last 20 avg 0.75
# Episode 59, episode return 0.0, last 20 avg 0.7
# Episode 60, episode return 1.0, last 20 avg 0.7
# Episode 61, episode return 1.0, last 20 avg 0.7
# Episode 62, episode return 1.0, last 20 avg 0.75
# Episode 63, episode return 1.0, last 20 avg 0.75
# Episode 64, episode return 0.0, last 20 avg 0.7
# Episode 65, episode return 1.0, last 20 avg 0.75
# Episode 66, episode return 1.0, last 20 avg 0.8
# Episode 67, episode return 1.0, last 20 avg 0.8
# Episode 68, episode return 0.0, last 20 avg 0.75
# Episode 69, episode return 1.0, last 20 avg 0.75
# Episode 70, episode return 1.0, last 20 avg 0.75
# Episode 71, episode return 1.0, last 20 avg 0.75
# Episode 72, episode return 1.0, last 20 avg 0.75
# Episode 73, episode return 1.0, last 20 avg 0.75
# Episode 74, episode return 1.0, last 20 avg 0.8
# Episode 75, episode return 0.0, last 20 avg 0.75
# Episode 76, episode return 1.0, last 20 avg 0.75
# Episode 77, episode return 1.0, last 20 avg 0.75
# Episode 78, episode return 1.0, last 20 avg 0.8
# Episode 79, episode return 0.0, last 20 avg 0.8
# Episode 80, episode return 1.0, last 20 avg 0.8
# Episode 81, episode return 1.0, last 20 avg 0.8
# Episode 82, episode return 1.0, last 20 avg 0.8
# Episode 83, episode return 1.0, last 20 avg 0.8
# Episode 84, episode return 1.0, last 20 avg 0.85
# Episode 85, episode return 1.0, last 20 avg 0.85
# Episode 86, episode return 0.0, last 20 avg 0.8
# Episode 87, episode return 1.0, last 20 avg 0.8
# Episode 88, episode return 1.0, last 20 avg 0.85
# Episode 89, episode return 1.0, last 20 avg 0.85
# Episode 90, episode return 1.0, last 20 avg 0.85
# Episode 91, episode return 1.0, last 20 avg 0.85
# Episode 92, episode return 0.0, last 20 avg 0.8
# Episode 93, episode return 1.0, last 20 avg 0.8
# Episode 94, episode return 1.0, last 20 avg 0.8
# Episode 95, episode return 1.0, last 20 avg 0.85
# Episode 96, episode return 1.0, last 20 avg 0.85
# Episode 97, episode return 1.0, last 20 avg 0.85
# Episode 98, episode return 1.0, last 20 avg 0.85
# Episode 99, episode return 1.0, last 20 avg 0.9
# Episode 100, episode return 1.0, last 20 avg 0.9
# Episode 101, episode return 1.0, last 20 avg 0.9
# Episode 102, episode return 1.0, last 20 avg 0.9
# Episode 103, episode return 0.0, last 20 avg 0.85
# Episode 104, episode return 1.0, last 20 avg 0.85
# Episode 105, episode return 1.0, last 20 avg 0.85
# Episode 106, episode return 0.0, last 20 avg 0.85
# Episode 107, episode return 0.0, last 20 avg 0.8
# Episode 108, episode return 0.0, last 20 avg 0.75
# Episode 109, episode return 1.0, last 20 avg 0.75
# Episode 110, episode return 1.0, last 20 avg 0.75
# Episode 111, episode return 1.0, last 20 avg 0.75
# Episode 112, episode return 1.0, last 20 avg 0.8
# Episode 113, episode return 1.0, last 20 avg 0.8
# Episode 114, episode return 1.0, last 20 avg 0.8
# Episode 115, episode return 1.0, last 20 avg 0.8
# Episode 116, episode return 1.0, last 20 avg 0.8
# Episode 117, episode return 1.0, last 20 avg 0.8
# Episode 118, episode return 1.0, last 20 avg 0.8
# Episode 119, episode return 1.0, last 20 avg 0.8
# Episode 120, episode return 1.0, last 20 avg 0.8
# Episode 121, episode return 1.0, last 20 avg 0.8
# Episode 122, episode return 1.0, last 20 avg 0.8
# Episode 123, episode return 1.0, last 20 avg 0.85
# Episode 124, episode return 1.0, last 20 avg 0.85
# Episode 125, episode return 0.0, last 20 avg 0.8
# Episode 126, episode return 1.0, last 20 avg 0.85
# Episode 127, episode return 1.0, last 20 avg 0.9
# Episode 128, episode return 1.0, last 20 avg 0.95
# Episode 129, episode return 1.0, last 20 avg 0.95
# Episode 130, episode return 1.0, last 20 avg 0.95
# Episode 131, episode return 1.0, last 20 avg 0.95
# Episode 132, episode return 1.0, last 20 avg 0.95
# Episode 133, episode return 1.0, last 20 avg 0.95
# Episode 134, episode return 1.0, last 20 avg 0.95
# Episode 135, episode return 1.0, last 20 avg 0.95
# Episode 136, episode return 1.0, last 20 avg 0.95
# Episode 137, episode return 1.0, last 20 avg 0.95
# Episode 138, episode return 1.0, last 20 avg 0.95
# Episode 139, episode return 1.0, last 20 avg 0.95
# Episode 140, episode return 1.0, last 20 avg 0.95
# Episode 141, episode return 1.0, last 20 avg 0.95
# Episode 142, episode return 1.0, last 20 avg 0.95
# Episode 143, episode return 1.0, last 20 avg 0.95
# Episode 144, episode return 1.0, last 20 avg 0.95
# Episode 145, episode return 1.0, last 20 avg 1.0
# Episode 146, episode return 1.0, last 20 avg 1.0
# Episode 147, episode return 1.0, last 20 avg 1.0
# Episode 148, episode return 0.0, last 20 avg 0.95
# Episode 149, episode return 1.0, last 20 avg 0.95
# Episode 150, episode return 1.0, last 20 avg 0.95
# Episode 151, episode return 1.0, last 20 avg 0.95
# Episode 152, episode return 1.0, last 20 avg 0.95
# Episode 153, episode return 1.0, last 20 avg 0.95
# Episode 154, episode return 1.0, last 20 avg 0.95
# Episode 155, episode return 0.0, last 20 avg 0.9
# Episode 156, episode return 1.0, last 20 avg 0.9
# Episode 157, episode return 1.0, last 20 avg 0.9
# Episode 158, episode return 0.0, last 20 avg 0.85
# Episode 159, episode return 1.0, last 20 avg 0.85
# Episode 160, episode return 1.0, last 20 avg 0.85
# Episode 161, episode return 1.0, last 20 avg 0.85
# Episode 162, episode return 1.0, last 20 avg 0.85
# Episode 163, episode return 0.0, last 20 avg 0.8
# Episode 164, episode return 1.0, last 20 avg 0.8
# Episode 165, episode return 1.0, last 20 avg 0.8
# Episode 166, episode return 1.0, last 20 avg 0.8
# Episode 167, episode return 1.0, last 20 avg 0.8
# Episode 168, episode return 1.0, last 20 avg 0.85
# Episode 169, episode return 1.0, last 20 avg 0.85
# Episode 170, episode return 1.0, last 20 avg 0.85
# Episode 171, episode return 1.0, last 20 avg 0.85
# Episode 172, episode return 1.0, last 20 avg 0.85
# Episode 173, episode return 1.0, last 20 avg 0.85
# Episode 174, episode return 1.0, last 20 avg 0.85
# Episode 175, episode return 0.0, last 20 avg 0.85
# Episode 176, episode return 1.0, last 20 avg 0.85
# Episode 177, episode return 1.0, last 20 avg 0.85
# Episode 178, episode return 1.0, last 20 avg 0.9
# Episode 179, episode return 1.0, last 20 avg 0.9
# Episode 180, episode return 0.0, last 20 avg 0.85
# Episode 181, episode return 1.0, last 20 avg 0.85
# Episode 182, episode return 1.0, last 20 avg 0.85
# Episode 183, episode return 1.0, last 20 avg 0.9
# Episode 184, episode return 1.0, last 20 avg 0.9
# Episode 185, episode return 0.0, last 20 avg 0.85
# Episode 186, episode return 1.0, last 20 avg 0.85
# Episode 187, episode return 1.0, last 20 avg 0.85
# Episode 188, episode return 1.0, last 20 avg 0.85
# Episode 189, episode return 1.0, last 20 avg 0.85
# Episode 190, episode return 1.0, last 20 avg 0.85
# Episode 191, episode return 1.0, last 20 avg 0.85
# Episode 192, episode return 1.0, last 20 avg 0.85
# Episode 193, episode return 0.0, last 20 avg 0.8
# Episode 194, episode return 1.0, last 20 avg 0.8
# Episode 195, episode return 1.0, last 20 avg 0.85
# Episode 196, episode return 1.0, last 20 avg 0.85
# Episode 197, episode return 1.0, last 20 avg 0.85
# Episode 198, episode return 1.0, last 20 avg 0.85
# Episode 199, episode return 1.0, last 20 avg 0.85
# Episode 200, episode return 1.0, last 20 avg 0.9
# Episode 201, episode return 1.0, last 20 avg 0.9
# Episode 202, episode return 1.0, last 20 avg 0.9
# Episode 203, episode return 1.0, last 20 avg 0.9
# Episode 204, episode return 1.0, last 20 avg 0.9
# Episode 205, episode return 1.0, last 20 avg 0.95
# Episode 206, episode return 1.0, last 20 avg 0.95
# Episode 207, episode return 1.0, last 20 avg 0.95
# Episode 208, episode return 1.0, last 20 avg 0.95
# Episode 209, episode return 1.0, last 20 avg 0.95
# Episode 210, episode return 1.0, last 20 avg 0.95
# Episode 211, episode return 1.0, last 20 avg 0.95
# Episode 212, episode return 1.0, last 20 avg 0.95
# Episode 213, episode return 0.0, last 20 avg 0.95
# Episode 214, episode return 1.0, last 20 avg 0.95
# Episode 215, episode return 0.0, last 20 avg 0.9
# Episode 216, episode return 1.0, last 20 avg 0.9
# Episode 217, episode return 0.0, last 20 avg 0.85
# Episode 218, episode return 1.0, last 20 avg 0.85
# Episode 219, episode return 1.0, last 20 avg 0.85
# Episode 220, episode return 1.0, last 20 avg 0.85
# Episode 221, episode return 1.0, last 20 avg 0.85
# Episode 222, episode return 1.0, last 20 avg 0.85
# Episode 223, episode return 1.0, last 20 avg 0.85
# Episode 224, episode return 1.0, last 20 avg 0.85
# Episode 225, episode return 1.0, last 20 avg 0.85
# Episode 226, episode return 1.0, last 20 avg 0.85
# Episode 227, episode return 1.0, last 20 avg 0.85
# Episode 228, episode return 1.0, last 20 avg 0.85
# Episode 229, episode return 1.0, last 20 avg 0.85
# Episode 230, episode return 1.0, last 20 avg 0.85
# Episode 231, episode return 1.0, last 20 avg 0.85
# Episode 232, episode return 1.0, last 20 avg 0.85
# Episode 233, episode return 1.0, last 20 avg 0.9
# Episode 234, episode return 1.0, last 20 avg 0.9
# Episode 235, episode return 1.0, last 20 avg 0.95
# Episode 236, episode return 1.0, last 20 avg 0.95
# Episode 237, episode return 1.0, last 20 avg 1.0
# Episode 238, episode return 1.0, last 20 avg 1.0
# Episode 239, episode return 1.0, last 20 avg 1.0
# Episode 240, episode return 1.0, last 20 avg 1.0
# Episode 241, episode return 1.0, last 20 avg 1.0
# Episode 242, episode return 1.0, last 20 avg 1.0
# Episode 243, episode return 1.0, last 20 avg 1.0
# Episode 244, episode return 1.0, last 20 avg 1.0
# Episode 245, episode return 1.0, last 20 avg 1.0
# Episode 246, episode return 1.0, last 20 avg 1.0
# Episode 247, episode return 1.0, last 20 avg 1.0
# Episode 248, episode return 1.0, last 20 avg 1.0
# Episode 249, episode return 1.0, last 20 avg 1.0
# Episode 250, episode return 1.0, last 20 avg 1.0
# Episode 251, episode return 1.0, last 20 avg 1.0
# Episode 252, episode return 1.0, last 20 avg 1.0
# Episode 253, episode return 1.0, last 20 avg 1.0
# Episode 254, episode return 0.0, last 20 avg 0.95
# Episode 255, episode return 1.0, last 20 avg 0.95
# Episode 256, episode return 1.0, last 20 avg 0.95
# Episode 257, episode return 0.0, last 20 avg 0.9
# Episode 258, episode return 1.0, last 20 avg 0.9
# Episode 259, episode return 1.0, last 20 avg 0.9
# Episode 260, episode return 1.0, last 20 avg 0.9
# Episode 261, episode return 1.0, last 20 avg 0.9
# Episode 262, episode return 1.0, last 20 avg 0.9
# Episode 263, episode return 1.0, last 20 avg 0.9
# Episode 264, episode return 1.0, last 20 avg 0.9
# Episode 265, episode return 1.0, last 20 avg 0.9
# Episode 266, episode return 1.0, last 20 avg 0.9
# Episode 267, episode return 0.0, last 20 avg 0.85
# Episode 268, episode return 1.0, last 20 avg 0.85
# Episode 269, episode return 1.0, last 20 avg 0.85
# Episode 270, episode return 0.0, last 20 avg 0.8
# Episode 271, episode return 1.0, last 20 avg 0.8
# Episode 272, episode return 0.0, last 20 avg 0.75
# Episode 273, episode return 0.0, last 20 avg 0.7
# Episode 274, episode return 1.0, last 20 avg 0.75
# Episode 275, episode return 1.0, last 20 avg 0.75
# Episode 276, episode return 1.0, last 20 avg 0.75
# Episode 277, episode return 1.0, last 20 avg 0.8
# Episode 278, episode return 0.0, last 20 avg 0.75
# Episode 279, episode return 1.0, last 20 avg 0.75
# Episode 280, episode return 1.0, last 20 avg 0.75
# Episode 281, episode return 1.0, last 20 avg 0.75
# Episode 282, episode return 1.0, last 20 avg 0.75
# Episode 283, episode return 1.0, last 20 avg 0.75
# Episode 284, episode return 0.0, last 20 avg 0.7
# Episode 285, episode return 0.0, last 20 avg 0.65
# Episode 286, episode return 1.0, last 20 avg 0.65
# Episode 287, episode return 1.0, last 20 avg 0.7
# Episode 288, episode return 1.0, last 20 avg 0.7
# Episode 289, episode return 1.0, last 20 avg 0.7
# Episode 290, episode return 1.0, last 20 avg 0.75
# Episode 291, episode return 1.0, last 20 avg 0.75
# Episode 292, episode return 1.0, last 20 avg 0.8
# Episode 293, episode return 1.0, last 20 avg 0.85
# Episode 294, episode return 1.0, last 20 avg 0.85
# Episode 295, episode return 1.0, last 20 avg 0.85
# Episode 296, episode return 1.0, last 20 avg 0.85
# Episode 297, episode return 1.0, last 20 avg 0.85
# Episode 298, episode return 1.0, last 20 avg 0.9
# Episode 299, episode return 1.0, last 20 avg 0.9
#
#  > Training DQN
#
# Episode 0, episode return 0.0, last 20 avg 0.0
# Episode 1, episode return 0.0, last 20 avg 0.0
# Episode 2, episode return 0.0, last 20 avg 0.0
# Episode 3, episode return 0.0, last 20 avg 0.0
# Episode 4, episode return 0.0, last 20 avg 0.0
# Episode 5, episode return 0.0, last 20 avg 0.0
# Episode 6, episode return 0.0, last 20 avg 0.0
# Episode 7, episode return 0.0, last 20 avg 0.0
# Episode 8, episode return 0.0, last 20 avg 0.0
# Episode 9, episode return 0.0, last 20 avg 0.0
# Episode 10, episode return 0.0, last 20 avg 0.0
# Episode 11, episode return 0.0, last 20 avg 0.0
# Episode 12, episode return 0.0, last 20 avg 0.0
# Episode 13, episode return 0.0, last 20 avg 0.0
# Episode 14, episode return 0.0, last 20 avg 0.0
# Episode 15, episode return 0.0, last 20 avg 0.0
# Episode 16, episode return 0.0, last 20 avg 0.0
# Episode 17, episode return 0.0, last 20 avg 0.0
# Episode 18, episode return 0.0, last 20 avg 0.0
# Episode 19, episode return 0.0, last 20 avg 0.0
# Episode 20, episode return 0.0, last 20 avg 0.0
# Episode 21, episode return 0.0, last 20 avg 0.0
# Episode 22, episode return 0.0, last 20 avg 0.0
# Episode 23, episode return 0.0, last 20 avg 0.0
# Episode 24, episode return 0.0, last 20 avg 0.0
# Episode 25, episode return 0.0, last 20 avg 0.0
# Episode 26, episode return 0.0, last 20 avg 0.0
# Episode 27, episode return 0.0, last 20 avg 0.0
# Episode 28, episode return 0.0, last 20 avg 0.0
# Episode 29, episode return 0.0, last 20 avg 0.0
# Episode 30, episode return 0.0, last 20 avg 0.0
# Episode 31, episode return 0.0, last 20 avg 0.0
# Episode 32, episode return 0.0, last 20 avg 0.0
# Episode 33, episode return 0.0, last 20 avg 0.0
# Episode 34, episode return 0.0, last 20 avg 0.0
# Episode 35, episode return 0.0, last 20 avg 0.0
# Episode 36, episode return 0.0, last 20 avg 0.0
# Episode 37, episode return 0.0, last 20 avg 0.0
# Episode 38, episode return 0.0, last 20 avg 0.0
# Episode 39, episode return 0.0, last 20 avg 0.0
# Episode 40, episode return 0.0, last 20 avg 0.0
# Episode 41, episode return 0.0, last 20 avg 0.0
# Episode 42, episode return 0.0, last 20 avg 0.0
# Episode 43, episode return 0.0, last 20 avg 0.0
# Episode 44, episode return 0.0, last 20 avg 0.0
# Episode 45, episode return 0.0, last 20 avg 0.0
# Episode 46, episode return 0.0, last 20 avg 0.0
# Episode 47, episode return 0.0, last 20 avg 0.0
# Episode 48, episode return 0.0, last 20 avg 0.0
# Episode 49, episode return 0.0, last 20 avg 0.0
# Episode 50, episode return 1.0, last 20 avg 0.05
# Episode 51, episode return 0.0, last 20 avg 0.05
# Episode 52, episode return 0.0, last 20 avg 0.05
# Episode 53, episode return 0.0, last 20 avg 0.05
# Episode 54, episode return 0.0, last 20 avg 0.05
# Episode 55, episode return 0.0, last 20 avg 0.05
# Episode 56, episode return 0.0, last 20 avg 0.05
# Episode 57, episode return 0.0, last 20 avg 0.05
# Episode 58, episode return 0.0, last 20 avg 0.05
# ...
# Episode 278, episode return 1.0, last 20 avg 0.95
# Episode 279, episode return 1.0, last 20 avg 0.95
# Episode 280, episode return 1.0, last 20 avg 0.95
# Episode 281, episode return 1.0, last 20 avg 0.95
# Episode 282, episode return 1.0, last 20 avg 0.95
# Episode 283, episode return 0.0, last 20 avg 0.9
# Episode 284, episode return 1.0, last 20 avg 0.9
# Episode 285, episode return 1.0, last 20 avg 0.9
# Episode 286, episode return 1.0, last 20 avg 0.9
# Episode 287, episode return 0.0, last 20 avg 0.85
# Episode 288, episode return 1.0, last 20 avg 0.85
# Episode 289, episode return 1.0, last 20 avg 0.85
# Episode 290, episode return 1.0, last 20 avg 0.85
# Episode 291, episode return 0.0, last 20 avg 0.8
# Episode 292, episode return 1.0, last 20 avg 0.8
# Episode 293, episode return 1.0, last 20 avg 0.8
# Episode 294, episode return 1.0, last 20 avg 0.8
# Episode 295, episode return 1.0, last 20 avg 0.8
# Episode 296, episode return 0.0, last 20 avg 0.8
# Episode 297, episode return 1.0, last 20 avg 0.8
# Episode 298, episode return 1.0, last 20 avg 0.8
# Episode 299, episode return 1.0, last 20 avg 0.8
#
#  > Training DQN
#
# Episode 0, episode return 0.0, last 20 avg 0.0
# Episode 1, episode return 0.0, last 20 avg 0.0
# Episode 2, episode return 0.0, last 20 avg 0.0
# Episode 3, episode return 0.0, last 20 avg 0.0
# Episode 4, episode return 0.0, last 20 avg 0.0
# Episode 5, episode return 0.0, last 20 avg 0.0
# Episode 6, episode return 0.0, last 20 avg 0.0
# Episode 7, episode return 0.0, last 20 avg 0.0
# Episode 8, episode return 0.0, last 20 avg 0.0
# Episode 9, episode return 0.0, last 20 avg 0.0
# Episode 10, episode return 1.0, last 20 avg 0.09090909090909091
# Episode 11, episode return 0.0, last 20 avg 0.08333333333333333
# Episode 12, episode return 0.0, last 20 avg 0.07692307692307693
# Episode 13, episode return 0.0, last 20 avg 0.07142857142857142
# Episode 14, episode return 0.0, last 20 avg 0.06666666666666667
# Episode 15, episode return 0.0, last 20 avg 0.0625
# Episode 16, episode return 0.0, last 20 avg 0.058823529411764705
# Episode 17, episode return 0.0, last 20 avg 0.05555555555555555
# Episode 18, episode return 0.0, last 20 avg 0.05263157894736842
# Episode 19, episode return 0.0, last 20 avg 0.05
# Episode 20, episode return 0.0, last 20 avg 0.05
# Episode 21, episode return 0.0, last 20 avg 0.05
# Episode 22, episode return 0.0, last 20 avg 0.05
# Episode 23, episode return 0.0, last 20 avg 0.05
# Episode 24, episode return 0.0, last 20 avg 0.05
# Episode 25, episode return 1.0, last 20 avg 0.1
# Episode 26, episode return 0.0, last 20 avg 0.1
# Episode 27, episode return 0.0, last 20 avg 0.1
# Episode 28, episode return 0.0, last 20 avg 0.1
# Episode 29, episode return 0.0, last 20 avg 0.1
# Episode 30, episode return 0.0, last 20 avg 0.05
# Episode 31, episode return 1.0, last 20 avg 0.1
# Episode 32, episode return 0.0, last 20 avg 0.1
# Episode 33, episode return 1.0, last 20 avg 0.15
# Episode 34, episode return 0.0, last 20 avg 0.15
# Episode 35, episode return 0.0, last 20 avg 0.15
# Episode 36, episode return 1.0, last 20 avg 0.2
# Episode 37, episode return 0.0, last 20 avg 0.2
# Episode 38, episode return 0.0, last 20 avg 0.2
# Episode 39, episode return 1.0, last 20 avg 0.25
# Episode 40, episode return 0.0, last 20 avg 0.25
# Episode 41, episode return 0.0, last 20 avg 0.25
# Episode 42, episode return 0.0, last 20 avg 0.25
# Episode 43, episode return 0.0, last 20 avg 0.25
# Episode 44, episode return 0.0, last 20 avg 0.25
# Episode 45, episode return 0.0, last 20 avg 0.2
# Episode 46, episode return 1.0, last 20 avg 0.25
# Episode 47, episode return 0.0, last 20 avg 0.25
# Episode 48, episode return 0.0, last 20 avg 0.25
# Episode 49, episode return 0.0, last 20 avg 0.25
# Episode 50, episode return 1.0, last 20 avg 0.3
# Episode 51, episode return 0.0, last 20 avg 0.25
# Episode 52, episode return 1.0, last 20 avg 0.3
# Episode 53, episode return 1.0, last 20 avg 0.3
# Episode 54, episode return 0.0, last 20 avg 0.3
# Episode 55, episode return 1.0, last 20 avg 0.35
# Episode 56, episode return 0.0, last 20 avg 0.3
# Episode 57, episode return 0.0, last 20 avg 0.3
# Episode 58, episode return 1.0, last 20 avg 0.35
# Episode 59, episode return 1.0, last 20 avg 0.35
# Episode 60, episode return 0.0, last 20 avg 0.35
# Episode 61, episode return 0.0, last 20 avg 0.35
# Episode 62, episode return 0.0, last 20 avg 0.35
# Episode 63, episode return 0.0, last 20 avg 0.35
# Episode 64, episode return 0.0, last 20 avg 0.35
# Episode 65, episode return 0.0, last 20 avg 0.35
# Episode 66, episode return 0.0, last 20 avg 0.3
# Episode 67, episode return 0.0, last 20 avg 0.3
# Episode 68, episode return 0.0, last 20 avg 0.3
# Episode 69, episode return 0.0, last 20 avg 0.3
# Episode 70, episode return 1.0, last 20 avg 0.3
# Episode 71, episode return 0.0, last 20 avg 0.3
# Episode 72, episode return 0.0, last 20 avg 0.25
# Episode 73, episode return 1.0, last 20 avg 0.25
# Episode 74, episode return 0.0, last 20 avg 0.25
# Episode 75, episode return 0.0, last 20 avg 0.2
# Episode 76, episode return 1.0, last 20 avg 0.25
# Episode 77, episode return 0.0, last 20 avg 0.25
# Episode 78, episode return 0.0, last 20 avg 0.2
# Episode 79, episode return 0.0, last 20 avg 0.15
# Episode 80, episode return 0.0, last 20 avg 0.15
# Episode 81, episode return 1.0, last 20 avg 0.2
# Episode 82, episode return 0.0, last 20 avg 0.2
# Episode 83, episode return 1.0, last 20 avg 0.25
# Episode 84, episode return 1.0, last 20 avg 0.3
# Episode 85, episode return 0.0, last 20 avg 0.3
# Episode 86, episode return 0.0, last 20 avg 0.3
# Episode 87, episode return 0.0, last 20 avg 0.3
# Episode 88, episode return 0.0, last 20 avg 0.3
# Episode 89, episode return 0.0, last 20 avg 0.3
# Episode 90, episode return 0.0, last 20 avg 0.25
# Episode 91, episode return 0.0, last 20 avg 0.25
# Episode 92, episode return 0.0, last 20 avg 0.25
# Episode 93, episode return 0.0, last 20 avg 0.2
# Episode 94, episode return 0.0, last 20 avg 0.2
# Episode 95, episode return 0.0, last 20 avg 0.2
# Episode 96, episode return 1.0, last 20 avg 0.2
# Episode 97, episode return 0.0, last 20 avg 0.2
# Episode 98, episode return 0.0, last 20 avg 0.2
# Episode 99, episode return 1.0, last 20 avg 0.25
# Episode 100, episode return 0.0, last 20 avg 0.25
# Episode 101, episode return 0.0, last 20 avg 0.2
# Episode 102, episode return 1.0, last 20 avg 0.25
# Episode 103, episode return 0.0, last 20 avg 0.2
# Episode 104, episode return 1.0, last 20 avg 0.2
# Episode 105, episode return 0.0, last 20 avg 0.2
# Episode 106, episode return 0.0, last 20 avg 0.2
# Episode 107, episode return 1.0, last 20 avg 0.25
# Episode 108, episode return 1.0, last 20 avg 0.3
# Episode 109, episode return 0.0, last 20 avg 0.3
# Episode 110, episode return 0.0, last 20 avg 0.3
# Episode 111, episode return 1.0, last 20 avg 0.35
# Episode 112, episode return 0.0, last 20 avg 0.35
# Episode 113, episode return 0.0, last 20 avg 0.35
# Episode 114, episode return 0.0, last 20 avg 0.35
# Episode 115, episode return 0.0, last 20 avg 0.35
# Episode 116, episode return 1.0, last 20 avg 0.35
# Episode 117, episode return 0.0, last 20 avg 0.35
# Episode 118, episode return 0.0, last 20 avg 0.35
# Episode 119, episode return 0.0, last 20 avg 0.3
# Episode 120, episode return 0.0, last 20 avg 0.3
# Episode 121, episode return 0.0, last 20 avg 0.3
# Episode 122, episode return 1.0, last 20 avg 0.3
# Episode 123, episode return 1.0, last 20 avg 0.35
# Episode 124, episode return 0.0, last 20 avg 0.3
# Episode 125, episode return 0.0, last 20 avg 0.3
# Episode 126, episode return 1.0, last 20 avg 0.35
# Episode 127, episode return 0.0, last 20 avg 0.3
# Episode 128, episode return 0.0, last 20 avg 0.25
# Episode 129, episode return 0.0, last 20 avg 0.25
# Episode 130, episode return 0.0, last 20 avg 0.25
# Episode 131, episode return 1.0, last 20 avg 0.25
# Episode 132, episode return 0.0, last 20 avg 0.25
# Episode 133, episode return 1.0, last 20 avg 0.3
# Episode 134, episode return 0.0, last 20 avg 0.3
# Episode 135, episode return 0.0, last 20 avg 0.3
# Episode 136, episode return 0.0, last 20 avg 0.25
# Episode 137, episode return 1.0, last 20 avg 0.3
# Episode 138, episode return 0.0, last 20 avg 0.3
# Episode 139, episode return 0.0, last 20 avg 0.3
# Episode 140, episode return 1.0, last 20 avg 0.35
# Episode 141, episode return 1.0, last 20 avg 0.4
# Episode 142, episode return 1.0, last 20 avg 0.4
# Episode 143, episode return 0.0, last 20 avg 0.35
# Episode 144, episode return 0.0, last 20 avg 0.35
# Episode 145, episode return 1.0, last 20 avg 0.4
# Episode 146, episode return 1.0, last 20 avg 0.4
# Episode 147, episode return 1.0, last 20 avg 0.45
# Episode 148, episode return 0.0, last 20 avg 0.45
# Episode 149, episode return 0.0, last 20 avg 0.45
# Episode 150, episode return 0.0, last 20 avg 0.45
# Episode 151, episode return 1.0, last 20 avg 0.45
# Episode 152, episode return 1.0, last 20 avg 0.5
# Episode 153, episode return 0.0, last 20 avg 0.45
# Episode 154, episode return 0.0, last 20 avg 0.45
# Episode 155, episode return 0.0, last 20 avg 0.45
# Episode 156, episode return 1.0, last 20 avg 0.5
# Episode 157, episode return 1.0, last 20 avg 0.5
# Episode 158, episode return 0.0, last 20 avg 0.5
# Episode 159, episode return 1.0, last 20 avg 0.55
# Episode 160, episode return 0.0, last 20 avg 0.5
# Episode 161, episode return 1.0, last 20 avg 0.5
# Episode 162, episode return 0.0, last 20 avg 0.45
# Episode 163, episode return 0.0, last 20 avg 0.45
# Episode 164, episode return 0.0, last 20 avg 0.45
# Episode 165, episode return 1.0, last 20 avg 0.45
# Episode 166, episode return 0.0, last 20 avg 0.4
# Episode 167, episode return 1.0, last 20 avg 0.4
# Episode 168, episode return 0.0, last 20 avg 0.4
# Episode 169, episode return 1.0, last 20 avg 0.45
# Episode 170, episode return 1.0, last 20 avg 0.5
# Episode 171, episode return 0.0, last 20 avg 0.45
# Episode 172, episode return 1.0, last 20 avg 0.45
# Episode 173, episode return 1.0, last 20 avg 0.5
# Episode 174, episode return 0.0, last 20 avg 0.5
# Episode 175, episode return 1.0, last 20 avg 0.55
# Episode 176, episode return 1.0, last 20 avg 0.55
# Episode 177, episode return 0.0, last 20 avg 0.5
# Episode 178, episode return 1.0, last 20 avg 0.55
# Episode 179, episode return 1.0, last 20 avg 0.55
# Episode 180, episode return 0.0, last 20 avg 0.55
# Episode 181, episode return 1.0, last 20 avg 0.55
# Episode 182, episode return 0.0, last 20 avg 0.55
# Episode 183, episode return 1.0, last 20 avg 0.6
# Episode 184, episode return 1.0, last 20 avg 0.65
# Episode 185, episode return 1.0, last 20 avg 0.65
# Episode 186, episode return 0.0, last 20 avg 0.65
# Episode 187, episode return 1.0, last 20 avg 0.65
# Episode 188, episode return 1.0, last 20 avg 0.7
# Episode 189, episode return 1.0, last 20 avg 0.7
# Episode 190, episode return 1.0, last 20 avg 0.7
# Episode 191, episode return 1.0, last 20 avg 0.75
# Episode 192, episode return 0.0, last 20 avg 0.7
# Episode 193, episode return 1.0, last 20 avg 0.7
# Episode 194, episode return 0.0, last 20 avg 0.7
# Episode 195, episode return 1.0, last 20 avg 0.7
# Episode 196, episode return 0.0, last 20 avg 0.65
# Episode 197, episode return 1.0, last 20 avg 0.7
# Episode 198, episode return 1.0, last 20 avg 0.7
# Episode 199, episode return 0.0, last 20 avg 0.65
# Episode 200, episode return 0.0, last 20 avg 0.65
# Episode 201, episode return 1.0, last 20 avg 0.65
# Episode 202, episode return 1.0, last 20 avg 0.7
# Episode 203, episode return 0.0, last 20 avg 0.65
# Episode 204, episode return 0.0, last 20 avg 0.6
# Episode 205, episode return 1.0, last 20 avg 0.6
# Episode 206, episode return 1.0, last 20 avg 0.65
# Episode 207, episode return 1.0, last 20 avg 0.65
# Episode 208, episode return 1.0, last 20 avg 0.65
# Episode 209, episode return 1.0, last 20 avg 0.65
# Episode 210, episode return 0.0, last 20 avg 0.6
# Episode 211, episode return 0.0, last 20 avg 0.55
# Episode 212, episode return 0.0, last 20 avg 0.55
# Episode 213, episode return 1.0, last 20 avg 0.55
# Episode 214, episode return 0.0, last 20 avg 0.55
# Episode 215, episode return 0.0, last 20 avg 0.5
# Episode 216, episode return 1.0, last 20 avg 0.55
# Episode 217, episode return 0.0, last 20 avg 0.5
# Episode 218, episode return 1.0, last 20 avg 0.5
# Episode 219, episode return 0.0, last 20 avg 0.5
# Episode 220, episode return 1.0, last 20 avg 0.55
# Episode 221, episode return 0.0, last 20 avg 0.5
# Episode 222, episode return 1.0, last 20 avg 0.5
# Episode 223, episode return 1.0, last 20 avg 0.55
# Episode 224, episode return 1.0, last 20 avg 0.6
# Episode 225, episode return 0.0, last 20 avg 0.55
# Episode 226, episode return 1.0, last 20 avg 0.55
# Episode 227, episode return 1.0, last 20 avg 0.55
# Episode 228, episode return 1.0, last 20 avg 0.55
# Episode 229, episode return 1.0, last 20 avg 0.55
# Episode 230, episode return 1.0, last 20 avg 0.6
# Episode 231, episode return 1.0, last 20 avg 0.65
# Episode 232, episode return 0.0, last 20 avg 0.65
# Episode 233, episode return 1.0, last 20 avg 0.65
# Episode 234, episode return 1.0, last 20 avg 0.7
# Episode 235, episode return 1.0, last 20 avg 0.75
# Episode 236, episode return 1.0, last 20 avg 0.75
# Episode 237, episode return 0.0, last 20 avg 0.75
# Episode 238, episode return 1.0, last 20 avg 0.75
# Episode 239, episode return 1.0, last 20 avg 0.8
# Episode 240, episode return 1.0, last 20 avg 0.8
# Episode 241, episode return 1.0, last 20 avg 0.85
# Episode 242, episode return 1.0, last 20 avg 0.85
# Episode 243, episode return 1.0, last 20 avg 0.85
# Episode 244, episode return 1.0, last 20 avg 0.85
# Episode 245, episode return 1.0, last 20 avg 0.9
# Episode 246, episode return 1.0, last 20 avg 0.9
# Episode 247, episode return 1.0, last 20 avg 0.9
# Episode 248, episode return 1.0, last 20 avg 0.9
# Episode 249, episode return 1.0, last 20 avg 0.9
# Episode 250, episode return 1.0, last 20 avg 0.9
# Episode 251, episode return 1.0, last 20 avg 0.9
# Episode 252, episode return 1.0, last 20 avg 0.95
# Episode 253, episode return 1.0, last 20 avg 0.95
# Episode 254, episode return 1.0, last 20 avg 0.95
# Episode 255, episode return 1.0, last 20 avg 0.95
# Episode 256, episode return 1.0, last 20 avg 0.95
# Episode 257, episode return 1.0, last 20 avg 1.0
# Episode 258, episode return 1.0, last 20 avg 1.0
# Episode 259, episode return 1.0, last 20 avg 1.0
# Episode 260, episode return 1.0, last 20 avg 1.0
# Episode 261, episode return 0.0, last 20 avg 0.95
# Episode 262, episode return 0.0, last 20 avg 0.9
# Episode 263, episode return 0.0, last 20 avg 0.85
# Episode 264, episode return 1.0, last 20 avg 0.85
# Episode 265, episode return 1.0, last 20 avg 0.85
# Episode 266, episode return 1.0, last 20 avg 0.85
# Episode 267, episode return 0.0, last 20 avg 0.8
# Episode 268, episode return 1.0, last 20 avg 0.8
# Episode 269, episode return 1.0, last 20 avg 0.8
# Episode 270, episode return 1.0, last 20 avg 0.8
# Episode 271, episode return 1.0, last 20 avg 0.8
# Episode 272, episode return 1.0, last 20 avg 0.8
# Episode 273, episode return 1.0, last 20 avg 0.8
# Episode 274, episode return 1.0, last 20 avg 0.8
# Episode 275, episode return 1.0, last 20 avg 0.8
# Episode 276, episode return 1.0, last 20 avg 0.8
# Episode 277, episode return 1.0, last 20 avg 0.8
# Episode 278, episode return 1.0, last 20 avg 0.8
# Episode 279, episode return 1.0, last 20 avg 0.8
# Episode 280, episode return 1.0, last 20 avg 0.8
# Episode 281, episode return 0.0, last 20 avg 0.8
# Episode 282, episode return 1.0, last 20 avg 0.85
# Episode 283, episode return 1.0, last 20 avg 0.9
# Episode 284, episode return 1.0, last 20 avg 0.9
# Episode 285, episode return 1.0, last 20 avg 0.9
# Episode 286, episode return 0.0, last 20 avg 0.85
# Episode 287, episode return 1.0, last 20 avg 0.9
# Episode 288, episode return 1.0, last 20 avg 0.9
# Episode 289, episode return 1.0, last 20 avg 0.9
# Episode 290, episode return 1.0, last 20 avg 0.9
# Episode 291, episode return 1.0, last 20 avg 0.9
# Episode 292, episode return 1.0, last 20 avg 0.9
# Episode 293, episode return 1.0, last 20 avg 0.9
# Episode 294, episode return 1.0, last 20 avg 0.9
# Episode 295, episode return 1.0, last 20 avg 0.9
# Episode 296, episode return 1.0, last 20 avg 0.9
# Episode 297, episode return 1.0, last 20 avg 0.9
# Episode 298, episode return 1.0, last 20 avg 0.9
# Episode 299, episode return 0.0, last 20 avg 0.85

# %% [markdown]
# Now, observe it's performances inside the harder 4 rooms map:

# %%
import matplotlib.pyplot as plt


environment = gym.make("goal_conditioned_discrete_grid_world-v0")
# We modified the map id to select the second map, the rest of the code is the same than above
environment.__init__(map_id=2)
environment.render()

nb_seeds = 4
nb_episodes_per_simulations = 600

her_seeds_rewards_result = []
her_seeds_tests_result = []
colors = ["#ff0000", "#ff9500"]

for seed_id in range(nb_seeds):
    print()
    print("###################")
    print()
    print("      SEED " + str(seed_id))
    print()
    print("###################")

    print()
    print(" > Training HERAgent")
    print()
    her_agent = HERAgent(environment.observation_space, environment.action_space)
    rewards_sum_per_episode, tests_results = simulation(environment, her_agent,
                                                        nb_episodes=nb_episodes_per_simulations)
    her_seeds_rewards_result.append(rewards_sum_per_episode)
    her_seeds_tests_result.append(tests_results)

    plt.cla()
    plt.title("Rewards sum per episode")
    her_means = np.mean(np.array(her_seeds_rewards_result), axis=0)
    her_stds = np.std(np.array(her_seeds_rewards_result), axis=0)
    plt.plot(her_means, color=colors[0], label="DQN + HER")
    plt.fill_between([x for x in range(len(her_means))], her_means + her_stds, her_means - her_stds, color=colors[0],
                     alpha=0.2)
    plt.legend()
    plt.show()

    plt.cla()
    plt.title("Tests grades evolution during agent learning")
    her_means = np.mean(np.array(her_seeds_tests_result), axis=0)
    her_stds = np.std(np.array(her_seeds_tests_result), axis=0)
    plt.plot(her_means, color=colors[0], label="DQN + HER")
    plt.fill_between([x for x in range(len(her_means))], her_means + her_stds, her_means - her_stds, color=colors[0],
                     alpha=0.2)
    plt.legend()
    plt.show()
# Out:
# ###################
#
#       SEED 0
#
# ###################
#
#  > Training HERAgent
#
# Episode 0, episode return 0.0, last 20 avg 0.0
# Episode 1, episode return 0.0, last 20 avg 0.0
# Episode 2, episode return 0.0, last 20 avg 0.0
# Episode 3, episode return 0.0, last 20 avg 0.0
# Episode 4, episode return 0.0, last 20 avg 0.0
# Episode 5, episode return 0.0, last 20 avg 0.0
# Episode 6, episode return 0.0, last 20 avg 0.0
# Episode 7, episode return 0.0, last 20 avg 0.0
# Episode 8, episode return 0.0, last 20 avg 0.0
# Episode 9, episode return 1.0, last 20 avg 0.1
# Episode 10, episode return 0.0, last 20 avg 0.09090909090909091
# Episode 11, episode return 0.0, last 20 avg 0.08333333333333333
# Episode 12, episode return 0.0, last 20 avg 0.07692307692307693
# Episode 13, episode return 0.0, last 20 avg 0.07142857142857142
# Episode 14, episode return 0.0, last 20 avg 0.06666666666666667
# Episode 15, episode return 0.0, last 20 avg 0.0625
# Episode 16, episode return 0.0, last 20 avg 0.058823529411764705
# Episode 17, episode return 0.0, last 20 avg 0.05555555555555555
# Episode 18, episode return 0.0, last 20 avg 0.05263157894736842
# Episode 19, episode return 0.0, last 20 avg 0.05
# Episode 20, episode return 1.0, last 20 avg 0.1
# Episode 21, episode return 0.0, last 20 avg 0.1
# Episode 22, episode return 0.0, last 20 avg 0.1
# Episode 23, episode return 0.0, last 20 avg 0.1
# Episode 24, episode return 0.0, last 20 avg 0.1
# Episode 25, episode return 0.0, last 20 avg 0.1
# Episode 26, episode return 0.0, last 20 avg 0.1
# Episode 27, episode return 0.0, last 20 avg 0.1
# Episode 28, episode return 0.0, last 20 avg 0.1
# Episode 29, episode return 0.0, last 20 avg 0.05
# Episode 30, episode return 0.0, last 20 avg 0.05
# Episode 31, episode return 0.0, last 20 avg 0.05
# Episode 32, episode return 0.0, last 20 avg 0.05
# Episode 33, episode return 0.0, last 20 avg 0.05
# Episode 34, episode return 1.0, last 20 avg 0.1
# Episode 35, episode return 0.0, last 20 avg 0.1
# Episode 36, episode return 0.0, last 20 avg 0.1
# Episode 37, episode return 0.0, last 20 avg 0.1
# Episode 38, episode return 0.0, last 20 avg 0.1
# Episode 39, episode return 0.0, last 20 avg 0.1
# Episode 40, episode return 0.0, last 20 avg 0.05
# Episode 41, episode return 0.0, last 20 avg 0.05
# Episode 42, episode return 0.0, last 20 avg 0.05
# Episode 43, episode return 0.0, last 20 avg 0.05
# Episode 44, episode return 0.0, last 20 avg 0.05
# Episode 45, episode return 0.0, last 20 avg 0.05
# Episode 46, episode return 1.0, last 20 avg 0.1
# Episode 47, episode return 0.0, last 20 avg 0.1
# Episode 48, episode return 0.0, last 20 avg 0.1
# Episode 49, episode return 0.0, last 20 avg 0.1
# Episode 50, episode return 0.0, last 20 avg 0.1
# Episode 51, episode return 0.0, last 20 avg 0.1
# Episode 52, episode return 0.0, last 20 avg 0.1
# Episode 53, episode return 0.0, last 20 avg 0.1
# Episode 54, episode return 0.0, last 20 avg 0.05
# Episode 55, episode return 0.0, last 20 avg 0.05
# Episode 56, episode return 0.0, last 20 avg 0.05
# Episode 57, episode return 0.0, last 20 avg 0.05
# Episode 58, episode return 0.0, last 20 avg 0.05
# Episode 59, episode return 0.0, last 20 avg 0.05
# Episode 60, episode return 0.0, last 20 avg 0.05
# Episode 61, episode return 0.0, last 20 avg 0.05
# Episode 62, episode return 0.0, last 20 avg 0.05
# Episode 63, episode return 0.0, last 20 avg 0.05
# Episode 64, episode return 0.0, last 20 avg 0.05
# Episode 65, episode return 0.0, last 20 avg 0.05
# Episode 66, episode return 0.0, last 20 avg 0.0
# Episode 67, episode return 0.0, last 20 avg 0.0
# Episode 68, episode return 1.0, last 20 avg 0.05
# Episode 69, episode return 0.0, last 20 avg 0.05
# Episode 70, episode return 0.0, last 20 avg 0.05
# Episode 71, episode return 0.0, last 20 avg 0.05
# Episode 72, episode return 0.0, last 20 avg 0.05
# Episode 73, episode return 0.0, last 20 avg 0.05
# Episode 74, episode return 0.0, last 20 avg 0.05
# Episode 75, episode return 0.0, last 20 avg 0.05
# Episode 76, episode return 1.0, last 20 avg 0.1
# Episode 77, episode return 1.0, last 20 avg 0.15
# Episode 78, episode return 0.0, last 20 avg 0.15
# Episode 79, episode return 1.0, last 20 avg 0.2
# Episode 80, episode return 0.0, last 20 avg 0.2
# Episode 81, episode return 0.0, last 20 avg 0.2
# Episode 82, episode return 1.0, last 20 avg 0.25
# Episode 83, episode return 0.0, last 20 avg 0.25
# Episode 84, episode return 0.0, last 20 avg 0.25
# Episode 85, episode return 0.0, last 20 avg 0.25
# Episode 86, episode return 1.0, last 20 avg 0.3
# Episode 87, episode return 0.0, last 20 avg 0.3
# Episode 88, episode return 0.0, last 20 avg 0.25
# Episode 89, episode return 0.0, last 20 avg 0.25
# Episode 90, episode return 0.0, last 20 avg 0.25
# Episode 91, episode return 0.0, last 20 avg 0.25
# Episode 92, episode return 1.0, last 20 avg 0.3
# Episode 93, episode return 0.0, last 20 avg 0.3
# Episode 94, episode return 0.0, last 20 avg 0.3
# Episode 95, episode return 0.0, last 20 avg 0.3
# Episode 96, episode return 0.0, last 20 avg 0.25
# Episode 97, episode return 0.0, last 20 avg 0.2
# Episode 98, episode return 0.0, last 20 avg 0.2
# Episode 99, episode return 0.0, last 20 avg 0.15
# Episode 100, episode return 0.0, last 20 avg 0.15
# Episode 101, episode return 0.0, last 20 avg 0.15
# Episode 102, episode return 0.0, last 20 avg 0.1
# Episode 103, episode return 1.0, last 20 avg 0.15
# Episode 104, episode return 0.0, last 20 avg 0.15
# Episode 105, episode return 0.0, last 20 avg 0.15
# Episode 106, episode return 0.0, last 20 avg 0.1
# Episode 107, episode return 1.0, last 20 avg 0.15
# Episode 108, episode return 0.0, last 20 avg 0.15
# Episode 109, episode return 0.0, last 20 avg 0.15
# Episode 110, episode return 0.0, last 20 avg 0.15
# Episode 111, episode return 0.0, last 20 avg 0.15
# Episode 112, episode return 0.0, last 20 avg 0.1
# Episode 113, episode return 0.0, last 20 avg 0.1
# Episode 114, episode return 1.0, last 20 avg 0.15
# Episode 115, episode return 0.0, last 20 avg 0.15
# Episode 116, episode return 0.0, last 20 avg 0.15
# Episode 117, episode return 1.0, last 20 avg 0.2
# Episode 118, episode return 0.0, last 20 avg 0.2
# Episode 119, episode return 0.0, last 20 avg 0.2
# Episode 120, episode return 0.0, last 20 avg 0.2
# Episode 121, episode return 0.0, last 20 avg 0.2
# Episode 122, episode return 0.0, last 20 avg 0.2
# Episode 123, episode return 0.0, last 20 avg 0.15
# Episode 124, episode return 0.0, last 20 avg 0.15
# Episode 125, episode return 1.0, last 20 avg 0.2
# Episode 126, episode return 0.0, last 20 avg 0.2
# Episode 127, episode return 1.0, last 20 avg 0.2
# Episode 128, episode return 1.0, last 20 avg 0.25
# Episode 129, episode return 1.0, last 20 avg 0.3
# Episode 130, episode return 0.0, last 20 avg 0.3
# Episode 131, episode return 0.0, last 20 avg 0.3
# Episode 132, episode return 0.0, last 20 avg 0.3
# Episode 133, episode return 1.0, last 20 avg 0.35
# Episode 134, episode return 0.0, last 20 avg 0.3
# Episode 135, episode return 1.0, last 20 avg 0.35
# Episode 136, episode return 0.0, last 20 avg 0.35
# Episode 137, episode return 0.0, last 20 avg 0.3
# Episode 138, episode return 0.0, last 20 avg 0.3
# Episode 139, episode return 0.0, last 20 avg 0.3
# Episode 140, episode return 0.0, last 20 avg 0.3
# Episode 141, episode return 0.0, last 20 avg 0.3
# Episode 142, episode return 0.0, last 20 avg 0.3
# Episode 143, episode return 0.0, last 20 avg 0.3
# Episode 144, episode return 0.0, last 20 avg 0.3
# Episode 145, episode return 1.0, last 20 avg 0.3
# Episode 146, episode return 0.0, last 20 avg 0.3
# Episode 147, episode return 0.0, last 20 avg 0.25
# Episode 148, episode return 0.0, last 20 avg 0.2
# Episode 149, episode return 0.0, last 20 avg 0.15
# Episode 150, episode return 0.0, last 20 avg 0.15
# Episode 151, episode return 0.0, last 20 avg 0.15
# Episode 152, episode return 0.0, last 20 avg 0.15
# Episode 153, episode return 0.0, last 20 avg 0.1
# Episode 154, episode return 1.0, last 20 avg 0.15
# Episode 155, episode return 0.0, last 20 avg 0.1
# Episode 156, episode return 0.0, last 20 avg 0.1
# Episode 157, episode return 0.0, last 20 avg 0.1
# Episode 158, episode return 1.0, last 20 avg 0.15
# Episode 159, episode return 0.0, last 20 avg 0.15
# Episode 160, episode return 0.0, last 20 avg 0.15
# Episode 161, episode return 0.0, last 20 avg 0.15
# Episode 162, episode return 0.0, last 20 avg 0.15
# Episode 163, episode return 1.0, last 20 avg 0.2
# Episode 164, episode return 0.0, last 20 avg 0.2
# Episode 165, episode return 0.0, last 20 avg 0.15
# Episode 166, episode return 1.0, last 20 avg 0.2
# Episode 167, episode return 0.0, last 20 avg 0.2
# Episode 168, episode return 0.0, last 20 avg 0.2
# Episode 169, episode return 0.0, last 20 avg 0.2
# Episode 170, episode return 0.0, last 20 avg 0.2
# Episode 171, episode return 0.0, last 20 avg 0.2
# Episode 172, episode return 0.0, last 20 avg 0.2
# Episode 173, episode return 1.0, last 20 avg 0.25
# Episode 174, episode return 1.0, last 20 avg 0.25
# Episode 175, episode return 0.0, last 20 avg 0.25
# Episode 176, episode return 1.0, last 20 avg 0.3
# Episode 177, episode return 0.0, last 20 avg 0.3
# Episode 178, episode return 1.0, last 20 avg 0.3
# Episode 179, episode return 0.0, last 20 avg 0.3
# Episode 180, episode return 1.0, last 20 avg 0.35
# Episode 181, episode return 0.0, last 20 avg 0.35
# Episode 182, episode return 0.0, last 20 avg 0.35
# Episode 183, episode return 1.0, last 20 avg 0.35
# Episode 184, episode return 0.0, last 20 avg 0.35
# Episode 185, episode return 0.0, last 20 avg 0.35
# Episode 186, episode return 0.0, last 20 avg 0.3
# Episode 187, episode return 1.0, last 20 avg 0.35
# Episode 188, episode return 0.0, last 20 avg 0.35
# Episode 189, episode return 0.0, last 20 avg 0.35
# Episode 190, episode return 0.0, last 20 avg 0.35
# Episode 191, episode return 0.0, last 20 avg 0.35
# Episode 192, episode return 0.0, last 20 avg 0.35
# Episode 193, episode return 0.0, last 20 avg 0.3
# Episode 194, episode return 0.0, last 20 avg 0.25
# Episode 195, episode return 0.0, last 20 avg 0.25
# Episode 196, episode return 1.0, last 20 avg 0.25
# Episode 197, episode return 0.0, last 20 avg 0.25
# Episode 198, episode return 1.0, last 20 avg 0.25
# Episode 199, episode return 0.0, last 20 avg 0.25
# Episode 200, episode return 0.0, last 20 avg 0.2
# Episode 201, episode return 1.0, last 20 avg 0.25
# Episode 202, episode return 0.0, last 20 avg 0.25
# Episode 203, episode return 0.0, last 20 avg 0.2
# Episode 204, episode return 0.0, last 20 avg 0.2
# Episode 205, episode return 0.0, last 20 avg 0.2
# Episode 206, episode return 0.0, last 20 avg 0.2
# Episode 207, episode return 0.0, last 20 avg 0.15
# Episode 208, episode return 0.0, last 20 avg 0.15
# Episode 209, episode return 1.0, last 20 avg 0.2
# Episode 210, episode return 0.0, last 20 avg 0.2
# Episode 211, episode return 1.0, last 20 avg 0.25
# Episode 212, episode return 1.0, last 20 avg 0.3
# Episode 213, episode return 0.0, last 20 avg 0.3
# Episode 214, episode return 0.0, last 20 avg 0.3
# Episode 215, episode return 1.0, last 20 avg 0.35
# Episode 216, episode return 1.0, last 20 avg 0.35
# Episode 217, episode return 1.0, last 20 avg 0.4
# Episode 218, episode return 0.0, last 20 avg 0.35
# Episode 219, episode return 1.0, last 20 avg 0.4
# Episode 220, episode return 1.0, last 20 avg 0.45
# Episode 221, episode return 1.0, last 20 avg 0.45
# Episode 222, episode return 0.0, last 20 avg 0.45
# Episode 223, episode return 1.0, last 20 avg 0.5
# Episode 224, episode return 0.0, last 20 avg 0.5
# Episode 225, episode return 0.0, last 20 avg 0.5
# Episode 226, episode return 0.0, last 20 avg 0.5
# Episode 227, episode return 0.0, last 20 avg 0.5
# Episode 228, episode return 0.0, last 20 avg 0.5
# Episode 229, episode return 0.0, last 20 avg 0.45
# Episode 230, episode return 1.0, last 20 avg 0.5
# Episode 231, episode return 0.0, last 20 avg 0.45
# Episode 232, episode return 0.0, last 20 avg 0.4
# Episode 233, episode return 0.0, last 20 avg 0.4
# Episode 234, episode return 0.0, last 20 avg 0.4
# Episode 235, episode return 0.0, last 20 avg 0.35
# Episode 236, episode return 1.0, last 20 avg 0.35
# Episode 237, episode return 0.0, last 20 avg 0.3
# Episode 238, episode return 0.0, last 20 avg 0.3
# Episode 239, episode return 0.0, last 20 avg 0.25
# Episode 240, episode return 1.0, last 20 avg 0.25
# Episode 241, episode return 0.0, last 20 avg 0.2
# Episode 242, episode return 0.0, last 20 avg 0.2
# Episode 243, episode return 1.0, last 20 avg 0.2
# Episode 244, episode return 1.0, last 20 avg 0.25
# Episode 245, episode return 1.0, last 20 avg 0.3
# Episode 246, episode return 0.0, last 20 avg 0.3
# Episode 247, episode return 0.0, last 20 avg 0.3
# Episode 248, episode return 0.0, last 20 avg 0.3
# Episode 249, episode return 0.0, last 20 avg 0.3
# Episode 250, episode return 1.0, last 20 avg 0.3
# Episode 251, episode return 1.0, last 20 avg 0.35
# Episode 252, episode return 0.0, last 20 avg 0.35
# Episode 253, episode return 0.0, last 20 avg 0.35
# Episode 254, episode return 1.0, last 20 avg 0.4
# Episode 255, episode return 0.0, last 20 avg 0.4
# Episode 256, episode return 1.0, last 20 avg 0.4
# Episode 257, episode return 0.0, last 20 avg 0.4
# Episode 258, episode return 1.0, last 20 avg 0.45
# Episode 259, episode return 0.0, last 20 avg 0.45
# Episode 260, episode return 1.0, last 20 avg 0.45
# Episode 261, episode return 0.0, last 20 avg 0.45
# Episode 262, episode return 0.0, last 20 avg 0.45
# Episode 263, episode return 0.0, last 20 avg 0.4
# Episode 264, episode return 0.0, last 20 avg 0.35
# Episode 265, episode return 0.0, last 20 avg 0.3
# Episode 266, episode return 0.0, last 20 avg 0.3
# Episode 267, episode return 1.0, last 20 avg 0.35
# Episode 268, episode return 1.0, last 20 avg 0.4
# Episode 269, episode return 1.0, last 20 avg 0.45
# Episode 270, episode return 0.0, last 20 avg 0.4
# Episode 271, episode return 0.0, last 20 avg 0.35
# Episode 272, episode return 0.0, last 20 avg 0.35
# Episode 273, episode return 0.0, last 20 avg 0.35
# Episode 274, episode return 0.0, last 20 avg 0.3
# Episode 275, episode return 1.0, last 20 avg 0.35
# Episode 276, episode return 0.0, last 20 avg 0.3
# Episode 277, episode return 0.0, last 20 avg 0.3
# Episode 278, episode return 1.0, last 20 avg 0.3
# Episode 279, episode return 0.0, last 20 avg 0.3
# Episode 280, episode return 1.0, last 20 avg 0.3
# Episode 281, episode return 0.0, last 20 avg 0.3
# Episode 282, episode return 0.0, last 20 avg 0.3
# Episode 283, episode return 1.0, last 20 avg 0.35
# Episode 284, episode return 0.0, last 20 avg 0.35
# Episode 285, episode return 0.0, last 20 avg 0.35
# Episode 286, episode return 0.0, last 20 avg 0.35
# Episode 287, episode return 0.0, last 20 avg 0.3
# Episode 288, episode return 0.0, last 20 avg 0.25
# Episode 289, episode return 0.0, last 20 avg 0.2
# Episode 290, episode return 0.0, last 20 avg 0.2
# Episode 291, episode return 0.0, last 20 avg 0.2
# Episode 292, episode return 1.0, last 20 avg 0.25
# Episode 293, episode return 1.0, last 20 avg 0.3
# Episode 294, episode return 1.0, last 20 avg 0.35
# Episode 295, episode return 1.0, last 20 avg 0.35
# Episode 296, episode return 0.0, last 20 avg 0.35
# Episode 297, episode return 1.0, last 20 avg 0.4
# Episode 298, episode return 1.0, last 20 avg 0.4
# Episode 299, episode return 0.0, last 20 avg 0.4
# Episode 300, episode return 0.0, last 20 avg 0.35
# Episode 301, episode return 1.0, last 20 avg 0.4
# Episode 302, episode return 0.0, last 20 avg 0.4
# Episode 303, episode return 0.0, last 20 avg 0.35
# Episode 304, episode return 0.0, last 20 avg 0.35
# Episode 305, episode return 1.0, last 20 avg 0.4
# Episode 306, episode return 0.0, last 20 avg 0.4
# Episode 307, episode return 0.0, last 20 avg 0.4
# Episode 308, episode return 1.0, last 20 avg 0.45
# Episode 309, episode return 1.0, last 20 avg 0.5
# Episode 310, episode return 0.0, last 20 avg 0.5
# Episode 311, episode return 1.0, last 20 avg 0.55
# Episode 312, episode return 0.0, last 20 avg 0.5
# Episode 313, episode return 0.0, last 20 avg 0.45
# Episode 314, episode return 0.0, last 20 avg 0.4
# Episode 315, episode return 0.0, last 20 avg 0.35
# Episode 316, episode return 1.0, last 20 avg 0.4
# Episode 317, episode return 0.0, last 20 avg 0.35
# Episode 318, episode return 0.0, last 20 avg 0.3
# Episode 319, episode return 0.0, last 20 avg 0.3
# Episode 320, episode return 0.0, last 20 avg 0.3
# Episode 321, episode return 0.0, last 20 avg 0.25
# Episode 322, episode return 0.0, last 20 avg 0.25
# Episode 323, episode return 0.0, last 20 avg 0.25
# Episode 324, episode return 0.0, last 20 avg 0.25
# Episode 325, episode return 1.0, last 20 avg 0.25
# Episode 326, episode return 0.0, last 20 avg 0.25
# Episode 327, episode return 0.0, last 20 avg 0.25
# Episode 328, episode return 0.0, last 20 avg 0.2
# Episode 329, episode return 0.0, last 20 avg 0.15
# Episode 330, episode return 0.0, last 20 avg 0.15
# Episode 331, episode return 1.0, last 20 avg 0.15
# Episode 332, episode return 1.0, last 20 avg 0.2
# Episode 333, episode return 0.0, last 20 avg 0.2
# Episode 334, episode return 0.0, last 20 avg 0.2
# Episode 335, episode return 1.0, last 20 avg 0.25
# Episode 336, episode return 0.0, last 20 avg 0.2
# Episode 337, episode return 1.0, last 20 avg 0.25
# Episode 338, episode return 0.0, last 20 avg 0.25
# Episode 339, episode return 1.0, last 20 avg 0.3
# Episode 340, episode return 1.0, last 20 avg 0.35
# Episode 341, episode return 0.0, last 20 avg 0.35
# Episode 342, episode return 0.0, last 20 avg 0.35
# Episode 343, episode return 1.0, last 20 avg 0.4
# Episode 344, episode return 0.0, last 20 avg 0.4
# Episode 345, episode return 1.0, last 20 avg 0.4
# Episode 346, episode return 1.0, last 20 avg 0.45
# Episode 347, episode return 0.0, last 20 avg 0.45
# Episode 348, episode return 0.0, last 20 avg 0.45
# Episode 349, episode return 1.0, last 20 avg 0.5
# Episode 350, episode return 0.0, last 20 avg 0.5
# Episode 351, episode return 0.0, last 20 avg 0.45
# Episode 352, episode return 0.0, last 20 avg 0.4
# Episode 353, episode return 0.0, last 20 avg 0.4
# Episode 354, episode return 1.0, last 20 avg 0.45
# Episode 355, episode return 1.0, last 20 avg 0.45
# Episode 356, episode return 0.0, last 20 avg 0.45
# Episode 357, episode return 0.0, last 20 avg 0.4
# Episode 358, episode return 0.0, last 20 avg 0.4
# Episode 359, episode return 0.0, last 20 avg 0.35
# Episode 360, episode return 1.0, last 20 avg 0.35
# Episode 361, episode return 1.0, last 20 avg 0.4
# Episode 362, episode return 0.0, last 20 avg 0.4
# Episode 363, episode return 0.0, last 20 avg 0.35
# Episode 364, episode return 0.0, last 20 avg 0.35
# Episode 365, episode return 0.0, last 20 avg 0.3
# Episode 366, episode return 0.0, last 20 avg 0.25
# Episode 367, episode return 1.0, last 20 avg 0.3
# Episode 368, episode return 0.0, last 20 avg 0.3
# Episode 369, episode return 1.0, last 20 avg 0.3
# Episode 370, episode return 1.0, last 20 avg 0.35
# Episode 371, episode return 1.0, last 20 avg 0.4
# Episode 372, episode return 1.0, last 20 avg 0.45
# Episode 373, episode return 0.0, last 20 avg 0.45
# Episode 374, episode return 0.0, last 20 avg 0.4
# Episode 375, episode return 0.0, last 20 avg 0.35
# Episode 376, episode return 0.0, last 20 avg 0.35
# Episode 377, episode return 0.0, last 20 avg 0.35
# Episode 378, episode return 1.0, last 20 avg 0.4
# Episode 379, episode return 1.0, last 20 avg 0.45
# Episode 380, episode return 1.0, last 20 avg 0.45
# Episode 381, episode return 0.0, last 20 avg 0.4
# Episode 382, episode return 0.0, last 20 avg 0.4
# Episode 383, episode return 1.0, last 20 avg 0.45
# Episode 384, episode return 0.0, last 20 avg 0.45
# Episode 385, episode return 0.0, last 20 avg 0.45
# Episode 386, episode return 0.0, last 20 avg 0.45
# Episode 387, episode return 1.0, last 20 avg 0.45
# Episode 388, episode return 0.0, last 20 avg 0.45
# Episode 389, episode return 0.0, last 20 avg 0.4
# Episode 390, episode return 1.0, last 20 avg 0.4
# Episode 391, episode return 1.0, last 20 avg 0.4
# Episode 392, episode return 1.0, last 20 avg 0.4
# Episode 393, episode return 0.0, last 20 avg 0.4
# Episode 394, episode return 1.0, last 20 avg 0.45
# Episode 395, episode return 0.0, last 20 avg 0.45
# Episode 396, episode return 0.0, last 20 avg 0.45
# Episode 397, episode return 0.0, last 20 avg 0.45
# Episode 398, episode return 1.0, last 20 avg 0.45
# Episode 399, episode return 0.0, last 20 avg 0.4
# Episode 400, episode return 0.0, last 20 avg 0.35
# Episode 401, episode return 1.0, last 20 avg 0.4
# Episode 402, episode return 0.0, last 20 avg 0.4
# Episode 403, episode return 0.0, last 20 avg 0.35
# Episode 404, episode return 0.0, last 20 avg 0.35
# Episode 405, episode return 0.0, last 20 avg 0.35
# Episode 406, episode return 0.0, last 20 avg 0.35
# Episode 407, episode return 0.0, last 20 avg 0.3
# Episode 408, episode return 0.0, last 20 avg 0.3
# Episode 409, episode return 0.0, last 20 avg 0.3
# Episode 410, episode return 0.0, last 20 avg 0.25
# Episode 411, episode return 0.0, last 20 avg 0.2
# Episode 412, episode return 1.0, last 20 avg 0.2
# Episode 413, episode return 1.0, last 20 avg 0.25
# Episode 414, episode return 0.0, last 20 avg 0.2
# Episode 415, episode return 0.0, last 20 avg 0.2
# Episode 416, episode return 0.0, last 20 avg 0.2
# Episode 417, episode return 0.0, last 20 avg 0.2
# Episode 418, episode return 0.0, last 20 avg 0.15
# Episode 419, episode return 0.0, last 20 avg 0.15
# Episode 420, episode return 1.0, last 20 avg 0.2
# Episode 421, episode return 0.0, last 20 avg 0.15
# Episode 422, episode return 0.0, last 20 avg 0.15
# Episode 423, episode return 1.0, last 20 avg 0.2
# Episode 424, episode return 0.0, last 20 avg 0.2
# Episode 425, episode return 0.0, last 20 avg 0.2
# Episode 426, episode return 0.0, last 20 avg 0.2
# Episode 427, episode return 1.0, last 20 avg 0.25
# Episode 428, episode return 0.0, last 20 avg 0.25
# Episode 429, episode return 0.0, last 20 avg 0.25
# Episode 430, episode return 0.0, last 20 avg 0.25
# Episode 431, episode return 1.0, last 20 avg 0.3
# Episode 432, episode return 1.0, last 20 avg 0.3
# Episode 433, episode return 0.0, last 20 avg 0.25
# Episode 434, episode return 0.0, last 20 avg 0.25
# Episode 435, episode return 0.0, last 20 avg 0.25
# Episode 436, episode return 0.0, last 20 avg 0.25
# Episode 437, episode return 0.0, last 20 avg 0.25
# Episode 438, episode return 0.0, last 20 avg 0.25
# Episode 439, episode return 1.0, last 20 avg 0.3
# Episode 440, episode return 0.0, last 20 avg 0.25
# Episode 441, episode return 1.0, last 20 avg 0.3
# Episode 442, episode return 0.0, last 20 avg 0.3
# Episode 443, episode return 0.0, last 20 avg 0.25
# Episode 444, episode return 1.0, last 20 avg 0.3
# Episode 445, episode return 0.0, last 20 avg 0.3
# Episode 446, episode return 0.0, last 20 avg 0.3
# Episode 447, episode return 1.0, last 20 avg 0.3
# Episode 448, episode return 0.0, last 20 avg 0.3
# Episode 449, episode return 1.0, last 20 avg 0.35
# Episode 450, episode return 0.0, last 20 avg 0.35
# Episode 451, episode return 0.0, last 20 avg 0.3
# Episode 452, episode return 0.0, last 20 avg 0.25
# Episode 453, episode return 0.0, last 20 avg 0.25
# Episode 454, episode return 0.0, last 20 avg 0.25
# Episode 455, episode return 0.0, last 20 avg 0.25
# Episode 456, episode return 0.0, last 20 avg 0.25
# Episode 457, episode return 1.0, last 20 avg 0.3
# Episode 458, episode return 0.0, last 20 avg 0.3
# Episode 459, episode return 0.0, last 20 avg 0.25
# Episode 460, episode return 0.0, last 20 avg 0.25
# Episode 461, episode return 1.0, last 20 avg 0.25
# Episode 462, episode return 0.0, last 20 avg 0.25
# Episode 463, episode return 1.0, last 20 avg 0.3
# Episode 464, episode return 0.0, last 20 avg 0.25
# Episode 465, episode return 0.0, last 20 avg 0.25
# Episode 466, episode return 1.0, last 20 avg 0.3
# Episode 467, episode return 0.0, last 20 avg 0.25
# Episode 468, episode return 1.0, last 20 avg 0.3
# Episode 469, episode return 0.0, last 20 avg 0.25
# Episode 470, episode return 0.0, last 20 avg 0.25
# Episode 471, episode return 0.0, last 20 avg 0.25
# Episode 472, episode return 0.0, last 20 avg 0.25
# Episode 473, episode return 0.0, last 20 avg 0.25
# Episode 474, episode return 0.0, last 20 avg 0.25
# Episode 475, episode return 1.0, last 20 avg 0.3
# Episode 476, episode return 0.0, last 20 avg 0.3
# Episode 477, episode return 1.0, last 20 avg 0.3
# Episode 478, episode return 0.0, last 20 avg 0.3
# Episode 479, episode return 1.0, last 20 avg 0.35
# Episode 480, episode return 0.0, last 20 avg 0.35
# Episode 481, episode return 1.0, last 20 avg 0.35
# Episode 482, episode return 0.0, last 20 avg 0.35
# Episode 483, episode return 0.0, last 20 avg 0.3
# Episode 484, episode return 0.0, last 20 avg 0.3
# Episode 485, episode return 0.0, last 20 avg 0.3
# Episode 486, episode return 1.0, last 20 avg 0.3
# Episode 487, episode return 0.0, last 20 avg 0.3
# Episode 488, episode return 0.0, last 20 avg 0.25
# Episode 489, episode return 0.0, last 20 avg 0.25
# Episode 490, episode return 0.0, last 20 avg 0.25
# Episode 491, episode return 1.0, last 20 avg 0.3
# Episode 492, episode return 1.0, last 20 avg 0.35
# Episode 493, episode return 0.0, last 20 avg 0.35
# Episode 494, episode return 0.0, last 20 avg 0.35
# Episode 495, episode return 0.0, last 20 avg 0.3
# Episode 496, episode return 0.0, last 20 avg 0.3
# Episode 497, episode return 0.0, last 20 avg 0.25
# Episode 498, episode return 1.0, last 20 avg 0.3
# Episode 499, episode return 0.0, last 20 avg 0.25
# Episode 500, episode return 1.0, last 20 avg 0.3
# Episode 501, episode return 1.0, last 20 avg 0.3
# Episode 502, episode return 1.0, last 20 avg 0.35
# Episode 503, episode return 0.0, last 20 avg 0.35
# Episode 504, episode return 1.0, last 20 avg 0.4
# Episode 505, episode return 0.0, last 20 avg 0.4
# Episode 506, episode return 0.0, last 20 avg 0.35
# Episode 507, episode return 1.0, last 20 avg 0.4
# Episode 508, episode return 0.0, last 20 avg 0.4
# Episode 509, episode return 0.0, last 20 avg 0.4
# Episode 510, episode return 0.0, last 20 avg 0.4
# Episode 511, episode return 0.0, last 20 avg 0.35
# Episode 512, episode return 1.0, last 20 avg 0.35
# Episode 513, episode return 0.0, last 20 avg 0.35
# Episode 514, episode return 0.0, last 20 avg 0.35
# Episode 515, episode return 0.0, last 20 avg 0.35
# Episode 516, episode return 0.0, last 20 avg 0.35
# Episode 517, episode return 0.0, last 20 avg 0.35
# Episode 518, episode return 1.0, last 20 avg 0.35
# Episode 519, episode return 1.0, last 20 avg 0.4
# Episode 520, episode return 1.0, last 20 avg 0.4
# Episode 521, episode return 1.0, last 20 avg 0.4
# Episode 522, episode return 1.0, last 20 avg 0.4
# Episode 523, episode return 1.0, last 20 avg 0.45
# Episode 524, episode return 0.0, last 20 avg 0.4
# Episode 525, episode return 0.0, last 20 avg 0.4
# Episode 526, episode return 0.0, last 20 avg 0.4
# Episode 527, episode return 1.0, last 20 avg 0.4
# Episode 528, episode return 1.0, last 20 avg 0.45
# Episode 529, episode return 0.0, last 20 avg 0.45
# Episode 530, episode return 0.0, last 20 avg 0.45
# Episode 531, episode return 1.0, last 20 avg 0.5
# Episode 532, episode return 0.0, last 20 avg 0.45
# Episode 533, episode return 1.0, last 20 avg 0.5
# Episode 534, episode return 0.0, last 20 avg 0.5
# Episode 535, episode return 1.0, last 20 avg 0.55
# Episode 536, episode return 1.0, last 20 avg 0.6
# Episode 537, episode return 1.0, last 20 avg 0.65
# Episode 538, episode return 0.0, last 20 avg 0.6
# Episode 539, episode return 1.0, last 20 avg 0.6
# Episode 540, episode return 0.0, last 20 avg 0.55
# Episode 541, episode return 0.0, last 20 avg 0.5
# Episode 542, episode return 0.0, last 20 avg 0.45
# Episode 543, episode return 1.0, last 20 avg 0.45
# Episode 544, episode return 1.0, last 20 avg 0.5
# Episode 545, episode return 1.0, last 20 avg 0.55
# Episode 546, episode return 0.0, last 20 avg 0.55
# Episode 547, episode return 0.0, last 20 avg 0.5
# Episode 548, episode return 0.0, last 20 avg 0.45
# Episode 549, episode return 0.0, last 20 avg 0.45
# Episode 550, episode return 0.0, last 20 avg 0.45
# Episode 551, episode return 1.0, last 20 avg 0.45
# Episode 552, episode return 1.0, last 20 avg 0.5
# Episode 553, episode return 0.0, last 20 avg 0.45
# Episode 554, episode return 1.0, last 20 avg 0.5
# Episode 555, episode return 0.0, last 20 avg 0.45
# Episode 556, episode return 0.0, last 20 avg 0.4
# Episode 557, episode return 0.0, last 20 avg 0.35
# Episode 558, episode return 1.0, last 20 avg 0.4
# Episode 559, episode return 0.0, last 20 avg 0.35
# Episode 560, episode return 0.0, last 20 avg 0.35
# Episode 561, episode return 0.0, last 20 avg 0.35
# Episode 562, episode return 1.0, last 20 avg 0.4
# Episode 563, episode return 1.0, last 20 avg 0.4
# Episode 564, episode return 0.0, last 20 avg 0.35
# Episode 565, episode return 1.0, last 20 avg 0.35
# Episode 566, episode return 0.0, last 20 avg 0.35
# Episode 567, episode return 0.0, last 20 avg 0.35
# Episode 568, episode return 0.0, last 20 avg 0.35
# Episode 569, episode return 0.0, last 20 avg 0.35
# Episode 570, episode return 1.0, last 20 avg 0.4
# Episode 571, episode return 0.0, last 20 avg 0.35
# Episode 572, episode return 0.0, last 20 avg 0.3
# Episode 573, episode return 0.0, last 20 avg 0.3
# Episode 574, episode return 0.0, last 20 avg 0.25
# Episode 575, episode return 0.0, last 20 avg 0.25
# Episode 576, episode return 0.0, last 20 avg 0.25
# Episode 577, episode return 1.0, last 20 avg 0.3
# Episode 578, episode return 0.0, last 20 avg 0.25
# Episode 579, episode return 1.0, last 20 avg 0.3
# Episode 580, episode return 1.0, last 20 avg 0.35
# Episode 581, episode return 0.0, last 20 avg 0.35
# Episode 582, episode return 1.0, last 20 avg 0.35
# Episode 583, episode return 1.0, last 20 avg 0.35
# Episode 584, episode return 1.0, last 20 avg 0.4
# Episode 585, episode return 0.0, last 20 avg 0.35
# Episode 586, episode return 0.0, last 20 avg 0.35
# Episode 587, episode return 1.0, last 20 avg 0.4
# Episode 588, episode return 0.0, last 20 avg 0.4
# Episode 589, episode return 0.0, last 20 avg 0.4
# Episode 590, episode return 0.0, last 20 avg 0.35
# Episode 591, episode return 1.0, last 20 avg 0.4
# Episode 592, episode return 0.0, last 20 avg 0.4
# Episode 593, episode return 1.0, last 20 avg 0.45
# Episode 594, episode return 0.0, last 20 avg 0.45
# Episode 595, episode return 1.0, last 20 avg 0.5
# Episode 596, episode return 1.0, last 20 avg 0.55
# Episode 597, episode return 0.0, last 20 avg 0.5
# Episode 598, episode return 1.0, last 20 avg 0.55
# Episode 599, episode return 1.0, last 20 avg 0.55
# ###################
#
#       SEED 1
#
# ###################
#
#  > Training HERAgent
#
# Episode 0, episode return 0.0, last 20 avg 0.0
# Episode 1, episode return 0.0, last 20 avg 0.0
# Episode 2, episode return 0.0, last 20 avg 0.0
# Episode 3, episode return 0.0, last 20 avg 0.0
# Episode 4, episode return 0.0, last 20 avg 0.0
# Episode 5, episode return 0.0, last 20 avg 0.0
# Episode 6, episode return 1.0, last 20 avg 0.14285714285714285
# Episode 7, episode return 0.0, last 20 avg 0.125
# Episode 8, episode return 0.0, last 20 avg 0.1111111111111111
# Episode 9, episode return 0.0, last 20 avg 0.1
# Episode 10, episode return 0.0, last 20 avg 0.09090909090909091
# Episode 11, episode return 0.0, last 20 avg 0.08333333333333333
# Episode 12, episode return 0.0, last 20 avg 0.07692307692307693
# Episode 13, episode return 0.0, last 20 avg 0.07142857142857142
# Episode 14, episode return 0.0, last 20 avg 0.06666666666666667
# Episode 15, episode return 0.0, last 20 avg 0.0625
# Episode 16, episode return 0.0, last 20 avg 0.058823529411764705
# Episode 17, episode return 0.0, last 20 avg 0.05555555555555555
# Episode 18, episode return 0.0, last 20 avg 0.05263157894736842
# Episode 19, episode return 0.0, last 20 avg 0.05
# Episode 20, episode return 0.0, last 20 avg 0.05
# Episode 21, episode return 0.0, last 20 avg 0.05
# Episode 22, episode return 1.0, last 20 avg 0.1
# Episode 23, episode return 0.0, last 20 avg 0.1
# Episode 24, episode return 0.0, last 20 avg 0.1
# Episode 25, episode return 0.0, last 20 avg 0.1
# Episode 26, episode return 0.0, last 20 avg 0.05
# Episode 27, episode return 0.0, last 20 avg 0.05
# Episode 28, episode return 0.0, last 20 avg 0.05
# Episode 29, episode return 0.0, last 20 avg 0.05
# Episode 30, episode return 1.0, last 20 avg 0.1
# Episode 31, episode return 0.0, last 20 avg 0.1
# Episode 32, episode return 0.0, last 20 avg 0.1
# Episode 33, episode return 0.0, last 20 avg 0.1
# Episode 34, episode return 0.0, last 20 avg 0.1
# Episode 35, episode return 0.0, last 20 avg 0.1
# Episode 36, episode return 0.0, last 20 avg 0.1
# Episode 37, episode return 0.0, last 20 avg 0.1
# Episode 38, episode return 0.0, last 20 avg 0.1
# Episode 39, episode return 0.0, last 20 avg 0.1
# Episode 40, episode return 0.0, last 20 avg 0.1
# Episode 41, episode return 1.0, last 20 avg 0.15
# Episode 42, episode return 0.0, last 20 avg 0.1
# Episode 43, episode return 0.0, last 20 avg 0.1
# Episode 44, episode return 0.0, last 20 avg 0.1
# Episode 45, episode return 0.0, last 20 avg 0.1
# Episode 46, episode return 0.0, last 20 avg 0.1
# Episode 47, episode return 0.0, last 20 avg 0.1
# Episode 48, episode return 0.0, last 20 avg 0.1
# Episode 49, episode return 0.0, last 20 avg 0.1
# Episode 50, episode return 0.0, last 20 avg 0.05
# Episode 51, episode return 0.0, last 20 avg 0.05
# Episode 52, episode return 0.0, last 20 avg 0.05
# Episode 53, episode return 0.0, last 20 avg 0.05
# Episode 54, episode return 0.0, last 20 avg 0.05
# Episode 55, episode return 0.0, last 20 avg 0.05
# Episode 56, episode return 0.0, last 20 avg 0.05
# Episode 57, episode return 0.0, last 20 avg 0.05
# Episode 58, episode return 1.0, last 20 avg 0.1
# Episode 59, episode return 0.0, last 20 avg 0.1
# Episode 60, episode return 0.0, last 20 avg 0.1
# Episode 61, episode return 0.0, last 20 avg 0.05
# Episode 62, episode return 1.0, last 20 avg 0.1
# Episode 63, episode return 0.0, last 20 avg 0.1
# Episode 64, episode return 0.0, last 20 avg 0.1
# Episode 65, episode return 0.0, last 20 avg 0.1
# Episode 66, episode return 0.0, last 20 avg 0.1
# Episode 67, episode return 0.0, last 20 avg 0.1
# Episode 68, episode return 0.0, last 20 avg 0.1
# Episode 69, episode return 1.0, last 20 avg 0.15
# Episode 70, episode return 0.0, last 20 avg 0.15
# Episode 71, episode return 0.0, last 20 avg 0.15
# Episode 72, episode return 0.0, last 20 avg 0.15
# Episode 73, episode return 0.0, last 20 avg 0.15
# Episode 74, episode return 0.0, last 20 avg 0.15
# Episode 75, episode return 0.0, last 20 avg 0.15
# Episode 76, episode return 0.0, last 20 avg 0.15
# Episode 77, episode return 1.0, last 20 avg 0.2
# Episode 78, episode return 0.0, last 20 avg 0.15
# Episode 79, episode return 0.0, last 20 avg 0.15
# Episode 80, episode return 0.0, last 20 avg 0.15
# Episode 81, episode return 0.0, last 20 avg 0.15
# Episode 82, episode return 0.0, last 20 avg 0.1
# Episode 83, episode return 0.0, last 20 avg 0.1
# Episode 84, episode return 0.0, last 20 avg 0.1
# Episode 85, episode return 0.0, last 20 avg 0.1
# Episode 86, episode return 0.0, last 20 avg 0.1
# Episode 87, episode return 1.0, last 20 avg 0.15
# Episode 88, episode return 1.0, last 20 avg 0.2
# Episode 89, episode return 0.0, last 20 avg 0.15
# Episode 90, episode return 0.0, last 20 avg 0.15
# Episode 91, episode return 0.0, last 20 avg 0.15
# Episode 92, episode return 0.0, last 20 avg 0.15
# Episode 93, episode return 0.0, last 20 avg 0.15
# Episode 94, episode return 0.0, last 20 avg 0.15
# Episode 95, episode return 0.0, last 20 avg 0.15
# Episode 96, episode return 0.0, last 20 avg 0.15
# Episode 97, episode return 0.0, last 20 avg 0.1
# Episode 98, episode return 1.0, last 20 avg 0.15
# Episode 99, episode return 0.0, last 20 avg 0.15
# Episode 100, episode return 1.0, last 20 avg 0.2
# Episode 101, episode return 0.0, last 20 avg 0.2
# Episode 102, episode return 1.0, last 20 avg 0.25
# Episode 103, episode return 0.0, last 20 avg 0.25
# Episode 104, episode return 0.0, last 20 avg 0.25
# Episode 105, episode return 0.0, last 20 avg 0.25
# Episode 106, episode return 0.0, last 20 avg 0.25
# Episode 107, episode return 0.0, last 20 avg 0.2
# Episode 108, episode return 0.0, last 20 avg 0.15
# Episode 109, episode return 0.0, last 20 avg 0.15
# Episode 110, episode return 0.0, last 20 avg 0.15
# Episode 111, episode return 0.0, last 20 avg 0.15
# Episode 112, episode return 0.0, last 20 avg 0.15
# Episode 113, episode return 0.0, last 20 avg 0.15
# Episode 114, episode return 0.0, last 20 avg 0.15
# Episode 115, episode return 1.0, last 20 avg 0.2
# Episode 116, episode return 0.0, last 20 avg 0.2
# Episode 117, episode return 0.0, last 20 avg 0.2
# Episode 118, episode return 0.0, last 20 avg 0.15
# Episode 119, episode return 1.0, last 20 avg 0.2
# Episode 120, episode return 0.0, last 20 avg 0.15
# Episode 121, episode return 0.0, last 20 avg 0.15
# Episode 122, episode return 0.0, last 20 avg 0.1
# Episode 123, episode return 0.0, last 20 avg 0.1
# Episode 124, episode return 0.0, last 20 avg 0.1
# Episode 125, episode return 1.0, last 20 avg 0.15
# Episode 126, episode return 0.0, last 20 avg 0.15
# Episode 127, episode return 0.0, last 20 avg 0.15
# Episode 128, episode return 1.0, last 20 avg 0.2
# Episode 129, episode return 0.0, last 20 avg 0.2
# Episode 130, episode return 0.0, last 20 avg 0.2
# Episode 131, episode return 1.0, last 20 avg 0.25
# Episode 132, episode return 0.0, last 20 avg 0.25
# Episode 133, episode return 0.0, last 20 avg 0.25
# Episode 134, episode return 1.0, last 20 avg 0.3
# Episode 135, episode return 0.0, last 20 avg 0.25
# Episode 136, episode return 0.0, last 20 avg 0.25
# Episode 137, episode return 0.0, last 20 avg 0.25
# Episode 138, episode return 0.0, last 20 avg 0.25
# Episode 139, episode return 0.0, last 20 avg 0.2
# Episode 140, episode return 0.0, last 20 avg 0.2
# Episode 141, episode return 0.0, last 20 avg 0.2
# Episode 142, episode return 0.0, last 20 avg 0.2
# Episode 143, episode return 0.0, last 20 avg 0.2
# Episode 144, episode return 0.0, last 20 avg 0.2
# Episode 145, episode return 0.0, last 20 avg 0.15
# Episode 146, episode return 0.0, last 20 avg 0.15
# Episode 147, episode return 0.0, last 20 avg 0.15
# Episode 148, episode return 0.0, last 20 avg 0.1
# Episode 149, episode return 1.0, last 20 avg 0.15
# Episode 150, episode return 0.0, last 20 avg 0.15
# Episode 151, episode return 0.0, last 20 avg 0.1
# Episode 152, episode return 0.0, last 20 avg 0.1
# Episode 153, episode return 0.0, last 20 avg 0.1
# Episode 154, episode return 1.0, last 20 avg 0.1
# Episode 155, episode return 0.0, last 20 avg 0.1
# Episode 156, episode return 0.0, last 20 avg 0.1
# Episode 157, episode return 0.0, last 20 avg 0.1
# Episode 158, episode return 0.0, last 20 avg 0.1
# Episode 159, episode return 0.0, last 20 avg 0.1
# Episode 160, episode return 0.0, last 20 avg 0.1
# Episode 161, episode return 1.0, last 20 avg 0.15
# Episode 162, episode return 0.0, last 20 avg 0.15
# Episode 163, episode return 1.0, last 20 avg 0.2
# Episode 164, episode return 0.0, last 20 avg 0.2
# Episode 165, episode return 1.0, last 20 avg 0.25
# Episode 166, episode return 1.0, last 20 avg 0.3
# Episode 167, episode return 0.0, last 20 avg 0.3
# Episode 168, episode return 0.0, last 20 avg 0.3
# Episode 169, episode return 0.0, last 20 avg 0.25
# Episode 170, episode return 0.0, last 20 avg 0.25
# Episode 171, episode return 1.0, last 20 avg 0.3
# Episode 172, episode return 1.0, last 20 avg 0.35
# Episode 173, episode return 1.0, last 20 avg 0.4
# Episode 174, episode return 0.0, last 20 avg 0.35
# Episode 175, episode return 0.0, last 20 avg 0.35
# Episode 176, episode return 0.0, last 20 avg 0.35
# Episode 177, episode return 0.0, last 20 avg 0.35
# Episode 178, episode return 0.0, last 20 avg 0.35
# Episode 179, episode return 0.0, last 20 avg 0.35
# Episode 180, episode return 0.0, last 20 avg 0.35
# Episode 181, episode return 1.0, last 20 avg 0.35
# Episode 182, episode return 0.0, last 20 avg 0.35
# Episode 183, episode return 1.0, last 20 avg 0.35
# Episode 184, episode return 0.0, last 20 avg 0.35
# Episode 185, episode return 1.0, last 20 avg 0.35
# Episode 186, episode return 0.0, last 20 avg 0.3
# Episode 187, episode return 0.0, last 20 avg 0.3
# Episode 188, episode return 0.0, last 20 avg 0.3
# Episode 189, episode return 0.0, last 20 avg 0.3
# Episode 190, episode return 0.0, last 20 avg 0.3
# Episode 191, episode return 1.0, last 20 avg 0.3
# Episode 192, episode return 0.0, last 20 avg 0.25
# Episode 193, episode return 1.0, last 20 avg 0.25
# Episode 194, episode return 0.0, last 20 avg 0.25
# Episode 195, episode return 0.0, last 20 avg 0.25
# Episode 196, episode return 1.0, last 20 avg 0.3
# Episode 197, episode return 0.0, last 20 avg 0.3
# Episode 198, episode return 0.0, last 20 avg 0.3
# Episode 199, episode return 1.0, last 20 avg 0.35
# Episode 200, episode return 1.0, last 20 avg 0.4
# Episode 201, episode return 0.0, last 20 avg 0.35
# Episode 202, episode return 0.0, last 20 avg 0.35
# Episode 203, episode return 1.0, last 20 avg 0.35
# Episode 204, episode return 0.0, last 20 avg 0.35
# Episode 205, episode return 0.0, last 20 avg 0.3
# Episode 206, episode return 0.0, last 20 avg 0.3
# Episode 207, episode return 0.0, last 20 avg 0.3
# Episode 208, episode return 0.0, last 20 avg 0.3
# Episode 209, episode return 1.0, last 20 avg 0.35
# Episode 210, episode return 1.0, last 20 avg 0.4
# Episode 211, episode return 1.0, last 20 avg 0.4
# Episode 212, episode return 1.0, last 20 avg 0.45
# Episode 213, episode return 0.0, last 20 avg 0.4
# Episode 214, episode return 1.0, last 20 avg 0.45
# Episode 215, episode return 0.0, last 20 avg 0.45
# Episode 216, episode return 0.0, last 20 avg 0.4
# Episode 217, episode return 0.0, last 20 avg 0.4
# Episode 218, episode return 1.0, last 20 avg 0.45
# Episode 219, episode return 1.0, last 20 avg 0.45
# Episode 220, episode return 0.0, last 20 avg 0.4
# Episode 221, episode return 0.0, last 20 avg 0.4
# Episode 222, episode return 1.0, last 20 avg 0.45
# Episode 223, episode return 1.0, last 20 avg 0.45
# Episode 224, episode return 1.0, last 20 avg 0.5
# Episode 225, episode return 0.0, last 20 avg 0.5
# Episode 226, episode return 0.0, last 20 avg 0.5
# Episode 227, episode return 1.0, last 20 avg 0.55
# Episode 228, episode return 0.0, last 20 avg 0.55
# Episode 229, episode return 1.0, last 20 avg 0.55
# Episode 230, episode return 0.0, last 20 avg 0.5
# Episode 231, episode return 1.0, last 20 avg 0.5
# Episode 232, episode return 0.0, last 20 avg 0.45
# Episode 233, episode return 0.0, last 20 avg 0.45
# Episode 234, episode return 0.0, last 20 avg 0.4
# Episode 235, episode return 0.0, last 20 avg 0.4
# Episode 236, episode return 1.0, last 20 avg 0.45
# Episode 237, episode return 0.0, last 20 avg 0.45
# Episode 238, episode return 1.0, last 20 avg 0.45
# Episode 239, episode return 0.0, last 20 avg 0.4
# Episode 240, episode return 0.0, last 20 avg 0.4
# Episode 241, episode return 0.0, last 20 avg 0.4
# Episode 242, episode return 1.0, last 20 avg 0.4
# Episode 243, episode return 0.0, last 20 avg 0.35
# Episode 244, episode return 1.0, last 20 avg 0.35
# Episode 245, episode return 0.0, last 20 avg 0.35
# Episode 246, episode return 0.0, last 20 avg 0.35
# Episode 247, episode return 0.0, last 20 avg 0.3
# Episode 248, episode return 1.0, last 20 avg 0.35
# Episode 249, episode return 0.0, last 20 avg 0.3
# Episode 250, episode return 0.0, last 20 avg 0.3
# Episode 251, episode return 0.0, last 20 avg 0.25
# Episode 252, episode return 0.0, last 20 avg 0.25
# Episode 253, episode return 1.0, last 20 avg 0.3
# Episode 254, episode return 0.0, last 20 avg 0.3
# Episode 255, episode return 0.0, last 20 avg 0.3
# Episode 256, episode return 1.0, last 20 avg 0.3
# Episode 257, episode return 1.0, last 20 avg 0.35
# Episode 258, episode return 0.0, last 20 avg 0.3
# Episode 259, episode return 0.0, last 20 avg 0.3
# Episode 260, episode return 1.0, last 20 avg 0.35
# Episode 261, episode return 1.0, last 20 avg 0.4
# Episode 262, episode return 1.0, last 20 avg 0.4
# Episode 263, episode return 0.0, last 20 avg 0.4
# Episode 264, episode return 0.0, last 20 avg 0.35
# Episode 265, episode return 1.0, last 20 avg 0.4
# Episode 266, episode return 1.0, last 20 avg 0.45
# Episode 267, episode return 1.0, last 20 avg 0.5
# Episode 268, episode return 0.0, last 20 avg 0.45
# Episode 269, episode return 0.0, last 20 avg 0.45
# Episode 270, episode return 1.0, last 20 avg 0.5
# Episode 271, episode return 0.0, last 20 avg 0.5
# Episode 272, episode return 1.0, last 20 avg 0.55
# Episode 273, episode return 0.0, last 20 avg 0.5
# Episode 274, episode return 0.0, last 20 avg 0.5
# Episode 275, episode return 0.0, last 20 avg 0.5
# Episode 276, episode return 0.0, last 20 avg 0.45
# Episode 277, episode return 0.0, last 20 avg 0.4
# Episode 278, episode return 0.0, last 20 avg 0.4
# Episode 279, episode return 0.0, last 20 avg 0.4
# Episode 280, episode return 0.0, last 20 avg 0.35
# Episode 281, episode return 0.0, last 20 avg 0.3
# Episode 282, episode return 1.0, last 20 avg 0.3
# Episode 283, episode return 0.0, last 20 avg 0.3
# Episode 284, episode return 0.0, last 20 avg 0.3
# Episode 285, episode return 0.0, last 20 avg 0.25
# Episode 286, episode return 1.0, last 20 avg 0.25
# Episode 287, episode return 0.0, last 20 avg 0.2
# Episode 288, episode return 0.0, last 20 avg 0.2
# Episode 289, episode return 0.0, last 20 avg 0.2
# Episode 290, episode return 0.0, last 20 avg 0.15
# Episode 291, episode return 0.0, last 20 avg 0.15
# Episode 292, episode return 0.0, last 20 avg 0.1
# Episode 293, episode return 0.0, last 20 avg 0.1
# Episode 294, episode return 0.0, last 20 avg 0.1
# Episode 295, episode return 0.0, last 20 avg 0.1
# Episode 296, episode return 0.0, last 20 avg 0.1
# Episode 297, episode return 1.0, last 20 avg 0.15
# Episode 298, episode return 1.0, last 20 avg 0.2
# Episode 299, episode return 1.0, last 20 avg 0.25
# Episode 300, episode return 1.0, last 20 avg 0.3
# Episode 301, episode return 0.0, last 20 avg 0.3
# Episode 302, episode return 0.0, last 20 avg 0.25
# Episode 303, episode return 0.0, last 20 avg 0.25
# Episode 304, episode return 0.0, last 20 avg 0.25
# Episode 305, episode return 1.0, last 20 avg 0.3
# Episode 306, episode return 0.0, last 20 avg 0.25
# Episode 307, episode return 1.0, last 20 avg 0.3
# Episode 308, episode return 0.0, last 20 avg 0.3
# Episode 309, episode return 0.0, last 20 avg 0.3
# Episode 310, episode return 0.0, last 20 avg 0.3
# Episode 311, episode return 0.0, last 20 avg 0.3
# Episode 312, episode return 1.0, last 20 avg 0.35
# Episode 313, episode return 1.0, last 20 avg 0.4
# Episode 314, episode return 0.0, last 20 avg 0.4
# Episode 315, episode return 0.0, last 20 avg 0.4
# Episode 316, episode return 0.0, last 20 avg 0.4
# Episode 317, episode return 0.0, last 20 avg 0.35
# Episode 318, episode return 1.0, last 20 avg 0.35
# Episode 319, episode return 0.0, last 20 avg 0.3
# Episode 320, episode return 0.0, last 20 avg 0.25
# Episode 321, episode return 0.0, last 20 avg 0.25
# Episode 322, episode return 0.0, last 20 avg 0.25
# Episode 323, episode return 0.0, last 20 avg 0.25
# Episode 324, episode return 1.0, last 20 avg 0.3
# Episode 325, episode return 0.0, last 20 avg 0.25
# Episode 326, episode return 0.0, last 20 avg 0.25
# Episode 327, episode return 0.0, last 20 avg 0.2
# Episode 328, episode return 1.0, last 20 avg 0.25
# Episode 329, episode return 0.0, last 20 avg 0.25
# Episode 330, episode return 0.0, last 20 avg 0.25
# Episode 331, episode return 0.0, last 20 avg 0.25
# Episode 332, episode return 0.0, last 20 avg 0.2
# Episode 333, episode return 1.0, last 20 avg 0.2
# Episode 334, episode return 0.0, last 20 avg 0.2
# Episode 335, episode return 1.0, last 20 avg 0.25
# Episode 336, episode return 1.0, last 20 avg 0.3
# Episode 337, episode return 0.0, last 20 avg 0.3
# Episode 338, episode return 0.0, last 20 avg 0.25
# Episode 339, episode return 0.0, last 20 avg 0.25
# Episode 340, episode return 0.0, last 20 avg 0.25
# Episode 341, episode return 1.0, last 20 avg 0.3
# Episode 342, episode return 0.0, last 20 avg 0.3
# Episode 343, episode return 0.0, last 20 avg 0.3
# Episode 344, episode return 0.0, last 20 avg 0.25
# Episode 345, episode return 0.0, last 20 avg 0.25
# Episode 346, episode return 0.0, last 20 avg 0.25
# Episode 347, episode return 0.0, last 20 avg 0.25
# Episode 348, episode return 1.0, last 20 avg 0.25
# Episode 349, episode return 0.0, last 20 avg 0.25
# Episode 350, episode return 1.0, last 20 avg 0.3
# Episode 351, episode return 0.0, last 20 avg 0.3
# Episode 352, episode return 0.0, last 20 avg 0.3
# Episode 353, episode return 0.0, last 20 avg 0.25
# Episode 354, episode return 0.0, last 20 avg 0.25
# Episode 355, episode return 0.0, last 20 avg 0.2
# Episode 356, episode return 1.0, last 20 avg 0.2
# Episode 357, episode return 0.0, last 20 avg 0.2
# Episode 358, episode return 0.0, last 20 avg 0.2
# Episode 359, episode return 0.0, last 20 avg 0.2
# Episode 360, episode return 0.0, last 20 avg 0.2
# Episode 361, episode return 0.0, last 20 avg 0.15
# Episode 362, episode return 0.0, last 20 avg 0.15
# Episode 363, episode return 0.0, last 20 avg 0.15
# Episode 364, episode return 0.0, last 20 avg 0.15
# ...
# Episode 277, episode return 0.0, last 20 avg 0.4
# Episode 278, episode return 1.0, last 20 avg 0.45
# Episode 279, episode return 0.0, last 20 avg 0.45
# Episode 280, episode return 1.0, last 20 avg 0.5
# Episode 281, episode return 1.0, last 20 avg 0.55
# Episode 282, episode return 0.0, last 20 avg 0.55
# Episode 283, episode return 1.0, last 20 avg 0.6
# Episode 284, episode return 0.0, last 20 avg 0.6
# Episode 285, episode return 0.0, last 20 avg 0.55
# Episode 286, episode return 0.0, last 20 avg 0.55
# Episode 287, episode return 0.0, last 20 avg 0.5
# Episode 288, episode return 1.0, last 20 avg 0.5
# Episode 289, episode return 0.0, last 20 avg 0.45
# Episode 290, episode return 0.0, last 20 avg 0.45
# Episode 291, episode return 0.0, last 20 avg 0.45
# Episode 292, episode return 1.0, last 20 avg 0.5
# Episode 293, episode return 0.0, last 20 avg 0.45
# Episode 294, episode return 0.0, last 20 avg 0.4
# Episode 295, episode return 1.0, last 20 avg 0.4
# Episode 296, episode return 1.0, last 20 avg 0.4
# Episode 297, episode return 0.0, last 20 avg 0.4
# Episode 298, episode return 0.0, last 20 avg 0.35
# Episode 299, episode return 0.0, last 20 avg 0.35
# Episode 300, episode return 0.0, last 20 avg 0.3
# Episode 301, episode return 0.0, last 20 avg 0.25
# Episode 302, episode return 0.0, last 20 avg 0.25
# Episode 303, episode return 0.0, last 20 avg 0.2
# Episode 304, episode return 0.0, last 20 avg 0.2
# Episode 305, episode return 1.0, last 20 avg 0.25
# Episode 306, episode return 0.0, last 20 avg 0.25
# Episode 307, episode return 0.0, last 20 avg 0.25
# Episode 308, episode return 0.0, last 20 avg 0.2
# Episode 309, episode return 0.0, last 20 avg 0.2
# Episode 310, episode return 1.0, last 20 avg 0.25
# Episode 311, episode return 1.0, last 20 avg 0.3
# Episode 312, episode return 0.0, last 20 avg 0.25
# Episode 313, episode return 1.0, last 20 avg 0.3
# Episode 314, episode return 0.0, last 20 avg 0.3
# Episode 315, episode return 0.0, last 20 avg 0.25
# Episode 316, episode return 0.0, last 20 avg 0.2
# Episode 317, episode return 0.0, last 20 avg 0.2
# Episode 318, episode return 0.0, last 20 avg 0.2
# Episode 319, episode return 0.0, last 20 avg 0.2
# Episode 320, episode return 1.0, last 20 avg 0.25
# Episode 321, episode return 1.0, last 20 avg 0.3
# Episode 322, episode return 0.0, last 20 avg 0.3
# Episode 323, episode return 0.0, last 20 avg 0.3
# Episode 324, episode return 0.0, last 20 avg 0.3
# Episode 325, episode return 1.0, last 20 avg 0.3
# Episode 326, episode return 1.0, last 20 avg 0.35
# Episode 327, episode return 0.0, last 20 avg 0.35
# Episode 328, episode return 1.0, last 20 avg 0.4
# Episode 329, episode return 1.0, last 20 avg 0.45
# Episode 330, episode return 1.0, last 20 avg 0.45
# Episode 331, episode return 1.0, last 20 avg 0.45
# Episode 332, episode return 0.0, last 20 avg 0.45
# Episode 333, episode return 0.0, last 20 avg 0.4
# Episode 334, episode return 0.0, last 20 avg 0.4
# Episode 335, episode return 0.0, last 20 avg 0.4
# Episode 336, episode return 0.0, last 20 avg 0.4
# Episode 337, episode return 0.0, last 20 avg 0.4
# Episode 338, episode return 0.0, last 20 avg 0.4
# Episode 339, episode return 0.0, last 20 avg 0.4
# Episode 340, episode return 0.0, last 20 avg 0.35
# Episode 341, episode return 0.0, last 20 avg 0.3
# Episode 342, episode return 0.0, last 20 avg 0.3
# Episode 343, episode return 0.0, last 20 avg 0.3
# Episode 344, episode return 0.0, last 20 avg 0.3
# Episode 345, episode return 0.0, last 20 avg 0.25
# Episode 346, episode return 0.0, last 20 avg 0.2
# Episode 347, episode return 0.0, last 20 avg 0.2
# Episode 348, episode return 1.0, last 20 avg 0.2
# Episode 349, episode return 0.0, last 20 avg 0.15
# Episode 350, episode return 1.0, last 20 avg 0.15
# Episode 351, episode return 1.0, last 20 avg 0.15
# Episode 352, episode return 1.0, last 20 avg 0.2
# Episode 353, episode return 0.0, last 20 avg 0.2
# Episode 354, episode return 1.0, last 20 avg 0.25
# Episode 355, episode return 0.0, last 20 avg 0.25
# Episode 356, episode return 0.0, last 20 avg 0.25
# Episode 357, episode return 1.0, last 20 avg 0.3
# Episode 358, episode return 0.0, last 20 avg 0.3
# Episode 359, episode return 1.0, last 20 avg 0.35
# Episode 360, episode return 0.0, last 20 avg 0.35
# Episode 361, episode return 1.0, last 20 avg 0.4
# Episode 362, episode return 0.0, last 20 avg 0.4
# Episode 363, episode return 1.0, last 20 avg 0.45
# Episode 364, episode return 0.0, last 20 avg 0.45
# Episode 365, episode return 0.0, last 20 avg 0.45
# Episode 366, episode return 1.0, last 20 avg 0.5
# Episode 367, episode return 0.0, last 20 avg 0.5
# Episode 368, episode return 0.0, last 20 avg 0.45
# Episode 369, episode return 1.0, last 20 avg 0.5
# Episode 370, episode return 0.0, last 20 avg 0.45
# Episode 371, episode return 0.0, last 20 avg 0.4
# Episode 372, episode return 0.0, last 20 avg 0.35
# Episode 373, episode return 0.0, last 20 avg 0.35
# Episode 374, episode return 0.0, last 20 avg 0.3
# Episode 375, episode return 1.0, last 20 avg 0.35
# Episode 376, episode return 1.0, last 20 avg 0.4
# Episode 377, episode return 0.0, last 20 avg 0.35
# Episode 378, episode return 0.0, last 20 avg 0.35
# Episode 379, episode return 0.0, last 20 avg 0.3
# Episode 380, episode return 0.0, last 20 avg 0.3
# Episode 381, episode return 0.0, last 20 avg 0.25
# Episode 382, episode return 0.0, last 20 avg 0.25
# Episode 383, episode return 0.0, last 20 avg 0.2
# Episode 384, episode return 0.0, last 20 avg 0.2
# Episode 385, episode return 1.0, last 20 avg 0.25
# Episode 386, episode return 0.0, last 20 avg 0.2
# Episode 387, episode return 1.0, last 20 avg 0.25
# Episode 388, episode return 0.0, last 20 avg 0.25
# Episode 389, episode return 0.0, last 20 avg 0.2
# Episode 390, episode return 1.0, last 20 avg 0.25
# Episode 391, episode return 1.0, last 20 avg 0.3
# Episode 392, episode return 0.0, last 20 avg 0.3
# Episode 393, episode return 1.0, last 20 avg 0.35
# Episode 394, episode return 1.0, last 20 avg 0.4
# Episode 395, episode return 0.0, last 20 avg 0.35
# Episode 396, episode return 1.0, last 20 avg 0.35
# Episode 397, episode return 0.0, last 20 avg 0.35
# Episode 398, episode return 0.0, last 20 avg 0.35
# Episode 399, episode return 0.0, last 20 avg 0.35
# Episode 400, episode return 0.0, last 20 avg 0.35
# Episode 401, episode return 0.0, last 20 avg 0.35
# Episode 402, episode return 0.0, last 20 avg 0.35
# Episode 403, episode return 1.0, last 20 avg 0.4
# Episode 404, episode return 0.0, last 20 avg 0.4
# Episode 405, episode return 0.0, last 20 avg 0.35
# Episode 406, episode return 1.0, last 20 avg 0.4
# Episode 407, episode return 0.0, last 20 avg 0.35
# Episode 408, episode return 1.0, last 20 avg 0.4
# Episode 409, episode return 0.0, last 20 avg 0.4
# Episode 410, episode return 0.0, last 20 avg 0.35
# Episode 411, episode return 1.0, last 20 avg 0.35
# Episode 412, episode return 0.0, last 20 avg 0.35
# Episode 413, episode return 0.0, last 20 avg 0.3
# Episode 414, episode return 1.0, last 20 avg 0.3
# Episode 415, episode return 1.0, last 20 avg 0.35
# Episode 416, episode return 0.0, last 20 avg 0.3
# Episode 417, episode return 0.0, last 20 avg 0.3
# Episode 418, episode return 0.0, last 20 avg 0.3
# Episode 419, episode return 0.0, last 20 avg 0.3
# Episode 420, episode return 1.0, last 20 avg 0.35
# Episode 421, episode return 1.0, last 20 avg 0.4
# Episode 422, episode return 0.0, last 20 avg 0.4
# Episode 423, episode return 0.0, last 20 avg 0.35
# Episode 424, episode return 0.0, last 20 avg 0.35
# Episode 425, episode return 0.0, last 20 avg 0.35
# Episode 426, episode return 0.0, last 20 avg 0.3
# Episode 427, episode return 1.0, last 20 avg 0.35
# Episode 428, episode return 0.0, last 20 avg 0.3
# Episode 429, episode return 0.0, last 20 avg 0.3
# Episode 430, episode return 0.0, last 20 avg 0.3
# Episode 431, episode return 0.0, last 20 avg 0.25
# Episode 432, episode return 1.0, last 20 avg 0.3
# Episode 433, episode return 0.0, last 20 avg 0.3
# Episode 434, episode return 0.0, last 20 avg 0.25
# Episode 435, episode return 0.0, last 20 avg 0.2
# Episode 436, episode return 0.0, last 20 avg 0.2
# Episode 437, episode return 0.0, last 20 avg 0.2
# Episode 438, episode return 0.0, last 20 avg 0.2
# Episode 439, episode return 1.0, last 20 avg 0.25
# Episode 440, episode return 0.0, last 20 avg 0.2
# Episode 441, episode return 1.0, last 20 avg 0.2
# Episode 442, episode return 0.0, last 20 avg 0.2
# Episode 443, episode return 0.0, last 20 avg 0.2
# Episode 444, episode return 1.0, last 20 avg 0.25
# Episode 445, episode return 1.0, last 20 avg 0.3
# Episode 446, episode return 0.0, last 20 avg 0.3
# Episode 447, episode return 0.0, last 20 avg 0.25
# Episode 448, episode return 1.0, last 20 avg 0.3
# Episode 449, episode return 1.0, last 20 avg 0.35
# Episode 450, episode return 0.0, last 20 avg 0.35
# Episode 451, episode return 0.0, last 20 avg 0.35
# Episode 452, episode return 1.0, last 20 avg 0.35
# Episode 453, episode return 1.0, last 20 avg 0.4
# Episode 454, episode return 0.0, last 20 avg 0.4
# Episode 455, episode return 0.0, last 20 avg 0.4
# Episode 456, episode return 0.0, last 20 avg 0.4
# Episode 457, episode return 0.0, last 20 avg 0.4
# Episode 458, episode return 0.0, last 20 avg 0.4
# Episode 459, episode return 0.0, last 20 avg 0.35
# Episode 460, episode return 1.0, last 20 avg 0.4
# Episode 461, episode return 0.0, last 20 avg 0.35
# Episode 462, episode return 0.0, last 20 avg 0.35
# Episode 463, episode return 0.0, last 20 avg 0.35
# Episode 464, episode return 0.0, last 20 avg 0.3
# Episode 465, episode return 0.0, last 20 avg 0.25
# Episode 466, episode return 0.0, last 20 avg 0.25
# Episode 467, episode return 1.0, last 20 avg 0.3
# Episode 468, episode return 1.0, last 20 avg 0.3
# Episode 469, episode return 1.0, last 20 avg 0.3
# Episode 470, episode return 0.0, last 20 avg 0.3
# Episode 471, episode return 0.0, last 20 avg 0.3
# Episode 472, episode return 0.0, last 20 avg 0.25
# Episode 473, episode return 0.0, last 20 avg 0.2
# Episode 474, episode return 1.0, last 20 avg 0.25
# Episode 475, episode return 0.0, last 20 avg 0.25
# Episode 476, episode return 0.0, last 20 avg 0.25
# Episode 477, episode return 0.0, last 20 avg 0.25
# Episode 478, episode return 0.0, last 20 avg 0.25
# Episode 479, episode return 0.0, last 20 avg 0.25
# Episode 480, episode return 0.0, last 20 avg 0.2
# Episode 481, episode return 0.0, last 20 avg 0.2
# Episode 482, episode return 0.0, last 20 avg 0.2
# Episode 483, episode return 0.0, last 20 avg 0.2
# Episode 484, episode return 0.0, last 20 avg 0.2
# Episode 485, episode return 0.0, last 20 avg 0.2
# Episode 486, episode return 0.0, last 20 avg 0.2
# Episode 487, episode return 0.0, last 20 avg 0.15
# Episode 488, episode return 0.0, last 20 avg 0.1
# Episode 489, episode return 0.0, last 20 avg 0.05
# Episode 490, episode return 1.0, last 20 avg 0.1
# Episode 491, episode return 0.0, last 20 avg 0.1
# Episode 492, episode return 0.0, last 20 avg 0.1
# Episode 493, episode return 0.0, last 20 avg 0.1
# Episode 494, episode return 1.0, last 20 avg 0.1
# Episode 495, episode return 0.0, last 20 avg 0.1
# Episode 496, episode return 0.0, last 20 avg 0.1
# Episode 497, episode return 0.0, last 20 avg 0.1
# Episode 498, episode return 0.0, last 20 avg 0.1
# Episode 499, episode return 1.0, last 20 avg 0.15
# Episode 500, episode return 0.0, last 20 avg 0.15
# Episode 501, episode return 0.0, last 20 avg 0.15
# Episode 502, episode return 0.0, last 20 avg 0.15
# Episode 503, episode return 0.0, last 20 avg 0.15
# Episode 504, episode return 1.0, last 20 avg 0.2
# Episode 505, episode return 1.0, last 20 avg 0.25
# Episode 506, episode return 0.0, last 20 avg 0.25
# Episode 507, episode return 0.0, last 20 avg 0.25
# Episode 508, episode return 0.0, last 20 avg 0.25
# Episode 509, episode return 0.0, last 20 avg 0.25
# Episode 510, episode return 0.0, last 20 avg 0.2
# Episode 511, episode return 1.0, last 20 avg 0.25
# Episode 512, episode return 0.0, last 20 avg 0.25
# Episode 513, episode return 0.0, last 20 avg 0.25
# Episode 514, episode return 1.0, last 20 avg 0.25
# Episode 515, episode return 1.0, last 20 avg 0.3
# Episode 516, episode return 0.0, last 20 avg 0.3
# Episode 517, episode return 0.0, last 20 avg 0.3
# Episode 518, episode return 0.0, last 20 avg 0.3
# Episode 519, episode return 1.0, last 20 avg 0.3
# Episode 520, episode return 0.0, last 20 avg 0.3
# Episode 521, episode return 1.0, last 20 avg 0.35
# Episode 522, episode return 0.0, last 20 avg 0.35
# Episode 523, episode return 1.0, last 20 avg 0.4
# Episode 524, episode return 0.0, last 20 avg 0.35
# Episode 525, episode return 1.0, last 20 avg 0.35
# Episode 526, episode return 0.0, last 20 avg 0.35
# Episode 527, episode return 0.0, last 20 avg 0.35
# Episode 528, episode return 0.0, last 20 avg 0.35
# Episode 529, episode return 1.0, last 20 avg 0.4
# Episode 530, episode return 0.0, last 20 avg 0.4
# Episode 531, episode return 1.0, last 20 avg 0.4
# Episode 532, episode return 0.0, last 20 avg 0.4
# Episode 533, episode return 0.0, last 20 avg 0.4
# Episode 534, episode return 1.0, last 20 avg 0.4
# Episode 535, episode return 0.0, last 20 avg 0.35
# Episode 536, episode return 1.0, last 20 avg 0.4
# Episode 537, episode return 0.0, last 20 avg 0.4
# Episode 538, episode return 1.0, last 20 avg 0.45
# Episode 539, episode return 0.0, last 20 avg 0.4
# Episode 540, episode return 1.0, last 20 avg 0.45
# Episode 541, episode return 0.0, last 20 avg 0.4
# Episode 542, episode return 0.0, last 20 avg 0.4
# Episode 543, episode return 0.0, last 20 avg 0.35
# Episode 544, episode return 0.0, last 20 avg 0.35
# Episode 545, episode return 0.0, last 20 avg 0.3
# Episode 546, episode return 0.0, last 20 avg 0.3
# Episode 547, episode return 0.0, last 20 avg 0.3
# Episode 548, episode return 1.0, last 20 avg 0.35
# Episode 549, episode return 0.0, last 20 avg 0.3
# Episode 550, episode return 1.0, last 20 avg 0.35
# Episode 551, episode return 0.0, last 20 avg 0.3
# Episode 552, episode return 1.0, last 20 avg 0.35
# Episode 553, episode return 0.0, last 20 avg 0.35
# Episode 554, episode return 1.0, last 20 avg 0.35
# Episode 555, episode return 0.0, last 20 avg 0.35
# Episode 556, episode return 0.0, last 20 avg 0.3
# Episode 557, episode return 0.0, last 20 avg 0.3
# Episode 558, episode return 0.0, last 20 avg 0.25
# Episode 559, episode return 0.0, last 20 avg 0.25
# Episode 560, episode return 1.0, last 20 avg 0.25
# Episode 561, episode return 0.0, last 20 avg 0.25
# Episode 562, episode return 0.0, last 20 avg 0.25
# Episode 563, episode return 1.0, last 20 avg 0.3
# Episode 564, episode return 0.0, last 20 avg 0.3
# Episode 565, episode return 0.0, last 20 avg 0.3
# Episode 566, episode return 0.0, last 20 avg 0.3
# Episode 567, episode return 1.0, last 20 avg 0.35
# Episode 568, episode return 0.0, last 20 avg 0.3
# Episode 569, episode return 1.0, last 20 avg 0.35
# Episode 570, episode return 1.0, last 20 avg 0.35
# Episode 571, episode return 0.0, last 20 avg 0.35
# Episode 572, episode return 1.0, last 20 avg 0.35
# Episode 573, episode return 0.0, last 20 avg 0.35
# Episode 574, episode return 0.0, last 20 avg 0.3
# Episode 575, episode return 1.0, last 20 avg 0.35
# Episode 576, episode return 1.0, last 20 avg 0.4
# Episode 577, episode return 0.0, last 20 avg 0.4
# Episode 578, episode return 1.0, last 20 avg 0.45
# Episode 579, episode return 1.0, last 20 avg 0.5
# Episode 580, episode return 1.0, last 20 avg 0.5
# Episode 581, episode return 1.0, last 20 avg 0.55
# Episode 582, episode return 0.0, last 20 avg 0.55
# Episode 583, episode return 0.0, last 20 avg 0.5
# Episode 584, episode return 1.0, last 20 avg 0.55
# Episode 585, episode return 0.0, last 20 avg 0.55
# Episode 586, episode return 0.0, last 20 avg 0.55
# Episode 587, episode return 0.0, last 20 avg 0.5
# Episode 588, episode return 1.0, last 20 avg 0.55
# Episode 589, episode return 0.0, last 20 avg 0.5
# Episode 590, episode return 0.0, last 20 avg 0.45
# Episode 591, episode return 0.0, last 20 avg 0.45
# Episode 592, episode return 0.0, last 20 avg 0.4
# Episode 593, episode return 1.0, last 20 avg 0.45
# Episode 594, episode return 0.0, last 20 avg 0.45
# Episode 595, episode return 0.0, last 20 avg 0.4
# Episode 596, episode return 0.0, last 20 avg 0.35
# Episode 597, episode return 0.0, last 20 avg 0.35
# Episode 598, episode return 0.0, last 20 avg 0.3
# Episode 599, episode return 0.0, last 20 avg 0.25

# %% [markdown]
# We saw that our agent learn, but is not able to reach every environments. We will se why with the next environment.

# %% [markdown]
# ## Swing up
#
# Now we will try to use HER to beat swing up (the custom cart-pole environment you tried to beat on RL5 without success). But Swing up is not a goal-conditionned environment!

# %% [markdown]
# <div class="alert alert-warning">
# How can we adapt our swing up environment to make it generate goals that help the agent to beat the environment?
# <div/>

# %% [markdown]
# <details class="alert alert-danger">
#     <summary markdown="span"><b>Ready to see the answer? (click to expand)</b></summary>
#
# We can simply generate angles between -pi and pi and angle dot so it can be used as goals to reach.
# <details/>

# %% [markdown]
# <div class="alert alert-warning">
# How can test the ability of a goal reaching agent to beat the environment? (remember that we need to give him a goal to make it run)
# <div/>

# %% [markdown]
# <details class="alert alert-danger">
#     <summary markdown="span"><b>Ready to see the answer? (click to expand)</b></summary>
# We know the coordinate of the Swing Up reward (angle = 0, angle dot = 0), we just need to generate this goal and see if our agent can reach it.
# <details/>

# %% [markdown]
# I created a custom environment GoalSwingUp, that do the trick for you. It generage goal on reset(), and the test function coded above ask the environment to generate a specifig goal for test. Now, test the HER agent on GoalSwingUp:

# %%
def demonstration(agent, environment):
    agent.on_simulation_start()
    if isinstance(environment, GoalCartPoleSwingUp):
        state, goal = environment.reset(test=True)
    else:
        state, goal = environment.reset()
    agent.on_episode_start(state, goal)
    environment.render()
    image = environment.render()
    
    done = False
    while not done:
        action = agent.action(state)
        state, _, done, _ = environment.step(action)
        environment.render()

# %%
import numpy as np
import matplotlib.pyplot as plt
from environments.swingup import GoalCartPoleSwingUp

environment = GoalCartPoleSwingUp()

nb_seeds = 4
nb_episodes_per_simulations = 300

her_seeds_rewards_result = []
her_seeds_tests_result = []
colors = ["#ff0000", "#ff9500"]

for seed_id in range(nb_seeds):
    print()
    print("###################")
    print()
    print("      SEED " + str(seed_id))
    print()
    print("###################")

    print()
    print(" > Training HERAgent")
    print()
    her_agent = HERAgent(environment.observation_space, environment.action_space, goal_size=2)
    rewards_sum_per_episode, tests_results = simulation(environment, her_agent,
                                                        nb_episodes=nb_episodes_per_simulations)
    her_seeds_rewards_result.append(rewards_sum_per_episode)
    her_seeds_tests_result.append(tests_results)

    plt.cla()
    plt.title("Rewards sum per episode")
    her_means = np.mean(np.array(her_seeds_rewards_result), axis=0)
    her_stds = np.std(np.array(her_seeds_rewards_result), axis=0)
    plt.plot(her_means, color=colors[0], label="DQN + HER")
    plt.fill_between([x for x in range(len(her_means))], her_means + her_stds, her_means - her_stds, color=colors[0],
                     alpha=0.2)
    plt.legend()
    plt.show()

    plt.cla()
    plt.title("Tests grades evolution during agent learning")
    her_means = np.mean(np.array(her_seeds_tests_result), axis=0)
    her_stds = np.std(np.array(her_seeds_tests_result), axis=0)
    plt.plot(her_means, color=colors[0], label="DQN + HER")
    plt.fill_between([x for x in range(len(her_means))], her_means + her_stds, her_means - her_stds, color=colors[0],
                     alpha=0.2)
    
    demonstration(her_agent, environment)
    plt.legend()
    plt.show()
# Out:
# /home/ubuntu/anaconda3/envs/pie-rl/lib/python3.8/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /home/ubuntu/anaconda3/envs/pie-rl/lib/python3.8/site-packages/gym/logger.py:30: UserWarning: WARN: You are calling 'step()' even though this environment has already returned done = True. You should always call 'reset()' once you receive 'done = True' -- any further steps are undefined behavior.
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# ###################
#
#       SEED 0
#
# ###################
#
#  > Training HERAgent
#
# Episode 0, episode return 2.0, last 20 avg 2.0
# Episode 1, episode return -3.0, last 20 avg -0.5
# Episode 2, episode return -7.0, last 20 avg -2.6666666666666665
# Episode 3, episode return 0.0, last 20 avg -2.0
# Episode 4, episode return -6.0, last 20 avg -2.8
# Episode 5, episode return 4.0, last 20 avg -1.6666666666666667
# /tmp/ipykernel_8522/3548704813.py:20: DeprecationWarning: In future, it will be an error for 'np.bool_' scalars to be interpreted as an index
#   return list(map(lambda x:torch.Tensor(x).to(self.device), list(zip(*batch))))
# Episode 6, episode return 2.0, last 20 avg -1.1428571428571428
# Episode 7, episode return -3.0, last 20 avg -1.375
# Episode 8, episode return -6.0, last 20 avg -1.8888888888888888
# Episode 9, episode return 5.0, last 20 avg -1.2
# Episode 10, episode return -3.0, last 20 avg -1.3636363636363635
# Episode 11, episode return -7.0, last 20 avg -1.8333333333333333
# Episode 12, episode return -7.0, last 20 avg -2.230769230769231
# Episode 13, episode return -9.0, last 20 avg -2.7142857142857144
# Episode 14, episode return -10.0, last 20 avg -3.2
# Episode 15, episode return -8.0, last 20 avg -3.5
# Episode 16, episode return -10.0, last 20 avg -3.8823529411764706
# Episode 17, episode return -7.0, last 20 avg -4.055555555555555
# Episode 18, episode return -10.0, last 20 avg -4.368421052631579
# Episode 19, episode return -6.0, last 20 avg -4.45
# Episode 20, episode return 0.0, last 20 avg -4.55
# Episode 21, episode return -8.0, last 20 avg -4.8
# Episode 22, episode return -10.0, last 20 avg -4.95
# Episode 23, episode return -7.0, last 20 avg -5.3
# Episode 24, episode return -7.0, last 20 avg -5.35
# Episode 25, episode return -8.0, last 20 avg -5.95
# Episode 26, episode return -8.0, last 20 avg -6.45
# Episode 27, episode return -9.0, last 20 avg -6.75
# Episode 28, episode return -8.0, last 20 avg -6.85
# Episode 29, episode return -8.0, last 20 avg -7.5
# Episode 30, episode return -8.0, last 20 avg -7.75
# Episode 31, episode return -10.0, last 20 avg -7.9
# Episode 32, episode return -7.0, last 20 avg -7.9
# Episode 33, episode return -6.0, last 20 avg -7.75
# Episode 34, episode return 4.0, last 20 avg -7.05
# Episode 35, episode return 11.0, last 20 avg -6.1
# Episode 36, episode return -1.0, last 20 avg -5.65
# Episode 37, episode return 8.0, last 20 avg -4.9
# Episode 38, episode return 2.0, last 20 avg -4.3
# Episode 39, episode return 9.0, last 20 avg -3.55
# Episode 40, episode return -1.0, last 20 avg -3.6
# Episode 41, episode return -7.0, last 20 avg -3.55
# Episode 42, episode return -10.0, last 20 avg -3.55
# Episode 43, episode return 35.0, last 20 avg -1.45
# Episode 44, episode return 23.0, last 20 avg 0.05
# Episode 45, episode return -7.0, last 20 avg 0.1
# Episode 46, episode return -8.0, last 20 avg 0.1
# Episode 47, episode return -1.0, last 20 avg 0.5
# Episode 48, episode return -6.0, last 20 avg 0.6
# Episode 49, episode return 7.0, last 20 avg 1.35
# Episode 50, episode return 18.0, last 20 avg 2.65
# Episode 51, episode return -6.0, last 20 avg 2.85
# Episode 52, episode return -10.0, last 20 avg 2.7
# Episode 53, episode return -3.0, last 20 avg 2.85
# Episode 54, episode return 6.0, last 20 avg 2.95
# Episode 55, episode return 47.0, last 20 avg 4.75
# Episode 56, episode return 6.0, last 20 avg 5.1
# Episode 57, episode return -7.0, last 20 avg 4.35
# Episode 58, episode return 19.0, last 20 avg 5.2
# Episode 59, episode return 3.0, last 20 avg 4.9
# Episode 60, episode return -10.0, last 20 avg 4.45
# Episode 61, episode return 9.0, last 20 avg 5.25
# Episode 62, episode return 1.0, last 20 avg 5.8
# Episode 63, episode return 10.0, last 20 avg 4.55
# Episode 64, episode return -1.0, last 20 avg 3.35
# Episode 65, episode return 2.0, last 20 avg 3.8
# Episode 66, episode return 17.0, last 20 avg 5.05
# Episode 67, episode return 24.0, last 20 avg 6.3
# Episode 68, episode return 8.0, last 20 avg 7.0
# Episode 69, episode return -1.0, last 20 avg 6.6
# Episode 70, episode return -4.0, last 20 avg 5.5
# Episode 71, episode return 0.0, last 20 avg 5.8
# Episode 72, episode return 2.0, last 20 avg 6.4
# Episode 73, episode return 5.0, last 20 avg 6.8
# Episode 74, episode return 9.0, last 20 avg 6.95
# Episode 75, episode return 7.0, last 20 avg 4.95
# Episode 76, episode return 1.0, last 20 avg 4.7
# Episode 77, episode return -10.0, last 20 avg 4.55
# Episode 78, episode return 13.0, last 20 avg 4.25
# Episode 79, episode return -5.0, last 20 avg 3.85
# Episode 80, episode return -6.0, last 20 avg 4.05
# Episode 81, episode return -4.0, last 20 avg 3.4
# Episode 82, episode return -2.0, last 20 avg 3.25
# Episode 83, episode return -2.0, last 20 avg 2.65
# Episode 84, episode return -8.0, last 20 avg 2.3
# Episode 85, episode return -2.0, last 20 avg 2.1
# Episode 86, episode return -1.0, last 20 avg 1.2
# Episode 87, episode return 4.0, last 20 avg 0.2
# Episode 88, episode return 30.0, last 20 avg 1.3
# Episode 89, episode return 19.0, last 20 avg 2.3
# Episode 90, episode return 12.0, last 20 avg 3.1
# Episode 91, episode return -1.0, last 20 avg 3.05
# Episode 92, episode return 109.0, last 20 avg 8.4
# Episode 93, episode return 189.0, last 20 avg 17.6
# Episode 94, episode return 14.0, last 20 avg 17.85
# Episode 95, episode return 31.0, last 20 avg 19.05
# Episode 96, episode return -5.0, last 20 avg 18.75
# Episode 97, episode return -1.0, last 20 avg 19.2
# Episode 98, episode return 3.0, last 20 avg 18.7
# Episode 99, episode return 16.0, last 20 avg 19.75
# Episode 100, episode return 19.0, last 20 avg 21.0
# Episode 101, episode return 3.0, last 20 avg 21.35
# Episode 102, episode return -7.0, last 20 avg 21.1
# Episode 103, episode return -6.0, last 20 avg 20.9
# Episode 104, episode return -10.0, last 20 avg 20.8
# Episode 105, episode return 9.0, last 20 avg 21.35
# Episode 106, episode return 4.0, last 20 avg 21.6
# Episode 107, episode return -6.0, last 20 avg 21.1
# Episode 108, episode return -10.0, last 20 avg 19.1
# Episode 109, episode return 15.0, last 20 avg 18.9
# Episode 110, episode return 35.0, last 20 avg 20.05
# Episode 111, episode return 37.0, last 20 avg 21.95
# Episode 112, episode return 15.0, last 20 avg 17.25
# Episode 113, episode return 2.0, last 20 avg 7.9
# Episode 114, episode return 23.0, last 20 avg 8.35
# Episode 115, episode return 29.0, last 20 avg 8.25
# Episode 116, episode return 14.0, last 20 avg 9.2
# Episode 117, episode return 44.0, last 20 avg 11.45
# Episode 118, episode return 5.0, last 20 avg 11.55
# Episode 119, episode return 13.0, last 20 avg 11.4
# Episode 120, episode return 25.0, last 20 avg 11.7
# Episode 121, episode return -4.0, last 20 avg 11.35
# Episode 122, episode return 46.0, last 20 avg 14.0
# Episode 123, episode return 71.0, last 20 avg 17.85
# Episode 124, episode return 26.0, last 20 avg 19.65
# Episode 125, episode return -10.0, last 20 avg 18.7
# Episode 126, episode return 47.0, last 20 avg 20.85
# Episode 127, episode return -10.0, last 20 avg 20.65
# Episode 128, episode return 31.0, last 20 avg 22.7
# Episode 129, episode return -2.0, last 20 avg 21.85
# Episode 130, episode return -6.0, last 20 avg 19.8
# Episode 131, episode return 18.0, last 20 avg 18.85
# Episode 132, episode return 28.0, last 20 avg 19.5
# Episode 133, episode return -3.0, last 20 avg 19.25
# Episode 134, episode return -10.0, last 20 avg 17.6
# Episode 135, episode return -10.0, last 20 avg 15.65
# Episode 136, episode return 24.0, last 20 avg 16.15
# Episode 137, episode return 19.0, last 20 avg 14.9
# Episode 138, episode return 1.0, last 20 avg 14.7
# Episode 139, episode return 33.0, last 20 avg 15.7
# Episode 140, episode return 1.0, last 20 avg 14.5
# Episode 141, episode return 24.0, last 20 avg 15.9
# Episode 142, episode return 14.0, last 20 avg 14.3
# Episode 143, episode return 22.0, last 20 avg 11.85
# Episode 144, episode return -6.0, last 20 avg 10.25
# Episode 145, episode return 17.0, last 20 avg 11.6
# Episode 146, episode return 67.0, last 20 avg 12.6
# Episode 147, episode return -1.0, last 20 avg 13.05
# Episode 148, episode return 16.0, last 20 avg 12.3
# Episode 149, episode return 43.0, last 20 avg 14.55
# Episode 150, episode return 135.0, last 20 avg 21.6
# Episode 151, episode return 10.0, last 20 avg 21.2
# Episode 152, episode return 40.0, last 20 avg 21.8
# Episode 153, episode return 4.0, last 20 avg 22.15
# Episode 154, episode return 6.0, last 20 avg 22.95
# Episode 155, episode return 18.0, last 20 avg 24.35
# Episode 156, episode return 19.0, last 20 avg 24.1
# Episode 157, episode return 104.0, last 20 avg 28.35
# Episode 158, episode return 48.0, last 20 avg 30.7
# Episode 159, episode return 50.0, last 20 avg 31.55
# Episode 160, episode return -7.0, last 20 avg 31.15
# Episode 161, episode return 49.0, last 20 avg 32.4
# Episode 162, episode return 28.0, last 20 avg 33.1
# Episode 163, episode return -7.0, last 20 avg 31.65
# Episode 164, episode return 21.0, last 20 avg 33.0
# Episode 165, episode return -9.0, last 20 avg 31.7
# Episode 166, episode return -8.0, last 20 avg 27.95
# Episode 167, episode return -1.0, last 20 avg 27.95
# Episode 168, episode return -6.0, last 20 avg 26.85
# Episode 169, episode return -7.0, last 20 avg 24.35
# Episode 170, episode return 21.0, last 20 avg 18.65
# Episode 171, episode return -9.0, last 20 avg 17.7
# Episode 172, episode return -10.0, last 20 avg 15.2
# Episode 173, episode return 28.0, last 20 avg 16.4
# Episode 174, episode return 68.0, last 20 avg 19.5
# Episode 175, episode return -8.0, last 20 avg 18.2
# Episode 176, episode return -8.0, last 20 avg 16.85
# Episode 177, episode return 13.0, last 20 avg 12.3
# Episode 178, episode return 111.0, last 20 avg 15.45
# Episode 179, episode return 70.0, last 20 avg 16.45
# Episode 180, episode return 4.0, last 20 avg 17.0
# Episode 181, episode return -6.0, last 20 avg 14.25
# Episode 182, episode return 7.0, last 20 avg 13.2
# Episode 183, episode return 7.0, last 20 avg 13.9
# Episode 184, episode return -7.0, last 20 avg 12.5
# Episode 185, episode return 28.0, last 20 avg 14.35
# Episode 186, episode return 80.0, last 20 avg 18.75
# Episode 187, episode return -1.0, last 20 avg 18.75
# Episode 188, episode return 4.0, last 20 avg 19.25
# Episode 189, episode return 1.0, last 20 avg 19.65
# Episode 190, episode return 24.0, last 20 avg 19.8
# Episode 191, episode return 27.0, last 20 avg 21.6
# Episode 192, episode return 7.0, last 20 avg 22.45
# Episode 193, episode return 8.0, last 20 avg 21.45
# Episode 194, episode return 21.0, last 20 avg 19.1
# Episode 195, episode return 12.0, last 20 avg 20.1
# Episode 196, episode return 105.0, last 20 avg 25.75
# Episode 197, episode return 19.0, last 20 avg 26.05
# Episode 198, episode return 7.0, last 20 avg 20.85
# Episode 199, episode return 20.0, last 20 avg 18.35
# Episode 200, episode return 25.0, last 20 avg 19.4
# Episode 201, episode return 13.0, last 20 avg 20.35
# Episode 202, episode return 5.0, last 20 avg 20.25
# Episode 203, episode return 8.0, last 20 avg 20.3
# Episode 204, episode return -10.0, last 20 avg 20.15
# Episode 205, episode return 13.0, last 20 avg 19.4
# Episode 206, episode return 43.0, last 20 avg 17.55
# Episode 207, episode return -2.0, last 20 avg 17.5
# Episode 208, episode return -4.0, last 20 avg 17.1
# Episode 209, episode return -3.0, last 20 avg 16.9
# Episode 210, episode return 9.0, last 20 avg 16.15
# Episode 211, episode return -1.0, last 20 avg 14.75
# Episode 212, episode return 46.0, last 20 avg 16.7
# Episode 213, episode return 25.0, last 20 avg 17.55
# Episode 214, episode return 25.0, last 20 avg 17.75
# Episode 215, episode return -10.0, last 20 avg 16.65
# Episode 216, episode return 6.0, last 20 avg 11.7
# Episode 217, episode return 90.0, last 20 avg 15.25
# Episode 218, episode return 134.0, last 20 avg 21.6
# Episode 219, episode return -10.0, last 20 avg 20.1
# Episode 220, episode return 4.0, last 20 avg 19.05
# Episode 221, episode return 13.0, last 20 avg 19.05
# Episode 222, episode return 27.0, last 20 avg 20.15
# Episode 223, episode return 11.0, last 20 avg 20.3
# Episode 224, episode return -5.0, last 20 avg 20.55
# Episode 225, episode return -1.0, last 20 avg 19.85
# Episode 226, episode return -7.0, last 20 avg 17.35
# Episode 227, episode return 50.0, last 20 avg 19.95
# Episode 228, episode return -9.0, last 20 avg 19.7
# Episode 229, episode return 15.0, last 20 avg 20.6
# Episode 230, episode return 15.0, last 20 avg 20.9
# Episode 231, episode return 45.0, last 20 avg 23.2
# Episode 232, episode return -5.0, last 20 avg 20.65
# Episode 233, episode return 22.0, last 20 avg 20.5
# Episode 234, episode return 6.0, last 20 avg 19.55
# Episode 235, episode return 60.0, last 20 avg 23.05
# Episode 236, episode return 4.0, last 20 avg 22.95
# Episode 237, episode return -2.0, last 20 avg 18.35
# Episode 238, episode return 17.0, last 20 avg 12.5
# Episode 239, episode return 37.0, last 20 avg 14.85
# Episode 240, episode return -10.0, last 20 avg 14.15
# Episode 241, episode return 8.0, last 20 avg 13.9
# Episode 242, episode return -10.0, last 20 avg 12.05
# Episode 243, episode return 12.0, last 20 avg 12.1
# Episode 244, episode return 5.0, last 20 avg 12.6
# Episode 245, episode return 0.0, last 20 avg 12.65
# Episode 246, episode return 13.0, last 20 avg 13.65
# Episode 247, episode return 8.0, last 20 avg 11.55
# Episode 248, episode return -2.0, last 20 avg 11.9
# Episode 249, episode return 7.0, last 20 avg 11.5
# Episode 250, episode return 17.0, last 20 avg 11.6
# Episode 251, episode return 4.0, last 20 avg 9.55
# Episode 252, episode return 0.0, last 20 avg 9.8
# Episode 253, episode return -4.0, last 20 avg 8.5
# Episode 254, episode return 105.0, last 20 avg 13.45
# Episode 255, episode return 32.0, last 20 avg 12.05
# Episode 256, episode return -9.0, last 20 avg 11.4
# Episode 257, episode return 24.0, last 20 avg 12.7
# Episode 258, episode return -1.0, last 20 avg 11.8
# Episode 259, episode return 8.0, last 20 avg 10.35
# Episode 260, episode return 63.0, last 20 avg 14.0
# Episode 261, episode return 2.0, last 20 avg 13.7
# Episode 262, episode return 34.0, last 20 avg 15.9
# Episode 263, episode return 0.0, last 20 avg 15.3
# Episode 264, episode return -8.0, last 20 avg 14.65
# Episode 265, episode return -7.0, last 20 avg 14.3
# Episode 266, episode return 32.0, last 20 avg 15.25
# Episode 267, episode return 21.0, last 20 avg 15.9
# Episode 268, episode return -3.0, last 20 avg 15.85
# Episode 269, episode return 2.0, last 20 avg 15.6
# Episode 270, episode return 51.0, last 20 avg 17.3
# Episode 271, episode return 9.0, last 20 avg 17.55
# Episode 272, episode return 67.0, last 20 avg 20.9
# Episode 273, episode return -8.0, last 20 avg 20.7
# Episode 274, episode return 14.0, last 20 avg 16.15
# Episode 275, episode return 14.0, last 20 avg 15.25
# Episode 276, episode return 64.0, last 20 avg 18.9
# Episode 277, episode return -5.0, last 20 avg 17.45
# Episode 278, episode return -10.0, last 20 avg 17.0
# Episode 279, episode return -5.0, last 20 avg 16.35
# Episode 280, episode return -10.0, last 20 avg 12.7
# Episode 281, episode return 6.0, last 20 avg 12.9
# Episode 282, episode return 24.0, last 20 avg 12.4
# Episode 283, episode return 7.0, last 20 avg 12.75
# Episode 284, episode return 17.0, last 20 avg 14.0
# Episode 285, episode return -7.0, last 20 avg 14.0
# Episode 286, episode return 84.0, last 20 avg 16.6
# Episode 287, episode return 45.0, last 20 avg 17.8
# Episode 288, episode return -6.0, last 20 avg 17.65
# Episode 289, episode return 144.0, last 20 avg 24.75
# Episode 290, episode return -6.0, last 20 avg 21.9
# Episode 291, episode return 33.0, last 20 avg 23.1
# Episode 292, episode return -8.0, last 20 avg 19.35
# Episode 293, episode return -9.0, last 20 avg 19.3
# Episode 294, episode return -8.0, last 20 avg 18.2
# Episode 295, episode return -3.0, last 20 avg 17.35
# Episode 296, episode return 36.0, last 20 avg 15.95
# Episode 297, episode return 6.0, last 20 avg 16.5
# Episode 298, episode return 162.0, last 20 avg 25.1
# Episode 299, episode return -8.0, last 20 avg 24.95
# ###################
#
#       SEED 1
#
# ###################
#
#  > Training HERAgent
#
# Episode 0, episode return -7.0, last 20 avg -7.0
# Episode 1, episode return -8.0, last 20 avg -7.5
# /tmp/ipykernel_8522/3548704813.py:20: DeprecationWarning: In future, it will be an error for 'np.bool_' scalars to be interpreted as an index
#   return list(map(lambda x:torch.Tensor(x).to(self.device), list(zip(*batch))))
# Episode 2, episode return -6.0, last 20 avg -7.0
# Episode 3, episode return -6.0, last 20 avg -6.75
# Episode 4, episode return -1.0, last 20 avg -5.6
# Episode 5, episode return -5.0, last 20 avg -5.5
# Episode 6, episode return -5.0, last 20 avg -5.428571428571429
# Episode 7, episode return 2.0, last 20 avg -4.5
# Episode 8, episode return -8.0, last 20 avg -4.888888888888889
# Episode 9, episode return -1.0, last 20 avg -4.5
# Episode 10, episode return -10.0, last 20 avg -5.0
# Episode 11, episode return -7.0, last 20 avg -5.166666666666667
# Episode 12, episode return -1.0, last 20 avg -4.846153846153846
# Episode 13, episode return -8.0, last 20 avg -5.071428571428571
# Episode 14, episode return -7.0, last 20 avg -5.2
# Episode 15, episode return -7.0, last 20 avg -5.3125
# Episode 16, episode return -7.0, last 20 avg -5.411764705882353
# Episode 17, episode return -9.0, last 20 avg -5.611111111111111
# Episode 18, episode return 0.0, last 20 avg -5.315789473684211
# Episode 19, episode return -4.0, last 20 avg -5.25
# Episode 20, episode return -7.0, last 20 avg -5.25
# Episode 21, episode return 27.0, last 20 avg -3.5
# Episode 22, episode return 5.0, last 20 avg -2.95
# Episode 23, episode return 5.0, last 20 avg -2.4
# Episode 24, episode return -4.0, last 20 avg -2.55
# Episode 25, episode return 3.0, last 20 avg -2.15
# Episode 26, episode return -10.0, last 20 avg -2.4
# Episode 27, episode return 3.0, last 20 avg -2.35
# Episode 28, episode return 1.0, last 20 avg -1.9
# Episode 29, episode return 2.0, last 20 avg -1.75
# Episode 30, episode return 21.0, last 20 avg -0.2
# Episode 31, episode return -8.0, last 20 avg -0.25
# Episode 32, episode return 1.0, last 20 avg -0.15
# Episode 33, episode return -2.0, last 20 avg 0.15
# Episode 34, episode return 0.0, last 20 avg 0.5
# Episode 35, episode return -6.0, last 20 avg 0.55
# Episode 36, episode return -4.0, last 20 avg 0.7
# Episode 37, episode return -1.0, last 20 avg 1.1
# Episode 38, episode return -1.0, last 20 avg 1.05
# Episode 39, episode return 4.0, last 20 avg 1.45
# Episode 40, episode return -5.0, last 20 avg 1.55
# Episode 41, episode return 36.0, last 20 avg 2.0
# Episode 42, episode return -6.0, last 20 avg 1.45
# Episode 43, episode return -2.0, last 20 avg 1.1
# Episode 44, episode return 13.0, last 20 avg 1.95
# Episode 45, episode return -6.0, last 20 avg 1.5
# Episode 46, episode return -5.0, last 20 avg 1.75
# Episode 47, episode return -5.0, last 20 avg 1.35
# Episode 48, episode return -1.0, last 20 avg 1.25
# Episode 49, episode return -4.0, last 20 avg 0.95
# Episode 50, episode return -8.0, last 20 avg -0.5
# Episode 51, episode return 34.0, last 20 avg 1.6
# Episode 52, episode return -10.0, last 20 avg 1.05
# Episode 53, episode return -4.0, last 20 avg 0.95
# Episode 54, episode return 7.0, last 20 avg 1.3
# Episode 55, episode return 17.0, last 20 avg 2.45
# Episode 56, episode return -5.0, last 20 avg 2.4
# Episode 57, episode return -4.0, last 20 avg 2.25
# Episode 58, episode return 13.0, last 20 avg 2.95
# Episode 59, episode return 9.0, last 20 avg 3.2
# Episode 60, episode return 22.0, last 20 avg 4.55
# Episode 61, episode return 5.0, last 20 avg 3.0
# Episode 62, episode return 19.0, last 20 avg 4.25
# Episode 63, episode return 18.0, last 20 avg 5.25
# Episode 64, episode return 63.0, last 20 avg 7.75
# Episode 65, episode return -4.0, last 20 avg 7.85
# Episode 66, episode return 2.0, last 20 avg 8.2
# Episode 67, episode return 12.0, last 20 avg 9.05
# Episode 68, episode return 5.0, last 20 avg 9.35
# Episode 69, episode return 0.0, last 20 avg 9.55
# Episode 70, episode return -4.0, last 20 avg 9.75
# Episode 71, episode return 12.0, last 20 avg 8.65
# Episode 72, episode return 6.0, last 20 avg 9.45
# Episode 73, episode return -2.0, last 20 avg 9.55
# Episode 74, episode return -8.0, last 20 avg 8.8
# Episode 75, episode return 0.0, last 20 avg 7.95
# Episode 76, episode return -1.0, last 20 avg 8.15
# Episode 77, episode return 6.0, last 20 avg 8.65
# Episode 78, episode return 0.0, last 20 avg 8.0
# Episode 79, episode return 12.0, last 20 avg 8.15
# Episode 80, episode return 3.0, last 20 avg 7.2
# Episode 81, episode return 12.0, last 20 avg 7.55
# Episode 82, episode return 3.0, last 20 avg 6.75
# Episode 83, episode return 50.0, last 20 avg 8.35
# Episode 84, episode return 28.0, last 20 avg 6.6
# Episode 85, episode return 13.0, last 20 avg 7.45
# Episode 86, episode return 8.0, last 20 avg 7.75
# Episode 87, episode return -1.0, last 20 avg 7.1
# Episode 88, episode return 15.0, last 20 avg 7.6
# Episode 89, episode return -3.0, last 20 avg 7.45
# Episode 90, episode return -4.0, last 20 avg 7.45
# Episode 91, episode return 16.0, last 20 avg 7.65
# Episode 92, episode return -3.0, last 20 avg 7.2
# Episode 93, episode return 3.0, last 20 avg 7.45
# Episode 94, episode return 5.0, last 20 avg 8.1
# Episode 95, episode return 7.0, last 20 avg 8.45
# Episode 96, episode return 66.0, last 20 avg 11.8
# Episode 97, episode return 19.0, last 20 avg 12.45
# Episode 98, episode return 22.0, last 20 avg 13.55
# Episode 99, episode return 23.0, last 20 avg 14.1
# Episode 100, episode return -5.0, last 20 avg 13.7
# Episode 101, episode return 6.0, last 20 avg 13.4
# Episode 102, episode return 19.0, last 20 avg 14.2
# Episode 103, episode return 8.0, last 20 avg 12.1
# Episode 104, episode return 11.0, last 20 avg 11.25
# Episode 105, episode return -3.0, last 20 avg 10.45
# Episode 106, episode return 8.0, last 20 avg 10.45
# Episode 107, episode return 23.0, last 20 avg 11.65
# Episode 108, episode return -10.0, last 20 avg 10.4
# Episode 109, episode return 39.0, last 20 avg 12.5
# Episode 110, episode return 14.0, last 20 avg 13.4
# Episode 111, episode return 3.0, last 20 avg 12.75
# Episode 112, episode return -1.0, last 20 avg 12.85
# Episode 113, episode return 12.0, last 20 avg 13.3
# Episode 114, episode return 21.0, last 20 avg 14.1
# Episode 115, episode return -4.0, last 20 avg 13.55
# Episode 116, episode return 3.0, last 20 avg 10.4
# Episode 117, episode return 11.0, last 20 avg 10.0
# Episode 118, episode return -2.0, last 20 avg 8.8
# Episode 119, episode return -5.0, last 20 avg 7.4
# Episode 120, episode return 9.0, last 20 avg 8.1
# Episode 121, episode return 32.0, last 20 avg 9.4
# Episode 122, episode return 46.0, last 20 avg 10.75
# Episode 123, episode return -10.0, last 20 avg 9.85
# Episode 124, episode return -10.0, last 20 avg 8.8
# Episode 125, episode return 1.0, last 20 avg 9.0
# Episode 126, episode return 9.0, last 20 avg 9.05
# Episode 127, episode return 21.0, last 20 avg 8.95
# Episode 128, episode return 9.0, last 20 avg 9.9
# Episode 129, episode return -10.0, last 20 avg 7.45
# Episode 130, episode return -3.0, last 20 avg 6.6
# Episode 131, episode return 5.0, last 20 avg 6.7
# Episode 132, episode return 15.0, last 20 avg 7.5
# Episode 133, episode return 2.0, last 20 avg 7.0
# Episode 134, episode return -10.0, last 20 avg 5.45
# Episode 135, episode return 39.0, last 20 avg 7.6
# Episode 136, episode return 30.0, last 20 avg 8.95
# Episode 137, episode return 7.0, last 20 avg 8.75
# Episode 138, episode return 6.0, last 20 avg 9.15
# Episode 139, episode return -4.0, last 20 avg 9.2
# Episode 140, episode return 3.0, last 20 avg 8.9
# Episode 141, episode return 21.0, last 20 avg 8.35
# Episode 142, episode return 49.0, last 20 avg 8.5
# Episode 143, episode return 1.0, last 20 avg 9.05
# Episode 144, episode return 28.0, last 20 avg 10.95
# Episode 145, episode return 32.0, last 20 avg 12.5
# Episode 146, episode return -3.0, last 20 avg 11.9
# Episode 147, episode return -6.0, last 20 avg 10.55
# Episode 148, episode return 7.0, last 20 avg 10.45
# Episode 149, episode return 20.0, last 20 avg 11.95
# Episode 150, episode return 14.0, last 20 avg 12.8
# Episode 151, episode return 4.0, last 20 avg 12.75
# Episode 152, episode return 52.0, last 20 avg 14.6
# Episode 153, episode return 81.0, last 20 avg 18.55
# Episode 154, episode return 2.0, last 20 avg 19.15
# Episode 155, episode return 11.0, last 20 avg 17.75
# Episode 156, episode return 86.0, last 20 avg 20.55
# Episode 157, episode return 11.0, last 20 avg 20.75
# Episode 158, episode return 20.0, last 20 avg 21.45
# Episode 159, episode return 11.0, last 20 avg 22.2
# Episode 160, episode return 22.0, last 20 avg 23.15
# Episode 161, episode return 14.0, last 20 avg 22.8
# Episode 162, episode return 9.0, last 20 avg 20.8
# Episode 163, episode return -7.0, last 20 avg 20.4
# Episode 164, episode return 13.0, last 20 avg 19.65
# Episode 165, episode return 31.0, last 20 avg 19.6
# Episode 166, episode return 11.0, last 20 avg 20.3
# Episode 167, episode return 21.0, last 20 avg 21.65
# Episode 168, episode return 16.0, last 20 avg 22.1
# Episode 169, episode return 39.0, last 20 avg 23.05
# Episode 170, episode return 7.0, last 20 avg 22.7
# Episode 171, episode return -3.0, last 20 avg 22.35
# Episode 172, episode return 130.0, last 20 avg 26.25
# Episode 173, episode return 3.0, last 20 avg 22.35
# Episode 174, episode return 4.0, last 20 avg 22.45
# Episode 175, episode return 67.0, last 20 avg 25.25
# Episode 176, episode return 58.0, last 20 avg 23.85
# Episode 177, episode return -8.0, last 20 avg 22.9
# Episode 178, episode return -10.0, last 20 avg 21.4
# Episode 179, episode return 33.0, last 20 avg 22.5
# Episode 180, episode return -8.0, last 20 avg 21.0
# Episode 181, episode return 55.0, last 20 avg 23.05
# Episode 182, episode return -6.0, last 20 avg 22.3
# Episode 183, episode return 9.0, last 20 avg 23.1
# Episode 184, episode return 23.0, last 20 avg 23.6
# Episode 185, episode return 54.0, last 20 avg 24.75
# Episode 186, episode return 14.0, last 20 avg 24.9
# Episode 187, episode return 0.0, last 20 avg 23.85
# Episode 188, episode return -7.0, last 20 avg 22.7
# Episode 189, episode return 16.0, last 20 avg 21.55
# Episode 190, episode return 28.0, last 20 avg 22.6
# Episode 191, episode return 10.0, last 20 avg 23.25
# Episode 192, episode return 22.0, last 20 avg 17.85
# Episode 193, episode return 33.0, last 20 avg 19.35
# Episode 194, episode return 14.0, last 20 avg 19.85
# Episode 195, episode return -6.0, last 20 avg 16.2
# Episode 196, episode return -8.0, last 20 avg 12.9
# Episode 197, episode return -8.0, last 20 avg 12.9
# Episode 198, episode return 57.0, last 20 avg 16.25
# Episode 199, episode return 28.0, last 20 avg 16.0
# Episode 200, episode return 0.0, last 20 avg 16.4
# Episode 201, episode return 38.0, last 20 avg 15.55
# Episode 202, episode return -2.0, last 20 avg 15.75
# Episode 203, episode return 19.0, last 20 avg 16.25
# Episode 204, episode return 22.0, last 20 avg 16.2
# Episode 205, episode return 4.0, last 20 avg 13.7
# Episode 206, episode return 85.0, last 20 avg 17.25
# Episode 207, episode return 9.0, last 20 avg 17.7
# Episode 208, episode return 16.0, last 20 avg 18.85
# Episode 209, episode return -4.0, last 20 avg 17.85
# Episode 210, episode return 14.0, last 20 avg 17.15
# Episode 211, episode return 5.0, last 20 avg 16.9
# Episode 212, episode return 7.0, last 20 avg 16.15
# Episode 213, episode return 3.0, last 20 avg 14.65
# Episode 214, episode return 13.0, last 20 avg 14.6
# Episode 215, episode return 1.0, last 20 avg 14.95
# Episode 216, episode return 52.0, last 20 avg 17.95
# Episode 217, episode return -8.0, last 20 avg 17.95
# Episode 218, episode return -5.0, last 20 avg 14.85
# Episode 219, episode return -7.0, last 20 avg 13.1
# Episode 220, episode return 37.0, last 20 avg 14.95
# Episode 221, episode return 76.0, last 20 avg 16.85
# Episode 222, episode return -4.0, last 20 avg 16.75
# Episode 223, episode return 45.0, last 20 avg 18.05
# Episode 224, episode return -10.0, last 20 avg 16.45
# Episode 225, episode return 13.0, last 20 avg 16.9
# Episode 226, episode return -7.0, last 20 avg 12.3
# Episode 227, episode return 9.0, last 20 avg 12.3
# Episode 228, episode return 25.0, last 20 avg 12.75
# Episode 229, episode return 57.0, last 20 avg 15.8
# Episode 230, episode return 112.0, last 20 avg 20.7
# Episode 231, episode return 18.0, last 20 avg 21.35
# Episode 232, episode return 108.0, last 20 avg 26.4
# Episode 233, episode return 9.0, last 20 avg 26.7
# Episode 234, episode return -2.0, last 20 avg 25.95
# Episode 235, episode return 26.0, last 20 avg 27.2
# Episode 236, episode return 60.0, last 20 avg 27.6
# Episode 237, episode return 26.0, last 20 avg 29.3
# Episode 238, episode return 12.0, last 20 avg 30.15
# Episode 239, episode return 10.0, last 20 avg 31.0
# Episode 240, episode return 17.0, last 20 avg 30.0
# Episode 241, episode return 15.0, last 20 avg 26.95
# Episode 242, episode return 7.0, last 20 avg 27.5
# Episode 243, episode return 37.0, last 20 avg 27.1
# Episode 244, episode return -10.0, last 20 avg 27.1
# Episode 245, episode return 39.0, last 20 avg 28.4
# Episode 246, episode return 21.0, last 20 avg 29.8
# Episode 247, episode return 35.0, last 20 avg 31.1
# Episode 248, episode return 13.0, last 20 avg 30.5
# Episode 249, episode return -3.0, last 20 avg 27.5
# Episode 250, episode return 6.0, last 20 avg 22.2
# Episode 251, episode return 9.0, last 20 avg 21.75
# Episode 252, episode return -10.0, last 20 avg 15.85
# Episode 253, episode return -10.0, last 20 avg 14.9
# Episode 254, episode return 20.0, last 20 avg 16.0
# Episode 255, episode return -6.0, last 20 avg 14.4
# Episode 256, episode return 89.0, last 20 avg 15.85
# Episode 257, episode return 12.0, last 20 avg 15.15
# Episode 258, episode return 28.0, last 20 avg 15.95
# Episode 259, episode return 46.0, last 20 avg 17.75
# Episode 260, episode return 90.0, last 20 avg 21.4
# Episode 261, episode return 24.0, last 20 avg 21.85
# Episode 262, episode return 18.0, last 20 avg 22.4
# Episode 263, episode return 26.0, last 20 avg 21.85
# Episode 264, episode return 42.0, last 20 avg 24.45
# Episode 265, episode return -7.0, last 20 avg 22.15
# Episode 266, episode return 19.0, last 20 avg 22.05
# Episode 267, episode return 26.0, last 20 avg 21.6
# Episode 268, episode return 32.0, last 20 avg 22.55
# Episode 269, episode return 82.0, last 20 avg 26.8
# Episode 270, episode return -10.0, last 20 avg 26.0
# Episode 271, episode return 38.0, last 20 avg 27.45
# Episode 272, episode return 12.0, last 20 avg 28.55
# Episode 273, episode return 36.0, last 20 avg 30.85
# Episode 274, episode return 63.0, last 20 avg 33.0
# Episode 275, episode return -7.0, last 20 avg 32.95
# Episode 276, episode return -10.0, last 20 avg 28.0
# Episode 277, episode return 41.0, last 20 avg 29.45
# Episode 278, episode return 59.0, last 20 avg 31.0
# Episode 279, episode return 28.0, last 20 avg 30.1
# Episode 280, episode return 26.0, last 20 avg 26.9
# Episode 281, episode return 17.0, last 20 avg 26.55
# Episode 282, episode return 18.0, last 20 avg 26.55
# Episode 283, episode return 7.0, last 20 avg 25.6
# Episode 284, episode return 11.0, last 20 avg 24.05
# Episode 285, episode return -2.0, last 20 avg 24.3
# Episode 286, episode return 55.0, last 20 avg 26.1
# Episode 287, episode return 15.0, last 20 avg 25.55
# Episode 288, episode return 103.0, last 20 avg 29.1
# Episode 289, episode return 17.0, last 20 avg 25.85
# Episode 290, episode return 21.0, last 20 avg 27.4
# Episode 291, episode return -7.0, last 20 avg 25.15
# Episode 292, episode return 41.0, last 20 avg 26.6
# Episode 293, episode return 3.0, last 20 avg 24.95
# Episode 294, episode return -7.0, last 20 avg 21.45
# Episode 295, episode return 5.0, last 20 avg 22.05
# Episode 296, episode return 18.0, last 20 avg 23.45
# Episode 297, episode return 6.0, last 20 avg 21.7
# Episode 298, episode return 10.0, last 20 avg 19.25
# Episode 299, episode return 32.0, last 20 avg 19.45
# ###################
#
#       SEED 2
#
# ###################
#
#  > Training HERAgent
#
# Episode 0, episode return 7.0, last 20 avg 7.0
# Episode 1, episode return -8.0, last 20 avg -0.5
# Episode 2, episode return -2.0, last 20 avg -1.0
# Episode 3, episode return -7.0, last 20 avg -2.5
# Episode 4, episode return -6.0, last 20 avg -3.2
# Episode 5, episode return -10.0, last 20 avg -4.333333333333333
# Episode 6, episode return -7.0, last 20 avg -4.714285714285714
# Episode 7, episode return -2.0, last 20 avg -4.375
# Episode 8, episode return -4.0, last 20 avg -4.333333333333333
# Episode 9, episode return -4.0, last 20 avg -4.3
# Episode 10, episode return -6.0, last 20 avg -4.454545454545454
# /tmp/ipykernel_8522/3548704813.py:20: DeprecationWarning: In future, it will be an error for 'np.bool_' scalars to be interpreted as an index
#   return list(map(lambda x:torch.Tensor(x).to(self.device), list(zip(*batch))))
# Episode 11, episode return -10.0, last 20 avg -4.916666666666667
# Episode 12, episode return -10.0, last 20 avg -5.3076923076923075
# Episode 13, episode return -4.0, last 20 avg -5.214285714285714
# Episode 14, episode return -10.0, last 20 avg -5.533333333333333
# Episode 15, episode return -7.0, last 20 avg -5.625
# Episode 16, episode return -7.0, last 20 avg -5.705882352941177
# Episode 17, episode return -9.0, last 20 avg -5.888888888888889
# Episode 18, episode return -7.0, last 20 avg -5.947368421052632
# Episode 19, episode return -4.0, last 20 avg -5.85
# Episode 20, episode return -5.0, last 20 avg -6.45
# Episode 21, episode return -5.0, last 20 avg -6.3
# Episode 22, episode return -4.0, last 20 avg -6.4
# Episode 23, episode return 2.0, last 20 avg -5.95
# Episode 24, episode return -10.0, last 20 avg -6.15
# Episode 25, episode return -1.0, last 20 avg -5.7
# Episode 26, episode return -7.0, last 20 avg -5.7
# Episode 27, episode return -10.0, last 20 avg -6.1
# Episode 28, episode return -8.0, last 20 avg -6.3
# Episode 29, episode return -4.0, last 20 avg -6.3
# Episode 30, episode return -3.0, last 20 avg -6.15
# Episode 31, episode return -3.0, last 20 avg -5.8
# Episode 32, episode return 5.0, last 20 avg -5.05
# Episode 33, episode return -10.0, last 20 avg -5.35
# Episode 34, episode return 1.0, last 20 avg -4.8
# Episode 35, episode return -7.0, last 20 avg -4.8
# Episode 36, episode return -10.0, last 20 avg -4.95
# Episode 37, episode return 9.0, last 20 avg -4.05
# Episode 38, episode return 0.0, last 20 avg -3.7
# Episode 39, episode return -2.0, last 20 avg -3.6
# Episode 40, episode return 5.0, last 20 avg -3.1
# Episode 41, episode return -8.0, last 20 avg -3.25
# Episode 42, episode return -10.0, last 20 avg -3.55
# Episode 43, episode return 5.0, last 20 avg -3.4
# Episode 44, episode return -8.0, last 20 avg -3.3
# Episode 45, episode return -5.0, last 20 avg -3.5
# Episode 46, episode return -2.0, last 20 avg -3.25
# Episode 47, episode return -10.0, last 20 avg -3.25
# Episode 48, episode return -10.0, last 20 avg -3.35
# Episode 49, episode return -10.0, last 20 avg -3.65
# Episode 50, episode return 7.0, last 20 avg -3.15
# Episode 51, episode return 9.0, last 20 avg -2.55
# Episode 52, episode return -6.0, last 20 avg -3.1
# Episode 53, episode return 14.0, last 20 avg -1.9
# Episode 54, episode return 7.0, last 20 avg -1.6
# Episode 55, episode return 7.0, last 20 avg -0.9
# Episode 56, episode return -6.0, last 20 avg -0.7
# Episode 57, episode return -1.0, last 20 avg -1.2
# Episode 58, episode return -8.0, last 20 avg -1.6
# Episode 59, episode return 101.0, last 20 avg 3.55
# Episode 60, episode return 128.0, last 20 avg 9.7
# Episode 61, episode return -8.0, last 20 avg 9.7
# Episode 62, episode return -8.0, last 20 avg 9.8
# Episode 63, episode return -8.0, last 20 avg 9.15
# Episode 64, episode return -4.0, last 20 avg 9.35
# Episode 65, episode return -7.0, last 20 avg 9.25
# Episode 66, episode return -3.0, last 20 avg 9.2
# Episode 67, episode return -8.0, last 20 avg 9.3
# Episode 68, episode return -10.0, last 20 avg 9.3
# Episode 69, episode return -6.0, last 20 avg 9.5
# Episode 70, episode return 123.0, last 20 avg 15.3
# Episode 71, episode return 98.0, last 20 avg 19.75
# Episode 72, episode return -2.0, last 20 avg 19.95
# Episode 73, episode return 14.0, last 20 avg 19.95
# Episode 74, episode return 15.0, last 20 avg 20.35
# Episode 75, episode return 94.0, last 20 avg 24.7
# Episode 76, episode return 2.0, last 20 avg 25.1
# Episode 77, episode return -10.0, last 20 avg 24.65
# Episode 78, episode return 0.0, last 20 avg 25.05
# Episode 79, episode return 10.0, last 20 avg 20.5
# Episode 80, episode return 35.0, last 20 avg 15.85
# Episode 81, episode return -10.0, last 20 avg 15.75
# Episode 82, episode return -3.0, last 20 avg 16.0
# Episode 83, episode return -3.0, last 20 avg 16.25
# Episode 84, episode return 20.0, last 20 avg 17.45
# Episode 85, episode return 36.0, last 20 avg 19.6
# Episode 86, episode return -6.0, last 20 avg 19.45
# Episode 87, episode return -6.0, last 20 avg 19.55
# Episode 88, episode return -5.0, last 20 avg 19.8
# Episode 89, episode return -7.0, last 20 avg 19.75
# Episode 90, episode return -4.0, last 20 avg 13.4
# Episode 91, episode return -10.0, last 20 avg 8.0
# Episode 92, episode return -4.0, last 20 avg 7.9
# Episode 93, episode return 2.0, last 20 avg 7.3
# Episode 94, episode return 16.0, last 20 avg 7.35
# Episode 95, episode return 69.0, last 20 avg 6.1
# Episode 96, episode return -1.0, last 20 avg 5.95
# Episode 97, episode return -4.0, last 20 avg 6.25
# Episode 98, episode return 58.0, last 20 avg 9.15
# Episode 99, episode return -3.0, last 20 avg 8.5
# Episode 100, episode return 17.0, last 20 avg 7.6
# Episode 101, episode return -6.0, last 20 avg 7.8
# Episode 102, episode return 59.0, last 20 avg 10.9
# Episode 103, episode return 39.0, last 20 avg 13.0
# Episode 104, episode return -6.0, last 20 avg 11.7
# Episode 105, episode return -8.0, last 20 avg 9.5
# Episode 106, episode return -8.0, last 20 avg 9.4
# Episode 107, episode return 25.0, last 20 avg 10.95
# Episode 108, episode return -2.0, last 20 avg 11.1
# Episode 109, episode return 0.0, last 20 avg 11.45
# Episode 110, episode return 38.0, last 20 avg 13.55
# Episode 111, episode return -1.0, last 20 avg 14.0
# Episode 112, episode return -3.0, last 20 avg 14.05
# Episode 113, episode return 7.0, last 20 avg 14.3
# Episode 114, episode return -7.0, last 20 avg 13.15
# Episode 115, episode return -8.0, last 20 avg 9.3
# Episode 116, episode return -8.0, last 20 avg 8.95
# Episode 117, episode return -8.0, last 20 avg 8.75
# Episode 118, episode return 6.0, last 20 avg 6.15
# Episode 119, episode return -7.0, last 20 avg 5.95
# Episode 120, episode return -1.0, last 20 avg 5.05
# Episode 121, episode return 0.0, last 20 avg 5.35
# Episode 122, episode return 63.0, last 20 avg 5.55
# Episode 123, episode return -7.0, last 20 avg 3.25
# Episode 124, episode return -2.0, last 20 avg 3.45
# Episode 125, episode return -7.0, last 20 avg 3.5
# Episode 126, episode return 43.0, last 20 avg 6.05
# Episode 127, episode return 3.0, last 20 avg 4.95
# Episode 128, episode return -1.0, last 20 avg 5.0
# Episode 129, episode return 8.0, last 20 avg 5.4
# Episode 130, episode return 26.0, last 20 avg 4.8
# Episode 131, episode return 51.0, last 20 avg 7.4
# Episode 132, episode return 30.0, last 20 avg 9.05
# Episode 133, episode return 25.0, last 20 avg 9.95
# Episode 134, episode return -8.0, last 20 avg 9.9
# Episode 135, episode return -6.0, last 20 avg 10.0
# Episode 136, episode return -8.0, last 20 avg 10.0
# Episode 137, episode return 7.0, last 20 avg 10.75
# Episode 138, episode return -9.0, last 20 avg 10.0
# Episode 139, episode return -8.0, last 20 avg 9.95
# Episode 140, episode return 19.0, last 20 avg 10.95
# Episode 141, episode return -1.0, last 20 avg 10.9
# Episode 142, episode return 47.0, last 20 avg 10.1
# Episode 143, episode return 2.0, last 20 avg 10.55
# Episode 144, episode return 15.0, last 20 avg 11.4
# Episode 145, episode return -8.0, last 20 avg 11.35
# Episode 146, episode return 137.0, last 20 avg 16.05
# Episode 147, episode return -8.0, last 20 avg 15.5
# Episode 148, episode return 173.0, last 20 avg 24.2
# Episode 149, episode return 15.0, last 20 avg 24.55
# Episode 150, episode return -9.0, last 20 avg 22.8
# Episode 151, episode return 5.0, last 20 avg 20.5
# Episode 152, episode return 9.0, last 20 avg 19.45
# Episode 153, episode return -3.0, last 20 avg 18.05
# Episode 154, episode return 7.0, last 20 avg 18.8
# Episode 155, episode return -8.0, last 20 avg 18.7
# Episode 156, episode return -4.0, last 20 avg 18.9
# Episode 157, episode return 162.0, last 20 avg 26.65
# Episode 158, episode return 50.0, last 20 avg 29.6
# Episode 159, episode return 1.0, last 20 avg 30.05
# Episode 160, episode return -5.0, last 20 avg 28.85
# Episode 161, episode return 3.0, last 20 avg 29.05
# Episode 162, episode return -7.0, last 20 avg 26.35
# Episode 163, episode return 2.0, last 20 avg 26.35
# Episode 164, episode return 33.0, last 20 avg 27.25
# Episode 165, episode return -8.0, last 20 avg 27.25
# Episode 166, episode return -3.0, last 20 avg 20.25
# Episode 167, episode return 91.0, last 20 avg 25.2
# Episode 168, episode return 24.0, last 20 avg 17.75
# Episode 169, episode return 44.0, last 20 avg 19.2
# Episode 170, episode return 2.0, last 20 avg 19.75
# Episode 171, episode return 1.0, last 20 avg 19.55
# Episode 172, episode return 20.0, last 20 avg 20.1
# Episode 173, episode return -8.0, last 20 avg 19.85
# Episode 174, episode return 18.0, last 20 avg 20.4
# Episode 175, episode return 26.0, last 20 avg 22.1
# Episode 176, episode return -4.0, last 20 avg 22.1
# Episode 177, episode return 23.0, last 20 avg 15.15
# Episode 178, episode return 3.0, last 20 avg 12.8
# Episode 179, episode return 48.0, last 20 avg 15.15
# Episode 180, episode return 4.0, last 20 avg 15.6
# Episode 181, episode return 189.0, last 20 avg 24.9
# Episode 182, episode return 6.0, last 20 avg 25.55
# Episode 183, episode return 6.0, last 20 avg 25.75
# Episode 184, episode return 2.0, last 20 avg 24.2
# Episode 185, episode return -10.0, last 20 avg 24.1
# Episode 186, episode return -4.0, last 20 avg 24.05
# Episode 187, episode return 139.0, last 20 avg 26.45
# Episode 188, episode return -10.0, last 20 avg 24.75
# Episode 189, episode return -6.0, last 20 avg 22.25
# Episode 190, episode return -7.0, last 20 avg 21.8
# Episode 191, episode return -1.0, last 20 avg 21.7
# Episode 192, episode return 1.0, last 20 avg 20.75
# Episode 193, episode return 22.0, last 20 avg 22.25
# Episode 194, episode return -3.0, last 20 avg 21.2
# Episode 195, episode return -2.0, last 20 avg 19.8
# Episode 196, episode return -6.0, last 20 avg 19.7
# Episode 197, episode return 50.0, last 20 avg 21.05
# Episode 198, episode return 8.0, last 20 avg 21.3
# Episode 199, episode return -2.0, last 20 avg 18.8
# Episode 200, episode return -7.0, last 20 avg 18.25
# Episode 201, episode return -2.0, last 20 avg 8.7
# Episode 202, episode return -5.0, last 20 avg 8.15
# Episode 203, episode return 37.0, last 20 avg 9.7
# Episode 204, episode return 7.0, last 20 avg 9.95
# Episode 205, episode return -4.0, last 20 avg 10.25
# Episode 206, episode return 10.0, last 20 avg 10.95
# Episode 207, episode return 8.0, last 20 avg 4.4
# Episode 208, episode return 93.0, last 20 avg 9.55
# Episode 209, episode return 13.0, last 20 avg 10.5
# Episode 210, episode return -8.0, last 20 avg 10.45
# Episode 211, episode return -10.0, last 20 avg 10.0
# Episode 212, episode return -7.0, last 20 avg 9.6
# Episode 213, episode return -6.0, last 20 avg 8.2
# Episode 214, episode return -1.0, last 20 avg 8.3
# Episode 215, episode return -1.0, last 20 avg 8.35
# Episode 216, episode return 0.0, last 20 avg 8.65
# Episode 217, episode return 9.0, last 20 avg 6.6
# Episode 218, episode return 1.0, last 20 avg 6.25
# Episode 219, episode return -2.0, last 20 avg 6.25
# Episode 220, episode return -7.0, last 20 avg 6.25
# Episode 221, episode return -6.0, last 20 avg 6.05
# Episode 222, episode return -10.0, last 20 avg 5.8
# Episode 223, episode return -1.0, last 20 avg 3.9
# Episode 224, episode return -6.0, last 20 avg 3.25
# Episode 225, episode return 3.0, last 20 avg 3.6
# Episode 226, episode return 4.0, last 20 avg 3.3
# Episode 227, episode return 12.0, last 20 avg 3.5
# Episode 228, episode return 21.0, last 20 avg -0.1
# Episode 229, episode return 111.0, last 20 avg 4.8
# Episode 230, episode return -1.0, last 20 avg 5.15
# Episode 231, episode return -8.0, last 20 avg 5.25
# Episode 232, episode return 0.0, last 20 avg 5.6
# Episode 233, episode return 87.0, last 20 avg 10.25
# Episode 234, episode return 59.0, last 20 avg 13.25
# Episode 235, episode return 15.0, last 20 avg 14.05
# Episode 236, episode return 22.0, last 20 avg 15.15
# Episode 237, episode return -4.0, last 20 avg 14.5
# Episode 238, episode return 69.0, last 20 avg 17.9
# Episode 239, episode return -6.0, last 20 avg 17.7
# Episode 240, episode return 71.0, last 20 avg 21.6
# Episode 241, episode return 10.0, last 20 avg 22.4
# Episode 242, episode return 16.0, last 20 avg 23.7
# Episode 243, episode return -2.0, last 20 avg 23.65
# Episode 244, episode return 91.0, last 20 avg 28.5
# Episode 245, episode return 3.0, last 20 avg 28.5
# Episode 246, episode return 25.0, last 20 avg 29.55
# Episode 247, episode return -8.0, last 20 avg 28.55
# Episode 248, episode return 121.0, last 20 avg 33.55
# Episode 249, episode return 6.0, last 20 avg 28.3
# Episode 250, episode return 12.0, last 20 avg 28.95
# Episode 251, episode return 2.0, last 20 avg 29.45
# Episode 252, episode return 3.0, last 20 avg 29.6
# Episode 253, episode return 25.0, last 20 avg 26.5
# Episode 254, episode return 5.0, last 20 avg 23.8
# Episode 255, episode return 5.0, last 20 avg 23.3
# Episode 256, episode return -1.0, last 20 avg 22.15
# Episode 257, episode return 2.0, last 20 avg 22.45
# Episode 258, episode return 70.0, last 20 avg 22.5
# Episode 259, episode return 0.0, last 20 avg 22.8
# Episode 260, episode return 63.0, last 20 avg 22.4
# Episode 261, episode return 34.0, last 20 avg 23.6
# Episode 262, episode return -2.0, last 20 avg 22.7
# Episode 263, episode return -4.0, last 20 avg 22.6
# Episode 264, episode return 54.0, last 20 avg 20.75
# Episode 265, episode return 3.0, last 20 avg 20.75
# Episode 266, episode return 55.0, last 20 avg 22.25
# Episode 267, episode return -1.0, last 20 avg 22.6
# Episode 268, episode return 16.0, last 20 avg 17.35
# Episode 269, episode return 1.0, last 20 avg 17.1
# Episode 270, episode return 1.0, last 20 avg 16.55
# Episode 271, episode return -3.0, last 20 avg 16.3
# Episode 272, episode return 7.0, last 20 avg 16.5
# Episode 273, episode return 1.0, last 20 avg 15.3
# Episode 274, episode return -4.0, last 20 avg 14.85
# Episode 275, episode return 0.0, last 20 avg 14.6
# Episode 276, episode return -7.0, last 20 avg 14.3
# Episode 277, episode return -6.0, last 20 avg 13.9
# Episode 278, episode return -3.0, last 20 avg 10.25
# Episode 279, episode return -8.0, last 20 avg 9.85
# Episode 280, episode return 7.0, last 20 avg 7.05
# Episode 281, episode return -4.0, last 20 avg 5.15
# Episode 282, episode return 3.0, last 20 avg 5.4
# Episode 283, episode return 24.0, last 20 avg 6.8
# Episode 284, episode return -3.0, last 20 avg 3.95
# Episode 285, episode return -3.0, last 20 avg 3.65
# Episode 286, episode return -2.0, last 20 avg 0.8
# Episode 287, episode return -2.0, last 20 avg 0.75
# Episode 288, episode return -10.0, last 20 avg -0.55
# Episode 289, episode return -5.0, last 20 avg -0.85
# Episode 290, episode return 36.0, last 20 avg 0.9
# Episode 291, episode return -10.0, last 20 avg 0.55
# Episode 292, episode return 162.0, last 20 avg 8.3
# Episode 293, episode return 96.0, last 20 avg 13.05
# Episode 294, episode return 5.0, last 20 avg 13.5
# Episode 295, episode return 40.0, last 20 avg 15.5
# Episode 296, episode return 72.0, last 20 avg 19.45
# Episode 297, episode return 58.0, last 20 avg 22.65
# Episode 298, episode return 15.0, last 20 avg 23.55
# Episode 299, episode return 5.0, last 20 avg 24.2
# ###################
#
#       SEED 3
#
# ###################
#
#  > Training HERAgent
#
# Episode 0, episode return -6.0, last 20 avg -6.0
# Episode 1, episode return -7.0, last 20 avg -6.5
# Episode 2, episode return 26.0, last 20 avg 4.333333333333333
# Episode 3, episode return -10.0, last 20 avg 0.75
# Episode 4, episode return -3.0, last 20 avg 0.0
# Episode 5, episode return -7.0, last 20 avg -1.1666666666666667
# /tmp/ipykernel_8522/3548704813.py:20: DeprecationWarning: In future, it will be an error for 'np.bool_' scalars to be interpreted as an index
#   return list(map(lambda x:torch.Tensor(x).to(self.device), list(zip(*batch))))
# Episode 6, episode return -6.0, last 20 avg -1.8571428571428572
# Episode 7, episode return -8.0, last 20 avg -2.625
# Episode 8, episode return -2.0, last 20 avg -2.5555555555555554
# Episode 9, episode return -7.0, last 20 avg -3.0
# Episode 10, episode return -10.0, last 20 avg -3.6363636363636362
# Episode 11, episode return -6.0, last 20 avg -3.8333333333333335
# Episode 12, episode return -8.0, last 20 avg -4.153846153846154
# Episode 13, episode return -6.0, last 20 avg -4.285714285714286
# Episode 14, episode return -10.0, last 20 avg -4.666666666666667
# Episode 15, episode return -5.0, last 20 avg -4.6875
# Episode 16, episode return -7.0, last 20 avg -4.823529411764706
# Episode 17, episode return 28.0, last 20 avg -3.0
# Episode 18, episode return 34.0, last 20 avg -1.0526315789473684
# Episode 19, episode return -5.0, last 20 avg -1.25
# Episode 20, episode return -3.0, last 20 avg -1.1
# Episode 21, episode return -7.0, last 20 avg -1.1
# Episode 22, episode return -5.0, last 20 avg -2.65
# Episode 23, episode return -5.0, last 20 avg -2.4
# Episode 24, episode return -10.0, last 20 avg -2.75
# Episode 25, episode return 9.0, last 20 avg -1.95
# Episode 26, episode return -1.0, last 20 avg -1.7
# Episode 27, episode return -3.0, last 20 avg -1.45
# Episode 28, episode return -2.0, last 20 avg -1.45
# Episode 29, episode return -3.0, last 20 avg -1.25
# Episode 30, episode return 8.0, last 20 avg -0.35
# Episode 31, episode return 7.0, last 20 avg 0.3
# Episode 32, episode return 16.0, last 20 avg 1.5
# Episode 33, episode return 9.0, last 20 avg 2.25
# Episode 34, episode return 0.0, last 20 avg 2.75
# Episode 35, episode return 1.0, last 20 avg 3.05
# Episode 36, episode return 50.0, last 20 avg 5.9
# Episode 37, episode return 7.0, last 20 avg 4.85
# Episode 38, episode return -1.0, last 20 avg 3.1
# Episode 39, episode return 24.0, last 20 avg 4.55
# Episode 40, episode return -8.0, last 20 avg 4.3
# Episode 41, episode return -6.0, last 20 avg 4.35
# Episode 42, episode return 25.0, last 20 avg 5.85
# Episode 43, episode return -3.0, last 20 avg 5.95
# Episode 44, episode return 5.0, last 20 avg 6.7
# Episode 45, episode return 2.0, last 20 avg 6.35
# Episode 46, episode return -7.0, last 20 avg 6.05
# Episode 47, episode return 14.0, last 20 avg 6.9
# Episode 48, episode return 35.0, last 20 avg 8.75
# Episode 49, episode return -4.0, last 20 avg 8.7
# Episode 50, episode return 5.0, last 20 avg 8.55
# Episode 51, episode return 22.0, last 20 avg 9.3
# Episode 52, episode return 7.0, last 20 avg 8.85
# Episode 53, episode return 4.0, last 20 avg 8.6
# Episode 54, episode return -3.0, last 20 avg 8.45
# Episode 55, episode return -7.0, last 20 avg 8.05
# Episode 56, episode return -7.0, last 20 avg 5.2
# Episode 57, episode return -6.0, last 20 avg 4.55
# Episode 58, episode return 38.0, last 20 avg 6.5
# Episode 59, episode return -6.0, last 20 avg 5.0
# Episode 60, episode return -5.0, last 20 avg 5.15
# Episode 61, episode return -6.0, last 20 avg 5.15
# Episode 62, episode return -8.0, last 20 avg 3.5
# Episode 63, episode return -2.0, last 20 avg 3.55
# Episode 64, episode return -4.0, last 20 avg 3.1
# Episode 65, episode return -1.0, last 20 avg 2.95
# Episode 66, episode return -6.0, last 20 avg 3.0
# Episode 67, episode return 18.0, last 20 avg 3.2
# Episode 68, episode return -4.0, last 20 avg 1.25
# Episode 69, episode return 6.0, last 20 avg 1.75
# Episode 70, episode return 2.0, last 20 avg 1.6
# Episode 71, episode return 0.0, last 20 avg 0.5
# Episode 72, episode return -9.0, last 20 avg -0.3
# Episode 73, episode return -2.0, last 20 avg -0.6
# Episode 74, episode return -6.0, last 20 avg -0.75
# Episode 75, episode return -2.0, last 20 avg -0.5
# Episode 76, episode return -10.0, last 20 avg -0.65
# Episode 77, episode return -7.0, last 20 avg -0.7
# Episode 78, episode return 3.0, last 20 avg -2.45
# Episode 79, episode return -4.0, last 20 avg -2.35
# Episode 80, episode return 0.0, last 20 avg -2.1
# Episode 81, episode return -4.0, last 20 avg -2.0
# Episode 82, episode return -7.0, last 20 avg -1.95
# Episode 83, episode return 31.0, last 20 avg -0.3
# Episode 84, episode return 6.0, last 20 avg 0.2
# Episode 85, episode return -6.0, last 20 avg -0.05
# Episode 86, episode return 23.0, last 20 avg 1.4
# Episode 87, episode return -3.0, last 20 avg 0.35
# Episode 88, episode return -8.0, last 20 avg 0.15
# Episode 89, episode return -2.0, last 20 avg -0.25
# Episode 90, episode return -2.0, last 20 avg -0.45
# Episode 91, episode return -10.0, last 20 avg -0.95
# Episode 92, episode return -7.0, last 20 avg -0.85
# Episode 93, episode return 2.0, last 20 avg -0.65
# Episode 94, episode return -5.0, last 20 avg -0.6
# Episode 95, episode return 1.0, last 20 avg -0.45
# Episode 96, episode return -2.0, last 20 avg -0.05
# Episode 97, episode return -7.0, last 20 avg -0.05
# Episode 98, episode return 11.0, last 20 avg 0.35
# Episode 99, episode return 90.0, last 20 avg 5.05
# Episode 100, episode return -10.0, last 20 avg 4.55
# Episode 101, episode return -10.0, last 20 avg 4.25
# Episode 102, episode return -10.0, last 20 avg 4.1
# Episode 103, episode return -7.0, last 20 avg 2.2
# Episode 104, episode return -10.0, last 20 avg 1.4
# Episode 105, episode return -7.0, last 20 avg 1.35
# Episode 106, episode return -4.0, last 20 avg 0.0
# Episode 107, episode return -10.0, last 20 avg -0.35
# Episode 108, episode return -7.0, last 20 avg -0.3
# Episode 109, episode return -8.0, last 20 avg -0.6
# Episode 110, episode return 19.0, last 20 avg 0.45
# Episode 111, episode return 34.0, last 20 avg 2.65
# Episode 112, episode return -10.0, last 20 avg 2.5
# Episode 113, episode return -10.0, last 20 avg 1.9
# Episode 114, episode return 2.0, last 20 avg 2.25
# Episode 115, episode return 29.0, last 20 avg 3.65
# Episode 116, episode return -2.0, last 20 avg 3.65
# Episode 117, episode return -10.0, last 20 avg 3.5
# Episode 118, episode return -2.0, last 20 avg 2.85
# Episode 119, episode return -8.0, last 20 avg -2.05
# Episode 120, episode return -6.0, last 20 avg -1.85
# Episode 121, episode return 21.0, last 20 avg -0.3
# Episode 122, episode return -3.0, last 20 avg 0.05
# Episode 123, episode return -6.0, last 20 avg 0.1
# Episode 124, episode return -8.0, last 20 avg 0.2
# Episode 125, episode return -2.0, last 20 avg 0.45
# Episode 126, episode return -3.0, last 20 avg 0.5
# Episode 127, episode return -5.0, last 20 avg 0.75
# Episode 128, episode return -2.0, last 20 avg 1.0
# Episode 129, episode return -8.0, last 20 avg 1.0
# Episode 130, episode return 189.0, last 20 avg 9.5
# Episode 131, episode return -4.0, last 20 avg 7.6
# Episode 132, episode return 6.0, last 20 avg 8.4
# Episode 133, episode return -8.0, last 20 avg 8.5
# Episode 134, episode return 3.0, last 20 avg 8.55
# Episode 135, episode return -7.0, last 20 avg 6.75
# Episode 136, episode return -10.0, last 20 avg 6.35
# Episode 137, episode return -5.0, last 20 avg 6.6
# Episode 138, episode return -7.0, last 20 avg 6.35
# Episode 139, episode return -5.0, last 20 avg 6.5
# Episode 140, episode return 18.0, last 20 avg 7.7
# Episode 141, episode return -7.0, last 20 avg 6.3
# Episode 142, episode return 14.0, last 20 avg 7.15
# Episode 143, episode return -10.0, last 20 avg 6.95
# Episode 144, episode return 1.0, last 20 avg 7.4
# Episode 145, episode return 0.0, last 20 avg 7.5
# Episode 146, episode return -1.0, last 20 avg 7.6
# Episode 147, episode return -10.0, last 20 avg 7.35
# Episode 148, episode return -10.0, last 20 avg 6.95
# Episode 149, episode return -10.0, last 20 avg 6.85
# Episode 150, episode return 0.0, last 20 avg -2.6
# Episode 151, episode return -8.0, last 20 avg -2.8
# Episode 152, episode return 8.0, last 20 avg -2.7
# Episode 153, episode return -5.0, last 20 avg -2.55
# Episode 154, episode return -2.0, last 20 avg -2.8
# Episode 155, episode return 63.0, last 20 avg 0.7
# Episode 156, episode return 48.0, last 20 avg 3.6
# Episode 157, episode return -4.0, last 20 avg 3.65
# Episode 158, episode return 9.0, last 20 avg 4.45
# Episode 159, episode return -2.0, last 20 avg 4.6
# Episode 160, episode return -5.0, last 20 avg 3.45
# Episode 161, episode return 63.0, last 20 avg 6.95
# Episode 162, episode return -8.0, last 20 avg 5.85
# Episode 163, episode return 5.0, last 20 avg 6.6
# Episode 164, episode return -7.0, last 20 avg 6.2
# Episode 165, episode return 13.0, last 20 avg 6.85
# Episode 166, episode return -8.0, last 20 avg 6.5
# Episode 167, episode return 46.0, last 20 avg 9.3
# Episode 168, episode return -2.0, last 20 avg 9.7
# Episode 169, episode return -6.0, last 20 avg 9.9
# Episode 170, episode return 189.0, last 20 avg 19.35
# Episode 171, episode return -8.0, last 20 avg 19.35
# Episode 172, episode return -1.0, last 20 avg 18.9
# Episode 173, episode return 82.0, last 20 avg 23.25
# Episode 174, episode return 14.0, last 20 avg 24.05
# Episode 175, episode return 49.0, last 20 avg 23.35
# Episode 176, episode return 7.0, last 20 avg 21.3
# Episode 177, episode return -10.0, last 20 avg 21.0
# Episode 178, episode return 6.0, last 20 avg 20.85
# Episode 179, episode return 25.0, last 20 avg 22.2
# Episode 180, episode return -5.0, last 20 avg 22.2
# Episode 181, episode return -1.0, last 20 avg 19.0
# Episode 182, episode return -2.0, last 20 avg 19.3
# Episode 183, episode return -3.0, last 20 avg 18.9
# Episode 184, episode return -10.0, last 20 avg 18.75
# Episode 185, episode return 7.0, last 20 avg 18.45
# Episode 186, episode return -1.0, last 20 avg 18.8
# Episode 187, episode return -10.0, last 20 avg 16.0
# Episode 188, episode return 9.0, last 20 avg 16.55
# Episode 189, episode return -9.0, last 20 avg 16.4
# Episode 190, episode return -10.0, last 20 avg 6.45
# Episode 191, episode return 43.0, last 20 avg 9.0
# Episode 192, episode return 0.0, last 20 avg 9.05
# Episode 193, episode return 0.0, last 20 avg 4.95
# Episode 194, episode return -5.0, last 20 avg 4.0
# Episode 195, episode return -8.0, last 20 avg 1.15
# Episode 196, episode return -6.0, last 20 avg 0.5
# Episode 197, episode return -10.0, last 20 avg 0.5
# Episode 198, episode return 17.0, last 20 avg 1.05
# Episode 199, episode return 9.0, last 20 avg 0.25
# Episode 200, episode return -1.0, last 20 avg 0.45
# Episode 201, episode return 5.0, last 20 avg 0.75
# Episode 202, episode return 26.0, last 20 avg 2.15
# Episode 203, episode return -2.0, last 20 avg 2.2
# Episode 204, episode return 7.0, last 20 avg 3.05
# Episode 205, episode return 19.0, last 20 avg 3.65
# Episode 206, episode return -2.0, last 20 avg 3.6
# Episode 207, episode return -5.0, last 20 avg 3.85
# Episode 208, episode return -2.0, last 20 avg 3.3
# Episode 209, episode return -5.0, last 20 avg 3.5
# Episode 210, episode return 6.0, last 20 avg 4.3
# Episode 211, episode return 70.0, last 20 avg 5.65
# Episode 212, episode return 3.0, last 20 avg 5.8
# Episode 213, episode return -1.0, last 20 avg 5.75
# Episode 214, episode return 6.0, last 20 avg 6.3
# Episode 215, episode return 77.0, last 20 avg 10.55
# Episode 216, episode return 0.0, last 20 avg 10.85
# Episode 217, episode return 1.0, last 20 avg 11.4
# Episode 218, episode return 25.0, last 20 avg 11.8
# Episode 219, episode return 3.0, last 20 avg 11.5
# Episode 220, episode return -3.0, last 20 avg 11.4
# Episode 221, episode return 55.0, last 20 avg 13.9
# Episode 222, episode return 5.0, last 20 avg 12.85
# Episode 223, episode return 5.0, last 20 avg 13.2
# Episode 224, episode return -10.0, last 20 avg 12.35
# Episode 225, episode return -7.0, last 20 avg 11.05
# Episode 226, episode return -6.0, last 20 avg 10.85
# Episode 227, episode return -7.0, last 20 avg 10.75
# Episode 228, episode return -7.0, last 20 avg 10.5
# Episode 229, episode return -10.0, last 20 avg 10.25
# Episode 230, episode return 127.0, last 20 avg 16.3
# Episode 231, episode return 79.0, last 20 avg 16.75
# Episode 232, episode return -10.0, last 20 avg 16.1
# Episode 233, episode return 13.0, last 20 avg 16.8
# Episode 234, episode return 23.0, last 20 avg 17.65
# Episode 235, episode return 13.0, last 20 avg 14.45
# Episode 236, episode return -1.0, last 20 avg 14.4
# Episode 237, episode return 33.0, last 20 avg 16.0
# Episode 238, episode return -5.0, last 20 avg 14.5
# Episode 239, episode return 24.0, last 20 avg 15.55
# Episode 240, episode return 135.0, last 20 avg 22.45
# Episode 241, episode return 189.0, last 20 avg 29.15
# Episode 242, episode return -2.0, last 20 avg 28.8
# Episode 243, episode return -8.0, last 20 avg 28.15
# Episode 244, episode return 143.0, last 20 avg 35.8
# Episode 245, episode return 4.0, last 20 avg 36.35
# Episode 246, episode return -5.0, last 20 avg 36.4
# Episode 247, episode return 71.0, last 20 avg 40.3
# Episode 248, episode return 16.0, last 20 avg 41.45
# Episode 249, episode return 4.0, last 20 avg 42.15
# Episode 250, episode return 4.0, last 20 avg 36.0
# Episode 251, episode return 20.0, last 20 avg 33.05
# Episode 252, episode return 158.0, last 20 avg 41.45
# Episode 253, episode return 10.0, last 20 avg 41.3
# Episode 254, episode return 6.0, last 20 avg 40.45
# Episode 255, episode return -10.0, last 20 avg 39.3
# Episode 256, episode return 88.0, last 20 avg 43.75
# Episode 257, episode return -4.0, last 20 avg 41.9
# Episode 258, episode return 1.0, last 20 avg 42.2
# Episode 259, episode return -5.0, last 20 avg 40.75
# Episode 260, episode return -2.0, last 20 avg 33.9
# Episode 261, episode return 132.0, last 20 avg 31.05
# Episode 262, episode return -1.0, last 20 avg 31.1
# Episode 263, episode return -10.0, last 20 avg 31.0
# Episode 264, episode return -2.0, last 20 avg 23.75
# Episode 265, episode return 8.0, last 20 avg 23.95
# Episode 266, episode return 6.0, last 20 avg 24.5
# Episode 267, episode return 11.0, last 20 avg 21.5
# Episode 268, episode return 27.0, last 20 avg 22.05
# Episode 269, episode return 7.0, last 20 avg 22.2
# Episode 270, episode return 8.0, last 20 avg 22.4
# Episode 271, episode return 14.0, last 20 avg 22.1
# Episode 272, episode return -7.0, last 20 avg 13.85
# Episode 273, episode return 3.0, last 20 avg 13.5
# Episode 274, episode return 8.0, last 20 avg 13.6
# Episode 275, episode return 1.0, last 20 avg 14.15
# Episode 276, episode return -2.0, last 20 avg 9.65
# Episode 277, episode return 47.0, last 20 avg 12.2
# Episode 278, episode return 16.0, last 20 avg 12.95
# Episode 279, episode return 28.0, last 20 avg 14.6
# Episode 280, episode return 67.0, last 20 avg 18.05
# Episode 281, episode return 0.0, last 20 avg 11.45
# Episode 282, episode return 31.0, last 20 avg 13.05
# Episode 283, episode return 167.0, last 20 avg 21.9
# Episode 284, episode return 23.0, last 20 avg 23.15
# Episode 285, episode return 26.0, last 20 avg 24.05
# Episode 286, episode return 18.0, last 20 avg 24.65
# Episode 287, episode return 18.0, last 20 avg 25.0
# Episode 288, episode return 7.0, last 20 avg 24.0
# Episode 289, episode return -4.0, last 20 avg 23.45
# Episode 290, episode return -4.0, last 20 avg 22.85
# Episode 291, episode return 40.0, last 20 avg 24.15
# Episode 292, episode return -6.0, last 20 avg 24.2
# Episode 293, episode return 4.0, last 20 avg 24.25
# Episode 294, episode return -7.0, last 20 avg 23.5
# Episode 295, episode return -5.0, last 20 avg 23.2
# Episode 296, episode return 9.0, last 20 avg 23.75
# Episode 297, episode return 33.0, last 20 avg 23.05
# Episode 298, episode return 26.0, last 20 avg 23.55
# Episode 299, episode return 48.0, last 20 avg 24.55

# %% [markdown]
# <div class="alert alert-warning">
# What is it working a bit, but the agent don't reach perfectly the goal everytime ?
# <div/>

# %% [markdown]
# <details class="alert alert-danger">
#     <summary markdown="span"><b>Ready to see the answer? (click to expand)</b></summary>
# We know the coordinate of the Swing Up reward (angle = 0, angle dot = 0), we just need to generate this goal and see if our agent can reach it.
# <details/>

# %% [markdown]
# <div class="alert alert-warning">
# How can we fix it?
# <div/>

# %% [markdown]
# <details class="alert alert-danger">
#     <summary markdown="span"><b>Ready to see the answer? (click to expand)</b></summary>
# Our agent just need more training time to learn how to pass through state space bottlenecks, and a bit more stability. For exemple, a SoftDQN (an adaptation of soft Actor-Critic for discrete state spaces) should do the trick.
# <details/>

# %% [markdown]
# ## To go further
#
# To help our agent to reach goals when the environment contains bottlenecks (mandatory states, where the agent should pass before to reach another sub-space of the environment state space), we can try to do planning, or to increase exploration.
#
# In planning, we want our agent to learn a topology (kind of a graph of states clusters) of the environment, so he can use this topology to reach far away goals using path finding on the graph.
#
# Many approches try to improve the exploration, using intrinsic rewards. For example, the agent can receive a reward when he find states that he didnt reach that much, or get a reward when he is not able to predict the next state, which mean that he never goes in this area of the state space.
